# %%
import cPickle
import unicodedata

# %%
with open('geotag_dict.pkl','rb') as f:
    geotag_dict = cPickle.load(f)

# %%
geotag_dict
# Out:
# {'Satara': {u'gt_lat': 17.6833,
#   u'gt_lon': 73.9833,
#   u'page_id': 31660,
#   u'page_len': 1084},
#  'Grand_Bahama': {u'gt_lat': 26.65,
#   u'gt_lon': -78.3167,
#   u'page_id': 13153,
#   u'page_len': 13951},
#  'Treis-Karden': {u'gt_lat': 50.1781,
#   u'gt_lon': 7.30222,
#   u'page_id': 36650,
#   u'page_len': 2899},
#  'Yibin': {u'gt_lat': 28.7667,
#   u'gt_lon': 104.617,
#   u'page_id': 40061,
#   u'page_len': 2942},
#  'Szczecin': {u'gt_lat': 53.4333,
#   u'gt_lon': 14.5333,
#   u'page_id': 34976,
#   u'page_len': 34164},
#  'Matabari': {u'gt_lat': 23.5031,
#   u'gt_lon': 91.5039,
#   u'page_id': 21617,
#   u'page_len': 2867},
#  'Neu-Ulm': {u'gt_lat': 48.3939,
#   u'gt_lon': 10.0074,
#   u'page_id': 142642,
#   u'page_len': 862},
#  'Sremski_Karlovci': {u'gt_lat': 45.2,
#   u'gt_lon': 19.93,
#   u'page_id': 135146,
#   u'page_len': 300},
#  'Warsaw/Bemowo': {u'gt_lat': 52.1,
#   u'gt_lon': 21.0,
#   u'page_id': 38482,
#   u'page_len': 2815},
#  'Rugia': {u'gt_lat': 54.4,
# ...

# %%
a = 'Ko\xc5\x82obrzeg'

# %%
a.decode('utf-8')
# Out:
# u'Ko\u0142obrzeg'

# %%
unicodedata.normalize('NFKD', a.decode('utf-8')).encode('ascii','ignore')
# Out:
# 'Koobrzeg'
