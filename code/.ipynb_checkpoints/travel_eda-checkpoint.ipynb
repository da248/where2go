# %% [markdown]
# # WIKIVOYAGE EDA

# %%
import pandas as pd
import json
from collections import defaultdict
import unicodedata
import mistune
from bs4 import BeautifulSoup
import string
import re
from nltk.tokenize import sent_tokenize, word_tokenize
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['text', 'test']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ##Load & Extract Articles

# %%
with open('../data/wikivoyage.json','rb') as f:
    data = json.loads(f.read())

# %% [markdown]
# ###Extract Article texts

# %%
articles = data['mediawiki']['page']

# %% [markdown]
# ### Save Articles by Titles

# %%
articles_dict = {}
for article in articles:
    # Lets strip the accents using unicodedata
    title = unicodedata.normalize('NFKD', article['title']).encode('ascii','ignore')
    articles_dict[title] = article

# %%
articles_dict.keys()[:10]
# Out:
# ['',
#  'Category:Articles needing style fixes',
#  'Szczecin',
#  'Category:West High Country',
#  'Rugia',
#  'New Australia',
#  'Natchez, Mississippi',
#  'File:WV new main page at 1920px.PNG',
#  'Nampa',
#  'Category:Pangasinan']

# %% [markdown]
# __You can see that some articles are files, categories ,etc with : in their names.
# Lets see how many of these there are.__

# %%
junk_articles_dict = defaultdict(int)
for article in articles:
    title = article['title']
    if ':' in title:
        junk_articles_dict[title.split(':')[0]] += 1

print len(junk_articles_dict)
junk_articles_dict
# Out:
# 11
# defaultdict(<type 'int'>, {u'Category': 4561, u'Itinerary': 1, u'General/Wikivoyage': 1, u'MediaWiki': 142, u'File': 816, u'Poland': 1, u'La Manzanilla': 1, u'Module': 23, u'Wikivoyage': 1561, u'Template': 1043, u'Help': 8})

# %% [markdown]
# __There are a lot of special type articles. Let's actually take a look at the content to see if they are useful.__

# %%
special_articles_dict = defaultdict(list)
for article in articles:
    title = article['title']
    if ':' in title:
        if len(special_articles_dict[title.split(':')[0]]) < 5:
            special_articles_dict[title.split(':')[0]].append(article) 

print len(special_articles_dict)
special_articles_dict.keys()
# Out:
# 11
# [u'Category',
#  u'Itinerary',
#  u'General/Wikivoyage',
#  u'MediaWiki',
#  u'File',
#  u'Poland',
#  u'La Manzanilla',
#  u'Module',
#  u'Wikivoyage',
#  u'Template',
#  u'Help']

# %% [markdown]
# __Let's take a look at two most common special type articles__

# %%
special_articles_dict['MediaWiki']
# Out:
# [{u'id': u'69005',
#   u'ns': u'8',
#   u'revision': {u'comment': u'+arytrekking\\.com',
#    u'contributor': {u'id': u'36420', u'username': u'Ikan Kekek'},
#    u'format': u'text/x-wiki',
#    u'id': u'2796508',
#    u'model': u'wikitext',
#    u'parentid': u'2781066',
#    u'sha1': u'l0bq8j7kgs7ttk8ngewi2h36byn4q61',
#    u'text': {u'#text': u'#{{shortcut|[[Spam]]<br>[[Blacklist]]}} \n #{{notice|\'\'\'DO NOT\'\'\' remove any URL or pattern from this list without first gaining consensus on [[{{TALKSPACE}}:{{PAGENAME}}]]. In addition to being used to block automated spam attacks this list is also occasionally used to stop persistent abuse of the [[Project:External links]] and [[Project:Don\'t tout]] policies.  Please add violators of the external links policy to this page \'\'\'ONLY\'\'\' after first trying to educate the user about why the link is inappropriate.  When adding external link violators to this page please explain the reason for the addition on [[{{TALKSPACE}}:{{PAGENAME}}]].}}\n\n # This is the local blacklist for Wiki spam URLs for Wikivoyage. It\'s used\n # by the \'\'\'[[Project:spam filter|spam filter]]\'\'\' to block contributions that use these URLs.\n #\n # To add a URL to the spam filter list just add the spam URL including\n # everything \'\'\'after\'\'\' the "http://" and \'\'\'before\'\'\' the first "/" to the list. \n #\n # In addition, the spam filter uses what are called regular expressions, so\n # special characters such as periods need to be escaped by putting a "\\" in\n # front of them.\n #\n # For example, <nowiki>"http://spam.spammer.net/foo.html"</nowiki> would be added as\n # "spam\\.spammer\\.net".  Notice that we don\'t include the "http://" nor\n # anything after the first "/" following the "http://" so "/foo.html" should\n # not be added.\n #\n # One caveat is that if the entire domain seems to be used only for spam we\n # don\'t bother to worry about sub-domains and in the example above would just\n # list "spammer\\.net".  \n #\n # For the spam filter to work properly you must indent one (1) space. It\n # helps everyone stay sane and find things better if the list is in\n # alphabetical order.\n #\n # External URLs matching this list will be blocked when added to a page.\n # This list affects only this wiki; refer also to the global blacklist.\n # For documentation see http://www.mediawiki.org/wiki/Extension:SpamBlacklist\n #\n # Syntax is as follows:\n #   * Everything from a "#" character to the end of the line is a comment\n #   * Every non-blank line is a regex fragment which will only match hosts inside URLs\n\n (Yangshuo).*(Julie)\n ((t|T)op.?level.?tour)\n 1cheaphotels\\.com\n 1carrental\\.org\n a-prague\\.com\n a2zrooms\\.com\n aaalimos\n abetterstay\\.com\n activetravelvietnam\\.com\n adollarhost\\.com\n adriatic-express\\.com\n africabusiness\\.com\n www\\.africanbluetours\\.com\n aiguarentacar\\.it\n air520\\.com\n airline-tickets\\.kwik\\.to\n airporttaxicabservices\\.com\n al-sufarahotel\\.com\n alemi2424\\.blogspot\\.com\n alemi24@gmail\\.com\n alfamahouse\\.com\n alleurohotels\\.com\n all-hotels-motels\\.com\n allmovieshere\\.servik\\.com\n amorpensionhouse\\.webs\\.com \n anycarhire\\.com\n apartmentsabroad\\.com\n apartmentsholiday\\.com\n apnabus\\.in\n archsanblas\\.tripod\\.com \n arguscarhire\\.com\n argusrentals\\.com\n aroundworld\\.in\\.ua\n arytrekking\\.com\n artofafricasafari\\.com\n auto-europe\\.co\n ayachtcharterathens\\.com\n ayachtcharterbodrum\\.com\n ayachtchartergreece\\.com\n ayachtcharteribiza\\.com\n ayachtcharteritaly\\.com\n ayachtchartermarmaris\\.com\n ayachtcharterspain\\.com\n ayachtcharterturkey\\.com\n azul-barcelona\\.com\n baligotours\\.com\n balipropertyconsultancy\\.com\n bandarbantours\\.com\n www\\.barcelonacheckin\\.com\n barcelonapoint\\.com\n bargains-hunter\\.blogspot\\.com\n baylodging\\.com\n bbvaticanstpeter\\.com\n bedandbreakfastmare\\.it\n begin_of_the_skype_highlighting\n benusang\n bh-hotels\\.com\n bienngoccruise\\.com\n bluesardiniaholidays\\.com\n www\\.booking\\.com\n boracay\\.cc\n boracay\\.org\\.ph\n boracay-packages\\.com\n boracay4less\\.com\n boracaypackages\\.spaces\\.live\\.com \n boracaypackages\\.net\n boracayregency\\.com\n boracayvacationpackages\\.com\n borneotourgigant\\.com\n budget\\.co\\.uk\n budpocketguide\\.com\n but ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-05-26T10:04:51Z'},
#   u'title': u'MediaWiki:Spam-blacklist'},
#  {u'id': u'69006',
#   u'ns': u'8',
#   u'revision': {u'comment': u'this is a legitimate listing that should be allowed',
#    u'contributor': {u'id': u'109373', u'username': u'Texugo'},
#    u'format': u'text/x-wiki',
#    u'id': u'2560091',
#    u'model': u'wikitext',
#    u'parentid': u'2389682',
#    u'sha1': u'scyypemwlpv7aq9jnukfart07dr1y5o',
#    u'text': {u'#text': u"#This is the local whitelist for URLs that are being incorrectly blocked by the [[Project:Spam filter]]. \n #Note that this list will have no effect on patterns being blocked by the [[Project:Local spam blacklist]], but it will unblock patterns that are being blocked by the http://wikivoyage.org/bannedcontent.txt list. \n #Note that the whitelist pattern must ''exactly'' match the pattern from the banned content list in order to be unblocked.\n\n #To add URLs or URL fragments to this list, add them in in alphabetical order between the pre tags, and indent one (1) space. \n #You should also leave a note on the [[Project:Local spam whitelist|talk page]] indicating why the URL is valid.\n\n#<pre>\n \\w+\\.sh\\.cn\n 00100roma\\.it\n aladdincasino\\.com\n albury-wodonga\\.com\n almaty-bus\\.narod\\.ru\n almaty-tramway\\.narod\\.ru\n almaty-trolleybus\\.narod\\.ru\n biscuit-palace\\.com\n casinovenezia\\.it\n chinabeijinghotel\\.com\\.cn\n china\\.com\n cuc\\.edu\\.cn\n cyu\\.edu\\.cn\n donga\\.com\n expo2010china\\.com\n freewebs\\.com\n fremontcasino\\.com\n gb\\.com\n geocities\\.com\n goldcoastcasino\\.com\n joes\\.com\n luggagestoregallery\\.org\n mainstreetcasino\\.com\n milfordplaza\\.com\n milford\\.com\n Milford\n nouveaucasino\\.net\n nynyhotelcasino\\.com\n pharmacymuseum\\.org\n pralniawodnik\\.republika\\.pl\n premiumflats\\.com\n reefcasino\\.com\\.au\n stbishoy\\.8k\\.com\n u-tokyo\\.ac\\.jp\n wikivoyage\\.org\n ya\\.ru\n#</pre>\n\n#{{WikivoyageDoc|administration}}\n\n#[[ru:Project:Spam whitelist]]\n#[[sv:Project:L\xe4nkar som inte skall blockeras]]",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2014-03-31T11:28:59Z'},
#   u'title': u'MediaWiki:Spam-whitelist'},
#  {u'id': u'78090',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Restore upgrade deletion problem (Import from wikitravel.org/en)',
#    u'contributor': {u'id': u'81383', u'username': u'EvanProdromou'},
#    u'format': u'text/x-wiki',
#    u'id': u'1850421',
#    u'model': u'wikitext',
#    u'sha1': u'rvpy29ko1t8vosvmt168nkph5xpneuf',
#    u'text': {u'#text': u'About Docents', u'@xml:space': u'preserve'},
#    u'timestamp': u'2007-07-02T13:02:37Z'},
#   u'title': u'MediaWiki:Aboutdocent'},
#  {u'id': u'78091',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879147',
#    u'model': u'wikitext',
#    u'parentid': u'1850423',
#    u'sha1': u'd5kvojs0geevrb5gt4nyso31trh02v7',
#    u'text': {u'#text': u'Wikivoyage:What is a docent?',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Aboutdocentpage'},
#  {u'id': u'78092',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879148',
#    u'model': u'wikitext',
#    u'parentid': u'1850424',
#    u'sha1': u'ofn3tpgcinir20ysedeykrruclghdm8',
#    u'text': {u'#text': u'Combined display of all available logs of {{SITENAME}}.\nYou can narrow down the view by selecting a log type, the user name, or the affected page.\n\n\n[[de:Special:Log]]\n\n[[es:Special:Log]]\n[[fi:Special:Log]]\n[[fr:Special:Log]]\n\n\n[[hu:Special:Log]]\n[[it:Special:Log]]\n[[ja:Special:Log]]\n[[nl:Special:Log]]\n[[pl:Special:Log]]\n[[pt:Special:Log]]\n[[ro:Special:Log]]\n[[ru:Special:Log]]\n[[sv:Special:Log]]',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Alllogstext'}]

# %%
special_articles_dict['Wikivoyage']
# Out:
# [{u'id': u'1539',
#   u'ns': u'4',
#   u'revision': {u'comment': u'isPartOf',
#    u'contributor': {u'id': u'1844', u'username': u'Globe-trotter'},
#    u'format': u'text/x-wiki',
#    u'id': u'2043579',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'1923444',
#    u'sha1': u'q2bedim1zidlfvjh6qy4zo6xf076gon',
#    u'text': {u'#text': u'{{joke}}\n\n\'\'\'Arial\'\'\' (Goudy: \'\'Helvetica\'\'), on [[Wikivoyage:Joke articles/Lower Caisse|Lower Caisse]], is a smaller and quieter town than hurly-burly [[Wikivoyage:Joke articles/Bodoni|Bodoni]], but travellers will get a chance to experience the \'\'real\'\' [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]] on a visit to this town.\n\nFounded in the 19th century by a colony of Swiss Utopians fleeing persecution in their own country, Arial has a Nordic look with somewhat more steeply sloped tin roofs to the buildings. The city is worth visiting for its period architecture and its white spaces. \n\n==Get in==\n===By parachute===\nUS navy aircraft regularly overfly the city. If you hitch a ride with them, you can drop in. This is by far the most convenient way of entering the city. \n\n===By helicopter===\nHelicopters can be hired from Poor Richard in [[Wikivoyage:Joke articles/Port Clarendon|Port Clarendon]]. As there is no helipad, you will have to \'\'\'rappel down\'\'\' once you reach your destination.\n\n==Get around==\n\n==See==\n\n[[Image:MissionSanJoseCA.LYH.jpg|right|thumb|The Spanish Mission is old.]]\n* \'\'\'Mission San Serriffe\'\'\'.  The oldest building in the country, the mission was built during the brief and ill-fated Spanish colonization period of the country.  The Mission\'s "leaning" attitude is one of the few remaining examples in the world of the "Italic Style" popular in Spain during the early 1500s. Islanders often come here for shelter during thunderstorms to pray for a blue skies to return.  Sometimes their prayers are answered, particularly during years when the El Ni\xf1o weather pattern is operating.\n\n==Do==\n\n* \'\'\'Pray for blue skies\'\'\' with the indigenous population wherever you may find yourself during a downpour.  It\'s a great way to immerse yourself in the local culture as this is one of the most popular pastimes on the island.\n* \'\'\'Jump\'\'\' Once a year on 31st June, you can participate in the Mission Jump. This bungee jump takes places off the Mission San Serriffe. Though you should beware of Rod Transparent objects, as they have caused problems in the past.\n\n==Buy==\n\n==Eat==\n*Aharoni is the pasta delicacy of the area, while bolder travellers may like to try the famous Magneto ice cream.\n\n==Drink==\n*Should you ever find yourself out and about Arial, completely thirsty and in need of a drink, visit the newly built pub, the Parchment.\n\n==Sleep==\n\n==Go next==\n\n{{joke}}\n{{isPartOf|Wikivoyage:Joke articles/Lower_Caisse}}',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-12-14T17:35:40Z'},
#   u'title': u'Wikivoyage:Joke articles/Arial'},
#  {u'id': u'1888',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Conversion of 5 legacy XML listings to [[Template:Listing]] per [[Wikivoyage talk:Listings#Tags to templates]]',
#    u'contributor': {u'id': u'210638', u'username': u'Wrh2Bot'},
#    u'format': u'text/x-wiki',
#    u'id': u'2316040',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'2192469',
#    u'sha1': u'm3sb7wodgdaxbns7rkpnw1tnq5vweal',
#    u'text': {u'#text': u'{{joke}}\n\n[[Image:Kelp forest on high profile reef P9041231.JPG|thumb|300px|Another day in Atlantis]]\n\n\'\'\'Atlantis\'\'\' is in the [[Islands of the Atlantic Ocean|Atlantic Ocean]]. Literally.\n\n==Regions==\n\n==Cities==\n* \'\'\'[[Bensalem]]\'\'\' - the largest city, founded by [[:WikiPedia:New Atlantis|Sir Francis Bacon]]. The sign says the city is where "generosity and enlightenment, dignity and splendour, piety and public spirit" are the norms of the local residents. It\'s a load of crock. \'\'\'Salomon\'s House\'\'\' is worth a visit, though.\n\n==Other destinations==\n\n==Understand==\n[[Image:Athanasius Kircher\'s Atlantis.gif|thumb|250px|Map of Atlantis, however, it might not be up to date]]\nAtlantis is a unique destination on the bottom of the Atlantic Ocean. It is governed by President Poseidon.\n\n===History===\nAtlantis allegedly sunk to the bottom of the ocean when the classified [[:WikiPedia:Eureka_(word)#Archimedes|Eureka!]]-project led by Archimedes went horribly wrong. \nIt is also <strike>suspected</strike> rumored that the [[:Wikipedia:New World Order (conspiracy theory)|New World Order]] had something to do with that event. Among the first visitors was the Greek philosopher Plato.\n\n==Talk==\nThe official language is [[Greek phrasebook|Ancient Greek]], but major world languages are spoken in establishments aimed at tourists.\n\n==Get in==\n{{VisaRestriction|[[Wikivoyage:Joke articles/Hell (Hades)|Hell]] blocks passports containing stamps or visas from Atlantis. Relations between Hades (Dictator of Hell) and President Poseidon have been strained after the [[:Wikipedia:The Lightning Thief|lightning bolt theft incident]]. If you plan to travel to [[Wikivoyage:Joke articles/Hell (Hades)|Hell]] after visiting Atlantis, you must get a second passport.}}\n[[Image:Yonaguni Ruins Scuba.jpg|thumb|300px|Diving offers a more intimate entrance into Atlantis]]\nTo get in to Atlantis you will need a valid visa and [[diving]] equipment. The most difficult part is knowing where to go, as Atlantis is not marked on regular maps.\n\n===By submarine===\nSome submarines are known to transport visitors to and from Atlantis. Prices are, however in the same class with tickets to [[space]].\n\n===By plane===\n\'\'\'Atlantis International Airport\'\'\' is connected by regular flights from [[Bermuda]] operated by Triangle Airlines and Oceanic Airlines. The return ticket will, however be virtually impossible to get. There are also non-stop flights from [[Mount Olympus]].\n\n===By train===\n\'\'\'Atlantis Train Station\'\'\' is served by 5000mph maglev trains coming from [[New York City|New York]] and [[London]] via the  [[:Wikipedia:Transatlantic tunnel|Transatlantic Tunnel]]. From [[London#By_train|London\'s Kings Cross Station]], take the train from [[:Wikipedia:Platform 9 \xbe|Platform 9 \xbe]]. From [[New_York_City#By_train|New York Grand Central Station]], trains leave from the [[:Wikipedia:Grand_Central_Station#Layout|"secret" sub-basement known as M42]].\n\n===By diving===\nThe backpacker\'s alternative - cheap and reliable. If you take your own sail boat it\'ll be very cheap.\n\n===By teleport===\nCheap as free! Just close your eyes and wish really hard. Next thing you know you are there!\n\n===By ruby slippers===\nClose your eyes, click your heels. Then just keep saying "There is no place like home, there\'s no place like home..."\n\n==Get around==\n===By subway===\n[[File:NYC Subway Atlantic Ave Station.jpg|thumb|200px|Atlantic Avenue Station: The Atlantis Subway System suffers from neglect and mismanagement.]]\nThousands of years ago, Atlantis was renowned for its cutting-edge mass transit system, but centuries of neglect, mismanagement, and extensive use have taken their toll. Vehicles are noisy and break down on a regular basis, the interiors are crowded, and the drivers can be very rude. On top of that, with recent budget cuts the fares keep rising. But the system is extensive and will ev ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-06-24T23:51:18Z'},
#   u'title': u'Wikivoyage:Joke articles/Atlantis'},
#  {u'id': u'4134',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* See */ Replace broken image',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420760',
#    u'model': u'wikitext',
#    u'parentid': u'2174923',
#    u'sha1': u'c4aq6msdqrmy50tkg11f7i7r4dyalbe',
#    u'text': {u'#text': u"{{joke}}\n\n'''Bodoni''' is [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]]'s tropical capital. With its heritage of Brutalist concrete architecture intermixed with the spices and mayhem of the South Seas, Bodoni presents a bold face to \nthe world and to the curious traveler.\n\n[[Image:Unarizaki PineappleHouse.JPG|thumb|400px|The Pineapple House, a local landmark]]\n\n==Understand==\n\n\n\n==Get in==\n\n===By plane===\n\n'''National Hero Antonio Bourgeois International Airport''' (IATA code: '''NHB''') is located just outside the city limits.  It's a bit too far to walk, so consider hiring a donqtuque to take you there.\n\n===By car===\n\nIf you want to get here by car, your car's wheels must be strong enough because there are many sharp stones on the city streets.\n\n===By bus===\n\nThere is only one bus service every day connecting the city hall and the mayor's official residence.\n\n===By boat===\n\nYour boat must be strong enough and not attract the sharks.\n\n==Get around==\nBecause of the small number of taxis (the only 4 licences are held by the President's sons), it is very difficult to catch one. Fights are very common and are encouraged by government as a way to solve disputes. The last man standing has the right to use the taxi. Unfortunately two of President's sons have a passion for gambling so don't be surprised if they lose the taxi at it while you're fighting.\n\n==See==\n\n* '''Pilcrow Palace''', 61 Avenida do Plenk.  An architectural landmark shaped like the letter P, painted in imposing shades of gray and constructed on the order of General Pica.  Now open to the public, sights inside include the mirror-lined '''Combat Duty Bedroom of the General''' and the grim '''Disco Inferno''', where political dissidents were subjected to reruns of ''Saturday Night Fever'' until they broke down and confessed.  Open alternate Tuesdays from 9:45 to 10:30 AM, admission 200 dR.\n* '''Hai Phen''', avenida do Bahia Tilde (''go the end of the trolley line, then join up with the beginning''). Bodoni's Little Chinatown, the Hai Phen district features many different kinds of spicey and ginger-scented swarfega prepared in Chinese style. Legal and gray-market CDs and DVDs are available, but be careful: many are region 8 encoded and dubbed over in Goudy.\n\n==Do==\n*'''Bodoni Theatre of the Incomprehensible''', 15 Avenida du Enigma. Actors perform on a giant scrabble board while the audience plays scrabble. Words from any of San Serriffe's many languages are allowed. As each word forms, the actors weave it into the story and continue the performance. The performance is known as a '''Play on Words'''. Tickets 125 dRn. (''Includes a complementary bottle of Plenque'')\n\n==Learn==\n\n==Work==\n\n==Buy==\n[[Image:Chipata_Market_Beans.JPG|thumb|Shopping at the Bean Market]]\n\n* '''Bean Market''' (''Mercado do Feij\xe3o'').  Popular among souvenir-shoppers, this market offers a wide selection of white beans, violet beans, purple beans and, on festive occasions, small dried fish.  Haggling is necessary.  It's advisable to visit the market in the morning, as in the afternoon the merchants' lunches start to digest and air quality tends to deteriorate.\n\n* '''Pineapple House''', 42 Calle do Anan\xe1s.  This distinctively-shaped building is a famed Bodonian landmark and nearly all tourists are dragged here by touts and/or the police at least twice per day.  Once inside, you have the choice of purchasing pineapple products like mashed pineapple, pineapple jam, pineapple wine (also available as an enema), etc.  Free entry, but getting out tends to be expensive.\n\n==Eat==\nBodoni provides an excellent opportunity to take a break from a monotonous diet of mashed swarfega and try everybody's favorite root vegetable in stewed or deep-fried form instead.  There are persistent rumors of turnips and even the occasional potato being available on the black market and served in private rooms at high-end restaurants, bu ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:49Z'},
#   u'title': u'Wikivoyage:Joke articles/Bodoni'},
#  {u'id': u'7878',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Replace broken images',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420759',
#    u'model': u'wikitext',
#    u'parentid': u'2043584',
#    u'sha1': u'fomf53acdni87my07vrc51p34nmkh0g',
#    u'text': {u'#text': u"{{joke}}\n\n[[File:Walking through the rocks to Lannacombe Beach - geograph.org.uk - 563727.jpg|thumb|400px|Looking for sand at Cocobanana Beach]]\n\n'''COCOBANANA BEACH''' is in [[Wikivoyage:Joke articles/Upper Caisse|Upper Caisse]], [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]].\n\n==Get in==\nThe only safest way to get here is by jeep. You can try another way by sea but beware of the sharks because many sharks want to be your friends.\n\n==Get around==\nYou can see shark palace in the bottom of the sea, but you have to have permission from immigration office.\n\n==See==\nCocobanana Beach is, of course, famed for '''its vast expanse of white sand''' and its bevy of Serriffean lovelies wearing only '''Flong thongs''', a garment prepared from coconut husk that can also be used to remove pieces of swarfega from between your teeth.  It should, however, be noted that the Flong thongs are traditionally worn only by men who have passed the demanding initiation rites of the '''Very Brotherly Fraternity of the Homoglyph''', and women usually opt for burlap sacks, or go naked, instead.\n\nCocobanana has suffered somewhat from development recently, with some residents objecting that the '''giant boulders of rock''' dumped from the nearby quarry onto the beach detract from the scenic beauty.  However, protests have quieted down after mine management, yielding to public pressure in a sign of the times, gave residents the democratic option of having the boulders quarried to either the beach or on top of their huts.\n\n==Do==\nYou can be sharks's friend by visiting them in their palace.\n\n==Buy==\nThere is only one mall around here selling cattles.\n\n==Eat==\nThere is no restaurant here, so you have to fish by yourself.\n\n==Drink==\nYou can drink water from the wells.\n\n==Sleep==\n[[File:Sijungho Rest House. W\u014fnsan Beach, North Korea.jpg|thumb|240px|Honeymoon Hideaway Suite at the Cocobanana Beach Resort]]\nThere is only one hotel around here, but beware of the mosquitos.\n\n===Splurge===\n* '''Cocobanana Beach Resort''', on National Highway 1, [http://cocobanana.com/].  Visitors to Cocobanana Beach Resort never cease to be amazed by its stunning appearance and the level of services available, and often leave with indelible memories of their experience.  For easy access, National Highway 1 runs right through the resort, and complimentary donkey carts to the beach (17 km away) are provided weekly.\n\n==Stay safe==\nBeware of locals with large sacks over their shoulder contacting you about purchase of foreign tubers. Remember: '''possession of foreign vegetables is a crime'''. Also, some of the local law enforcement officials pose as tuber salesmen to trap foreign visitors. If you are a victim of one of these traps, a payment offer 2,000dNr will normally allow you to go on your way (and you can keep the tubers).\n\n==Go next==\nIf you want to get out fast from this place just call 911.\n{{isPartOf|Wikivoyage:Joke articles/Upper_Caisse}}\n{{joke}}",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:04Z'},
#   u'title': u'Wikivoyage:Joke articles/Cocobanana Beach'},
#  {u'id': u'8213',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* Things for users to know */',
#    u'contributor': {u'id': u'188833', u'username': u'GZWDer'},
#    u'format': u'text/x-wiki',
#    u'id': u'2711166',
#    u'model': u'wikitext',
#    u'parentid': u'2691276',
#    u'sha1': u'tcjjs7wkqhav49aabwumx9rlcsr5lgm',
#    u'text': {u'#text': u'{{nutshell|All written contributions to this project are automatically licenced under CC BY-SA 3.0. All files uploaded to the project must be licenced under CC BY-SA or a compatible licence.}}\n{{shortcut|[[WV:Copyvio]]}}\n[[Image:The Universal Declaration of Wikivoyage Copyleft.png|thumb|370px|The Universal License of Our Wiki]]\n\nWikivoyage uses a \'\'\'copyleft\'\'\' license for all content on the website. \'\'\'Anyone can use\'\'\' Wikivoyage content according to the terms of the \'\'\'Creative Commons Attribution-ShareAlike\'\'\' license. And \'\'\'anyone can contribute\'\'\' their own or other people\'s content, as long as the work is their own or available under a compatible license.\n\nIt is very important that you \'\'\'understand how copyleft works before you contribute to Wikivoyage\'\'\'.  If you find your work reused by someone else in a manner that you didn\'t consider, or if you stop using Wikivoyage for any reason, it is not possible to change the license for the work you have done. Although you always own the copyright in your work, that does not give you the right to change its license retrospectively.\n\n==Licensing==\n\n\'\'If this seems confusing, <big>\'\'\'skip down to [[#Frequently asked questions|the FAQ]].\'\'\'</big>\'\'\n\nAll \'\'\'written contributions\'\'\' to Wikivoyage are and must be licensed under Creative Commons Attribution-ShareAlike 3.0 ([http://creativecommons.org/licenses/by-sa/3.0/legalcode CC-by-SA 3.0]) or a compatible license (e.g., Public Domain, CC-by-SA any, dual CC-by-SA/GFDL any, etc.). Consequently, all redistributed and derivative works of Wikivoyage text must also be licensed as CC-by-SA 3.0.\n\n\'\'\'Images\'\'\' almost always must be uploaded to [[:Commons:Main page|Wikimedia Commons]], and images\' individual licensing is described on individual image pages. Any images hosted locally on Wikivoyage comply with our [[Wikivoyage:Non-free content]], meaning that they do have a license compatible with our copyleft, but are derivative works of something \'\'not\'\' free, like a work of art. As with text contributions, all files uploaded here must have a license that allows derivative works and commercial re-use (usually CC-by or CC-by-SA, never CC-No Derivatives or CC-Non-Commercial)\u2014see [[Wikivoyage:Non-free content#Exemption Doctrine Policy]] for more information.\n\nAll redistributed and derivative works including Wikivoyage images and other files must provide file-specific attribution and licensing information, available on the individual file page.\n\n==Things for users to know==\n\n\'\'\'Copyleft\'\'\' means that every single author, editor, illustrator, mapmaker, factchecker and photographer who puts their work into Wikivoyage gives you the right to read, copy, print, save, download, read aloud, project, modify, email, distribute, sell, photocopy and correct their work however you want to.\n\nThe only restrictions are that:\n* \'\'if you distribute it, or derive new work from it\'\'\n** you must give \'\'\'attribution\'\'\' to the creators\n** you must retain the work and any derivative works \'\'\'under the same licensing\'\'\'.\n\n[[Image:Cc-by new.svg|thumb|150px|Attribution]]\n\nIn other words, we give you practically every freedom within the boundaries of the law to use the information in Wikivoyage, except the freedom to take that freedom away from others.\n\nThe license we use is the \'\'\'Attribution-ShareAlike\'\'\' license. It\'s a piece of legal documentation created by the great people at [http://www.creativecommons.org/ Creative Commons] that basically says the same thing as above: give Wikivoyagers credit for their work, and share with other people.\n\nIf you want you can read the [http://creativecommons.org/licenses/by-sa/3.0/legalcode full text of the Attribution-ShareAlike 3.0 license]. For the purposes of the License, a \'\'Work\'\' is the formatted text that makes up a single Wikivoyage article. Each image individually is ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-01-09T05:07:38Z'},
#   u'title': u'Wikivoyage:Copyleft'}]

# %% [markdown]
# __These special articles are not actual travel guide articles so I will create a new dictionary without them.__

# %%
# articles without :'s in their titles
articles_dict = {}
for article in articles:
    # Lets strip the accents using unicodedata
    title = unicodedata.normalize('NFKD', article['title']).encode('ascii','ignore')
    if ':' not in title:
        articles_dict[title] = article

print len(articles_dict)
articles_dict[articles_dict.keys()[1]]
# Out:
# 42754
# {u'id': u'34976',
#  u'ns': u'0',
#  u'revision': {u'contributor': {u'id': u'244322',
#    u'username': u'Double sharp'},
#   u'format': u'text/x-wiki',
#   u'id': u'2763935',
#   u'minor': None,
#   u'model': u'wikitext',
#   u'parentid': u'2739009',
#   u'sha1': u'jfmz1rvkzz1nfe7dqzq0izms4v764dh',
#   u'text': {u'#text': u'{{pagebanner|Szczecin Wikivoyage Banner.png}}\n\n\'\'\'[http://www.szczecin.eu/en/ Szczecin]\'\'\', (pronounced \'\'Shchetsin\'\', German: \'\'Stettin\'\', Latin: \'\'Stetinum\'\'; is maritime port city and the capital of [[Zachodniopomorskie]] in [[Poland]]. The city has a population of over 400 000 thousand, with almost 800 000 living its metro area, and is one of the seven largest metropoles in the country. It lies in the northwestern corner of Poland, very close to the German border, and it is in fact easier to get to Szczecin from some parts of Germany, notable from [[Berlin]], than it is from much of the Polish territory. For a significant part of its history, actually, Szczecin was a part of Germany, as well as, in other periods, of Denmark and Sweden.\n\nSzczecin is Poland\'s third-largest port and much of its industrial base used to be a part of an important shipyard, so it may come as a surprise to the casual tourist that the city does not lay on a seaside, but rather over the river Odra (German: \'\'Oder\'\'), some 20&nbsp;kilometres south of the Baltic Sea as the crow flies, and many more by road. Many visitors to Poland are also unaware of Szczecin\'s architectural attractiveness, as the large parts of the city were designed by Baron Haussmann, the same gentleman who designed the boulevards of [[Paris]]. \n\n==Understand==\nThe place now known as Szczecin was first mentioned in written history in 1st century when West-Roman historian Tacitus located East Germanic tribe of Rugians somewhere in the area; the Rugians left in 5th Century during the Great Migration. Sometime in the 8th century Western Slavic tribe of Pomeranians built their stronghold here. In 10th century the town was mentioned as "one of major in Pomerania" in Abraham ben Jacob\'s chronicle. In approximately 1080 its area was incorporated into [[Poland]], but within eight years, the town was controlled by the Dukedom of Pomerania, and five years later, [[Denmark]]. In 12th century when its competitor, [[Wolin]] (also known as Veneta in medieval chronicles) declined Szczecin began to prosper from trade and became one of the major Baltic sea harbours. Its name was first recorded in 1133 as "Stetin". \n\nIn 1181 Pomeranian dukes joined Holy Roman Empire. In 1243 Szczecin got city rights before it became member of the Hanseatic League in 1278. Until early 17th century the city was the capital of Pomeranian Dukedom, then in 1630 when local dukes died out it became part of [[Sweden]],  then Kingdom of Prussia, then for a brief period, due to Napoleon\'s conquests, the Empire of [[France]]. Beginning in the 18th century, the city constituted as a part of [[Germany]] and served as the "port of Berlin". During World War II the city was hit hard by Allied bombers - city centre, Old Town and industrial areas were totally ruined. After the Soviet forces invaded Nazi Germany in 1945, according to Potsdam Conference agreements Poland annexed all lands up to the Oder river, expelling the native German population and ultimately extending the border to include Stettin. Poland thus gained control of the city.\n\nIn more recent history, the city was (together with [[Tricity]]) one of the birthplaces of Solidarity movement.\n\nAn unusual feature of Szczecin is its urban planning - many roundabouts and wide avenues. Stettin was rebuilt in 1880\'s using designs by Georges-Eugene Haussmann, who also did the urban planning for [[Paris]]. His design style is still being used for newly-built (or modified) city areas.\n\nThe maritime industry is still strong with a busy port and repair shipyard, as well as being a center of service industries in Poland. Situated near the border between Germany and Poland, Szczecin is sometimes considered one of most liberal Polish cities.\n\n==Get in==\n\n===By plane===\n\nSzczecin-Goleni\xf3w airport (SZZ) [http://www.airport.com.pl/en/show/start-page] is located almost 50&nbsp;km from the city centre, near Goleni\xf3w ...
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2015-04-12T05:43:19Z'},
#  u'title': u'Szczecin'}

# %% [markdown]
# ### Now that we have a dictionary of travel guide articles, lets check out the article lenghts.

# %%
article_lengths_dict = {}
for key, value in articles_dict.iteritems():
    article_length = len(value['revision']['text']['#text'])
    article_lengths_dict[key] = article_length

article_lengths_dict
# Out:
# {'': 20,
#  'Szczecin': 33999,
#  'San Juan Islands': 21187,
#  'Rugia': 11293,
#  'New Australia': 875,
#  'Natchez, Mississippi': 21,
#  'Nampa': 7084,
#  'Jamaica (disambiguation)': 380,
#  'Hyanger': 791,
#  'Xigatse (prefecture)': 1794,
#  'York (Maine)': 19321,
#  'Calangute Beach': 23,
#  'Fulda': 9523,
#  'Novi Sad': 26800,
#  'Eure': 28,
#  'Moovattupuzha': 26,
#  'Gravesend': 1874,
#  'Turkmen phrasebook': 3126,
#  'Caen': 5997,
#  'Madeira Islands': 21,
#  'Miami Springs': 896,
#  'Houston/East Houston': 4176,
#  'Gwangalli': 26,
#  'Malabon': 1082,
#  'Wind surfing': 24,
#  'Hikone': 7609,
#  'Pea Ridge': 2272,
#  'Airline consolidators': 36,
#  'Kearney': 20,
#  'Mokhotlong': 1467,
#  'Loei': 7551,
#  'Loen': 19,
#  'Pergamon': 21,
#  'Paris/Champs Elysee': 38,
#  'Central Limburg (Belgium)': 31,
#  'Rio de janerio': 28,
#  'South Uist': 9641,
#  'Cahir': 1378,
#  'Volta Delta': 563,
#  'Jeffersonville': 703,
#  'Indian Harbour Beach (Florida)': 34,
#  'Orcas Village': 7316,
#  'Scituate (Rhode Island)': 12021,
#  'Western Nevada': 7920,
#  'Pampa': 12355,
#  "Church's Ferry": 27,
#  'Gangtok': 20410,
#  'Bali (Crete)': 8091,
#  'Lucknow': 32642,
#  'Montreal/Parc Jean-Drapeau': 6548,
#  'Kilimanjaro': 31,
#  'Shahrisabz': 25,
#  'Hamilton': 1086,
#  'Kaokoland': 6524,
#  'Fridley': 38,
#  'Florida (Uruguay)': 40,
#  'Santiago do Cacem': 975,
#  'Salem (Massachusetts)': 59333,
#  'Pleasure Island': 466,
#  'Northern Virginia': 12480,
#  'Caravanning': 25,
#  'Discovery Bay': 349,
#  'Limousin': 1127,
#  'Eco tour': 24,
#  'Narvik': 9754,
#  'Mont-Saint-Michel': 31,
#  'Mahajanga': 1051,
#  'Quartzsite': 10821,
#  'Mountainair': 4445,
#  'Stanhope': 2310,
#  'Palmyra': 13788,
#  'Nagano (city)': 20,
#  'Ungalik (Alaska)': 21,
#  'Northern Alberta': 32,
#  'Corydon (Indiana)': 21,
#  'Hallefors': 3538,
#  'Canton (Michigan)': 1280,
#  'Leonardo da Vinci-Fiumicino Airport': 8539,
#  'Harvey': 2396,
#  'Ambala': 4982,
#  'Montone': 2272,
#  'Rendsburg': 1272,
#  'Ulldecona': 23996,
#  'Halong': 9132,
#  'Alcoholic drinks': 33,
#  'Cooperstown ND': 40,
#  'Laguna Miramar': 7590,
#  'Wakefield (New Zealand)': 1125,
#  'Okeechobee': 3868,
#  'Nishitokyo': 8694,
#  'Sainybuli Province': 27,
#  'Taipei/Datong': 3052,
#  'Noukendai': 22,
#  'West Papua': 19,
#  'Banagher': 1059,
#  'Greater Santo Domingo': 3235,
#  'Fort Sumner': 1275,
#  'Wauchula': 5146,
#  'Woodland (California)': 5016,
#  'Dazaifu': 3548,
#  'Deutschland': 21,
#  'Montville (Connecticut)': 1646,
#  'Predjama': 22,
#  'Kallooppara': 6387,
#  "Zikhron Ya'akov": 595,
#  'Karonga': 3160,
#  'Dekalb County (Georgia)': 37,
#  'Singkep-Lingga': 4541,
#  'Rahacou': 1178,
#  'Malay Phrasebook': 30,
#  'Dac Lac': 41,
#  'Salamanca (city)': 23,
#  'Colombia': 63307,
#  'Boston (disambiguation)': 780,
#  'Zhejiang Province': 22,
#  'Travel news': 891,
#  'Mineral Bluff': 1539,
#  'Lolland-Falster': 1163,
#  'Aberdyfi': 18641,
#  'Haute-Garonne': 543,
#  'Mustang District': 23,
#  'Ylivieska': 4790,
#  'Sangkhla': 27,
#  'Oberon': 1075,
#  'Chicago/Chinatown': 42,
#  'Ly': 32,
#  'Inland Sea': 29,
#  'Sherman Oaks': 6431,
#  'Gracanica (Bosnia and Herzegovina)': 48,
#  'Godthaab': 18,
#  'Far Western Nepal': 19,
#  'Ponmudi': 2186,
#  'Bombay/Vikhroli': 36,
#  'Falcon': 20,
#  'Tanjore': 23,
#  'Lappajarvi': 5794,
#  'Barnesville': 464,
#  'Caledon': 449,
#  'Isabela (province)': 414,
#  'Fogo': 5925,
#  'Rail travel': 2417,
#  'Georgia (American state)': 29,
#  'El Jem': 4932,
#  'Rewalsar': 1578,
#  'Matunuck': 11609,
#  'Nizhniy Novgorod': 29,
#  'Manzanillo (Mexico)': 24,
#  'Ganzhou': 2029,
#  'Playas De Este': 20,
#  'Golden Triangle': 994,
#  'Gustrow': 951,
#  'Harlingen (Netherlands)': 11765,
#  'Urban backpacking': 8369,
#  'Ishpeming': 2187,
#  'Blackstone': 7914,
#  'Badajoz': 1252,
#  'Poipet': 24493,
#  'Diving the Cape Peninsula and False Bay/Balcony': 3683,
#  'Robertson': 3360,
#  'Ojcow National Park': 759,
#  'Boxford': 441,
#  'Viloyati Mukhtori Kuhistoni Badakhshon': 23,
#  'Weerribben-Wieden National Park': 9467,
#  'Central Wyoming': 3497,
#  'Alcantara': 1353,
#  'Stevenson Ranch': 27,
#  'Tianshui': 3391,
#  'Montague': 4200,
#  'Lung-tan': 21,
#  'Koidu': 1430,
#  'Unusual Places in Ashdown Forest': 28,
#  'Canton (disambiguation)': 1655,
#  'Gataia': 20,
#  'Newfoundland and Labradour': 39,
#  'Goshen': 7906,
#  'Aegina (city)': 1932,
#  'Hickory': 13937,
#  'Kashid': 7799,
#  'Pathum Thani': 6460,
#  'Medelpad': 35,
#  'Brighton (disambiguation)': 22,
#  'Freeport (Illinois)': 707,
#  'Thera': 18,
#  'Dumfries': 17326,
#  'Saxony Anhalt': 27,
#  'Pieterburen': 1852,
#  'Bowdon': 2535,
#  'Geraardsbergen': 707,
#  'Montpelier (Vermont)': 24,
#  'Magnesia': 3252,
#  'Frde': 2318,
#  'Marigha': 1630,
#  'Przemysl': 22,
#  'Satsuma': 36,
#  'Cavalcante': 15528,
#  'Kedzierzyn-Kozle': 787,
#  'Tiburon': 10441,
#  'Central and South Central (Parana)': 1003,
#  'Toamasina Province': 519,
#  'Jamestown': 658,
#  'Lutsk': 66728,
#  'Lao': 28,
#  'Pomerania': 23,
#  'Baoding': 1380,
#  'Cavado': 19,
#  'Bourgogne': 22,
#  'Great Eastern Highway': 3768,
#  'Indigenous Americans': 47,
#  'New Milford': 24448,
#  'Fort McMurray, Alberta': 27,
#  'Elazg': 20,
#  'Irwin (Pennsylvania)': 972,
#  'Rhinecliff': 23,
#  'Tarnaveni': 3284,
#  'Waterloo (Ontario)': 26812,
#  'Noboribetsu': 4415,
#  'Washington (State)': 32,
#  'Spiritwood': 707,
#  'Porquerolles': 7382,
#  'Tetun phrasebook': 30,
#  'Holland (Michigan)': 9139,
#  'Poulton-le-Fylde': 722,
#  'Cuzco': 89514,
#  'Outback (Australia)': 21,
#  'Yagodnoye': 1797,
#  'Arlington Heights': 8112,
#  'Niger': 26499,
#  'Kerikeri': 18147,
#  'Lampung': 2936,
#  'Dornogobi': 18,
#  'Montserrat (Spain)': 6369,
#  'Echo Park': 35,
#  'Sepupa': 1838,
#  'Sunshine Coast (British Columbia)': 5875,
#  'Ostia Antica': 19,
#  'Toronto/Scarborough': 10470,
#  'Driving in China': 35367,
#  'Rachel, Nevada': 20,
#  'Western Uganda': 3070,
#  'Ballina': 366,
#  'La Tomatina': 19,
#  'Lancaster (Lancashire)': 33,
#  'Introdacqua': 2140,
#  'Pillnitz': 21,
#  'San Juan (La Union)': 3903,
#  'Aran Islands': 10771,
#  'Scarboro': 42,
#  'Wupperthal': 4286,
#  'Chatham (Ontario)': 26,
#  'Niigata (city)': 21,
#  'Agadir': 16352,
#  'Diving the Cape Peninsula and False Bay/HNMS Bato': 4751,
#  'Ban Nalan trail': 29,
#  'Cheyenne Wells': 2051,
#  'Ballestas Islands': 664,
#  'Benton (disambiguation)': 20,
#  'Polish Phrasebook': 31,
#  'Zurich (region)': 1182,
#  'Bocas del Toro (town)': 28,
#  'Volta Region': 25,
#  'Ramkhamhaeng': 34,
#  'Arnhem Land': 20034,
#  'Rockland (Idaho)': 32,
#  "Diving the Cape Peninsula and False Bay/Finlay's Deep": 4725,
#  'Chicago': 154994,
#  'Fortuna (California)': 2277,
#  'Diving the Cape Peninsula and False Bay/SS Lusitania': 15575,
#  'Belarussian': 35,
#  'The Other 1': 4801,
#  'Nykbing F': 30,
#  'Kusinara': 24,
#  'Antrim (disambiguation)': 20,
#  'Narva-joesuu': 26,
#  'Waikoloa': 4776,
#  'Kismayo': 1825,
#  'Honaunau': 613,
#  'Roscommon': 7170,
#  'San Francisco/Western Addition': 21862,
#  'Krakow/Old Town': 56955,
#  'Arieseni': 22,
#  'Venice (disambiguation)': 682,
#  'Dothan': 15489,
#  'Playa Hermosa (Osa)': 2101,
#  'North Shore (New Zealand)/Torbay': 20,
#  'Azamgarh': 27,
#  'Oostende': 20,
#  'Seattle/West Seattle': 26,
#  'Kamphaeng Phet (province)': 28,
#  'Saint George': 1429,
#  'Pomerania lake district': 28,
#  'Indonesian Phrasebook': 35,
#  'Kentucky Bourbon Distilleries Tours': 13649,
#  'Far Northeast Philadelphia': 36,
#  'Shanhaiguan': 37,
#  'Sadecki Beskids': 25,
#  'Chico (WA)': 32,
#  'Caucasian Biosphere Reserve': 1986,
#  'Honolulu/Manoa': 22,
#  'Torno': 4413,
#  'Montefalco': 3690,
#  'Riberac': 2603,
#  'Rome (New York)': 2148,
#  'Bombay/Santa cruz': 36,
#  'Clarksville (Indiana)': 20941,
#  'Cunha': 3916,
#  'Gunnison': 306,
#  'Oberammergau': 6794,
#  'Haut-Rhin': 20,
#  'NEA ANCHIALOS': 27,
#  'Kyaukme': 2779,
#  'Dhulikhel': 5374,
#  'Itapecerica da Serra': 2438,
#  'Belmont (California)': 4964,
#  'Captian Obvious': 55,
#  'Ashburn (Virginia)': 7228,
#  'Kanazawa ward': 22,
#  'Worcester Hills': 10213,
#  'Winnemucca': 4737,
#  'Hillsboro (North Dakota)': 4733,
#  'French Gulch': 2710,
#  'Hoani': 1078,
#  'Dubrovnik-Neretva': 1735,
#  'Kilwa Kisiwani': 19,
#  'Newton (Massachusetts)': 19,
#  'Rawanduz': 1276,
#  'Garland (Arkansas)': 606,
#  'Washington (Pennsylvania)': 2803,
#  'Study Butte/Terlingua': 35,
#  'Congo, Republic of the': 35,
#  "'s-Hertogenbosch": 22309,
#  'Backpacking the Canadian Rockies': 43,
#  'Andover': 443,
#  'Kallil Temple': 20,
#  'Akhty': 527,
#  'Rio': 28,
#  'Khao Yai': 36,
#  'Landmannalaugar': 7208,
#  'Indianola': 497,
#  'Trebisacce': 913,
#  'Koege': 18,
#  'Sargodha Division': 22,
#  'Portsmouth (Dominica)': 899,
#  'Nagaon': 1190,
#  'Anderson': 342,
#  'Gaoxiong': 23,
#  'Jeffersonville (Indiana)': 17424,
#  'Narberth': 374,
#  'Bonito (Brazil)': 41,
#  'Rail Travel in North America': 42,
#  'Lower Caisse': 51,
#  'Tunbridge Wells': 22041,
#  'Flower Ridge Trail': 40,
#  'Guayana': 591,
#  'Eurail': 41,
#  'Chugoku': 15733,
#  'Northern Montserrat': 24,
#  'Bogota/Teusaquillo-Salitre': 40,
#  'Trekking in everest': 36,
#  'Ojen': 876,
#  'Burhaniye': 1565,
#  'Tokyo Station': 34,
#  'Dornod': 30,
#  'Perigueux': 23,
#  'Bronx': 43927,
#  'Norfolk (Massachusetts)': 622,
#  'Kargil District': 19,
#  'Mealhada': 1690,
#  'Sanjo': 1941,
#  'Lithia springs': 28,
#  'Isle (Minnesota)': 24,
#  'Casselberry (Florida)': 2037,
#  'Everglades and Lake Okeechobee': 31,
#  'Resolute': 2079,
#  'Cauvery Basin': 2977,
#  'Norvalspont': 1938,
#  'Hope (New Jersey)': 1087,
#  'Hightstown': 7472,
#  'Benalla': 1589,
#  'Logansport': 1377,
#  'Diving the Cape Peninsula and False Bay/Fishermans Beach': 3612,
#  'Xiaozhou': 23,
#  'New South Wales': 44282,
#  'Lincoln (Illinois)': 5492,
#  'Llanybydder': 837,
#  'Fuji-Hakone-Izu National Park': 4859,
#  'Hoge Veluwe': 39,
#  'First and business class travel': 15570,
#  'Balkh': 3211,
#  'Clarens': 572,
#  'Middle Volga': 26,
#  'Northern Italy': 19,
#  'Chicago skyline': 35,
#  'Iwakuni': 17339,
#  'Ko Phai': 29,
#  'Royal National Park (disambiguation)': 375,
#  'Guruvayoorappan': 23,
#  'Riviera adriatica': 31,
#  'Krasnoyarsk-26': 27,
#  'Bahasa Malaysia phrasebook': 30,
#  'Longtan': 4173,
#  'Pirin National Park': 5073,
#  'Santa Teresa (Costa Rica)': 4479,
#  'Machadodorp': 1789,
#  'Parsippany': 9809,
#  'Serbo Croatian': 28,
#  'Huntington (Virginia)': 624,
#  'Alencon': 21,
#  'Mountain Home (Idaho)': 2824,
#  'Consensus': 31,
#  'Barren Island': 32,
#  'Fjadundraland': 26,
#  'Acadia National Park': 15283,
#  'Elgin': 4024,
#  'Spello': 9098,
#  'Okehampton': 633,
#  'Courtray': 22,
#  'Manchester (Tennessee)': 995,
#  'TDF': 46,
#  'Yoshkar-Ola': 35073,
#  'Moritzburg': 713,
#  'Courtrai': 22,
#  'Bohemian-Moravian Highlands': 1323,
#  'European Turkey': 28,
#  'Chhukhung': 897,
#  'Puebla (state)': 706,
#  'Norwegian Cruise Line': 26,
#  'Clarksburg': 717,
#  'Puno (city)': 17,
#  'Marumbi': 1519,
#  'Neuquen': 30,
#  'Brookings': 288,
#  'Atlantic Seaboard': 653,
#  'South Coast Highway': 2292,
#  'Udaigiri': 20,
#  'Fort Myers': 16554,
#  'Central Aegean': 4788,
#  'Tahitian': 33,
#  'Moszna Castle (Zamek Moszna)': 28,
#  'Glengarriff': 6288,
#  "Les Sables d'Olonne": 1807,
#  'San Angelo': 30239,
#  'Bangka (Sumatra)': 29,
#  'Jacks Fork River': 22,
#  "Sant' Andrea Apostolo dello Jonio": 832,
#  'Chantilly (Virginia)': 11895,
#  'Rebun': 51,
#  'Woodridge (Illinois)': 935,
#  'Tahara': 3154,
#  'Kilwinning': 2746,
#  'Persia': 18,
#  'Karak (Khyber Pakhtunkhwa)': 32,
#  'Black Forest': 7392,
#  'Sherwood Forest (Massachusetts)': 20,
#  'Rapid Bay': 1336,
#  'Shinyokohama': 22,
#  'Washington (D.D.)/Southwest': 41,
#  'Florence (Province)': 33,
#  'Philadelphia/West Philly': 31,
#  'Chicago/West Town': 33,
#  'Kavieng': 5935,
#  'Hancock (Maryland)': 1552,
#  'Mountain Province': 877,
#  'Dexter': 1466,
#  'Mountain View (California)': 19143,
#  'Cerro Punta': 2032,
#  'Camalu': 3427,
#  'Winter Hill': 21,
#  'Johnson Creek': 2498,
#  'Ada (Michigan)': 785,
#  'Marina del Rey': 39413,
#  'Kashmir Valley': 15356,
#  'Suwa': 3262,
#  'Collier County': 31,
#  'Alphen aan den Rijn': 6990,
#  'Minneapolis/Stadium Village': 35,
#  'Cappadoccia': 24,
#  'Diving inland in South Africa/Wondergat': 7449,
#  'Connecticut': 21535,
#  'Albenga': 3117,
#  'Jokhang temple': 19,
#  'Rio de Janeiro/Santa Teresa': 34,
#  'Lampedusa': 28,
#  'North Stonington': 6788,
#  'Fucking, Austria': 21,
#  'Samut Prakan': 9054,
#  'Bath (Maine)': 4573,
#  'College Park (Maryland)': 18390,
#  'Tipping': 4464,
#  'Citta del Vaticano': 26,
#  'Silimbong': 1622,
#  'Schleswig-Holstein': 9406,
#  'Ko Jum': 7199,
#  'Sainte Genevieve': 28,
#  'Cullohill': 1481,
#  'Mount Meron': 1071,
#  'Leghorn': 21,
#  'Freetown (Massachusetts)': 5640,
#  'Janakpur (zone)': 19,
#  'Kununurra': 53639,
#  'Santa Rosa (Colombia)': 33,
#  'Hong Kong/Central Hong Kong Island': 31,
#  'Latera': 11243,
#  'Montignac, Dordogne': 34,
#  'Isla Ometepe': 29,
#  'Accomac (Virginia)': 21,
#  'Beskids': 1485,
#  'Ledu': 1084,
#  'Cuc Phuong': 38,
#  'Beskidy': 21,
#  'Mangamuka Bridge': 844,
#  'Pahokee': 513,
#  'South Corsica': 628,
#  'Passaic': 375,
#  'Perryton': 5078,
#  'Chubu Airport': 50,
#  'Ingleside': 409,
#  'Devanagari': 33,
#  'West Azerbaijan': 32,
#  'Celebration': 20246,
#  'Chihuahua (state)': 6100,
#  'Sosua': 28593,
#  'Cieszyn': 3079,
#  'Oxbow': 279,
#  'West Point': 34,
#  'Panhandle (Nebraska)': 5502,
#  'Papallacta': 3561,
#  'Statia': 28,
#  'Prinsenbeek': 19,
#  'Vintage railroad': 43,
#  'Hongrie': 21,
#  'Detroit (Oregon)': 48,
#  'Lavenham': 2515,
#  'Merida (Yucatan)': 29,
#  'Crystal Lake': 3003,
#  'China (Texas)': 948,
#  'Macclesfield': 7489,
#  'Central Slovenia': 2286,
#  'Sitka': 18675,
#  'Ladino phrasebook': 4138,
#  'Berlin (Connecticut)': 1192,
#  'Jotunheimen': 9422,
#  'Northwest (Rio Grande do Sul)': 763,
#  'Mary Province': 938,
#  'Vernon': 960,
#  'Bakel Fort': 19,
#  'Ende': 13195,
#  'Si Lom': 27,
#  'Grand Anse': 19,
#  'Bingzhongluo': 1906,
#  'Stockholm/Liljeholmen': 32,
#  'Rockland County': 9323,
#  'Franciacorta': 5084,
#  'Tokyo/Akihabara': 21311,
#  'Kinik': 19,
#  'Udon': 24,
#  'Film and TV series travel': 40,
#  'La Paz (Mexico)': 10310,
#  'Chubu Centrair International Airport': 12157,
#  'Hartford (Vermont)': 34,
#  'Gilli Islands': 26,
#  'Carlisle (Iowa)': 831,
#  'Thimpu': 21,
#  'Aakirkeby': 1326,
#  'Szamotuly': 23,
#  'Yaren': 19,
#  'Chainat': 22,
#  'Bocholt': 1866,
#  'Pleasanton': 9213,
#  'Sydney/Milsons Point': 38,
#  'Brest': 272,
#  'El Golea': 1795,
#  'Sao Paulo/Historic Center': 32,
#  'Jogindernagar': 21327,
#  'North Country': 4728,
#  'Xiazhou': 23,
#  'Sannicolau Mare': 1938,
#  'Arid Midlands': 27,
#  'Big Pine': 1826,
#  'Hovd (province)': 30,
#  'Bay Point': 286,
#  'Riverview': 590,
#  'Oberndorf bei Salzburg': 57,
#  'Rudolph, wisconsin': 21,
#  'McArthur': 2327,
#  'West (Hill Country)': 1127,
#  'Misquamicut': 11268,
#  'Bethany (Oklahoma)': 1020,
#  'Kaili': 4042,
#  'Targu-Mures': 25,
#  'Tokyo/Chiyoda': 23398,
#  'Cheorwon': 4991,
#  'Lake Habbaniyah': 26,
#  'Cuckoo trail': 26,
#  'Ialysos': 1936,
#  'Pelhrimov': 23,
#  'London (West)/Kensington': 45,
#  'Kullu Manali': 20,
#  'Catalan Phrasebook': 32,
#  'MacDonnell Ranges': 3739,
#  'Gardena': 3210,
#  'Melbourne': 92373,
#  'Chisago': 26,
#  'Wellington (Ontario)': 34,
#  'Inverigo': 1071,
#  'Suprasl': 23,
#  'Spennymoor': 21608,
#  'Ballycastle': 2985,
#  'Port Stephens (Australia)': 45,
#  'Pointe-Noire (Republic of the Congo)': 26,
#  'Wallowa County': 28,
#  'Clewiston': 1762,
#  'Nouakchott': 9202,
#  'Ithaca, New York': 31,
#  'Cacapava': 591,
#  'Bellevue (Nebraska)': 10931,
#  'Dallol depression': 32,
#  'Corentyne': 31,
#  'Holbk': 17236,
#  'Onslow County': 508,
#  'Kabale': 3599,
#  'Travel topics': 10618,
#  'Semmering': 11933,
#  'Ipswich': 452,
#  'Science-fiction tourism': 1415,
#  'Mundau': 1055,
#  'Lleida': 2465,
#  'Majuli': 3207,
#  'Kasauli': 10794,
#  'Fairmont City': 2766,
#  'Western Highlands': 243,
#  'Kherson': 2665,
#  'Lake District National Park': 18274,
#  'WikiVoyage': 27,
#  'Faliraki': 6641,
#  'Macedon Ranges': 1572,
#  'Bombay/Kurla': 36,
#  'Loudoun County (Virginia)': 11683,
#  'Ahmedabad': 100439,
#  'Northern Kazakhstan': 24,
#  'Trechtingshausen': 3415,
#  'Butaritari': 7216,
#  'Longwood (Florida)': 2300,
#  'Jungmun': 25,
#  'Cronulla': 29,
#  'Kelmend': 355,
#  'Enniskillen': 13674,
#  'Nicosia district (South)': 990,
#  'Skelleftea': 5642,
#  'Hjrundfjord': 6881,
#  'Northampton County': 27,
#  'Laguna Beach': 30074,
#  'Kuala Terengganu': 9343,
#  'Greenville (South Carolina)': 40150,
#  'Yukon Territory': 19,
#  'Kamyanets-Podilsky': 33,
#  'Marathon (Florida)': 19331,
#  'Santa Barbara': 61276,
#  'Spencer (West Virginia)': 6027,
#  'Tak': 6026,
#  'Mt Chokai': 24,
#  'Silvia': 855,
#  'Meru': 835,
#  'Kemmerer': 893,
#  'Plastira Lake': 2594,
#  'Pilion': 26,
#  'Hervey Bay': 19652,
#  '100 Mile House': 6897,
#  'Vila Real de Santo Antonio': 40,
#  'Kalinga': 784,
#  'Turkey (disambiguation)': 385,
#  'Berneray (disambiguation)': 552,
#  'Mandalgovi': 24,
#  "'s Hertogenbosch": 30,
#  'Peechi Vazhani Wildlife Sanctuary': 2099,
#  'Matabeleland South': 26,
#  'Pamplona': 19129,
#  'Mn': 3951,
#  'Staniel Cay,Exumas,Bahamas': 25,
#  'Somerset (Massachusetts)': 5178,
#  'Dorking': 3231,
#  'Richmond, ky': 33,
#  'Province of Chieti': 31,
#  'Krems an der Donau': 19,
#  'Suquamish (Washington)': 23,
#  'Interior (Iceland)': 4803,
#  'Isle of Lismore': 3580,
#  'Nevada (disambiguation)': 351,
#  'Montgomery Township': 3650,
#  'Chapada dos Guimaraes': 1403,
#  'Baiyu': 50,
#  'Bol': 9760,
#  'Jardin': 8889,
#  'Antep': 23,
#  'Bowling Green (Ohio)': 14983,
#  'Thornton': 3445,
#  'Khakassia': 2439,
#  'Ambalappuzha': 23,
#  'Clitheroe': 3352,
#  'Camp Chase Trail': 4508,
#  'Sedibeng': 759,
#  'Lake Louise': 14009,
#  "Praia D'El Rey": 20,
#  'Mardana': 1396,
#  'Davidson': 5450,
#  'August': 6037,
#  'Watsonville': 25659,
#  'Eco tourism': 24,
#  'Charlevoix michigan': 35,
#  'Nong Khai (province)': 23,
#  'Yulin (Guangxi)': 497,
#  'Bog': 602,
#  'Iris': 28,
#  'Hawera': 3309,
#  'Phillip Island': 10707,
#  'Mount Tai': 11637,
#  'Artyom': 2959,
#  'Prineville': 1772,
#  'Northern and western outskirts of Uppsala': 33,
#  'Caras Severin County': 19,
#  'Prague/West bank of Vltava': 15995,
#  'Chiufen': 20,
#  'Cape May': 25514,
#  'Hell (disambiguation)': 18,
#  'Devala': 1264,
#  'Helmstedt': 3596,
#  'Diving the Cape Peninsula and False Bay/Justins Caves': 10706,
#  'Sri petaling': 32,
#  'Dover (New Hampshire)': 9639,
#  'Salar de Uyuni': 18582,
#  'Katse': 20,
#  'Captain obvious': 55,
#  'Marquette (Iowa)': 815,
#  'Etawah': 3226,
#  'Laotian': 28,
#  'Lake Como': 16676,
#  'Golden Temple': 22,
#  'Diving the Cape Peninsula and False Bay/South Paw': 4851,
#  'Ls': 4315,
#  'Mexicali': 31261,
#  'Shelburne (Nova Scotia)': 1629,
#  'Punxsutawney': 3693,
#  'North (Canada)': 2960,
#  'Eastham': 22216,
#  'Karula National Park': 1986,
#  'Hecho': 1244,
#  'Robin Hood': 29,
#  'Issyk-Kul and the Tian Shan': 41,
#  'Shiga': 4700,
#  'Inner Hebrides': 4876,
#  'Agulhas National Park': 1532,
#  'Beichuan': 1732,
#  'Yukon (Oklahoma)': 959,
#  'Manning Park': 37,
#  'Joliet': 11755,
#  'Rodeo (event)': 478,
#  'Three Rivers': 6006,
#  'Tangomarkkinat': 22,
#  'Kura Araks Lowland': 32,
#  'Lamesa': 2507,
#  'STN': 36,
#  'Samsun': 14846,
#  'Far Eastern': 30,
#  'Italian lakes': 35,
#  'Dire-Dawa': 23,
#  'Sicilia': 20,
#  'Saintes Maries de la Mer': 1882,
#  'Opolskie Voivodship': 22,
#  'Travel videos': 32,
#  'Narragansett in the Winter': 26,
#  'Esmeraldas': 6934,
#  'Barcelona/Barceloneta': 36,
#  'Keminmaa': 18,
#  'Capena': 982,
#  'Arena football': 31,
#  'Fish Camp': 3551,
#  'Trebizond': 21,
#  'Vincentia': 1746,
#  'Kanye': 3787,
#  'Paris/10th arrondissement': 15209,
#  'Rancho Cucamonga': 6808,
#  'Northfield': 579,
#  'Nagoya (Batam)': 32,
#  'Pantellaeria': 25,
#  'Lhuentse': 696,
#  'Peterborough': 9761,
#  'Bowie': 11303,
#  'Southwest Florida': 15749,
#  'West Berlin': 20,
#  'Welwyn Garden City': 6678,
#  'Sturbridge': 27862,
#  'Manual of Style': 40,
#  'Cromwell': 731,
#  'Yarrawonga Mulwala': 32,
#  'Khewra Salt Mine': 2793,
#  'Cypress': 5270,
#  'Escanaba': 2623,
#  'GR 20': 3316,
#  'Nang Rong': 4876,
#  'Alvdalen': 1875,
#  'Assisi': 14095,
#  'Kien Giang': 30,
#  'Yarmouth (Maine)': 2167,
#  'Monza': 4654,
#  'Nantwich': 9028,
#  'Kruger National Park/Olifants': 34,
#  'Southern Streymoy': 617,
#  'Kemi': 8662,
#  'Surrey County': 2216,
#  'Superior (Montana)': 1486,
#  'Scarborough (Tobago)': 47,
#  'Webster': 860,
#  'Offenbach am Main': 23,
#  'Bali Township': 27,
#  'Fair Haven Disambiguation': 24,
#  'Ukhahlamba Drakensberg': 7845,
#  'Towada-Hachimantai National Park': 10161,
#  'Lesotho': 29359,
#  'Funafuti': 3332,
#  'Morenci': 256,
#  'Bechatow': 1630,
#  'San Francisco/Richmond': 39,
#  'Panzano': 19,
#  'Mactan Island': 24,
#  'Southeastern France': 2124,
#  'Rankin Inlet': 16762,
#  'Santa Fe De Bogota': 20,
#  'Hunedoara County': 23,
#  'Foochow': 20,
#  'Fanwood': 1134,
#  'New Castle (Delaware)': 13550,
#  'Devon (Alberta)': 592,
#  'Off-highway vehicle riding in Oregon': 5026,
#  'Killorglin': 1830,
#  'Bac Trung Bo': 37,
#  'Patagonia (Arizona)': 8080,
#  'Jiangsu': 5513,
#  'Seti (zone)': 19,
#  'Gering': 25,
#  'Michigan': 26496,
#  'Bungmati': 1907,
#  'Natham - Abiramam': 36,
#  'Mackenzie Country': 3881,
#  'Lefkara': 3309,
#  'Richmond (Tasmania)': 2957,
#  "Hawke's Bay": 6135,
#  'Mongar': 1693,
#  'Centre du Quebec': 30,
#  'Glacier National Park': 64014,
#  'Grasslands National Park': 1877,
#  'Banda Acheh': 24,
#  'Clearlake': 4553,
#  'Lower Peninsula': 1265,
#  'Indian Sub-continent': 24,
#  'Niassa': 33,
#  'St. Charles, Missouri': 36,
#  'Eftimie Murgu': 2769,
#  'Carcasonne': 25,
#  'Braintree (Massachusetts)': 5541,
#  'Coast and Mayombe': 567,
#  'Davidson County': 31,
#  'Arlington (Washington)': 1175,
#  'Fleurieu Peninsula': 586,
#  'South Africa': 112969,
#  'Prien am Chiemsee': 6825,
#  'Portarlington': 5278,
#  'Washington (D.C.)/Takoma-Petworth': 45,
#  'Murdeshwara': 2817,
#  'Ruvo di Puglia': 1354,
#  'Veitshochheim': 4064,
#  'Charleston (West Virginia)': 17076,
#  'Bombay/Malad': 30,
#  'Blenheim (New Zealand)': 28220,
#  'Kanipakam': 1513,
#  'Dane County': 34,
#  'Norwalk': 328,
#  'Bratsk': 1560,
#  'Port Augusta': 9357,
#  'Custer State Park': 1177,
#  'Kosovska Mitrovica': 23,
#  'Kirishima National Park': 42,
#  'Pixley': 2900,
#  'Majorda': 22,
#  'Marijampole': 563,
#  'South orange': 26,
#  'Istanbul/Golden Horn': 18190,
#  'Low cost flights': 36,
#  'Sipadan Island': 21,
#  'Swabi': 32,
#  'Kunene': 30,
#  'Kulpsville': 908,
#  'Suomenlinna': 34,
#  'Manovo Gounda St Floris National Park': 52,
#  'Hammerfest': 4253,
#  'Chittur': 3949,
#  'Culiacan Rosales': 22,
#  'Vulcano': 5278,
#  'Southeast Arizona': 31151,
#  'Time zones': 18827,
#  'Traveling with pets': 34,
#  'Manville (New Jersey)': 6170,
#  'Indian Pacific Railway': 58,
#  'Swanzey': 581,
#  'Waldo County': 3757,
#  'Zonguldak': 2000,
#  'Rio de Janeiro/Zona Oeste': 11575,
#  'Sangha and Likouala': 1095,
#  "O'Fallon (Illinois)": 2938,
#  'Houston/West Houston': 4367,
#  'Chamarajanagar (district)': 5426,
#  'Mindong phrasebook': 11956,
#  'Skaraborg': 31,
#  'Mu Ko Surin National Park': 1848,
#  'Penlee House': 22,
#  'West Chester (Pennsylvania)': 16748,
#  'New York City/Bronx': 19,
#  'Sutter County': 433,
#  'Ounasvaara': 23,
#  'Baoting': 1473,
#  'Port Angeles': 7039,
#  'Northumbria': 32,
#  'Qasr Amra': 1402,
#  'Newton-le-Willows': 1735,
#  'Ankola': 1047,
#  'Lester B Pearson International Airport': 51,
#  'Carlsbad Caverns': 44,
#  'Upper Takutu-Upper Essequibo': 32,
#  'Northern Tunisia': 1968,
#  'Tornedalen': 31,
#  'Trains in Sweden': 43,
#  'Hale': 24,
#  'Tegernsee': 8083,
#  'Southern Armenia': 13119,
#  'Limestone (disambiguation)': 23,
#  'Santa Cruz de la Sierra': 40,
#  'Gunung Mulu National Park': 11981,
#  'Sycamore': 3651,
#  'Pago Pago, American Samoa': 22,
#  'La Coruna': 21,
#  'Southwestern Indiana': 651,
#  'Frisian phrasebook': 37,
#  'Annur': 2491,
#  'Chicago/Near West side': 36,
#  'Muang Ngeun': 2164,
#  'Map showing Mexico Jalisco Chapala': 21,
#  'Skokloster': 22,
#  'Minca': 614,
#  'Colorado Bend State Park': 5630,
#  'Manchester (New Hampshire)': 27494,
#  'Munster (Ortze)': 36,
#  'Cheb': 3838,
#  'Northern Coast (Puerto Rico)': 737,
#  'Capurgana': 6881,
#  'Vire': 831,
#  'Charlestown (Saint Kitts and Nevis)': 19,
#  'Chem': 3934,
#  'Franeker': 2541,
#  'Chelmsford (England)': 30295,
#  'Geelong': 10708,
#  'Williams, California': 35,
#  'Pontiac (Michigan)': 1951,
#  'Vale dos Dinossauros': 861,
#  'Tohoku': 9983,
#  'Ethiopia': 55052,
#  'Yala (province)': 18,
#  'Mount Pleasant, MI': 39,
#  'Ski': 1782,
#  'Budoni': 1507,
#  'Pontal do Parana': 5992,
#  'Elmina': 5841,
#  'Llanrwst': 2059,
#  'Oakland (Maine)': 1122,
#  'Erechim': 4122,
#  'Tok Pisin phrasebook': 20875,
#  'Marshfield (Missouri)': 2349,
#  'Copper Canyon National Park': 27,
#  'Adilabad': 4471,
#  'Lewistown': 319,
#  'Rottweil': 4111,
#  'Berlin/Schoneberg': 30,
#  'North Africa': 5441,
#  'Montejaque': 3759,
#  'Swieradow-Zdroj': 889,
#  'Altamonte Springs': 3723,
#  'Buying a car in Australia': 34,
#  'Montgomery (Ohio)': 996,
#  'Saitama prefecture': 34,
#  'Natural Bridge State Park': 9650,
#  'Olean': 636,
#  'Mid-Atlantic': 25720,
#  'Upplands-Bro': 43,
#  'East Central Saskatchewan': 34,
#  'Rehoboth': 2467,
#  'Roccella Ionica': 2287,
#  'Connemara': 7920,
#  'Hakka Tulou': 29,
#  'Ostrava': 21177,
#  'Chainat town': 22,
#  'James River Plantations': 1879,
#  'Nederland (Colorado)': 1064,
#  'Gumusluk': 3748,
#  ...}

# %% [markdown]
# __Check out some articles with short lengths__

# %%
articles_dict['Berneray (disambiguation)']
# Out:
# {u'id': u'3554',
#  u'ns': u'0',
#  u'revision': {u'comment': u'/* United Kingdom */ Add Great Bernera',
#   u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#   u'format': u'text/x-wiki',
#   u'id': u'2592780',
#   u'model': u'wikitext',
#   u'parentid': u'2381967',
#   u'sha1': u'bz5yrk7qxjzi4c711uuyt1lmwgfk9u5',
#   u'text': {u'#text': u"{{pagebanner|Disambiguation banner.png|pgname=Berneray}}\nThere's more than one place called '''Berneray''':\n\n=== [[United Kingdom]] ===\n\n* [[Berneray]] (Bhe\xe0rnaraidh) - one of two inhabited islands in the Sound of Harris, to the north of [[North Uist]] in the [[Outer Hebrides]], [[Scotland]]\n\n* [[Berneray (Barra Head)]] - an uninhabited island, and the southernmost part of the [[Outer Hebrides]], [[Scotland]]\n\n* [[Great Bernera]] - is in an island off the northwest coast of [[Lewis]] in the [[Outer Hebrides]]. \n\n[[WikiPedia:Berneray]]\n\n{{disamb}}",
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2014-05-25T16:33:55Z'},
#  u'title': u'Berneray (disambiguation)'}

# %%
df_article_lengths = pd.DataFrame(article_lengths_dict.items(), columns = ['title', 'length'])

# %% [markdown]
# __Plot histogram to see the distribution of articles by length.__

# %%
condition1 = df_article_lengths['length'] < 10000
df_article_lengths[condition1].hist(bins=100);

# %%
### STUDY HOW MANY CHARS ARTICLES HAVE.
condition2 = df_article_lengths['length'] < 500
df_article_lengths[condition2].hist(bins=10)

## IT CAN BE SEEN THAT THERE ARE ABOUT 17,000 ARTICLES LESS THAN 200 CHARACTERS.
## ARTICLES WITH LESS THAN 200 WORDS WOULD MEAN THEY DON'T HAVE GOOD DESTINATION DESCRIPTONS OR ARE AMBIGUOUS DESTINATIONS, MEANING THEY AREN'T
## POPULAR DESTINATIONS.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1088a1e10>]], dtype=object)

# %%
condition3 = df_article_lengths['length'] < 200
df_article_200_char_plus = df_article_lengths[-condition3]

# %%
final_titles = df_article_200_char_plus['title']

# %%
final_titles.head(10)
# Out:
# 1                     Szczecin
# 2             San Juan Islands
# 3                        Rugia
# 4                New Australia
# 6                        Nampa
# 7     Jamaica (disambiguation)
# 8                      Hyanger
# 9         Xigatse (prefecture)
# 10                York (Maine)
# 12                       Fulda
# Name: title, dtype: object

# %%
final_dict = {}
for title in final_titles:
    final_dict[title] = unicodedata.normalize('NFKD', articles_dict[title]['revision']['text']['#text']).encode('ascii','ignore')
final_dict
print len(final_dict)
# Out:
# 25916

# %%
final_dict['Paris']
# Out:
# '{{pagebanner|Paris banner.jpg|dotm=yes|unesco=yes}}\n{{otheruses}}\n{{printDistricts}}\n[[Image:Paris, France.jpg|thumb|300px|Paris and the river Seine]]\n\n\'\'\'[http://www.parisinfo.com/ Paris]\'\'\', the cosmopolitan capital of [[France]], is one of the largest agglomerations in [[Europe]], with 2.2&nbsp;million people living in the dense (105&nbsp;km2) central city and almost 12&nbsp;million people living in the metropolitan area. In the north of the country on the river Seine, Paris has the reputation of being the most beautiful and romantic of all cities, brimming with historic associations and remaining vastly influential in the realms of culture, art, fashion, food and design.  Dubbed the \'\'\'City of Light\'\'\' (\'\'la Ville Lumiere\'\') and \'\'\'Capital of Fashion\'\'\', it is home to some of the world\'s finest and most luxurious fashion designers and cosmetics, such as \'\'Chanel\'\', \'\'Christian Dior\'\', \'\'Yves Saint-Laurent\'\', \'\'Guerlain\'\', \'\'Lancome\'\', \'\'L\'Oreal\'\', and \'\'Clarins\'\'. A large part of the city, including the River Seine, is a [[UNESCO World Heritage List|UNESCO World Heritage Site]]. The city has the second highest number of Michelin-restaurants in the world (after [[Tokyo]]) and contains numerous iconic landmarks such as the \'\'\'Eiffel Tower\'\'\', the \'\'\'Arc de Triomphe\'\'\', the \'\'\'Notre-Dame Cathedral\'\'\', the \'\'\'Louvre Museum\'\'\', \'\'\'Moulin Rouge\'\'\', \'\'\'Lido\'\'\', making it one of the most popular international tourist destinations in the world, with around 14 million tourists annually.\n\n==Districts==\nThe city of Paris itself is officially divided into 20 districts called \'\'arrondissements\'\', numbered from 1 to 20 in a clockwise spiral from the centre of the city (which is known as \'\'Kilometre Zero\'\' and is located at the front of Notre Dame).  \'\'Arrondissements\'\' are named according to their number. You might, for example, stay in the "5th", which would be written as \'\'5e\'\' in French. The 12th and 16th arrondissements include large suburban parks, the \'\'Bois de Vincennes\'\', and the \'\'Bois de Boulogne\'\' respectively.\n\nThe very best map you can get for Paris is called "\'\'Paris Pratique par Arrondissement\'\'" which you can buy for about 5 at any news stand.  It makes navigating the city easy. The various tourist information centres and hotels in Paris also provide various city and metro maps for free and which contain all the essential details for a tourist.\n\nEach \'\'arrondissement\'\' has its own unique character and selection of attractions for the traveller:\n\n[[Image:Paris overview map with listings 2.png|thumb|650px|The Layout of Paris by district]]\n\n*\'\'\'[[Paris/1st arrondissement|1st (1<sup>er</sup>)]]\'\'\'. The geographical centre of Paris and a great starting point for travellers. The \'\'Musee du Louvre\'\', the \'\'Jardin des Tuileries\'\', \'\'Place Vendome\'\', \'\'Les Halles\'\' shopping centre, \'\'Palais Royal\'\', \'\'Comedie-Francaise\'\', \'\'theatre du Chatelet\'\', \'\'Arc de Triomphe du Carrousel\'\', and the western half of \'\'Ile de la Cite\'\' (Paris\'s largest island).\n\n*\'\'\'[[Paris/2nd arrondissement|2nd (2<sup>e</sup>)]]\'\'\'. The central business district of the city  the \'\'Bourse\'\' (the Paris Stock Exchange), \'\'Opera-Comique\'\', \'\'Theatre des Varietes\'\', \'\'Passage des Panoramas\'\', \'\'Theatre des Bouffes Parisiens\'\' and the former \'\'Bibliotheque Nationale\'\' are here.\n\n*\'\'\'[[Paris/3rd arrondissement|3rd (3<sup>e</sup>)]]\'\'\'. \'\'Archives Nationales\'\', \'\'Musee Carnavalet\'\', \'\'Conservatoire des Arts et Metiers\'\', \'\'Hotel de Soubise\'\', the former \'\'Temple\'\' fortress, and the northern, quieter part of the \'\'Marais\'\'.\n\n*\'\'\'[[Paris/4th arrondissement|4th (4<sup>e</sup>)]]\'\'\'. \'\'Notre-Dame de Paris\'\', the \'\'Hotel de Ville\'\' (Paris city hall), \'\'Hotel de Sully\'\', \'\'Beaubourg\'\', \'\'Rue des Rosiers\'\'  ...

# %%
def clean_paragraph(string):
    # get rid of https:
    m = re.sub(r'(https?://\S+\ +\S+)', '', string)
    # get rid of [File:stuff]
    m = re.sub(r'\[File:[^)]*\]','', m)
    # get rid of ==stuff==
    m = re.sub(r'(\=+[^)]+\=+)','', m)
    #get rid of ], [, '. E.g. [[Paris]] --> Paris
    m = re.sub(r'[\[\]\']','',unicodedata.normalize('NFKD', m).encode('ascii','ignore')).strip()

    return m

# %%
test = mistune.markdown(final_dict['Szczecin'])

# %%
parsed_test = BeautifulSoup(test)

# %%
parsed_test
# Out:
# <html><body><p>{{pagebanner|Szczecin Wikivoyage Banner.png}}</p>
# <p>'''[<a href="http://www.szczecin.eu/en/">http://www.szczecin.eu/en/</a> Szczecin]''', (pronounced ''Shchetsin'', German: ''Stettin'', Latin: ''Stetinum''; is maritime port city and the capital of [[Zachodniopomorskie]] in [[Poland]]. The city has a population of over 400 000 thousand, with almost 800 000 living its metro area, and is one of the seven largest metropoles in the country. It lies in the northwestern corner of Poland, very close to the German border, and it is in fact easier to get to Szczecin from some parts of Germany, notable from [[Berlin]], than it is from much of the Polish territory. For a significant part of its history, actually, Szczecin was a part of Germany, as well as, in other periods, of Denmark and Sweden.</p>
# <p>Szczecin is Poland's third-largest port and much of its industrial base used to be a part of an important shipyard, so it may come as a surprise to the casual tourist that the city does not lay on a seaside, but rather over the river Odra (German: ''Oder''), some 20 kilometres south of the Baltic Sea as the crow flies, and many more by road. Many visitors to Poland are also unaware of Szczecin's architectural attractiveness, as the large parts of the city were designed by Baron Haussmann, the same gentleman who designed the boulevards of [[Paris]].</p>
# <p>==Understand==
# The place now known as Szczecin was first mentioned in written history in 1st century when West-Roman historian Tacitus located East Germanic tribe of Rugians somewhere in the area; the Rugians left in 5th Century during the Great Migration. Sometime in the 8th century Western Slavic tribe of Pomeranians built their stronghold here. In 10th century the town was mentioned as "one of major in Pomerania" in Abraham ben Jacob's chronicle. In approximately 1080 its area was incorporated into [[Poland]], but within eight years, the town was controlled by the Dukedom of Pomerania, and five years later, [[Denmark]]. In 12th century when its competitor, [[Wolin]] (also known as Veneta in medieval chronicles) declined Szczecin began to prosper from trade and became one of the major Baltic sea harbours. Its name was first recorded in 1133 as "Stetin".</p>
# <p>In 1181 Pomeranian dukes joined Holy Roman Empire. In 1243 Szczecin got city rights before it became member of the Hanseatic League in 1278. Until early 17th century the city was the capital of Pomeranian Dukedom, then in 1630 when local dukes died out it became part of [[Sweden]],  then Kingdom of Prussia, then for a brief period, due to Napoleon's conquests, the Empire of [[France]]. Beginning in the 18th century, the city constituted as a part of [[Germany]] and served as the "port of Berlin". During World War II the city was hit hard by Allied bombers - city centre, Old Town and industrial areas were totally ruined. After the Soviet forces invaded Nazi Germany in 1945, according to Potsdam Conference agreements Poland annexed all lands up to the Oder river, expelling the native German population and ultimately extending the border to include Stettin. Poland thus gained control of the city.</p>
# <p>In more recent history, the city was (together with [[Tricity]]) one of the birthplaces of Solidarity movement.</p>
# <p>An unusual feature of Szczecin is its urban planning - many roundabouts and wide avenues. Stettin was rebuilt in 1880's using designs by Georges-Eugene Haussmann, who also did the urban planning for [[Paris]]. His design style is still being used for newly-built (or modified) city areas.</p>
# <p>The maritime industry is still strong with a busy port and repair shipyard, as well as being a center of service industries in Poland. Situated near the border between Germany and Poland, Szczecin is sometimes considered one of most liberal Polish cities.</p>
# <p>==Get in==</p>
# <p>===By plane===</p>
# <p>Szczecin-Goleniow airport (SZZ) [<a href="http://www.airport.com.pl/en/show/start-page">http://www.airport.com.pl/en/show/start-page</a>] is located almost 50 km from the city centre, near Goleniow.</p>
# <ul>
# <li>Ryanair operates daily flights between Szczecin and [[London]] (Stansted), and 2 flights per week to and from [[Dublin]] and [[Liverpool]].</li>
# <li>LOT has several flights daily between Szczecin and [[Warsaw]]. Note that cancellations do happen, so take that into account when planning onward travel. </li>
# <li>Eurolot [<a href="http://eurolot.com">http://eurolot.com</a>] has flights from Szczecin to [[Krakow]] (both direct and via [[Poznan]], 4 times a week) and to [[Rzeszow]] (twice a week).</li>
# <li>Norwegian operates two flights per week between Szczecin and both [[Trondheim]] and [[Oslo]].
# You can reach the airport by car (the journey may take up to 1 hour, depending on traffic), by taxi (about 120 PLN), or by minibus - LOT operates a minibus to and from the airport for all LOT's flights (free of charge for passengers), leaving from LOT's office (al. Wyzwolenia 17) about 90 minutes before departure, and Interglobus has minibuses for all international flights. In July 2013, a railway service linking the airport's terminal directly with Szczecin's main railway station and with [[Koobrzeg]] was inaugurated.</li>
# </ul>
# <p>Due to Szczecin's proximity to [[Berlin]], you may use the latter's airports to get to Szczecin as well. From there, you can reach Szczecin by minibus (numerous Szczecin-based companies, including Atlastransfer - Berlinia.eu [<a href="http://berlinia.eu/en/">http://berlinia.eu/en/</a>]  and Interglobus [<a href="http://www.interglobus.pl/_Interglobus.aspx">http://www.interglobus.pl/_Interglobus.aspx</a>], operate regular services to Tegel and Schoenefeld airports at attractive prices), by car or by train in 23 hours.</p>
# <p>===By train===</p>
# <p>Polish State Railways (PKP) [<a href="http://www.pkp.pl/">http://www.pkp.pl/</a>] has connections to and from all major Polish cities. There are several trains daily to and from [[Warsaw]] - travel time on express or Intercity trains is less than 6 hours, but minor delays are not uncommon. To [[Poznan]], travel time is about 2.5 hours (from PLN 40), with frequent trains running throughout the day. There are also frequent trains to [[Swinoujscie]] (2 hours).</p>
# <p>German Railways [<a href="http://www.bahn.de">http://www.bahn.de</a>] has train connections from [[Berlin]], [[Amsterdam]], [[Prague]] and many cities in neighboring [[Mecklenburg-Western Pomerania]].</p>
# <p>The cheapest way to get to [[Berlin]] is by joining a group of up to 5 people riding on one Berlin-Brandenburg Ticket, which is valid from 9 am to 3 am the following day for travel on all local and regional German trains and on local public transport systems in all cities and towns, including Berlin and Szczecin. The ticket costs 28 euros, so one person can travel for ca. 5 euros. The groups often form spontaneously before departure or on the train itself. There is also the new Berlin-Stettin-Ticket for 10 Euros per person one way.</p>
# <p>Berlin-Stettin-Ticket, Brandenburg-Berlin-Ticket, Brandenburg-Berlin-Ticket Nacht, Mecklenburg-Vorpommern-Ticket, and Schones-Wochenende-Ticket are valid for routes to and from the city of Szczecin and for the entire public transport system in Szczecin.</p>
# <p>You even can get from or to the Danish border via Schleswig-Holstein-Ticket, valid in the regional trains of Mecklenburg-Vorpommern, Hamburg, Schleswig-Holstein until Padborg or Tonder (DK) with a surcharge of 2,50 for the ride from the Polish border to Szczecin.</p>
# <p>===By car===
# You can reach Szczecin by car from major Polish cities, including [[Warsaw]], [[Poznan]], [[Gdansk]], [[Wrocaw]], and also from [[Berlin]]. Thanks to its location close to the border and direct link with the German motorway system, Szczecin has the best road connection with Western Europe of all Polish cities.</p>
# <p>The main route to Szczecin from Berlin is the E28 (German: A11, Polish: A6). The journey takes about 2 hours, depending on traffic. Note that the German A11 motorway is undergoing continuous improvements, resulting in some disturbances in certain sections.</p>
# <p>Travelling by car to and from other parts of Poland can be troublesome - the traffic is pretty heavy, the distances are large and there is a general shortage of motorways. It also takes quite some time - for example, the trip to Gdansk (350 km) usually takes 45 hours, and to Warsaw (520 km along national road no. 10) you need at least 67 hours, even if you don't follow the speed limits too strictly.</p>
# <p>You can also reach Szczecin from [[Sweden]] ([[Ystad]]) and [[Denmark]] ([[Copenhagen]]) using the ferry connections to and from [[Swinoujscie]]. From there, the journey takes about 1.5 hours, although this road gets completely jammed on summer weekends. To avoid traffic jams in high season, follow the yellow "tourist route" ("Trasa turystyczna") signs. These will take you along B-roads, bypassing the most crowded section of national road no.3.</p>
# <p>===By bus===</p>
# <p>Many international and domestic connections (see [[Poland#By bus|Poland::By bus]]).</p>
# <ul>
# <li>[<a href="http://www.pks.szczecin.pl/">http://www.pks.szczecin.pl/</a> PKS Szczecin] operates daily connection with [[Schwedt]] in [[Germany]]</li>
# <li>dozens of minibus operators driving to and from [[Berlin]]</li>
# </ul>
# <p>===By boat===
# Szczecin is situated on the banks of the Oder (Polish: ''Odra'') and Regalica (branch of the Oder) rivers and Lake Dabie, near the Szczecin Lagoon. There is a number of marinas, most of them situated in the northern districts and on the shores of Lake Dabie.</p>
# <p>In April 2008, hydrofoil service was re-established between Szczecin and Swinoujscie.  Bosman-Express [<a href="http://www.wodolot-szczecin.pl">http://www.wodolot-szczecin.pl</a>] hydrofoil runs twice a day from the Way Chrobrego embankment, reaching Swinoujscie in about 75 minutes. Tickets are a bit overpriced at PLN 50/70 (economy/VIP class - but don't expect any luxury), and there are discounts for children and groups. There is a snack-bar on board, beer is served. There is also a small viewing deck. Along the way you can see some quite interesting industrial sights in the northern part of Szczecin.</p>
# <p>Despite being a restored Soviet-made Meteor, now equipped with new engines, the hydrofoil is the quickest way to get to Swinoujscie - it moors at the left (western) bank of the Swina, so the passengers avoid the need to use the ferry.</p>
# <p>==Get around==
# Szczecin is split in two parts (Lewobrzeze and Prawobrzeze) named after their location on banks of Oder (Lewobrzeze = left bank) and Regalica (Prawobrzeze = right bank) rivers. The port is situated in between. City centre and most of attractions are situated in Lewobrzeze.
# [[Image:SzczecinFacades.jpg|thumb|Facades in new old town]]</p>
# <p>===Public transport===
# Szczecin has extensive public transport network covered by trams and buses. See the maps [<a href="http://www.zditm.szczecin.pl/schematy.php">http://www.zditm.szczecin.pl/schematy.php</a>] (''dziennej'' = by day, ''nocnej'' = by night, ''tramwajowej'' = trams) and schedules [<a href="http://www.zditm.szczecin.pl/rozklady/">http://www.zditm.szczecin.pl/rozklady/</a>]. You can also install the timetables on your mobile phone: for J2ME compatible phones and Symbian: MPK Mobile [<a href="http://www.mmpk.info/">http://www.mmpk.info/</a>], Microbus [<a href="http://www.microbus.szczecin.pl/">http://www.microbus.szczecin.pl/</a>], for Android and Windows Phone: Transportoid [<a href="http://transportoid.com/">http://transportoid.com/</a>].</p>
# <p>====Tickets====
# Tickets are randomly checked by plain clothed inspectors; fines are severe and can be a major hassle, so it's better for you to buy them. They are available at all newspaper stands and you can buy them from the driver after 18:00. If you happen to have an account in Polish bank you can also use your mobile phone [<a href="http://www.mobilet.pl/home.htm">http://www.mobilet.pl/home.htm</a>]. Rush hours are 7:00-8:00 and 16:00-17:00, night hours are between 23:00 and 5:00. Tickets for express buses are twice expensive. You can change between lines freely as long you stay within time limit (the exception is changing from "normal" bus or tram to express bus). Prices:</p>
# <ul>
# <li>15 minutes: 2.00 z</li>
# <li>30 minutes: 3.00 z</li>
# <li>1 hour: 4.00 z</li>
# <li>2 hours: 5.00 z</li>
# <li>24 hours: 12 z</li>
# <li>5 days: 35 z</li>
# <li>Family weekend ticket: 14 z - valid on weekends for one or two adults with at least one child up to 16 years old.</li>
# </ul>
# <p>There are also tickets valid for 10 days, a month and a quarter.</p>
# <p>'''Remember to stamp your ticket immediately after you board the tram/bus!'''</p>
# <p>Brandenburg-Berlin, Mecklenburg-Vorpommern, Schleswig-Holstein, Schones Wochenende and Brandenburg-Berlin Nacht tickets issued by Deutsche Bahn are valid for public transport operated by ZDiTM (trams and buses) in Szczecin. Monthly/quarterly tickets issued by ZDiTM are valid for DB trains within the city (Szczecin Gowny-Szczecin Gumience) [<a href="http://bip.um.szczecin.pl/files/3574D615E29E43F6A5E0E6FB0A7F6DCC/876-05.pdf">http://bip.um.szczecin.pl/files/3574D615E29E43F6A5E0E6FB0A7F6DCC/876-05.pdf</a>].</p>
# <p>====Lines====</p>
# <ul>
# <li>0 - tourist tram line</li>
# <li>1-12 - trams</li>
# <li>50, 100 - tourist bus lines</li>
# <li>51-111 - buses</li>
# <li>A, B, C, D, E, F, G - express buses</li>
# <li>521-534 - night buses</li>
# <li>7xx - free buses (to and from shopping malls)</li>
# </ul>
# <p>====Tourist lines====</p>
# <ul>
# <li>Tourist lines (vintage trams and buses) operate in July and August on Saturdays and Sundays. The fare costs 3 z (paid to the driver). Line numbers: 0 (tram), 50 and 100 (buses).</li>
# </ul>
# <p>====Railway====
# If for any reason you want to go to or from the city centre (station name: Szczecin Gowny) to districts of Dabie, Gumience, Podjuchy, Zdroje, Zdunowo or Zaom (or nearby suburban towns of [[Goleniow]], [[Gryfino]] or [[Stargard]]), the fastest way might be the train. Check times with  PKP [<a href="http://www.pkp.com.pl">http://www.pkp.com.pl</a>]; you have to buy separate ticket (6 z, one way, no matter how many stops), the exception are trains operated by DB (see above).</p>
# <p>===By foot===
# City center can be covered by foot (depending on your fitness, etc.). Look for the red line on the pavements - so called "red walk" which connects nearly all the attractions within the centre. This is by far the best way to discover the centre on foot, as all attractions are marked by a number (there are about 40) on the pavement, so you won't miss one. At each of them there is a sign explaining some details about the sight.
# The red line starts and ends at the train station. When you exit through the main entrance, turn left on the sidewalk and look for it, some of the paint may have already vanished. Close to the start is also a map showing the route and the attractions. You can get a similar map that also includes the red line at the tourist information center.
# [[Image:SquareInNewOldSzczecin.jpg|thumb|Museum at new old town]]</p>
# <p>===By car===
# Streets in Szczecin are (compared to other Polish cities) easy to navigate and not congested.</p>
# <p>However: parking within the centre during business hours (8:00 - 17:00, from Monday to Friday - after 17:00 and on weekends it is free) is paid; the pay depends on the zone and parking time. You can buy tickets from vending machines. Most of malls have free parking, and no one will check if you visited the mall or just used free parking opportunity.</p>
# <p>DUI is serious criminal offense (up to 3 years in prison) and the police have no mercy for drunk drivers - many of "zero tolerance for drunk drivers" programs ongoing in Poland have started in Szczecin.</p>
# <p>'''Because of major renovation works in the city centre and Niebuszewo district held this year expect detours and/or traffic jams, especially during rush hours. If you stay in the city consider leaving your car on parking and using public transport.'''</p>
# <p>===By bicycle===
# There is network of [[cycling|bicycle]] paths connecting the city center with the suburbs. You can take your bike on public transport for free (outside rush hours).
# If you want to see Szczecin from the bicycle but don't have one you can rent it:</p>
# <ul>
# <li>Bicyklownia [<a href="http://www.bicyklownia.pl/">http://www.bicyklownia.pl/</a>], ul. Wielkopolska 15, tel. +48784152358. (near City Park)</li>
# <li>Biker [<a href="http://www.biker.szczecin.pl/">http://www.biker.szczecin.pl/</a>], ul. Swietego Ducha 2a, tel. +48506667400 (Center)</li>
# <li>Centrum Wynajmu i Turystyki [<a href="http://www.centrumwynajmu.pl/ang/bike_pl.htm">http://www.centrumwynajmu.pl/ang/bike_pl.htm</a>], ul. Kolumba 1/6m, tel. +48914340006 (near Szczecin Gowny railway station]
# If you happen to be present in Szczecin on any last Friday of the month, feel free to join the Critical Mass - the start point is Plac Lotnikow square, 6:00 pm.</li>
# </ul>
# <p>===Taxi===</p>
# <ul>
# <li>Hail taxi cab from the street or stand only in emergency or if very tired/drunk! It is much cheaper to call for one - ask locals for numbers or see taxi advertisements, they are nearly everywhere. When you call, ask the operator when the taxi will arrive and then look for car plastered with number of company you called.</li>
# <li>There is taxi "mafia" operating from stands near railway station, popular clubs, hotels etc. - avoid these rip-offs, they are VERY expensive!</li>
# <li>Taxi fare within the centre shouldn't cost you more than about 12-15 z. Fare from left side of the river (Lewobrzeze) to the right side (Prawobrzeze) or the other way is about 40-50 z. Fares during the night are slightly more expensive.</li>
# <li>All officially registered taxis have meters, the driver should turn them on just after you enter.</li>
# <li>Payment: have cash ready, only the minority of taxi drivers have necessary equipment for payments with debit or credit cards. Ask if in doubt.</li>
# </ul>
# <p>Some of taxi companies operating in the city:</p>
# <ul>
# <li>Auto Taxi: +48 91 4535555</li>
# <li>City Taxi: +48 91 4335335</li>
# <li>Express Taxi: +48 91 4261038</li>
# <li>Euro Taxi: +48 91 4343434</li>
# <li>Gold Taxi: +48 91 8122222</li>
# <li>Granada Taxi: +48 91 4554554</li>
# <li>Szczecin Taxi: +48 91 4835835</li>
# </ul>
# <p>==See==
# [[Image:SzczecinCastle.jpg|thumb|Castle]]
# [[File:PolandSzczecinPortGate.JPG|thumb|Harbour Gate (Brama Portowa)]]</p>
# <ul>
# <li>Pomeranian Dukes Castle [<a href="http://www.zamek.szczecin.pl/">http://www.zamek.szczecin.pl/</a>] (''Zamek Ksiazat Pomorskich''), which houses museum, restaurants and cafes. It also houses tourist information office, you can get some free maps, pamphlets etc. here.</li>
# <li>Old Town (''Stary Rynek'') - despite being jokingly referred to by locals as "Brand New Old Town" (it was started to be rebuilt in late 1990s, the reconstruction is still ongoing), there are some nice houses rebuilt to original plans. Many shops, restaurants and cafes. There is museum situated in Old Town Hall.</li>
# <li>Kamienica Loitzow (''Loitzs Tenement'') - interesting tenement just next to Old Town. Go from Old Town in direction of Castle, and you'll see it after about 2030 meters on the left side. It is painted flashy orange, you can't miss it.</li>
# <li>Way Chrobrego (German name: ''Hakenterrasse'') - promenade with great views on Oder river and port. Many cafes are situated here. See the museum (''Muzeum Morskie''), situated just in the center of Waly which houses some artifacts from history of the city and also has big collections of African and maritime artifacts.</li>
# <li>Katedra sw. Jakuba (''St. Jacob's Cathedral'') - big Gothic cathedral.</li>
# <li>Park Kasprowicza - city park, place for all kinds of physical activities by locals, spreading through nearly all of the city. Just behind the City Council.</li>
# <li>Park Zeromskiego - another city park, situated in the very center of the city between Waly Chrobrego and Pazim/Galaxy.</li>
# <li>Cmentarz Centralny [<a href="http://www.cmentarzcentralny.szczecin.pl/">http://www.cmentarzcentralny.szczecin.pl/</a>] - third biggest cemetery in Europe.</li>
# <li>S-1 blast &amp; fallout shelter [<a href="http://www.podziemnyszczecin.com/">http://www.podziemnyszczecin.com/</a>] - biggest in Poland (entry 15 z). Two tours to choose: WWII or Cold War.</li>
# <li>Pionier Cinema [<a href="http://www.kino-pionier.com.pl">http://www.kino-pionier.com.pl</a>] - oldest cinema in the world still in operation (est. 1909) [<a href="http://www.kino-pionier.com.pl/img/certy.jpg">http://www.kino-pionier.com.pl/img/certy.jpg</a> [2]].</li>
# <li>Railway suspension bridge on Regalica - something for railway fans, the only one of a kind in operation in Poland. Podjuchy district, ul. Szklana Huta.</li>
# <li>Emerald Lake (''jezioro Szmaragdowe'') and Puszcza Bukowa - lake, artificial cave and forest area situated in Zdroje district. Many great views on the city and nice area for one day hiking/bike riding.</li>
# <li>Paac pod Globusem (''Palace under the Globe'' / ''Palace of Grumbkov'') - the building where two rulers of Russia (Catherine II and Maria Fiodorovna) were born. Pl. Ora Biaego.</li>
# <li>Parisienne Sub-Urb: Many historistic and art nouveau boulevards in prussian pseudo-parissienne style around Plac Grunwaldzki, Jagiellonska and Wielkopolska streets.</li>
# <li>Museum of Technology (''Muzeum Techniki'') [<a href="http://www.muzeumtechniki.eu/muzeumtechniki/chapter_88000.asp">http://www.muzeumtechniki.eu/muzeumtechniki/chapter_88000.asp</a>] - has nice collection of vintage cars, motorcycles, buses and trams. Niemierzynska 18A.</li>
# </ul>
# <p>==Do==</p>
# <ul>
# <li>See the panorama of Szczecin - from the cafe on top of Pazim building, just by Galaxy shopping center (admission free), from St.Jacob's Cathedral tower (paid admission) or from one of the towers of Pomeranian Dukes Castle.</li>
# <li>Take a trip through Szczecin's waterways and port - many boats go from the river bank near Way Chrobrego.</li>
# <li>Kayak through the city and lower Oder valley - if you don't have your kayak you can borrow one at Kapielisko Dziewoklicz (ul. Autostrada Poznanska, public transport - bus No. 61, stop "Dziewoklicz") or any of the neighbouring towns situated by the Oder river - look for ''wypozyczalnia kajakow'' (kayak rentals) or ''kajaki'' (kayaks).</li>
# <li>See ''dancing fountain'' near Teatr Pleciuga (ul. Wielkopolska). It might not be the most impressive fountain show in the world but still it's nice eyecandy and it's free. The show lasts 30 minutes and starts every summer day at 21:30.</li>
# </ul>
# <p>===Events===</p>
# <ul>
# <li>Juwenalia 1620 May</li>
# <li>Baltic Rock Meeting 25 May - 3 June</li>
# <li>Dni Morza / Days of the Sea [<a href="http://dnimorza.szczecin.eu/">http://dnimorza.szczecin.eu/</a>] June</li>
# <li>Boogie Brain Festival [<a href="http://www.boogiebrainfestival.pl/">http://www.boogiebrainfestival.pl/</a>] October</li>
# </ul>
# <p>==Learn==</p>
# <ul>
# <li>Maritime University of Szczecin [<a href="http://am.szczecin.pl">http://am.szczecin.pl</a>]</li>
# <li>University of Szczecin [<a href="http://www.us.szc.pl/">http://www.us.szc.pl/</a>]</li>
# <li>West Pomeranian University of Technology [<a href="http://www.zut.edu.pl/">http://www.zut.edu.pl/</a>]</li>
# <li>Pomeranian Medical University [<a href="http://www.pam.szczecin.pl/">http://www.pam.szczecin.pl/</a>]</li>
# <li>Academy of Arts [<a href="http://www.akademiasztuki.eu/">http://www.akademiasztuki.eu/</a>]</li>
# <li>West Pomeranian Business School [<a href="http://www.zpsb.szczecin.pl/">http://www.zpsb.szczecin.pl/</a>]</li>
# </ul>
# <p>==Work==
# English teachers and IT developers/engineers are in high demand.</p>
# <p>==Buy==
# Szczecin has many shopping malls:</p>
# <ul>
# <li>'''Auchan''' - situated in Ustowo. Don't go there if you don't have a car, the place is totally pedestrian unfriendly.</li>
# <li>'''Carrefour''' - situated near Media Markt (mall with electronics) in Pomorzany district. Open 8:00-21:00.</li>
# <li>'''CH Ster''' - situated near Castorama (big shop for DIY builders) in Gumience district, nearest mall from the German border. Open 8:00-21:00.</li>
# <li>'''CH Turzyn''' - another mall in the Center. Open 8:00-21:00.</li>
# <li>'''Kaskada''' - the newest and the biggest shopping mall in Szczecin, best brands and spacious foodcourt. Open 9:00-21:00.</li>
# <li>'''Galaxy''' shopping mall - many outlets of major brands. Situated in the Center,near Kaskada. Open 8:00-21:00.</li>
# <li>'''Tesco''' - another one, just across the street of the Carrefour mentioned above. Open 24/7.</li>
# </ul>
# <p>==Eat==</p>
# <p>===Fast Food===
# You will easily find global favorites like hamburgers, hot dogs, kebabs, pizza etc., but for unique Szczecin twist on fast food try ''paszteciki'' (plural, singular is ''pasztecik'') - which are kind of deep fried cake with meat or cheese and mushrooms filling. They taste best hot and combined with a cup of ''barszcz czerwony'' (red beetroot soup).</p>
# <p>===Budget===</p>
# <ul>
# <li>'''Turysta Milk Bar''', Obroncow Stalingradu 6a (open 7:30-18:30)</li>
# <li>'''Zacisze Bar''', Asnyka 19 (Niebuszewo district)</li>
# <li>'''Akademia Kulinarna''', Mickiewicza 45 (open 9:00-17:00)</li>
# <li>'''Bar Zen''', Bohaterow Warszawy (near CH Turzyn) - Vietnamese buddhist cuisine (vegan) (open 10:00-20:00)</li>
# </ul>
# <p>===Mid-range===</p>
# <ul>
# <li>'''Amar''', Slaska 9 (open Monday-Friday 11:00-19:00, Saturday &amp; Sunday 12:00-17:00) - vegan &amp; vegetarian. If you are on limited budget, order their "danie dnia" (dish of a day) and/or "zupa dnia" (soup of a day) which are always very affordable.</li>
# <li>'''Brama Jazz Cafe''', Plac Hodu Pruskiego 1 - Mexican &amp; fusion</li>
# <li>'''Camarillo''', Msciwoja 8 - fusion</li>
# <li>'''Green Way''', Krzywoustego 16 (open Monday-Friday 10:00-21:00, weekends 11:00-19:00) - vegetarian</li>
# <li>'''Golden Dragon''', Jana Kazimierza 21 - Chinese</li>
# <li>'''Mandaryn''', ul. Bolesawa Smiaego 27 - Chinese</li>
# </ul>
# <p>===Splurge===</p>
# <ul>
# <li>'''Bombay''', Partyzantow 1 - Indian</li>
# <li>'''Chief''', Rayskiego 16 - all kinds of sea food</li>
# <li>'''adoga''', Jana z Kolna - Russian</li>
# <li>'''Sake''', Piastow 1 - Japanese</li>
# <li>'''Sushi Mado''', Pocztowa 20 (entry from Bohaterow Warszawy) - Japanese</li>
# <li>'''Columbus''' - On Waly Chrobrego by Marine Academy</li>
# <li><p>{{eat
# | name=Chrobry | url=<a href="http://www.chrobrypub.pl/">http://www.chrobrypub.pl/</a> | email=chrobry@chrobrypub.pl
# | address=Waly Chrobrego 1B | lat= | long= | directions=by Provincial Government building
# | phone=+48 914880163 | tollfree= | fax=
# | hours= | price=PLN 40 for a main course
# | content=Good Polish food. Chrobry is located under a dome supported by pillars. There is a bar and a two-story restaurant below ground and also serving upstairs between the columns with a view over the Oder.
# }}</p>
# </li>
# <li><p>'''Colorado''' - on Waly Chrobrego by Polski Theatre</p>
# </li>
# <li>'''Karczma Polska''' - Lotnikow Square</li>
# <li>'''Szpilka''' - ul.Maopolska 45 - Delicious fusion</li>
# </ul>
# <p>==Drink==</p>
# <p>The majority of pubs and bars can be found in the old town (''Stary Rynek'') or around ul. Bogusawa in the middle town area.  Expect to pay between 6zl and 8zl for a large beer and around 6zl for a 50ml shot of vodka.</p>
# <p>*{{drink
# | name=Alter Ego | url=<a href="http://www.alterego.art.pl/">http://www.alterego.art.pl/</a> | email=
# | address=Pl. Batorego 4 | lat= | long= | directions=under the red town house, near bus and rail stations
# | phone= | tollfree= | fax=
# | hours=11:00-until the last client | price=
# | content=Restaurant during the day, live music and/or DJs on weekend nights.
# }}</p>
# <p>*{{drink
# | name=Boston Pub &amp; Club | url=<a href="http://www.bostonpub.com.pl">http://www.bostonpub.com.pl</a> | email=
# | address=Niepodlegosci 22 | lat= | long= | directions=city centre
# | phone= | tollfree= | fax=
# | hours= | price=
# | content=Every day parties! Music: 70's, 80's &amp; 90's. Karaoke Nights, Student Nights, Every Weekend Parties &amp; Afterparty till 6AM
# }}</p>
# <p>*{{drink
# | name=City Hall | url=<a href="http://www.cityhall.pl/">http://www.cityhall.pl/</a> | email=
# | address=ul. 3 maja | lat= | long= | directions=near the railway station
# | phone= | tollfree= | fax=
# | hours=21:00-last client | price=
# | content=Funk, hip-hop, house, etc.
# }}</p>
# <p>*{{drink
# | name=Free Blues Club | url=<a href="http://www.freebluesclub.pl/">http://www.freebluesclub.pl/</a> | email=
# | address=Powstancow Wielkopolskich 20 | lat= | long= | directions=Pomorzany District, trams 4, 11, 12
# | phone=+48914853161 | tollfree= | fax=
# | hours=19:30-until the last client | price=
# | content=Something for blues (and rock) fans - live music, jam sessions, etc.
# }}</p>
# <p>*{{drink
# | name=Hormon | url=<a href="http://www.hormon.pl/">http://www.hormon.pl/</a> | email=
# | address=ul. Pisudskiego | lat= | long= | directions=middle town area
# | phone=+48914341303 | tollfree= | fax=
# | hours=19:00-until the last client | price=
# | content=Very popular among the students; rock/alternative party every day, live music from time to time.
# }}</p>
# <p>*{{drink
# | name=Mezzoforte | url=<a href="http://www.mezzoforte.pl/">http://www.mezzoforte.pl/</a> | email=
# | address=ul. Bogusawa | lat= | long= | directions=pedestrian area
# | phone= | tollfree= | fax=
# | hours= | price=
# | content=Italian food restaurant during the day, DJ parties on weekends.
# }}</p>
# <p>*{{drink
# | name=Petit Paris | url=<a href="http://www.petitparis.eu/">http://www.petitparis.eu/</a> | email=
# | address=Sw. Wojciecha 11 | lat= | long= | directions=city centre
# | phone=+48692489167 | tollfree= | fax=
# | hours=12:00-24:00 | price=
# | content=Restaurant and bar owned by French expatriate. French food, nice collection of beers and quirky prices on menu (paying the decimal parts of 1 z is a part of experience).
# }}</p>
# <p>*{{drink
# | name=Piwnica Kany | url= | email=
# | address=Plac Piotra i Pawa 4/5 | lat= | long= | directions=across the main street from Pomeranian Dukes Castle, near Way Chrobrego
# | phone= | tollfree= | fax=
# | hours=15:00-last client | price=
# | content=Pub belonging to Kana alternative theatre, popular among students and artists (and theatre visitors). Has free wireless Internet (ask the bartender for the password).
# }}</p>
# <p>*{{drink
# | name=Rocker Club | url=<a href="http://www.rockerclub.pl/">http://www.rockerclub.pl/</a> | email=
# | address=Partyzantow 2 | lat= | long= | directions=The very city centre
# | phone= | tollfree= | fax=
# | hours=19:00-last client | price=
# | content=Live rock music, karaoke, you name it.
# }}</p>
# <p>*{{drink
# | name=Royal Jazz Club | url=<a href="http://www.royal.szczecin.pl/">http://www.royal.szczecin.pl/</a> | email=
# | address=Mariacka 26 | lat= | long= | directions=near the Pomeranian Dukes Castle
# | phone= | tollfree= | fax=
# | hours=12:00-until the last client | price=
# | content=jazz, all that jazz. Often live.
# }}</p>
# <p>*{{drink
# | name=Tiger Club | url=<a href="http://www.tigerclub.pl/">http://www.tigerclub.pl/</a> | email=
# | address=Felczaka 9 | lat= | long= | directions=under the City Council Building, near the city park
# | phone= | tollfree= | fax=
# | hours= | price=
# | content=Restaurant during the day, disco on weekends, live jazz every Monday.
# }}</p>
# <p>===Local beer, local vodka===</p>
# <ul>
# <li>'''Bosman beer''' is made by local brewery. There are variants with red (''czerwony'') and green (''zielony'') label, both of them are lager. You can buy it at most of general stores and some pubs.</li>
# <li>'''Taverna pub''' has its own microbrewery making lager and porter type beers.</li>
# <li>'''Starka''' is a special kind of seasoned vodka made by Polmos Szczecin distillery. There are variants which are 10, 18, 25 and 50 years old. You can buy them at Polmos store (situated corner of Jagiellonska and Bohaterow Warszawy streets); as you can guess, Starka is rather expensive (especially the 50 year old one) and available only in limited amounts. You can also tour the factory [<a href="http://www.polmos.szczecin.pl/en/">http://www.polmos.szczecin.pl/en/</a>], which is quite interesting, tasting Starka is included with the tour (email them for booking and information).</li>
# </ul>
# <p>==Sleep==</p>
# <p>===Budget===</p>
# <ul>
# <li>{{sleep
# | name=CUMA youth hostel | alt= | url=<a href="http://www.infhotel.pl/szczecin/cuma">http://www.infhotel.pl/szczecin/cuma</a> | email=
# | address= | lat= | long= | directions=
# | phone=091 4224761 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Ul. Monte Cassino 19a,
# }}</li>
# <li>{{sleep
# | name=HoHo Hostel | alt= | url=<a href="http://www.hostelszczecin.com/?lang=en">http://www.hostelszczecin.com/?lang=en</a> | email=
# | address= | lat= | long= | directions=
# | phone=+48 790 490 824 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Ul. Wyszynskiego 39,
# }}</li>
# <li>{{sleep
# | name=Hotel Albert | alt= | url=<a href="http://www.hotelarbet.webpark.pl/">http://www.hotelarbet.webpark.pl/</a> | email=
# | address= | lat= | long= | directions=
# | phone=091 4623137 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Piesza 11,
# }}</li>
# <li>{{sleep
# | name=Hotel Migrand | alt= | url=<a href="http://www.migrand.pl/">http://www.migrand.pl/</a> | email=
# | address= | lat= | long= | directions=
# | phone=+48914420960 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Robotnicza 28/29,
# }}</li>
# </ul>
# <p>===Mid-range===</p>
# <ul>
# <li>{{sleep
# | name=Campanile Hotel Szczecin | alt= | url=<a href="http://www.campanile.com.pl/szcz_cmp.html">http://www.campanile.com.pl/szcz_cmp.html</a> | email=
# | address= | lat= | long= | directions=
# | phone=091 4817700 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Ul. Wyszynskiego 30.
# }}
# ===Splurge===</li>
# <li>{{sleep
# | name=Hotel Park | alt= | url=<a href="http://www.parkhotel.szczecin.pl/">http://www.parkhotel.szczecin.pl/</a> | email=
# | address= | lat= | long= | directions=
# | phone=091 4340050 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Ul. Plantowa 1.
# }}</li>
# <li>{{sleep
# | name=Atrium Hotel | alt= | url=<a href="http://www.hotel-atrium.pl/">http://www.hotel-atrium.pl/</a> | email=
# | address= | lat= | long= | directions=
# | phone=091 4243532 | tollfree= | fax=
# | price= | checkin= | checkout=
# | content=Al. Wojska Polskiego 75.
# }}</li>
# </ul>
# <p>==Connect==
# ===Free Wireless Internet===</p>
# <ul>
# <li>Alter Ego, pl. Batorego 4</li>
# <li>Brama Jazz Cafe, ul. Hodu Pruskiego 1</li>
# <li>City Council building, pl. Armii Krajowej 1</li>
# <li>CH Galaxy, ul. Wyzwolenia 18</li>
# <li>whole ul. Bogusawa</li>
# <li>every KFC outlet</li>
# <li>every McDonald's</li>
# <li>Ksiaznica Pomorska (public library), ul. Podgorna 15/16</li>
# <li>Szczecin-Goleniow Airport</li>
# <li>Park Kasprowicza (city park), Jasne Bonia (whole area between City Council building and "Three Eagles" monument)</li>
# <li>Piwnica przy Kanie, pl. sw. Piotra i Pawa 4/5</li>
# <li>Politechnika Szczecinska - Wydzia Mechaniczny (''Technical University of Szczecin''), al. Piastow 17</li>
# <li>Pub Colorado, Way Chrobrego 1a</li>
# <li>Uniwersytet Szczecinski - Wydzia Nauk Ekonomicznych i Zarzadzania (''University of Szczecin''), ul. Mickiewicza</li>
# <li>Wyzsza Szkoa Administracji Publicznej (''Higher School of Public Administration''), ul. Marii Curie-Sklodowskiej 4</li>
# <li>Zachodniopomorska Szkoa Biznesu - Budynek A (''West Pomeranian Business School''), ul. Zonierska 53</li>
# </ul>
# <p>==Stay safe==
# Szczecin used to be infamous in Poland for its organized crime, but these days are long gone - nearly all the gangsters are dead or in prison. Nowadays it is a very safe city. However, you should stay away from some of its "bad" suburbs, like Gocaw, especially after dark. As always, use your common sense.
# Be careful when crossing streets - jaywalking is a crime in Poland and the police often lie in wait for tourists crossing streets when the pedestrian crossing is on red.  If stopped, claim that your money and passport are in your hotel and you may get away with it.</p>
# <p>==Cope==
# ===Consulates===</p>
# <ul>
# <li>Cyprus, ul. Slaska 7, 091/4330766</li>
# <li>Czech Republic, ul. Monte Cassino 27, 091/4237980</li>
# <li>Denmark, ul. Pisudskiego 1a, 091/4330930</li>
# <li>Estonia, ul. Kurza Stopka 5/cd, 091/8123827</li>
# <li>France, ul. Skodowskiej-Curie 4, 091/4761546</li>
# <li>Germany, ul. Chodkiewicza 2a, 091/4850657</li>
# <li>Kazakhstan, ul. Grodzka 14/14, 091/3264011</li>
# <li>Mexico, ul. Energetykow 3/4, 091/4624371</li>
# <li>Norway, ul. Niepodlegosci 17, 091/8121430</li>
# <li>Slovakia, ul. Skodowskiej-Curie 4, 091/4890661</li>
# <li>Sweden, ul. Skodowskiej-Curie 4, 091/4862673</li>
# <li>United Kingdom, ul. Starego Wiarusa 32, 091/4870302</li>
# </ul>
# <p>==Go next==</p>
# <p>On the mainland:</p>
# <ul>
# <li>The town of [[Police]] and its Jasienica district - monuments from the Middle Ages, small marina in the Old Town on the arpia (Oder) River and WWII ruins of Hydrierwerke synthetic gasoline factory. Szczecin shares its public transport with Police and borders the town - you can go to [[Police]] by taking public bus.</li>
# <li>sea resort and medieval town of [[Kamien Pomorski]]</li>
# <li>sea resort and medieval town of [[Koobrzeg]]</li>
# <li>Gothic church ruins in [[Trzesacz]]</li>
# <li>medieval town of [[Stargard Szczecinski]] with a cathedral over a hundred metres high</li>
# <li>birds reservation in [[Swidwie]]</li>
# <li>[[Miedzyodrze]] (''Lower Oder valley''), picturesque marsh area full of wildlife</li>
# <li>quiet medieval town of [[Nowe Warpno]]</li>
# <li>resort of [[Trzebiez]] with big marina</li>
# </ul>
# <p>On the [[Wolin]] island:</p>
# <ul>
# <li>Wolinski National Park</li>
# <li>Game reserve of wisents</li>
# <li>93-metres high Gosan cliff </li>
# <li>Kawcza Gora Mountain</li>
# <li>sea resort and port [[Swinoujscie]]</li>
# <li>sea resort [[Dziwnow]]</li>
# <li>sea resort [[Miedzyzdroje]]</li>
# <li>ancient town of [[Wolin (town)]]</li>
# <li>medieval town of [[Lubin]]</li>
# </ul>
# <p>{{IsPartOf|Zachodniopomorskie}}
# {{geo|53.433333|14.533333}}
# {{usablecity}}</p>
# <p>[[Commons:Szczecin]]
# [[Wikipedia:Szczecin]]
# [[Dmoz:Regional/Europe/Poland/Voivodships/Western Pomerania/Szczecin]]</p>
# </body></html>

# %%
sentence = 'this is a sentence'

# %%
word_tokenize(sentence)
# Out:
# ['this', 'is', 'a', 'sentence']

# %%
parsed_test_wo_dict = []
for line in parsed_test.find_all(['p','li']):
    text = line.text
    if '{{' not in text:
        text = clean_paragraph(text)
        sentences = sent_tokenize(text)
        for sentence in sentences:
            # punctuation and numbers to be removed
            punctuation = re.compile(r'[-.?!,":;()|0-9]')
            sent = re.sub(punctuation,'', sentence)
            word_list = sent.split()
            parsed_test_wo_dict.append(word_list)

# %%
parsed_test_wo_dict
# Out:
# [['pronounced',
#   'Shchetsin',
#   'German',
#   'Stettin',
#   'Latin',
#   'Stetinum',
#   'is',
#   'maritime',
#   'port',
#   'city',
#   'and',
#   'the',
#   'capital',
#   'of',
#   'Zachodniopomorskie',
#   'in',
#   'Poland'],
#  ['The',
#   'city',
#   'has',
#   'a',
#   'population',
#   'of',
#   'over',
#   'thousand',
#   'with',
#   'almost',
#   'living',
#   'its',
#   'metro',
#   'area',
#   'and',
#   'is',
#   'one',
#   'of',
#   'the',
#   'seven',
#   'largest',
#   'metropoles',
#   'in',
#   'the',
#   'country'],
#  ['It',
#   'lies',
#   'in',
#   'the',
#   'northwestern',
#   'corner',
#   'of',
#   'Poland',
#   'very',
#   'close',
#   'to',
#   'the',
#   'German',
#   'border',
#   'and',
#   'it',
#   'is',
#   'in',
#   'fact',
#   'easier',
#   'to',
#   'get',
#   'to',
#   'Szczecin',
#   'from',
#   'some',
#   'parts',
#   'of',
#   'Germany',
#   'notable',
#   'from',
#   'Berlin',
#   'than',
#   'it',
#   'is',
#   'from',
#   'much',
#   'of',
#   'the',
#   'Polish',
#   'territory'],
#  ['For',
#   'a',
#   'significant',
#   'part',
#   'of',
#   'its',
#   'history',
#   'actually',
#   'Szczecin',
#   'was',
#   'a',
#   'part',
#   'of',
#   'Germany',
#   'as',
#   'well',
#   'as',
#   'in',
#   'other',
#   'periods',
#   'of',
#   'Denmark',
#   'and',
#   'Sweden'],
#  ['Szczecin',
#   'is',
#   'Polands',
#   'thirdlargest',
#   'port',
#   'and',
#   'much',
#   'of',
#   'its',
#   'industrial',
#   'base',
#   'used',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of',
#   'an',
#   'important',
#   'shipyard',
#   'so',
#   'it',
#   'may',
#   'come',
#   'as',
#   'a',
#   'surprise',
#   'to',
#   'the',
#   'casual',
#   'tourist',
#   'that',
#   'the',
#   'city',
#   'does',
#   'not',
#   'lay',
#   'on',
#   'a',
#   'seaside',
#   'but',
#   'rather',
#   'over',
#   'the',
#   'river',
#   'Odra',
#   'German',
#   'Oder',
#   'some',
#   'kilometres',
#   'south',
#   'of',
#   'the',
#   'Baltic',
#   'Sea',
#   'as',
#   'the',
#   'crow',
#   'flies',
#   'and',
#   'many',
#   'more',
#   'by',
#   'road'],
#  ['Many',
#   'visitors',
#   'to',
#   'Poland',
#   'are',
#   'also',
#   'unaware',
#   'of',
#   'Szczecins',
#   'architectural',
#   'attractiveness',
#   'as',
#   'the',
#   'large',
#   'parts',
#   'of',
#   'the',
#   'city',
#   'were',
#   'designed',
#   'by',
#   'Baron',
#   'Haussmann',
#   'the',
#   'same',
#   'gentleman',
#   'who',
#   'designed',
#   'the',
#   'boulevards',
#   'of',
#   'Paris'],
#  ['The',
#   'place',
#   'now',
#   'known',
#   'as',
#   'Szczecin',
#   'was',
#   'first',
#   'mentioned',
#   'in',
#   'written',
#   'history',
#   'in',
#   'st',
#   'century',
#   'when',
#   'WestRoman',
#   'historian',
#   'Tacitus',
#   'located',
#   'East',
#   'Germanic',
#   'tribe',
#   'of',
#   'Rugians',
#   'somewhere',
#   'in',
#   'the',
#   'area',
#   'the',
#   'Rugians',
#   'left',
#   'in',
#   'th',
#   'Century',
#   'during',
#   'the',
#   'Great',
#   'Migration'],
#  ['Sometime',
#   'in',
#   'the',
#   'th',
#   'century',
#   'Western',
#   'Slavic',
#   'tribe',
#   'of',
#   'Pomeranians',
#   'built',
#   'their',
#   'stronghold',
#   'here'],
#  ['In',
#   'th',
#   'century',
#   'the',
#   'town',
#   'was',
#   'mentioned',
#   'as',
#   'one',
#   'of',
#   'major',
#   'in',
#   'Pomerania',
#   'in',
#   'Abraham',
#   'ben',
#   'Jacobs',
#   'chronicle'],
#  ['In',
#   'approximately',
#   'its',
#   'area',
#   'was',
#   'incorporated',
#   'into',
#   'Poland',
#   'but',
#   'within',
#   'eight',
#   'years',
#   'the',
#   'town',
#   'was',
#   'controlled',
#   'by',
#   'the',
#   'Dukedom',
#   'of',
#   'Pomerania',
#   'and',
#   'five',
#   'years',
#   'later',
#   'Denmark'],
#  ['In',
#   'th',
#   'century',
#   'when',
#   'its',
#   'competitor',
#   'Wolin',
#   'also',
#   'known',
#   'as',
#   'Veneta',
#   'in',
#   'medieval',
#   'chronicles',
#   'declined',
#   'Szczecin',
#   'began',
#   'to',
#   'prosper',
#   'from',
#   'trade',
#   'and',
#   'became',
#   'one',
#   'of',
#   'the',
#   'major',
#   'Baltic',
#   'sea',
#   'harbours'],
#  ['Its', 'name', 'was', 'first', 'recorded', 'in', 'as', 'Stetin'],
#  ['In', 'Pomeranian', 'dukes', 'joined', 'Holy', 'Roman', 'Empire'],
#  ['In',
#   'Szczecin',
#   'got',
#   'city',
#   'rights',
#   'before',
#   'it',
#   'became',
#   'member',
#   'of',
#   'the',
#   'Hanseatic',
#   'League',
#   'in'],
#  ['Until',
#   'early',
#   'th',
#   'century',
#   'the',
#   'city',
#   'was',
#   'the',
#   'capital',
#   'of',
#   'Pomeranian',
#   'Dukedom',
#   'then',
#   'in',
#   'when',
#   'local',
#   'dukes',
#   'died',
#   'out',
#   'it',
#   'became',
#   'part',
#   'of',
#   'Sweden',
#   'then',
#   'Kingdom',
#   'of',
#   'Prussia',
#   'then',
#   'for',
#   'a',
#   'brief',
#   'period',
#   'due',
#   'to',
#   'Napoleons',
#   'conquests',
#   'the',
#   'Empire',
#   'of',
#   'France'],
#  ['Beginning',
#   'in',
#   'the',
#   'th',
#   'century',
#   'the',
#   'city',
#   'constituted',
#   'as',
#   'a',
#   'part',
#   'of',
#   'Germany',
#   'and',
#   'served',
#   'as',
#   'the',
#   'port',
#   'of',
#   'Berlin'],
#  ['During',
#   'World',
#   'War',
#   'II',
#   'the',
#   'city',
#   'was',
#   'hit',
#   'hard',
#   'by',
#   'Allied',
#   'bombers',
#   'city',
#   'centre',
#   'Old',
#   'Town',
#   'and',
#   'industrial',
#   'areas',
#   'were',
#   'totally',
#   'ruined'],
#  ['After',
#   'the',
#   'Soviet',
#   'forces',
#   'invaded',
#   'Nazi',
#   'Germany',
#   'in',
#   'according',
#   'to',
#   'Potsdam',
#   'Conference',
#   'agreements',
#   'Poland',
#   'annexed',
#   'all',
#   'lands',
#   'up',
#   'to',
#   'the',
#   'Oder',
#   'river',
#   'expelling',
#   'the',
#   'native',
#   'German',
#   'population',
#   'and',
#   'ultimately',
#   'extending',
#   'the',
#   'border',
#   'to',
#   'include',
#   'Stettin'],
#  ['Poland', 'thus', 'gained', 'control', 'of', 'the', 'city'],
#  ['In',
#   'more',
#   'recent',
#   'history',
#   'the',
#   'city',
#   'was',
#   'together',
#   'with',
#   'Tricity',
#   'one',
#   'of',
#   'the',
#   'birthplaces',
#   'of',
#   'Solidarity',
#   'movement'],
#  ['An',
#   'unusual',
#   'feature',
#   'of',
#   'Szczecin',
#   'is',
#   'its',
#   'urban',
#   'planning',
#   'many',
#   'roundabouts',
#   'and',
#   'wide',
#   'avenues'],
#  ['Stettin',
#   'was',
#   'rebuilt',
#   'in',
#   's',
#   'using',
#   'designs',
#   'by',
#   'GeorgesEugene',
#   'Haussmann',
#   'who',
#   'also',
#   'did',
#   'the',
#   'urban',
#   'planning',
#   'for',
#   'Paris'],
#  ['His',
#   'design',
#   'style',
#   'is',
#   'still',
#   'being',
#   'used',
#   'for',
#   'newlybuilt',
#   'or',
#   'modified',
#   'city',
#   'areas'],
#  ['The',
#   'maritime',
#   'industry',
#   'is',
#   'still',
#   'strong',
#   'with',
#   'a',
#   'busy',
#   'port',
#   'and',
#   'repair',
#   'shipyard',
#   'as',
#   'well',
#   'as',
#   'being',
#   'a',
#   'center',
#   'of',
#   'service',
#   'industries',
#   'in',
#   'Poland'],
#  ['Situated',
#   'near',
#   'the',
#   'border',
#   'between',
#   'Germany',
#   'and',
#   'Poland',
#   'Szczecin',
#   'is',
#   'sometimes',
#   'considered',
#   'one',
#   'of',
#   'most',
#   'liberal',
#   'Polish',
#   'cities'],
#  ['SzczecinGoleniow',
#   'airport',
#   'SZZ',
#   'located',
#   'almost',
#   'km',
#   'from',
#   'the',
#   'city',
#   'centre',
#   'near',
#   'Goleniow'],
#  ['Ryanair',
#   'operates',
#   'daily',
#   'flights',
#   'between',
#   'Szczecin',
#   'and',
#   'London',
#   'Stansted',
#   'and',
#   'flights',
#   'per',
#   'week',
#   'to',
#   'and',
#   'from',
#   'Dublin',
#   'and',
#   'Liverpool'],
#  ['LOT',
#   'has',
#   'several',
#   'flights',
#   'daily',
#   'between',
#   'Szczecin',
#   'and',
#   'Warsaw'],
#  ['Note',
#   'that',
#   'cancellations',
#   'do',
#   'happen',
#   'so',
#   'take',
#   'that',
#   'into',
#   'account',
#   'when',
#   'planning',
#   'onward',
#   'travel'],
#  ['Eurolot',
#   'flights',
#   'from',
#   'Szczecin',
#   'to',
#   'Krakow',
#   'both',
#   'direct',
#   'and',
#   'via',
#   'Poznan',
#   'times',
#   'a',
#   'week',
#   'and',
#   'to',
#   'Rzeszow',
#   'twice',
#   'a',
#   'week'],
#  ['Norwegian',
#   'operates',
#   'two',
#   'flights',
#   'per',
#   'week',
#   'between',
#   'Szczecin',
#   'and',
#   'both',
#   'Trondheim',
#   'and',
#   'Oslo'],
#  ['You',
#   'can',
#   'reach',
#   'the',
#   'airport',
#   'by',
#   'car',
#   'the',
#   'journey',
#   'may',
#   'take',
#   'up',
#   'to',
#   'hour',
#   'depending',
#   'on',
#   'traffic',
#   'by',
#   'taxi',
#   'about',
#   'PLN',
#   'or',
#   'by',
#   'minibus',
#   'LOT',
#   'operates',
#   'a',
#   'minibus',
#   'to',
#   'and',
#   'from',
#   'the',
#   'airport',
#   'for',
#   'all',
#   'LOTs',
#   'flights',
#   'free',
#   'of',
#   'charge',
#   'for',
#   'passengers',
#   'leaving',
#   'from',
#   'LOTs',
#   'office',
#   'al'],
#  ['Wyzwolenia',
#   'about',
#   'minutes',
#   'before',
#   'departure',
#   'and',
#   'Interglobus',
#   'has',
#   'minibuses',
#   'for',
#   'all',
#   'international',
#   'flights'],
#  ['In',
#   'July',
#   'a',
#   'railway',
#   'service',
#   'linking',
#   'the',
#   'airports',
#   'terminal',
#   'directly',
#   'with',
#   'Szczecins',
#   'main',
#   'railway',
#   'station',
#   'and',
#   'with',
#   'Koobrzeg',
#   'was',
#   'inaugurated'],
#  ['Due',
#   'to',
#   'Szczecins',
#   'proximity',
#   'to',
#   'Berlin',
#   'you',
#   'may',
#   'use',
#   'the',
#   'latters',
#   'airports',
#   'to',
#   'get',
#   'to',
#   'Szczecin',
#   'as',
#   'well'],
#  ['From',
#   'there',
#   'you',
#   'can',
#   'reach',
#   'Szczecin',
#   'by',
#   'minibus',
#   'numerous',
#   'Szczecinbased',
#   'companies',
#   'including',
#   'Atlastransfer',
#   'Berliniaeu',
#   'Interglobus',
#   'regular',
#   'services',
#   'to',
#   'Tegel',
#   'and',
#   'Schoenefeld',
#   'airports',
#   'at',
#   'attractive',
#   'prices',
#   'by',
#   'car',
#   'or',
#   'by',
#   'train',
#   'in',
#   'hours'],
#  ['Polish',
#   'State',
#   'Railways',
#   'PKP',
#   'connections',
#   'to',
#   'and',
#   'from',
#   'all',
#   'major',
#   'Polish',
#   'cities'],
#  ['There',
#   'are',
#   'several',
#   'trains',
#   'daily',
#   'to',
#   'and',
#   'from',
#   'Warsaw',
#   'travel',
#   'time',
#   'on',
#   'express',
#   'or',
#   'Intercity',
#   'trains',
#   'is',
#   'less',
#   'than',
#   'hours',
#   'but',
#   'minor',
#   'delays',
#   'are',
#   'not',
#   'uncommon'],
#  ['To',
#   'Poznan',
#   'travel',
#   'time',
#   'is',
#   'about',
#   'hours',
#   'from',
#   'PLN',
#   'with',
#   'frequent',
#   'trains',
#   'running',
#   'throughout',
#   'the',
#   'day'],
#  ['There', 'are', 'also', 'frequent', 'trains', 'to', 'Swinoujscie', 'hours'],
#  ['German',
#   'Railways',
#   'train',
#   'connections',
#   'from',
#   'Berlin',
#   'Amsterdam',
#   'Prague',
#   'and',
#   'many',
#   'cities',
#   'in',
#   'neighboring',
#   'MecklenburgWestern',
#   'Pomerania'],
#  ['The',
#   'cheapest',
#   'way',
#   'to',
#   'get',
#   'to',
#   'Berlin',
#   'is',
#   'by',
#   'joining',
#   'a',
#   'group',
#   'of',
#   'up',
#   'to',
#   'people',
#   'riding',
#   'on',
#   'one',
#   'BerlinBrandenburg',
#   'Ticket',
#   'which',
#   'is',
#   'valid',
#   'from',
#   'am',
#   'to',
#   'am',
#   'the',
#   'following',
#   'day',
#   'for',
#   'travel',
#   'on',
#   'all',
#   'local',
#   'and',
#   'regional',
#   'German',
#   'trains',
#   'and',
#   'on',
#   'local',
#   'public',
#   'transport',
#   'systems',
#   'in',
#   'all',
#   'cities',
#   'and',
#   'towns',
#   'including',
#   'Berlin',
#   'and',
#   'Szczecin'],
#  ['The',
#   'ticket',
#   'costs',
#   'euros',
#   'so',
#   'one',
#   'person',
#   'can',
#   'travel',
#   'for',
#   'ca'],
#  ['euros'],
#  ['The',
#   'groups',
#   'often',
#   'form',
#   'spontaneously',
#   'before',
#   'departure',
#   'or',
#   'on',
#   'the',
#   'train',
#   'itself'],
#  ['There',
#   'is',
#   'also',
#   'the',
#   'new',
#   'BerlinStettinTicket',
#   'for',
#   'Euros',
#   'per',
#   'person',
#   'one',
#   'way'],
#  ['BerlinStettinTicket',
#   'BrandenburgBerlinTicket',
#   'BrandenburgBerlinTicket',
#   'Nacht',
#   'MecklenburgVorpommernTicket',
#   'and',
#   'SchonesWochenendeTicket',
#   'are',
#   'valid',
#   'for',
#   'routes',
#   'to',
#   'and',
#   'from',
#   'the',
#   'city',
#   'of',
#   'Szczecin',
#   'and',
#   'for',
#   'the',
#   'entire',
#   'public',
#   'transport',
#   'system',
#   'in',
#   'Szczecin'],
#  ['You',
#   'even',
#   'can',
#   'get',
#   'from',
#   'or',
#   'to',
#   'the',
#   'Danish',
#   'border',
#   'via',
#   'SchleswigHolsteinTicket',
#   'valid',
#   'in',
#   'the',
#   'regional',
#   'trains',
#   'of',
#   'MecklenburgVorpommern',
#   'Hamburg',
#   'SchleswigHolstein',
#   'until',
#   'Padborg',
#   'or',
#   'Tonder',
#   'DK',
#   'with',
#   'a',
#   'surcharge',
#   'of',
#   'for',
#   'the',
#   'ride',
#   'from',
#   'the',
#   'Polish',
#   'border',
#   'to',
#   'Szczecin'],
#  ['You',
#   'can',
#   'reach',
#   'Szczecin',
#   'by',
#   'car',
#   'from',
#   'major',
#   'Polish',
#   'cities',
#   'including',
#   'Warsaw',
#   'Poznan',
#   'Gdansk',
#   'Wrocaw',
#   'and',
#   'also',
#   'from',
#   'Berlin'],
#  ['Thanks',
#   'to',
#   'its',
#   'location',
#   'close',
#   'to',
#   'the',
#   'border',
#   'and',
#   'direct',
#   'link',
#   'with',
#   'the',
#   'German',
#   'motorway',
#   'system',
#   'Szczecin',
#   'has',
#   'the',
#   'best',
#   'road',
#   'connection',
#   'with',
#   'Western',
#   'Europe',
#   'of',
#   'all',
#   'Polish',
#   'cities'],
#  ['The',
#   'main',
#   'route',
#   'to',
#   'Szczecin',
#   'from',
#   'Berlin',
#   'is',
#   'the',
#   'E',
#   'German',
#   'A',
#   'Polish',
#   'A'],
#  ['The', 'journey', 'takes', 'about', 'hours', 'depending', 'on', 'traffic'],
#  ['Note',
#   'that',
#   'the',
#   'German',
#   'A',
#   'motorway',
#   'is',
#   'undergoing',
#   'continuous',
#   'improvements',
#   'resulting',
#   'in',
#   'some',
#   'disturbances',
#   'in',
#   'certain',
#   'sections'],
#  ['Travelling',
#   'by',
#   'car',
#   'to',
#   'and',
#   'from',
#   'other',
#   'parts',
#   'of',
#   'Poland',
#   'can',
#   'be',
#   'troublesome',
#   'the',
#   'traffic',
#   'is',
#   'pretty',
#   'heavy',
#   'the',
#   'distances',
#   'are',
#   'large',
#   'and',
#   'there',
#   'is',
#   'a',
#   'general',
#   'shortage',
#   'of',
#   'motorways'],
#  ['It',
#   'also',
#   'takes',
#   'quite',
#   'some',
#   'time',
#   'for',
#   'example',
#   'the',
#   'trip',
#   'to',
#   'Gdansk',
#   'km',
#   'usually',
#   'takes',
#   'hours',
#   'and',
#   'to',
#   'Warsaw',
#   'km',
#   'along',
#   'national',
#   'road',
#   'no'],
#  ['you',
#   'need',
#   'at',
#   'least',
#   'hours',
#   'even',
#   'if',
#   'you',
#   'dont',
#   'follow',
#   'the',
#   'speed',
#   'limits',
#   'too',
#   'strictly'],
#  ['You',
#   'can',
#   'also',
#   'reach',
#   'Szczecin',
#   'from',
#   'Sweden',
#   'Ystad',
#   'and',
#   'Denmark',
#   'Copenhagen',
#   'using',
#   'the',
#   'ferry',
#   'connections',
#   'to',
#   'and',
#   'from',
#   'Swinoujscie'],
#  ['From',
#   'there',
#   'the',
#   'journey',
#   'takes',
#   'about',
#   'hours',
#   'although',
#   'this',
#   'road',
#   'gets',
#   'completely',
#   'jammed',
#   'on',
#   'summer',
#   'weekends'],
#  ['To',
#   'avoid',
#   'traffic',
#   'jams',
#   'in',
#   'high',
#   'season',
#   'follow',
#   'the',
#   'yellow',
#   'tourist',
#   'route',
#   'Trasa',
#   'turystyczna',
#   'signs'],
#  ['These',
#   'will',
#   'take',
#   'you',
#   'along',
#   'Broads',
#   'bypassing',
#   'the',
#   'most',
#   'crowded',
#   'section',
#   'of',
#   'national',
#   'road',
#   'no'],
#  ['Many',
#   'international',
#   'and',
#   'domestic',
#   'connections',
#   'see',
#   'Poland#By',
#   'busPolandBy',
#   'bus'],
#  ['Szczecin',
#   'operates',
#   'daily',
#   'connection',
#   'with',
#   'Schwedt',
#   'in',
#   'Germany'],
#  ['dozens',
#   'of',
#   'minibus',
#   'operators',
#   'driving',
#   'to',
#   'and',
#   'from',
#   'Berlin'],
#  ['Szczecin',
#   'is',
#   'situated',
#   'on',
#   'the',
#   'banks',
#   'of',
#   'the',
#   'Oder',
#   'Polish',
#   'Odra',
#   'and',
#   'Regalica',
#   'branch',
#   'of',
#   'the',
#   'Oder',
#   'rivers',
#   'and',
#   'Lake',
#   'Dabie',
#   'near',
#   'the',
#   'Szczecin',
#   'Lagoon'],
#  ['There',
#   'is',
#   'a',
#   'number',
#   'of',
#   'marinas',
#   'most',
#   'of',
#   'them',
#   'situated',
#   'in',
#   'the',
#   'northern',
#   'districts',
#   'and',
#   'on',
#   'the',
#   'shores',
#   'of',
#   'Lake',
#   'Dabie'],
#  ['In',
#   'April',
#   'hydrofoil',
#   'service',
#   'was',
#   'reestablished',
#   'between',
#   'Szczecin',
#   'and',
#   'Swinoujscie'],
#  ['BosmanExpress',
#   'runs',
#   'twice',
#   'a',
#   'day',
#   'from',
#   'the',
#   'Way',
#   'Chrobrego',
#   'embankment',
#   'reaching',
#   'Swinoujscie',
#   'in',
#   'about',
#   'minutes'],
#  ['Tickets',
#   'are',
#   'a',
#   'bit',
#   'overpriced',
#   'at',
#   'PLN',
#   '/',
#   'economy/VIP',
#   'class',
#   'but',
#   'dont',
#   'expect',
#   'any',
#   'luxury',
#   'and',
#   'there',
#   'are',
#   'discounts',
#   'for',
#   'children',
#   'and',
#   'groups'],
#  ['There', 'is', 'a', 'snackbar', 'on', 'board', 'beer', 'is', 'served'],
#  ['There', 'is', 'also', 'a', 'small', 'viewing', 'deck'],
#  ['Along',
#   'the',
#   'way',
#   'you',
#   'can',
#   'see',
#   'some',
#   'quite',
#   'interesting',
#   'industrial',
#   'sights',
#   'in',
#   'the',
#   'northern',
#   'part',
#   'of',
#   'Szczecin'],
#  ['Despite',
#   'being',
#   'a',
#   'restored',
#   'Sovietmade',
#   'Meteor',
#   'now',
#   'equipped',
#   'with',
#   'new',
#   'engines',
#   'the',
#   'hydrofoil',
#   'is',
#   'the',
#   'quickest',
#   'way',
#   'to',
#   'get',
#   'to',
#   'Swinoujscie',
#   'it',
#   'moors',
#   'at',
#   'the',
#   'left',
#   'western',
#   'bank',
#   'of',
#   'the',
#   'Swina',
#   'so',
#   'the',
#   'passengers',
#   'avoid',
#   'the',
#   'need',
#   'to',
#   'use',
#   'the',
#   'ferry'],
#  ['Szczecin',
#   'is',
#   'split',
#   'in',
#   'two',
#   'parts',
#   'Lewobrzeze',
#   'and',
#   'Prawobrzeze',
#   'named',
#   'after',
#   'their',
#   'location',
#   'on',
#   'banks',
#   'of',
#   'Oder',
#   'Lewobrzeze',
#   '=',
#   'left',
#   'bank',
#   'and',
#   'Regalica',
#   'Prawobrzeze',
#   '=',
#   'right',
#   'bank',
#   'rivers'],
#  ['The', 'port', 'is', 'situated', 'in', 'between'],
#  ['City',
#   'centre',
#   'and',
#   'most',
#   'of',
#   'attractions',
#   'are',
#   'situated',
#   'in',
#   'Lewobrzeze'],
#  ['ImageSzczecinFacadesjpgthumbFacades', 'in', 'new', 'old', 'town'],
#  ['trams',
#   'and',
#   'schedules',
#   'can',
#   'also',
#   'install',
#   'the',
#   'timetables',
#   'on',
#   'your',
#   'mobile',
#   'phone',
#   'for',
#   'JME',
#   'compatible',
#   'phones',
#   'and',
#   'Symbian',
#   'MPK',
#   'Mobile',
#   'Android',
#   'and',
#   'Windows',
#   'Phone',
#   'Transportoid',
#   'http//transportoidcom/'],
#  ['Tickets',
#   'are',
#   'randomly',
#   'checked',
#   'by',
#   'plain',
#   'clothed',
#   'inspectors',
#   'fines',
#   'are',
#   'severe',
#   'and',
#   'can',
#   'be',
#   'a',
#   'major',
#   'hassle',
#   'so',
#   'its',
#   'better',
#   'for',
#   'you',
#   'to',
#   'buy',
#   'them'],
#  ['They',
#   'are',
#   'available',
#   'at',
#   'all',
#   'newspaper',
#   'stands',
#   'and',
#   'you',
#   'can',
#   'buy',
#   'them',
#   'from',
#   'the',
#   'driver',
#   'after'],
#  ['If',
#   'you',
#   'happen',
#   'to',
#   'have',
#   'an',
#   'account',
#   'in',
#   'Polish',
#   'bank',
#   'you',
#   'can',
#   'also',
#   'use',
#   'your',
#   'mobile',
#   'phone',
#   'hours',
#   'are',
#   'and',
#   'night',
#   'hours',
#   'are',
#   'between',
#   'and'],
#  ['Tickets', 'for', 'express', 'buses', 'are', 'twice', 'expensive'],
#  ['You',
#   'can',
#   'change',
#   'between',
#   'lines',
#   'freely',
#   'as',
#   'long',
#   'you',
#   'stay',
#   'within',
#   'time',
#   'limit',
#   'the',
#   'exception',
#   'is',
#   'changing',
#   'from',
#   'normal',
#   'bus',
#   'or',
#   'tram',
#   'to',
#   'express',
#   'bus'],
#  ['Prices'],
#  ['minutes', 'z'],
#  ['minutes', 'z'],
#  ['hour', 'z'],
#  ['hours', 'z'],
#  ['hours', 'z'],
#  ['days', 'z'],
#  ['Family',
#   'weekend',
#   'ticket',
#   'z',
#   'valid',
#   'on',
#   'weekends',
#   'for',
#   'one',
#   'or',
#   'two',
#   'adults',
#   'with',
#   'at',
#   'least',
#   'one',
#   'child',
#   'up',
#   'to',
#   'years',
#   'old'],
#  ['There',
#   'are',
#   'also',
#   'tickets',
#   'valid',
#   'for',
#   'days',
#   'a',
#   'month',
#   'and',
#   'a',
#   'quarter'],
#  ['Remember',
#   'to',
#   'stamp',
#   'your',
#   'ticket',
#   'immediately',
#   'after',
#   'you',
#   'board',
#   'the',
#   'tram/bus'],
#  ['BrandenburgBerlin',
#   'MecklenburgVorpommern',
#   'SchleswigHolstein',
#   'Schones',
#   'Wochenende',
#   'and',
#   'BrandenburgBerlin',
#   'Nacht',
#   'tickets',
#   'issued',
#   'by',
#   'Deutsche',
#   'Bahn',
#   'are',
#   'valid',
#   'for',
#   'public',
#   'transport',
#   'operated',
#   'by',
#   'ZDiTM',
#   'trams',
#   'and',
#   'buses',
#   'in',
#   'Szczecin'],
#  ['Monthly/quarterly',
#   'tickets',
#   'issued',
#   'by',
#   'ZDiTM',
#   'are',
#   'valid',
#   'for',
#   'DB',
#   'trains',
#   'within',
#   'the',
#   'city',
#   'Szczecin',
#   'GownySzczecin',
#   'Gumience',
#   'http//bipumszczecinpl/files/DEEFAEEFBAFDCC/pdf'],
#  ['tourist', 'tram', 'line'],
#  ['trams'],
#  ['tourist', 'bus', 'lines'],
#  ['buses'],
#  ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'express', 'buses'],
#  ['night', 'buses'],
#  ['xx', 'free', 'buses', 'to', 'and', 'from', 'shopping', 'malls'],
#  ['Tourist',
#   'lines',
#   'vintage',
#   'trams',
#   'and',
#   'buses',
#   'operate',
#   'in',
#   'July',
#   'and',
#   'August',
#   'on',
#   'Saturdays',
#   'and',
#   'Sundays'],
#  ['The', 'fare', 'costs', 'z', 'paid', 'to', 'the', 'driver'],
#  ['Line', 'numbers', 'tram', 'and', 'buses'],
#  ['If',
#   'for',
#   'any',
#   'reason',
#   'you',
#   'want',
#   'to',
#   'go',
#   'to',
#   'or',
#   'from',
#   'the',
#   'city',
#   'centre',
#   'station',
#   'name',
#   'Szczecin',
#   'Gowny',
#   'to',
#   'districts',
#   'of',
#   'Dabie',
#   'Gumience',
#   'Podjuchy',
#   'Zdroje',
#   'Zdunowo',
#   'or',
#   'Zaom',
#   'or',
#   'nearby',
#   'suburban',
#   'towns',
#   'of',
#   'Goleniow',
#   'Gryfino',
#   'or',
#   'Stargard',
#   'the',
#   'fastest',
#   'way',
#   'might',
#   'be',
#   'the',
#   'train'],
#  ['Check',
#   'times',
#   'with',
#   'PKP',
#   'have',
#   'to',
#   'buy',
#   'separate',
#   'ticket',
#   'z',
#   'one',
#   'way',
#   'no',
#   'matter',
#   'how',
#   'many',
#   'stops',
#   'the',
#   'exception',
#   'are',
#   'trains',
#   'operated',
#   'by',
#   'DB',
#   'see',
#   'above'],
#  ['City',
#   'center',
#   'can',
#   'be',
#   'covered',
#   'by',
#   'foot',
#   'depending',
#   'on',
#   'your',
#   'fitness',
#   'etc'],
#  ['Look',
#   'for',
#   'the',
#   'red',
#   'line',
#   'on',
#   'the',
#   'pavements',
#   'so',
#   'called',
#   'red',
#   'walk',
#   'which',
#   'connects',
#   'nearly',
#   'all',
#   'the',
#   'attractions',
#   'within',
#   'the',
#   'centre'],
#  ['This',
#   'is',
#   'by',
#   'far',
#   'the',
#   'best',
#   'way',
#   'to',
#   'discover',
#   'the',
#   'centre',
#   'on',
#   'foot',
#   'as',
#   'all',
#   'attractions',
#   'are',
#   'marked',
#   'by',
#   'a',
#   'number',
#   'there',
#   'are',
#   'about',
#   'on',
#   'the',
#   'pavement',
#   'so',
#   'you',
#   'wont',
#   'miss',
#   'one'],
#  ['At',
#   'each',
#   'of',
#   'them',
#   'there',
#   'is',
#   'a',
#   'sign',
#   'explaining',
#   'some',
#   'details',
#   'about',
#   'the',
#   'sight'],
#  ['The',
#   'red',
#   'line',
#   'starts',
#   'and',
#   'ends',
#   'at',
#   'the',
#   'train',
#   'station'],
#  ['When',
#   'you',
#   'exit',
#   'through',
#   'the',
#   'main',
#   'entrance',
#   'turn',
#   'left',
#   'on',
#   'the',
#   'sidewalk',
#   'and',
#   'look',
#   'for',
#   'it',
#   'some',
#   'of',
#   'the',
#   'paint',
#   'may',
#   'have',
#   'already',
#   'vanished'],
#  ['Close',
#   'to',
#   'the',
#   'start',
#   'is',
#   'also',
#   'a',
#   'map',
#   'showing',
#   'the',
#   'route',
#   'and',
#   'the',
#   'attractions'],
#  ['You',
#   'can',
#   'get',
#   'a',
#   'similar',
#   'map',
#   'that',
#   'also',
#   'includes',
#   'the',
#   'red',
#   'line',
#   'at',
#   'the',
#   'tourist',
#   'information',
#   'center'],
#  ['ImageSquareInNewOldSzczecinjpgthumbMuseum', 'at', 'new', 'old', 'town'],
#  ['Streets',
#   'in',
#   'Szczecin',
#   'are',
#   'compared',
#   'to',
#   'other',
#   'Polish',
#   'cities',
#   'easy',
#   'to',
#   'navigate',
#   'and',
#   'not',
#   'congested'],
#  ['However',
#   'parking',
#   'within',
#   'the',
#   'centre',
#   'during',
#   'business',
#   'hours',
#   'from',
#   'Monday',
#   'to',
#   'Friday',
#   'after',
#   'and',
#   'on',
#   'weekends',
#   'it',
#   'is',
#   'free',
#   'is',
#   'paid',
#   'the',
#   'pay',
#   'depends',
#   'on',
#   'the',
#   'zone',
#   'and',
#   'parking',
#   'time'],
#  ['You', 'can', 'buy', 'tickets', 'from', 'vending', 'machines'],
#  ['Most',
#   'of',
#   'malls',
#   'have',
#   'free',
#   'parking',
#   'and',
#   'no',
#   'one',
#   'will',
#   'check',
#   'if',
#   'you',
#   'visited',
#   'the',
#   'mall',
#   'or',
#   'just',
#   'used',
#   'free',
#   'parking',
#   'opportunity'],
#  ['DUI',
#   'is',
#   'serious',
#   'criminal',
#   'offense',
#   'up',
#   'to',
#   'years',
#   'in',
#   'prison',
#   'and',
#   'the',
#   'police',
#   'have',
#   'no',
#   'mercy',
#   'for',
#   'drunk',
#   'drivers',
#   'many',
#   'of',
#   'zero',
#   'tolerance',
#   'for',
#   'drunk',
#   'drivers',
#   'programs',
#   'ongoing',
#   'in',
#   'Poland',
#   'have',
#   'started',
#   'in',
#   'Szczecin'],
#  ['Because',
#   'of',
#   'major',
#   'renovation',
#   'works',
#   'in',
#   'the',
#   'city',
#   'centre',
#   'and',
#   'Niebuszewo',
#   'district',
#   'held',
#   'this',
#   'year',
#   'expect',
#   'detours',
#   'and/or',
#   'traffic',
#   'jams',
#   'especially',
#   'during',
#   'rush',
#   'hours'],
#  ['If',
#   'you',
#   'stay',
#   'in',
#   'the',
#   'city',
#   'consider',
#   'leaving',
#   'your',
#   'car',
#   'on',
#   'parking',
#   'and',
#   'using',
#   'public',
#   'transport'],
#  ['There',
#   'is',
#   'network',
#   'of',
#   'cyclingbicycle',
#   'paths',
#   'connecting',
#   'the',
#   'city',
#   'center',
#   'with',
#   'the',
#   'suburbs'],
#  ['You',
#   'can',
#   'take',
#   'your',
#   'bike',
#   'on',
#   'public',
#   'transport',
#   'for',
#   'free',
#   'outside',
#   'rush',
#   'hours'],
#  ['If',
#   'you',
#   'want',
#   'to',
#   'see',
#   'Szczecin',
#   'from',
#   'the',
#   'bicycle',
#   'but',
#   'dont',
#   'have',
#   'one',
#   'you',
#   'can',
#   'rent',
#   'it'],
#  ['Bicyklownia', 'Wielkopolska', 'tel'],
#  ['+'],
#  ['near', 'City', 'Park'],
#  ['Biker', 'Swietego', 'Ducha', 'a', 'tel'],
#  ['+', 'Center'],
#  ['Centrum', 'Wynajmu', 'i', 'Turystyki', 'Kolumba', '/m', 'tel'],
#  ['+',
#   'near',
#   'Szczecin',
#   'Gowny',
#   'railway',
#   'station',
#   'If',
#   'you',
#   'happen',
#   'to',
#   'be',
#   'present',
#   'in',
#   'Szczecin',
#   'on',
#   'any',
#   'last',
#   'Friday',
#   'of',
#   'the',
#   'month',
#   'feel',
#   'free',
#   'to',
#   'join',
#   'the',
#   'Critical',
#   'Mass',
#   'the',
#   'start',
#   'point',
#   'is',
#   'Plac',
#   'Lotnikow',
#   'square',
#   'pm'],
#  ['Hail',
#   'taxi',
#   'cab',
#   'from',
#   'the',
#   'street',
#   'or',
#   'stand',
#   'only',
#   'in',
#   'emergency',
#   'or',
#   'if',
#   'very',
#   'tired/drunk'],
#  ['It',
#   'is',
#   'much',
#   'cheaper',
#   'to',
#   'call',
#   'for',
#   'one',
#   'ask',
#   'locals',
#   'for',
#   'numbers',
#   'or',
#   'see',
#   'taxi',
#   'advertisements',
#   'they',
#   'are',
#   'nearly',
#   'everywhere'],
#  ['When',
#   'you',
#   'call',
#   'ask',
#   'the',
#   'operator',
#   'when',
#   'the',
#   'taxi',
#   'will',
#   'arrive',
#   'and',
#   'then',
#   'look',
#   'for',
#   'car',
#   'plastered',
#   'with',
#   'number',
#   'of',
#   'company',
#   'you',
#   'called'],
#  ['There',
#   'is',
#   'taxi',
#   'mafia',
#   'operating',
#   'from',
#   'stands',
#   'near',
#   'railway',
#   'station',
#   'popular',
#   'clubs',
#   'hotels',
#   'etc'],
#  ['avoid', 'these', 'ripoffs', 'they', 'are', 'VERY', 'expensive'],
#  ['Taxi',
#   'fare',
#   'within',
#   'the',
#   'centre',
#   'shouldnt',
#   'cost',
#   'you',
#   'more',
#   'than',
#   'about',
#   'z'],
#  ['Fare',
#   'from',
#   'left',
#   'side',
#   'of',
#   'the',
#   'river',
#   'Lewobrzeze',
#   'to',
#   'the',
#   'right',
#   'side',
#   'Prawobrzeze',
#   'or',
#   'the',
#   'other',
#   'way',
#   'is',
#   'about',
#   'z'],
#  ['Fares', 'during', 'the', 'night', 'are', 'slightly', 'more', 'expensive'],
#  ['All',
#   'officially',
#   'registered',
#   'taxis',
#   'have',
#   'meters',
#   'the',
#   'driver',
#   'should',
#   'turn',
#   'them',
#   'on',
#   'just',
#   'after',
#   'you',
#   'enter'],
#  ['Payment',
#   'have',
#   'cash',
#   'ready',
#   'only',
#   'the',
#   'minority',
#   'of',
#   'taxi',
#   'drivers',
#   'have',
#   'necessary',
#   'equipment',
#   'for',
#   'payments',
#   'with',
#   'debit',
#   'or',
#   'credit',
#   'cards'],
#  ['Ask', 'if', 'in', 'doubt'],
#  ['Some', 'of', 'taxi', 'companies', 'operating', 'in', 'the', 'city'],
#  ['Auto', 'Taxi', '+'],
#  ['City', 'Taxi', '+'],
#  ['Express', 'Taxi', '+'],
#  ['Euro', 'Taxi', '+'],
#  ['Gold', 'Taxi', '+'],
#  ['Granada', 'Taxi', '+'],
#  ['Szczecin', 'Taxi', '+'],
#  ['ImageSzczecinCastlejpgthumbCastle',
#   'FilePolandSzczecinPortGateJPGthumbHarbour',
#   'Gate',
#   'Brama',
#   'Portowa'],
#  ['Pomeranian',
#   'Dukes',
#   'Castle',
#   'Ksiazat',
#   'Pomorskich',
#   'which',
#   'houses',
#   'museum',
#   'restaurants',
#   'and',
#   'cafes'],
#  ['It',
#   'also',
#   'houses',
#   'tourist',
#   'information',
#   'office',
#   'you',
#   'can',
#   'get',
#   'some',
#   'free',
#   'maps',
#   'pamphlets',
#   'etc'],
#  ['here'],
#  ['Old',
#   'Town',
#   'Stary',
#   'Rynek',
#   'despite',
#   'being',
#   'jokingly',
#   'referred',
#   'to',
#   'by',
#   'locals',
#   'as',
#   'Brand',
#   'New',
#   'Old',
#   'Town',
#   'it',
#   'was',
#   'started',
#   'to',
#   'be',
#   'rebuilt',
#   'in',
#   'late',
#   's',
#   'the',
#   'reconstruction',
#   'is',
#   'still',
#   'ongoing',
#   'there',
#   'are',
#   'some',
#   'nice',
#   'houses',
#   'rebuilt',
#   'to',
#   'original',
#   'plans'],
#  ['Many', 'shops', 'restaurants', 'and', 'cafes'],
#  ['There', 'is', 'museum', 'situated', 'in', 'Old', 'Town', 'Hall'],
#  ['Kamienica',
#   'Loitzow',
#   'Loitzs',
#   'Tenement',
#   'interesting',
#   'tenement',
#   'just',
#   'next',
#   'to',
#   'Old',
#   'Town'],
#  ['Go',
#   'from',
#   'Old',
#   'Town',
#   'in',
#   'direction',
#   'of',
#   'Castle',
#   'and',
#   'youll',
#   'see',
#   'it',
#   'after',
#   'about',
#   'meters',
#   'on',
#   'the',
#   'left',
#   'side'],
#  ['It', 'is', 'painted', 'flashy', 'orange', 'you', 'cant', 'miss', 'it'],
#  ['Way',
#   'Chrobrego',
#   'German',
#   'name',
#   'Hakenterrasse',
#   'promenade',
#   'with',
#   'great',
#   'views',
#   'on',
#   'Oder',
#   'river',
#   'and',
#   'port'],
#  ['Many', 'cafes', 'are', 'situated', 'here'],
#  ['See',
#   'the',
#   'museum',
#   'Muzeum',
#   'Morskie',
#   'situated',
#   'just',
#   'in',
#   'the',
#   'center',
#   'of',
#   'Waly',
#   'which',
#   'houses',
#   'some',
#   'artifacts',
#   'from',
#   'history',
#   'of',
#   'the',
#   'city',
#   'and',
#   'also',
#   'has',
#   'big',
#   'collections',
#   'of',
#   'African',
#   'and',
#   'maritime',
#   'artifacts'],
#  ['Katedra',
#   'sw',
#   'Jakuba',
#   'St',
#   'Jacobs',
#   'Cathedral',
#   'big',
#   'Gothic',
#   'cathedral'],
#  ['Park',
#   'Kasprowicza',
#   'city',
#   'park',
#   'place',
#   'for',
#   'all',
#   'kinds',
#   'of',
#   'physical',
#   'activities',
#   'by',
#   'locals',
#   'spreading',
#   'through',
#   'nearly',
#   'all',
#   'of',
#   'the',
#   'city'],
#  ['Just', 'behind', 'the', 'City', 'Council'],
#  ['Park',
#   'Zeromskiego',
#   'another',
#   'city',
#   'park',
#   'situated',
#   'in',
#   'the',
#   'very',
#   'center',
#   'of',
#   'the',
#   'city',
#   'between',
#   'Waly',
#   'Chrobrego',
#   'and',
#   'Pazim/Galaxy'],
#  ['Cmentarz', 'Centralny', 'third', 'biggest', 'cemetery', 'in', 'Europe'],
#  ['S',
#   'blast',
#   '&',
#   'fallout',
#   'shelter',
#   'biggest',
#   'in',
#   'Poland',
#   'entry',
#   'z'],
#  ['Two', 'tours', 'to', 'choose', 'WWII', 'or', 'Cold', 'War'],
#  ['Pionier',
#   'Cinema',
#   'oldest',
#   'cinema',
#   'in',
#   'the',
#   'world',
#   'still',
#   'in',
#   'operation',
#   'est'],
#  [],
#  ['Railway',
#   'suspension',
#   'bridge',
#   'on',
#   'Regalica',
#   'something',
#   'for',
#   'railway',
#   'fans',
#   'the',
#   'only',
#   'one',
#   'of',
#   'a',
#   'kind',
#   'in',
#   'operation',
#   'in',
#   'Poland'],
#  ['Podjuchy', 'district', 'ul'],
#  ['Szklana', 'Huta'],
#  ['Emerald',
#   'Lake',
#   'jezioro',
#   'Szmaragdowe',
#   'and',
#   'Puszcza',
#   'Bukowa',
#   'lake',
#   'artificial',
#   'cave',
#   'and',
#   'forest',
#   'area',
#   'situated',
#   'in',
#   'Zdroje',
#   'district'],
#  ['Many',
#   'great',
#   'views',
#   'on',
#   'the',
#   'city',
#   'and',
#   'nice',
#   'area',
#   'for',
#   'one',
#   'day',
#   'hiking/bike',
#   'riding'],
#  ['Paac',
#   'pod',
#   'Globusem',
#   'Palace',
#   'under',
#   'the',
#   'Globe',
#   '/',
#   'Palace',
#   'of',
#   'Grumbkov',
#   'the',
#   'building',
#   'where',
#   'two',
#   'rulers',
#   'of',
#   'Russia',
#   'Catherine',
#   'II',
#   'and',
#   'Maria',
#   'Fiodorovna',
#   'were',
#   'born'],
#  ['Pl'],
#  ['Ora', 'Biaego'],
#  ['Parisienne',
#   'SubUrb',
#   'Many',
#   'historistic',
#   'and',
#   'art',
#   'nouveau',
#   'boulevards',
#   'in',
#   'prussian',
#   'pseudoparissienne',
#   'style',
#   'around',
#   'Plac',
#   'Grunwaldzki',
#   'Jagiellonska',
#   'and',
#   'Wielkopolska',
#   'streets'],
#  ['Museum',
#   'of',
#   'Technology',
#   'Muzeum',
#   'Techniki',
#   'has',
#   'nice',
#   'collection',
#   'of',
#   'vintage',
#   'cars',
#   'motorcycles',
#   'buses',
#   'and',
#   'trams'],
#  ['Niemierzynska', 'A'],
#  ['See',
#   'the',
#   'panorama',
#   'of',
#   'Szczecin',
#   'from',
#   'the',
#   'cafe',
#   'on',
#   'top',
#   'of',
#   'Pazim',
#   'building',
#   'just',
#   'by',
#   'Galaxy',
#   'shopping',
#   'center',
#   'admission',
#   'free',
#   'from',
#   'StJacobs',
#   'Cathedral',
#   'tower',
#   'paid',
#   'admission',
#   'or',
#   'from',
#   'one',
#   'of',
#   'the',
#   'towers',
#   'of',
#   'Pomeranian',
#   'Dukes',
#   'Castle'],
#  ['Take',
#   'a',
#   'trip',
#   'through',
#   'Szczecins',
#   'waterways',
#   'and',
#   'port',
#   'many',
#   'boats',
#   'go',
#   'from',
#   'the',
#   'river',
#   'bank',
#   'near',
#   'Way',
#   'Chrobrego'],
#  ['Kayak',
#   'through',
#   'the',
#   'city',
#   'and',
#   'lower',
#   'Oder',
#   'valley',
#   'if',
#   'you',
#   'dont',
#   'have',
#   'your',
#   'kayak',
#   'you',
#   'can',
#   'borrow',
#   'one',
#   'at',
#   'Kapielisko',
#   'Dziewoklicz',
#   'ul'],
#  ['Autostrada', 'Poznanska', 'public', 'transport', 'bus', 'No'],
#  ['stop',
#   'Dziewoklicz',
#   'or',
#   'any',
#   'of',
#   'the',
#   'neighbouring',
#   'towns',
#   'situated',
#   'by',
#   'the',
#   'Oder',
#   'river',
#   'look',
#   'for',
#   'wypozyczalnia',
#   'kajakow',
#   'kayak',
#   'rentals',
#   'or',
#   'kajaki',
#   'kayaks'],
#  ['See', 'dancing', 'fountain', 'near', 'Teatr', 'Pleciuga', 'ul'],
#  ['Wielkopolska'],
#  ['It',
#   'might',
#   'not',
#   'be',
#   'the',
#   'most',
#   'impressive',
#   'fountain',
#   'show',
#   'in',
#   'the',
#   'world',
#   'but',
#   'still',
#   'its',
#   'nice',
#   'eyecandy',
#   'and',
#   'its',
#   'free'],
#  ['The',
#   'show',
#   'lasts',
#   'minutes',
#   'and',
#   'starts',
#   'every',
#   'summer',
#   'day',
#   'at'],
#  ['Juwenalia', 'May'],
#  ['Baltic', 'Rock', 'Meeting', 'May', 'June'],
#  ['Dni', 'Morza', '/', 'Days', 'of', 'the', 'Sea'],
#  ['Boogie', 'Brain', 'Festival'],
#  ['Maritime', 'University', 'of', 'Szczecin', 'http//amszczecinpl'],
#  ['University', 'of', 'Szczecin', 'http//wwwusszcpl/'],
#  ['West',
#   'Pomeranian',
#   'University',
#   'of',
#   'Technology',
#   'http//wwwzutedupl/'],
#  ['Pomeranian', 'Medical', 'University', 'http//wwwpamszczecinpl/'],
#  ['Academy', 'of', 'Arts', 'http//wwwakademiasztukieu/'],
#  ['West', 'Pomeranian', 'Business', 'School', 'http//wwwzpsbszczecinpl/'],
#  ['English',
#   'teachers',
#   'and',
#   'IT',
#   'developers/engineers',
#   'are',
#   'in',
#   'high',
#   'demand'],
#  ['Szczecin', 'has', 'many', 'shopping', 'malls'],
#  ['Auchan', 'situated', 'in', 'Ustowo'],
#  ['Dont',
#   'go',
#   'there',
#   'if',
#   'you',
#   'dont',
#   'have',
#   'a',
#   'car',
#   'the',
#   'place',
#   'is',
#   'totally',
#   'pedestrian',
#   'unfriendly'],
#  ['Carrefour',
#   'situated',
#   'near',
#   'Media',
#   'Markt',
#   'mall',
#   'with',
#   'electronics',
#   'in',
#   'Pomorzany',
#   'district'],
#  ['Open'],
#  ['CH',
#   'Ster',
#   'situated',
#   'near',
#   'Castorama',
#   'big',
#   'shop',
#   'for',
#   'DIY',
#   'builders',
#   'in',
#   'Gumience',
#   'district',
#   'nearest',
#   'mall',
#   'from',
#   'the',
#   'German',
#   'border'],
#  ['Open'],
#  ['CH', 'Turzyn', 'another', 'mall', 'in', 'the', 'Center'],
#  ['Open'],
#  ['Kaskada',
#   'the',
#   'newest',
#   'and',
#   'the',
#   'biggest',
#   'shopping',
#   'mall',
#   'in',
#   'Szczecin',
#   'best',
#   'brands',
#   'and',
#   'spacious',
#   'foodcourt'],
#  ['Open'],
#  ['Galaxy', 'shopping', 'mall', 'many', 'outlets', 'of', 'major', 'brands'],
#  ['Situated', 'in', 'the', 'Centernear', 'Kaskada'],
#  ['Open'],
#  ['Tesco',
#   'another',
#   'one',
#   'just',
#   'across',
#   'the',
#   'street',
#   'of',
#   'the',
#   'Carrefour',
#   'mentioned',
#   'above'],
#  ['Open', '/'],
#  ['You',
#   'will',
#   'easily',
#   'find',
#   'global',
#   'favorites',
#   'like',
#   'hamburgers',
#   'hot',
#   'dogs',
#   'kebabs',
#   'pizza',
#   'etc',
#   'but',
#   'for',
#   'unique',
#   'Szczecin',
#   'twist',
#   'on',
#   'fast',
#   'food',
#   'try',
#   'paszteciki',
#   'plural',
#   'singular',
#   'is',
#   'pasztecik',
#   'which',
#   'are',
#   'kind',
#   'of',
#   'deep',
#   'fried',
#   'cake',
#   'with',
#   'meat',
#   'or',
#   'cheese',
#   'and',
#   'mushrooms',
#   'filling'],
#  ['They',
#   'taste',
#   'best',
#   'hot',
#   'and',
#   'combined',
#   'with',
#   'a',
#   'cup',
#   'of',
#   'barszcz',
#   'czerwony',
#   'red',
#   'beetroot',
#   'soup'],
#  ['Turysta', 'Milk', 'Bar', 'Obroncow', 'Stalingradu', 'a', 'open'],
#  ['Zacisze', 'Bar', 'Asnyka', 'Niebuszewo', 'district'],
#  ['Akademia', 'Kulinarna', 'Mickiewicza', 'open'],
#  ['Bar',
#   'Zen',
#   'Bohaterow',
#   'Warszawy',
#   'near',
#   'CH',
#   'Turzyn',
#   'Vietnamese',
#   'buddhist',
#   'cuisine',
#   'vegan',
#   'open'],
#  ['Amar',
#   'Slaska',
#   'open',
#   'MondayFriday',
#   'Saturday',
#   '&',
#   'Sunday',
#   'vegan',
#   '&',
#   'vegetarian'],
#  ['If',
#   'you',
#   'are',
#   'on',
#   'limited',
#   'budget',
#   'order',
#   'their',
#   'danie',
#   'dnia',
#   'dish',
#   'of',
#   'a',
#   'day',
#   'and/or',
#   'zupa',
#   'dnia',
#   'soup',
#   'of',
#   'a',
#   'day',
#   'which',
#   'are',
#   'always',
#   'very',
#   'affordable'],
#  ['Brama',
#   'Jazz',
#   'Cafe',
#   'Plac',
#   'Hodu',
#   'Pruskiego',
#   'Mexican',
#   '&',
#   'fusion'],
#  ['Camarillo', 'Msciwoja', 'fusion'],
#  ['Green',
#   'Way',
#   'Krzywoustego',
#   'open',
#   'MondayFriday',
#   'weekends',
#   'vegetarian'],
#  ['Golden', 'Dragon', 'Jana', 'Kazimierza', 'Chinese'],
#  ['Mandaryn', 'ul'],
#  ['Bolesawa', 'Smiaego', 'Chinese'],
#  ['Bombay', 'Partyzantow', 'Indian'],
#  ['Chief', 'Rayskiego', 'all', 'kinds', 'of', 'sea', 'food'],
#  ['adoga', 'Jana', 'z', 'Kolna', 'Russian'],
#  ['Sake', 'Piastow', 'Japanese'],
#  ['Sushi',
#   'Mado',
#   'Pocztowa',
#   'entry',
#   'from',
#   'Bohaterow',
#   'Warszawy',
#   'Japanese'],
#  ['Columbus', 'On', 'Waly', 'Chrobrego', 'by', 'Marine', 'Academy'],
#  ['Colorado', 'on', 'Waly', 'Chrobrego', 'by', 'Polski', 'Theatre'],
#  ['Colorado', 'on', 'Waly', 'Chrobrego', 'by', 'Polski', 'Theatre'],
#  ['Karczma', 'Polska', 'Lotnikow', 'Square'],
#  ['Szpilka', 'ulMaopolska', 'Delicious', 'fusion'],
#  ['The',
#   'majority',
#   'of',
#   'pubs',
#   'and',
#   'bars',
#   'can',
#   'be',
#   'found',
#   'in',
#   'the',
#   'old',
#   'town',
#   'Stary',
#   'Rynek',
#   'or',
#   'around',
#   'ul'],
#  ['Bogusawa', 'in', 'the', 'middle', 'town', 'area'],
#  ['Expect',
#   'to',
#   'pay',
#   'between',
#   'zl',
#   'and',
#   'zl',
#   'for',
#   'a',
#   'large',
#   'beer',
#   'and',
#   'around',
#   'zl',
#   'for',
#   'a',
#   'ml',
#   'shot',
#   'of',
#   'vodka'],
#  ['Bosman', 'beer', 'is', 'made', 'by', 'local', 'brewery'],
#  ['There',
#   'are',
#   'variants',
#   'with',
#   'red',
#   'czerwony',
#   'and',
#   'green',
#   'zielony',
#   'label',
#   'both',
#   'of',
#   'them',
#   'are',
#   'lager'],
#  ['You',
#   'can',
#   'buy',
#   'it',
#   'at',
#   'most',
#   'of',
#   'general',
#   'stores',
#   'and',
#   'some',
#   'pubs'],
#  ['Taverna',
#   'pub',
#   'has',
#   'its',
#   'own',
#   'microbrewery',
#   'making',
#   'lager',
#   'and',
#   'porter',
#   'type',
#   'beers'],
#  ['Starka',
#   'is',
#   'a',
#   'special',
#   'kind',
#   'of',
#   'seasoned',
#   'vodka',
#   'made',
#   'by',
#   'Polmos',
#   'Szczecin',
#   'distillery'],
#  ['There', 'are', 'variants', 'which', 'are', 'and', 'years', 'old'],
#  ['You',
#   'can',
#   'buy',
#   'them',
#   'at',
#   'Polmos',
#   'store',
#   'situated',
#   'corner',
#   'of',
#   'Jagiellonska',
#   'and',
#   'Bohaterow',
#   'Warszawy',
#   'streets',
#   'as',
#   'you',
#   'can',
#   'guess',
#   'Starka',
#   'is',
#   'rather',
#   'expensive',
#   'especially',
#   'the',
#   'year',
#   'old',
#   'one',
#   'and',
#   'available',
#   'only',
#   'in',
#   'limited',
#   'amounts'],
#  ['You',
#   'can',
#   'also',
#   'tour',
#   'the',
#   'factory',
#   'is',
#   'quite',
#   'interesting',
#   'tasting',
#   'Starka',
#   'is',
#   'included',
#   'with',
#   'the',
#   'tour',
#   'email',
#   'them',
#   'for',
#   'booking',
#   'and',
#   'information'],
#  ['Alter', 'Ego', 'pl'],
#  ['Batorego'],
#  ['Brama', 'Jazz', 'Cafe', 'ul'],
#  ['Hodu', 'Pruskiego'],
#  ['City', 'Council', 'building', 'pl'],
#  ['Armii', 'Krajowej'],
#  ['CH', 'Galaxy', 'ul'],
#  ['Wyzwolenia'],
#  ['whole', 'ul'],
#  ['Bogusawa'],
#  ['every', 'KFC', 'outlet'],
#  ['every', 'McDonalds'],
#  ['Ksiaznica', 'Pomorska', 'public', 'library', 'ul'],
#  ['Podgorna', '/'],
#  ['SzczecinGoleniow', 'Airport'],
#  ['Park',
#   'Kasprowicza',
#   'city',
#   'park',
#   'Jasne',
#   'Bonia',
#   'whole',
#   'area',
#   'between',
#   'City',
#   'Council',
#   'building',
#   'and',
#   'Three',
#   'Eagles',
#   'monument'],
#  ['Piwnica', 'przy', 'Kanie', 'pl'],
#  ['sw', 'Piotra', 'i', 'Pawa', '/'],
#  ['Politechnika',
#   'Szczecinska',
#   'Wydzia',
#   'Mechaniczny',
#   'Technical',
#   'University',
#   'of',
#   'Szczecin',
#   'al'],
#  ['Piastow'],
#  ['Pub', 'Colorado', 'Way', 'Chrobrego', 'a'],
#  ['Uniwersytet',
#   'Szczecinski',
#   'Wydzia',
#   'Nauk',
#   'Ekonomicznych',
#   'i',
#   'Zarzadzania',
#   'University',
#   'of',
#   'Szczecin',
#   'ul'],
#  ['Mickiewicza'],
#  ['Wyzsza',
#   'Szkoa',
#   'Administracji',
#   'Publicznej',
#   'Higher',
#   'School',
#   'of',
#   'Public',
#   'Administration',
#   'ul'],
#  ['Marii', 'CurieSklodowskiej'],
#  ['Zachodniopomorska',
#   'Szkoa',
#   'Biznesu',
#   'Budynek',
#   'A',
#   'West',
#   'Pomeranian',
#   'Business',
#   'School',
#   'ul'],
#  ['Zonierska'],
#  ['Szczecin',
#   'used',
#   'to',
#   'be',
#   'infamous',
#   'in',
#   'Poland',
#   'for',
#   'its',
#   'organized',
#   'crime',
#   'but',
#   'these',
#   'days',
#   'are',
#   'long',
#   'gone',
#   'nearly',
#   'all',
#   'the',
#   'gangsters',
#   'are',
#   'dead',
#   'or',
#   'in',
#   'prison'],
#  ['Nowadays', 'it', 'is', 'a', 'very', 'safe', 'city'],
#  ['However',
#   'you',
#   'should',
#   'stay',
#   'away',
#   'from',
#   'some',
#   'of',
#   'its',
#   'bad',
#   'suburbs',
#   'like',
#   'Gocaw',
#   'especially',
#   'after',
#   'dark'],
#  ['As', 'always', 'use', 'your', 'common', 'sense'],
#  ['Be',
#   'careful',
#   'when',
#   'crossing',
#   'streets',
#   'jaywalking',
#   'is',
#   'a',
#   'crime',
#   'in',
#   'Poland',
#   'and',
#   'the',
#   'police',
#   'often',
#   'lie',
#   'in',
#   'wait',
#   'for',
#   'tourists',
#   'crossing',
#   'streets',
#   'when',
#   'the',
#   'pedestrian',
#   'crossing',
#   'is',
#   'on',
#   'red'],
#  ['If',
#   'stopped',
#   'claim',
#   'that',
#   'your',
#   'money',
#   'and',
#   'passport',
#   'are',
#   'in',
#   'your',
#   'hotel',
#   'and',
#   'you',
#   'may',
#   'get',
#   'away',
#   'with',
#   'it'],
#  ['Cyprus', 'ul'],
#  ['Slaska', '/'],
#  ['Czech', 'Republic', 'ul'],
#  ['Monte', 'Cassino', '/'],
#  ['Denmark', 'ul'],
#  ['Pisudskiego', 'a', '/'],
#  ['Estonia', 'ul'],
#  ['Kurza', 'Stopka', '/cd', '/'],
#  ['France', 'ul'],
#  ['SkodowskiejCurie', '/'],
#  ['Germany', 'ul'],
#  ['Chodkiewicza', 'a', '/'],
#  ['Kazakhstan', 'ul'],
#  ['Grodzka', '/', '/'],
#  ['Mexico', 'ul'],
#  ['Energetykow', '/', '/'],
#  ['Norway', 'ul'],
#  ['Niepodlegosci', '/'],
#  ['Slovakia', 'ul'],
#  ['SkodowskiejCurie', '/'],
#  ['Sweden', 'ul'],
#  ['SkodowskiejCurie', '/'],
#  ['United', 'Kingdom', 'ul'],
#  ['Starego', 'Wiarusa', '/'],
#  ['On', 'the', 'mainland'],
#  ['The',
#   'town',
#   'of',
#   'Police',
#   'and',
#   'its',
#   'Jasienica',
#   'district',
#   'monuments',
#   'from',
#   'the',
#   'Middle',
#   'Ages',
#   'small',
#   'marina',
#   'in',
#   'the',
#   'Old',
#   'Town',
#   'on',
#   'the',
#   'arpia',
#   'Oder',
#   'River',
#   'and',
#   'WWII',
#   'ruins',
#   'of',
#   'Hydrierwerke',
#   'synthetic',
#   'gasoline',
#   'factory'],
#  ['Szczecin',
#   'shares',
#   'its',
#   'public',
#   'transport',
#   'with',
#   'Police',
#   'and',
#   'borders',
#   'the',
#   'town',
#   'you',
#   'can',
#   'go',
#   'to',
#   'Police',
#   'by',
#   'taking',
#   'public',
#   'bus'],
#  ['sea', 'resort', 'and', 'medieval', 'town', 'of', 'Kamien', 'Pomorski'],
#  ['sea', 'resort', 'and', 'medieval', 'town', 'of', 'Koobrzeg'],
#  ['Gothic', 'church', 'ruins', 'in', 'Trzesacz'],
#  ['medieval',
#   'town',
#   'of',
#   'Stargard',
#   'Szczecinski',
#   'with',
#   'a',
#   'cathedral',
#   'over',
#   'a',
#   'hundred',
#   'metres',
#   'high'],
#  ['birds', 'reservation', 'in', 'Swidwie'],
#  ['Miedzyodrze',
#   'Lower',
#   'Oder',
#   'valley',
#   'picturesque',
#   'marsh',
#   'area',
#   'full',
#   'of',
#   'wildlife'],
#  ['quiet', 'medieval', 'town', 'of', 'Nowe', 'Warpno'],
#  ['resort', 'of', 'Trzebiez', 'with', 'big', 'marina'],
#  ['On', 'the', 'Wolin', 'island'],
#  ['Wolinski', 'National', 'Park'],
#  ['Game', 'reserve', 'of', 'wisents'],
#  ['metres', 'high', 'Gosan', 'cliff'],
#  ['Kawcza', 'Gora', 'Mountain'],
#  ['sea', 'resort', 'and', 'port', 'Swinoujscie'],
#  ['sea', 'resort', 'Dziwnow'],
#  ['sea', 'resort', 'Miedzyzdroje'],
#  ['ancient', 'town', 'of', 'Wolin', 'town'],
#  ['medieval', 'town', 'of', 'Lubin'],
#  ['CommonsSzczecin',
#   'WikipediaSzczecin',
#   'DmozRegional/Europe/Poland/Voivodships/Western',
#   'Pomerania/Szczecin']]

# %%
s = parsed_test_wo_dict[117]

# %%
s
# Out:
# ['You', 'can', 'buy', 'tickets', 'from', 'vending', 'machines']

# %%
s = remove_file_https_links(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-493-520d54280bc3> in <module>()
# ----> 1 s = remove_file_https_links(s)
#
# <ipython-input-485-e95088894402> in remove_file_https_links(string)
#       7     m = re.sub(r'(\=+\w+\=+)','', m)
#       8     #get rid of ], [, '. E.g. [[Paris]] --> Paris
# ----> 9     m = re.sub(r'[\[\]\']','',unicodedata.normalize('NFKD', m).encode('ascii','ignore')).strip()
#      10
#      11     return m
#
# TypeError: must be unicode, not str

# %%
s = sent_tokenize(s)

# %%
s
# Out:
# ['CH Turzyn - another mall in the Center.', 'Open 8:00-21:00.']
