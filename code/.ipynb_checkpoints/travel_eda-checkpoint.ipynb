# %% [markdown]
# # WIKIVOYAGE EDA

# %%
import pandas as pd
import json
from collections import defaultdict
import unicodedata
import mistune
from bs4 import BeautifulSoup
import string
import re
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from sklearn.manifold import MDS
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Load & Extract Articles

# %%
with open('../data/wikivoyage.json','rb') as f:
    data = json.loads(f.read())

# %% [markdown]
# ###Extract Article texts

# %%
articles = data['mediawiki']['page']

# %% [markdown]
# ### Save Articles by Titles

# %%
articles_dict = {}
for article in articles:
    # Lets strip the accents using unicodedata
    title = unicodedata.normalize('NFKD', article['title']).encode('ascii','ignore')
    articles_dict[title] = article

# %%
articles_dict.keys()[:10]
# Out:
# ['',
#  'Category:Articles needing style fixes',
#  'Szczecin',
#  'Category:West High Country',
#  'Rugia',
#  'New Australia',
#  'Natchez, Mississippi',
#  'File:WV new main page at 1920px.PNG',
#  'Nampa',
#  'Category:Pangasinan']

# %% [markdown]
# __You can see that some articles are files, categories ,etc with : in their names.
# Lets see how many of these there are.__

# %%
junk_articles_dict = defaultdict(int)
for article in articles:
    title = article['title']
    if ':' in title:
        junk_articles_dict[title.split(':')[0]] += 1

print len(junk_articles_dict)
junk_articles_dict
# Out:
# 11
# defaultdict(<type 'int'>, {u'Category': 4561, u'Itinerary': 1, u'General/Wikivoyage': 1, u'MediaWiki': 142, u'File': 816, u'Poland': 1, u'La Manzanilla': 1, u'Module': 23, u'Wikivoyage': 1561, u'Template': 1043, u'Help': 8})

# %% [markdown]
# __There are a lot of special type articles. Let's actually take a look at the content to see if they are useful.__

# %%
special_articles_dict = defaultdict(list)
for article in articles:
    title = article['title']
    if ':' in title:
        if len(special_articles_dict[title.split(':')[0]]) < 5:
            special_articles_dict[title.split(':')[0]].append(article) 

print len(special_articles_dict)
special_articles_dict.keys()
# Out:
# 11
# [u'Category',
#  u'Itinerary',
#  u'General/Wikivoyage',
#  u'MediaWiki',
#  u'File',
#  u'Poland',
#  u'La Manzanilla',
#  u'Module',
#  u'Wikivoyage',
#  u'Template',
#  u'Help']

# %% [markdown]
# __Let's take a look at two most common special type articles__

# %%
special_articles_dict['MediaWiki']
# Out:
# [{u'id': u'69005',
#   u'ns': u'8',
#   u'revision': {u'comment': u'+arytrekking\\.com',
#    u'contributor': {u'id': u'36420', u'username': u'Ikan Kekek'},
#    u'format': u'text/x-wiki',
#    u'id': u'2796508',
#    u'model': u'wikitext',
#    u'parentid': u'2781066',
#    u'sha1': u'l0bq8j7kgs7ttk8ngewi2h36byn4q61',
#    u'text': {u'#text': u'#{{shortcut|[[Spam]]<br>[[Blacklist]]}} \n #{{notice|\'\'\'DO NOT\'\'\' remove any URL or pattern from this list without first gaining consensus on [[{{TALKSPACE}}:{{PAGENAME}}]]. In addition to being used to block automated spam attacks this list is also occasionally used to stop persistent abuse of the [[Project:External links]] and [[Project:Don\'t tout]] policies.  Please add violators of the external links policy to this page \'\'\'ONLY\'\'\' after first trying to educate the user about why the link is inappropriate.  When adding external link violators to this page please explain the reason for the addition on [[{{TALKSPACE}}:{{PAGENAME}}]].}}\n\n # This is the local blacklist for Wiki spam URLs for Wikivoyage. It\'s used\n # by the \'\'\'[[Project:spam filter|spam filter]]\'\'\' to block contributions that use these URLs.\n #\n # To add a URL to the spam filter list just add the spam URL including\n # everything \'\'\'after\'\'\' the "http://" and \'\'\'before\'\'\' the first "/" to the list. \n #\n # In addition, the spam filter uses what are called regular expressions, so\n # special characters such as periods need to be escaped by putting a "\\" in\n # front of them.\n #\n # For example, <nowiki>"http://spam.spammer.net/foo.html"</nowiki> would be added as\n # "spam\\.spammer\\.net".  Notice that we don\'t include the "http://" nor\n # anything after the first "/" following the "http://" so "/foo.html" should\n # not be added.\n #\n # One caveat is that if the entire domain seems to be used only for spam we\n # don\'t bother to worry about sub-domains and in the example above would just\n # list "spammer\\.net".  \n #\n # For the spam filter to work properly you must indent one (1) space. It\n # helps everyone stay sane and find things better if the list is in\n # alphabetical order.\n #\n # External URLs matching this list will be blocked when added to a page.\n # This list affects only this wiki; refer also to the global blacklist.\n # For documentation see http://www.mediawiki.org/wiki/Extension:SpamBlacklist\n #\n # Syntax is as follows:\n #   * Everything from a "#" character to the end of the line is a comment\n #   * Every non-blank line is a regex fragment which will only match hosts inside URLs\n\n (Yangshuo).*(Julie)\n ((t|T)op.?level.?tour)\n 1cheaphotels\\.com\n 1carrental\\.org\n a-prague\\.com\n a2zrooms\\.com\n aaalimos\n abetterstay\\.com\n activetravelvietnam\\.com\n adollarhost\\.com\n adriatic-express\\.com\n africabusiness\\.com\n www\\.africanbluetours\\.com\n aiguarentacar\\.it\n air520\\.com\n airline-tickets\\.kwik\\.to\n airporttaxicabservices\\.com\n al-sufarahotel\\.com\n alemi2424\\.blogspot\\.com\n alemi24@gmail\\.com\n alfamahouse\\.com\n alleurohotels\\.com\n all-hotels-motels\\.com\n allmovieshere\\.servik\\.com\n amorpensionhouse\\.webs\\.com \n anycarhire\\.com\n apartmentsabroad\\.com\n apartmentsholiday\\.com\n apnabus\\.in\n archsanblas\\.tripod\\.com \n arguscarhire\\.com\n argusrentals\\.com\n aroundworld\\.in\\.ua\n arytrekking\\.com\n artofafricasafari\\.com\n auto-europe\\.co\n ayachtcharterathens\\.com\n ayachtcharterbodrum\\.com\n ayachtchartergreece\\.com\n ayachtcharteribiza\\.com\n ayachtcharteritaly\\.com\n ayachtchartermarmaris\\.com\n ayachtcharterspain\\.com\n ayachtcharterturkey\\.com\n azul-barcelona\\.com\n baligotours\\.com\n balipropertyconsultancy\\.com\n bandarbantours\\.com\n www\\.barcelonacheckin\\.com\n barcelonapoint\\.com\n bargains-hunter\\.blogspot\\.com\n baylodging\\.com\n bbvaticanstpeter\\.com\n bedandbreakfastmare\\.it\n begin_of_the_skype_highlighting\n benusang\n bh-hotels\\.com\n bienngoccruise\\.com\n bluesardiniaholidays\\.com\n www\\.booking\\.com\n boracay\\.cc\n boracay\\.org\\.ph\n boracay-packages\\.com\n boracay4less\\.com\n boracaypackages\\.spaces\\.live\\.com \n boracaypackages\\.net\n boracayregency\\.com\n boracayvacationpackages\\.com\n borneotourgigant\\.com\n budget\\.co\\.uk\n budpocketguide\\.com\n but ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-05-26T10:04:51Z'},
#   u'title': u'MediaWiki:Spam-blacklist'},
#  {u'id': u'69006',
#   u'ns': u'8',
#   u'revision': {u'comment': u'this is a legitimate listing that should be allowed',
#    u'contributor': {u'id': u'109373', u'username': u'Texugo'},
#    u'format': u'text/x-wiki',
#    u'id': u'2560091',
#    u'model': u'wikitext',
#    u'parentid': u'2389682',
#    u'sha1': u'scyypemwlpv7aq9jnukfart07dr1y5o',
#    u'text': {u'#text': u"#This is the local whitelist for URLs that are being incorrectly blocked by the [[Project:Spam filter]]. \n #Note that this list will have no effect on patterns being blocked by the [[Project:Local spam blacklist]], but it will unblock patterns that are being blocked by the http://wikivoyage.org/bannedcontent.txt list. \n #Note that the whitelist pattern must ''exactly'' match the pattern from the banned content list in order to be unblocked.\n\n #To add URLs or URL fragments to this list, add them in in alphabetical order between the pre tags, and indent one (1) space. \n #You should also leave a note on the [[Project:Local spam whitelist|talk page]] indicating why the URL is valid.\n\n#<pre>\n \\w+\\.sh\\.cn\n 00100roma\\.it\n aladdincasino\\.com\n albury-wodonga\\.com\n almaty-bus\\.narod\\.ru\n almaty-tramway\\.narod\\.ru\n almaty-trolleybus\\.narod\\.ru\n biscuit-palace\\.com\n casinovenezia\\.it\n chinabeijinghotel\\.com\\.cn\n china\\.com\n cuc\\.edu\\.cn\n cyu\\.edu\\.cn\n donga\\.com\n expo2010china\\.com\n freewebs\\.com\n fremontcasino\\.com\n gb\\.com\n geocities\\.com\n goldcoastcasino\\.com\n joes\\.com\n luggagestoregallery\\.org\n mainstreetcasino\\.com\n milfordplaza\\.com\n milford\\.com\n Milford\n nouveaucasino\\.net\n nynyhotelcasino\\.com\n pharmacymuseum\\.org\n pralniawodnik\\.republika\\.pl\n premiumflats\\.com\n reefcasino\\.com\\.au\n stbishoy\\.8k\\.com\n u-tokyo\\.ac\\.jp\n wikivoyage\\.org\n ya\\.ru\n#</pre>\n\n#{{WikivoyageDoc|administration}}\n\n#[[ru:Project:Spam whitelist]]\n#[[sv:Project:L\xe4nkar som inte skall blockeras]]",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2014-03-31T11:28:59Z'},
#   u'title': u'MediaWiki:Spam-whitelist'},
#  {u'id': u'78090',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Restore upgrade deletion problem (Import from wikitravel.org/en)',
#    u'contributor': {u'id': u'81383', u'username': u'EvanProdromou'},
#    u'format': u'text/x-wiki',
#    u'id': u'1850421',
#    u'model': u'wikitext',
#    u'sha1': u'rvpy29ko1t8vosvmt168nkph5xpneuf',
#    u'text': {u'#text': u'About Docents', u'@xml:space': u'preserve'},
#    u'timestamp': u'2007-07-02T13:02:37Z'},
#   u'title': u'MediaWiki:Aboutdocent'},
#  {u'id': u'78091',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879147',
#    u'model': u'wikitext',
#    u'parentid': u'1850423',
#    u'sha1': u'd5kvojs0geevrb5gt4nyso31trh02v7',
#    u'text': {u'#text': u'Wikivoyage:What is a docent?',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Aboutdocentpage'},
#  {u'id': u'78092',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879148',
#    u'model': u'wikitext',
#    u'parentid': u'1850424',
#    u'sha1': u'ofn3tpgcinir20ysedeykrruclghdm8',
#    u'text': {u'#text': u'Combined display of all available logs of {{SITENAME}}.\nYou can narrow down the view by selecting a log type, the user name, or the affected page.\n\n\n[[de:Special:Log]]\n\n[[es:Special:Log]]\n[[fi:Special:Log]]\n[[fr:Special:Log]]\n\n\n[[hu:Special:Log]]\n[[it:Special:Log]]\n[[ja:Special:Log]]\n[[nl:Special:Log]]\n[[pl:Special:Log]]\n[[pt:Special:Log]]\n[[ro:Special:Log]]\n[[ru:Special:Log]]\n[[sv:Special:Log]]',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Alllogstext'}]

# %%
special_articles_dict['Wikivoyage']
# Out:
# [{u'id': u'1539',
#   u'ns': u'4',
#   u'revision': {u'comment': u'isPartOf',
#    u'contributor': {u'id': u'1844', u'username': u'Globe-trotter'},
#    u'format': u'text/x-wiki',
#    u'id': u'2043579',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'1923444',
#    u'sha1': u'q2bedim1zidlfvjh6qy4zo6xf076gon',
#    u'text': {u'#text': u'{{joke}}\n\n\'\'\'Arial\'\'\' (Goudy: \'\'Helvetica\'\'), on [[Wikivoyage:Joke articles/Lower Caisse|Lower Caisse]], is a smaller and quieter town than hurly-burly [[Wikivoyage:Joke articles/Bodoni|Bodoni]], but travellers will get a chance to experience the \'\'real\'\' [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]] on a visit to this town.\n\nFounded in the 19th century by a colony of Swiss Utopians fleeing persecution in their own country, Arial has a Nordic look with somewhat more steeply sloped tin roofs to the buildings. The city is worth visiting for its period architecture and its white spaces. \n\n==Get in==\n===By parachute===\nUS navy aircraft regularly overfly the city. If you hitch a ride with them, you can drop in. This is by far the most convenient way of entering the city. \n\n===By helicopter===\nHelicopters can be hired from Poor Richard in [[Wikivoyage:Joke articles/Port Clarendon|Port Clarendon]]. As there is no helipad, you will have to \'\'\'rappel down\'\'\' once you reach your destination.\n\n==Get around==\n\n==See==\n\n[[Image:MissionSanJoseCA.LYH.jpg|right|thumb|The Spanish Mission is old.]]\n* \'\'\'Mission San Serriffe\'\'\'.  The oldest building in the country, the mission was built during the brief and ill-fated Spanish colonization period of the country.  The Mission\'s "leaning" attitude is one of the few remaining examples in the world of the "Italic Style" popular in Spain during the early 1500s. Islanders often come here for shelter during thunderstorms to pray for a blue skies to return.  Sometimes their prayers are answered, particularly during years when the El Ni\xf1o weather pattern is operating.\n\n==Do==\n\n* \'\'\'Pray for blue skies\'\'\' with the indigenous population wherever you may find yourself during a downpour.  It\'s a great way to immerse yourself in the local culture as this is one of the most popular pastimes on the island.\n* \'\'\'Jump\'\'\' Once a year on 31st June, you can participate in the Mission Jump. This bungee jump takes places off the Mission San Serriffe. Though you should beware of Rod Transparent objects, as they have caused problems in the past.\n\n==Buy==\n\n==Eat==\n*Aharoni is the pasta delicacy of the area, while bolder travellers may like to try the famous Magneto ice cream.\n\n==Drink==\n*Should you ever find yourself out and about Arial, completely thirsty and in need of a drink, visit the newly built pub, the Parchment.\n\n==Sleep==\n\n==Go next==\n\n{{joke}}\n{{isPartOf|Wikivoyage:Joke articles/Lower_Caisse}}',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-12-14T17:35:40Z'},
#   u'title': u'Wikivoyage:Joke articles/Arial'},
#  {u'id': u'1888',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Conversion of 5 legacy XML listings to [[Template:Listing]] per [[Wikivoyage talk:Listings#Tags to templates]]',
#    u'contributor': {u'id': u'210638', u'username': u'Wrh2Bot'},
#    u'format': u'text/x-wiki',
#    u'id': u'2316040',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'2192469',
#    u'sha1': u'm3sb7wodgdaxbns7rkpnw1tnq5vweal',
#    u'text': {u'#text': u'{{joke}}\n\n[[Image:Kelp forest on high profile reef P9041231.JPG|thumb|300px|Another day in Atlantis]]\n\n\'\'\'Atlantis\'\'\' is in the [[Islands of the Atlantic Ocean|Atlantic Ocean]]. Literally.\n\n==Regions==\n\n==Cities==\n* \'\'\'[[Bensalem]]\'\'\' - the largest city, founded by [[:WikiPedia:New Atlantis|Sir Francis Bacon]]. The sign says the city is where "generosity and enlightenment, dignity and splendour, piety and public spirit" are the norms of the local residents. It\'s a load of crock. \'\'\'Salomon\'s House\'\'\' is worth a visit, though.\n\n==Other destinations==\n\n==Understand==\n[[Image:Athanasius Kircher\'s Atlantis.gif|thumb|250px|Map of Atlantis, however, it might not be up to date]]\nAtlantis is a unique destination on the bottom of the Atlantic Ocean. It is governed by President Poseidon.\n\n===History===\nAtlantis allegedly sunk to the bottom of the ocean when the classified [[:WikiPedia:Eureka_(word)#Archimedes|Eureka!]]-project led by Archimedes went horribly wrong. \nIt is also <strike>suspected</strike> rumored that the [[:Wikipedia:New World Order (conspiracy theory)|New World Order]] had something to do with that event. Among the first visitors was the Greek philosopher Plato.\n\n==Talk==\nThe official language is [[Greek phrasebook|Ancient Greek]], but major world languages are spoken in establishments aimed at tourists.\n\n==Get in==\n{{VisaRestriction|[[Wikivoyage:Joke articles/Hell (Hades)|Hell]] blocks passports containing stamps or visas from Atlantis. Relations between Hades (Dictator of Hell) and President Poseidon have been strained after the [[:Wikipedia:The Lightning Thief|lightning bolt theft incident]]. If you plan to travel to [[Wikivoyage:Joke articles/Hell (Hades)|Hell]] after visiting Atlantis, you must get a second passport.}}\n[[Image:Yonaguni Ruins Scuba.jpg|thumb|300px|Diving offers a more intimate entrance into Atlantis]]\nTo get in to Atlantis you will need a valid visa and [[diving]] equipment. The most difficult part is knowing where to go, as Atlantis is not marked on regular maps.\n\n===By submarine===\nSome submarines are known to transport visitors to and from Atlantis. Prices are, however in the same class with tickets to [[space]].\n\n===By plane===\n\'\'\'Atlantis International Airport\'\'\' is connected by regular flights from [[Bermuda]] operated by Triangle Airlines and Oceanic Airlines. The return ticket will, however be virtually impossible to get. There are also non-stop flights from [[Mount Olympus]].\n\n===By train===\n\'\'\'Atlantis Train Station\'\'\' is served by 5000mph maglev trains coming from [[New York City|New York]] and [[London]] via the  [[:Wikipedia:Transatlantic tunnel|Transatlantic Tunnel]]. From [[London#By_train|London\'s Kings Cross Station]], take the train from [[:Wikipedia:Platform 9 \xbe|Platform 9 \xbe]]. From [[New_York_City#By_train|New York Grand Central Station]], trains leave from the [[:Wikipedia:Grand_Central_Station#Layout|"secret" sub-basement known as M42]].\n\n===By diving===\nThe backpacker\'s alternative - cheap and reliable. If you take your own sail boat it\'ll be very cheap.\n\n===By teleport===\nCheap as free! Just close your eyes and wish really hard. Next thing you know you are there!\n\n===By ruby slippers===\nClose your eyes, click your heels. Then just keep saying "There is no place like home, there\'s no place like home..."\n\n==Get around==\n===By subway===\n[[File:NYC Subway Atlantic Ave Station.jpg|thumb|200px|Atlantic Avenue Station: The Atlantis Subway System suffers from neglect and mismanagement.]]\nThousands of years ago, Atlantis was renowned for its cutting-edge mass transit system, but centuries of neglect, mismanagement, and extensive use have taken their toll. Vehicles are noisy and break down on a regular basis, the interiors are crowded, and the drivers can be very rude. On top of that, with recent budget cuts the fares keep rising. But the system is extensive and will ev ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-06-24T23:51:18Z'},
#   u'title': u'Wikivoyage:Joke articles/Atlantis'},
#  {u'id': u'4134',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* See */ Replace broken image',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420760',
#    u'model': u'wikitext',
#    u'parentid': u'2174923',
#    u'sha1': u'c4aq6msdqrmy50tkg11f7i7r4dyalbe',
#    u'text': {u'#text': u"{{joke}}\n\n'''Bodoni''' is [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]]'s tropical capital. With its heritage of Brutalist concrete architecture intermixed with the spices and mayhem of the South Seas, Bodoni presents a bold face to \nthe world and to the curious traveler.\n\n[[Image:Unarizaki PineappleHouse.JPG|thumb|400px|The Pineapple House, a local landmark]]\n\n==Understand==\n\n\n\n==Get in==\n\n===By plane===\n\n'''National Hero Antonio Bourgeois International Airport''' (IATA code: '''NHB''') is located just outside the city limits.  It's a bit too far to walk, so consider hiring a donqtuque to take you there.\n\n===By car===\n\nIf you want to get here by car, your car's wheels must be strong enough because there are many sharp stones on the city streets.\n\n===By bus===\n\nThere is only one bus service every day connecting the city hall and the mayor's official residence.\n\n===By boat===\n\nYour boat must be strong enough and not attract the sharks.\n\n==Get around==\nBecause of the small number of taxis (the only 4 licences are held by the President's sons), it is very difficult to catch one. Fights are very common and are encouraged by government as a way to solve disputes. The last man standing has the right to use the taxi. Unfortunately two of President's sons have a passion for gambling so don't be surprised if they lose the taxi at it while you're fighting.\n\n==See==\n\n* '''Pilcrow Palace''', 61 Avenida do Plenk.  An architectural landmark shaped like the letter P, painted in imposing shades of gray and constructed on the order of General Pica.  Now open to the public, sights inside include the mirror-lined '''Combat Duty Bedroom of the General''' and the grim '''Disco Inferno''', where political dissidents were subjected to reruns of ''Saturday Night Fever'' until they broke down and confessed.  Open alternate Tuesdays from 9:45 to 10:30 AM, admission 200 dR.\n* '''Hai Phen''', avenida do Bahia Tilde (''go the end of the trolley line, then join up with the beginning''). Bodoni's Little Chinatown, the Hai Phen district features many different kinds of spicey and ginger-scented swarfega prepared in Chinese style. Legal and gray-market CDs and DVDs are available, but be careful: many are region 8 encoded and dubbed over in Goudy.\n\n==Do==\n*'''Bodoni Theatre of the Incomprehensible''', 15 Avenida du Enigma. Actors perform on a giant scrabble board while the audience plays scrabble. Words from any of San Serriffe's many languages are allowed. As each word forms, the actors weave it into the story and continue the performance. The performance is known as a '''Play on Words'''. Tickets 125 dRn. (''Includes a complementary bottle of Plenque'')\n\n==Learn==\n\n==Work==\n\n==Buy==\n[[Image:Chipata_Market_Beans.JPG|thumb|Shopping at the Bean Market]]\n\n* '''Bean Market''' (''Mercado do Feij\xe3o'').  Popular among souvenir-shoppers, this market offers a wide selection of white beans, violet beans, purple beans and, on festive occasions, small dried fish.  Haggling is necessary.  It's advisable to visit the market in the morning, as in the afternoon the merchants' lunches start to digest and air quality tends to deteriorate.\n\n* '''Pineapple House''', 42 Calle do Anan\xe1s.  This distinctively-shaped building is a famed Bodonian landmark and nearly all tourists are dragged here by touts and/or the police at least twice per day.  Once inside, you have the choice of purchasing pineapple products like mashed pineapple, pineapple jam, pineapple wine (also available as an enema), etc.  Free entry, but getting out tends to be expensive.\n\n==Eat==\nBodoni provides an excellent opportunity to take a break from a monotonous diet of mashed swarfega and try everybody's favorite root vegetable in stewed or deep-fried form instead.  There are persistent rumors of turnips and even the occasional potato being available on the black market and served in private rooms at high-end restaurants, bu ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:49Z'},
#   u'title': u'Wikivoyage:Joke articles/Bodoni'},
#  {u'id': u'7878',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Replace broken images',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420759',
#    u'model': u'wikitext',
#    u'parentid': u'2043584',
#    u'sha1': u'fomf53acdni87my07vrc51p34nmkh0g',
#    u'text': {u'#text': u"{{joke}}\n\n[[File:Walking through the rocks to Lannacombe Beach - geograph.org.uk - 563727.jpg|thumb|400px|Looking for sand at Cocobanana Beach]]\n\n'''COCOBANANA BEACH''' is in [[Wikivoyage:Joke articles/Upper Caisse|Upper Caisse]], [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]].\n\n==Get in==\nThe only safest way to get here is by jeep. You can try another way by sea but beware of the sharks because many sharks want to be your friends.\n\n==Get around==\nYou can see shark palace in the bottom of the sea, but you have to have permission from immigration office.\n\n==See==\nCocobanana Beach is, of course, famed for '''its vast expanse of white sand''' and its bevy of Serriffean lovelies wearing only '''Flong thongs''', a garment prepared from coconut husk that can also be used to remove pieces of swarfega from between your teeth.  It should, however, be noted that the Flong thongs are traditionally worn only by men who have passed the demanding initiation rites of the '''Very Brotherly Fraternity of the Homoglyph''', and women usually opt for burlap sacks, or go naked, instead.\n\nCocobanana has suffered somewhat from development recently, with some residents objecting that the '''giant boulders of rock''' dumped from the nearby quarry onto the beach detract from the scenic beauty.  However, protests have quieted down after mine management, yielding to public pressure in a sign of the times, gave residents the democratic option of having the boulders quarried to either the beach or on top of their huts.\n\n==Do==\nYou can be sharks's friend by visiting them in their palace.\n\n==Buy==\nThere is only one mall around here selling cattles.\n\n==Eat==\nThere is no restaurant here, so you have to fish by yourself.\n\n==Drink==\nYou can drink water from the wells.\n\n==Sleep==\n[[File:Sijungho Rest House. W\u014fnsan Beach, North Korea.jpg|thumb|240px|Honeymoon Hideaway Suite at the Cocobanana Beach Resort]]\nThere is only one hotel around here, but beware of the mosquitos.\n\n===Splurge===\n* '''Cocobanana Beach Resort''', on National Highway 1, [http://cocobanana.com/].  Visitors to Cocobanana Beach Resort never cease to be amazed by its stunning appearance and the level of services available, and often leave with indelible memories of their experience.  For easy access, National Highway 1 runs right through the resort, and complimentary donkey carts to the beach (17 km away) are provided weekly.\n\n==Stay safe==\nBeware of locals with large sacks over their shoulder contacting you about purchase of foreign tubers. Remember: '''possession of foreign vegetables is a crime'''. Also, some of the local law enforcement officials pose as tuber salesmen to trap foreign visitors. If you are a victim of one of these traps, a payment offer 2,000dNr will normally allow you to go on your way (and you can keep the tubers).\n\n==Go next==\nIf you want to get out fast from this place just call 911.\n{{isPartOf|Wikivoyage:Joke articles/Upper_Caisse}}\n{{joke}}",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:04Z'},
#   u'title': u'Wikivoyage:Joke articles/Cocobanana Beach'},
#  {u'id': u'8213',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* Things for users to know */',
#    u'contributor': {u'id': u'188833', u'username': u'GZWDer'},
#    u'format': u'text/x-wiki',
#    u'id': u'2711166',
#    u'model': u'wikitext',
#    u'parentid': u'2691276',
#    u'sha1': u'tcjjs7wkqhav49aabwumx9rlcsr5lgm',
#    u'text': {u'#text': u'{{nutshell|All written contributions to this project are automatically licenced under CC BY-SA 3.0. All files uploaded to the project must be licenced under CC BY-SA or a compatible licence.}}\n{{shortcut|[[WV:Copyvio]]}}\n[[Image:The Universal Declaration of Wikivoyage Copyleft.png|thumb|370px|The Universal License of Our Wiki]]\n\nWikivoyage uses a \'\'\'copyleft\'\'\' license for all content on the website. \'\'\'Anyone can use\'\'\' Wikivoyage content according to the terms of the \'\'\'Creative Commons Attribution-ShareAlike\'\'\' license. And \'\'\'anyone can contribute\'\'\' their own or other people\'s content, as long as the work is their own or available under a compatible license.\n\nIt is very important that you \'\'\'understand how copyleft works before you contribute to Wikivoyage\'\'\'.  If you find your work reused by someone else in a manner that you didn\'t consider, or if you stop using Wikivoyage for any reason, it is not possible to change the license for the work you have done. Although you always own the copyright in your work, that does not give you the right to change its license retrospectively.\n\n==Licensing==\n\n\'\'If this seems confusing, <big>\'\'\'skip down to [[#Frequently asked questions|the FAQ]].\'\'\'</big>\'\'\n\nAll \'\'\'written contributions\'\'\' to Wikivoyage are and must be licensed under Creative Commons Attribution-ShareAlike 3.0 ([http://creativecommons.org/licenses/by-sa/3.0/legalcode CC-by-SA 3.0]) or a compatible license (e.g., Public Domain, CC-by-SA any, dual CC-by-SA/GFDL any, etc.). Consequently, all redistributed and derivative works of Wikivoyage text must also be licensed as CC-by-SA 3.0.\n\n\'\'\'Images\'\'\' almost always must be uploaded to [[:Commons:Main page|Wikimedia Commons]], and images\' individual licensing is described on individual image pages. Any images hosted locally on Wikivoyage comply with our [[Wikivoyage:Non-free content]], meaning that they do have a license compatible with our copyleft, but are derivative works of something \'\'not\'\' free, like a work of art. As with text contributions, all files uploaded here must have a license that allows derivative works and commercial re-use (usually CC-by or CC-by-SA, never CC-No Derivatives or CC-Non-Commercial)\u2014see [[Wikivoyage:Non-free content#Exemption Doctrine Policy]] for more information.\n\nAll redistributed and derivative works including Wikivoyage images and other files must provide file-specific attribution and licensing information, available on the individual file page.\n\n==Things for users to know==\n\n\'\'\'Copyleft\'\'\' means that every single author, editor, illustrator, mapmaker, factchecker and photographer who puts their work into Wikivoyage gives you the right to read, copy, print, save, download, read aloud, project, modify, email, distribute, sell, photocopy and correct their work however you want to.\n\nThe only restrictions are that:\n* \'\'if you distribute it, or derive new work from it\'\'\n** you must give \'\'\'attribution\'\'\' to the creators\n** you must retain the work and any derivative works \'\'\'under the same licensing\'\'\'.\n\n[[Image:Cc-by new.svg|thumb|150px|Attribution]]\n\nIn other words, we give you practically every freedom within the boundaries of the law to use the information in Wikivoyage, except the freedom to take that freedom away from others.\n\nThe license we use is the \'\'\'Attribution-ShareAlike\'\'\' license. It\'s a piece of legal documentation created by the great people at [http://www.creativecommons.org/ Creative Commons] that basically says the same thing as above: give Wikivoyagers credit for their work, and share with other people.\n\nIf you want you can read the [http://creativecommons.org/licenses/by-sa/3.0/legalcode full text of the Attribution-ShareAlike 3.0 license]. For the purposes of the License, a \'\'Work\'\' is the formatted text that makes up a single Wikivoyage article. Each image individually is ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-01-09T05:07:38Z'},
#   u'title': u'Wikivoyage:Copyleft'}]

# %% [markdown]
# __These special articles are not actual travel guide articles so I will create a new dictionary without them.__

# %%
# articles without :'s in their titles
articles_dict = {}
for article in articles:
    # Lets strip the accents using unicodedata
    title = unicodedata.normalize('NFKD', article['title']).encode('ascii','ignore')
    if ':' not in title:
        articles_dict[title] = article

print len(articles_dict)
articles_dict[articles_dict.keys()[1]]
# Out:
# 42754
# {u'id': u'34976',
#  u'ns': u'0',
#  u'revision': {u'contributor': {u'id': u'244322',
#    u'username': u'Double sharp'},
#   u'format': u'text/x-wiki',
#   u'id': u'2763935',
#   u'minor': None,
#   u'model': u'wikitext',
#   u'parentid': u'2739009',
#   u'sha1': u'jfmz1rvkzz1nfe7dqzq0izms4v764dh',
#   u'text': {u'#text': u'{{pagebanner|Szczecin Wikivoyage Banner.png}}\n\n\'\'\'[http://www.szczecin.eu/en/ Szczecin]\'\'\', (pronounced \'\'Shchetsin\'\', German: \'\'Stettin\'\', Latin: \'\'Stetinum\'\'; is maritime port city and the capital of [[Zachodniopomorskie]] in [[Poland]]. The city has a population of over 400 000 thousand, with almost 800 000 living its metro area, and is one of the seven largest metropoles in the country. It lies in the northwestern corner of Poland, very close to the German border, and it is in fact easier to get to Szczecin from some parts of Germany, notable from [[Berlin]], than it is from much of the Polish territory. For a significant part of its history, actually, Szczecin was a part of Germany, as well as, in other periods, of Denmark and Sweden.\n\nSzczecin is Poland\'s third-largest port and much of its industrial base used to be a part of an important shipyard, so it may come as a surprise to the casual tourist that the city does not lay on a seaside, but rather over the river Odra (German: \'\'Oder\'\'), some 20&nbsp;kilometres south of the Baltic Sea as the crow flies, and many more by road. Many visitors to Poland are also unaware of Szczecin\'s architectural attractiveness, as the large parts of the city were designed by Baron Haussmann, the same gentleman who designed the boulevards of [[Paris]]. \n\n==Understand==\nThe place now known as Szczecin was first mentioned in written history in 1st century when West-Roman historian Tacitus located East Germanic tribe of Rugians somewhere in the area; the Rugians left in 5th Century during the Great Migration. Sometime in the 8th century Western Slavic tribe of Pomeranians built their stronghold here. In 10th century the town was mentioned as "one of major in Pomerania" in Abraham ben Jacob\'s chronicle. In approximately 1080 its area was incorporated into [[Poland]], but within eight years, the town was controlled by the Dukedom of Pomerania, and five years later, [[Denmark]]. In 12th century when its competitor, [[Wolin]] (also known as Veneta in medieval chronicles) declined Szczecin began to prosper from trade and became one of the major Baltic sea harbours. Its name was first recorded in 1133 as "Stetin". \n\nIn 1181 Pomeranian dukes joined Holy Roman Empire. In 1243 Szczecin got city rights before it became member of the Hanseatic League in 1278. Until early 17th century the city was the capital of Pomeranian Dukedom, then in 1630 when local dukes died out it became part of [[Sweden]],  then Kingdom of Prussia, then for a brief period, due to Napoleon\'s conquests, the Empire of [[France]]. Beginning in the 18th century, the city constituted as a part of [[Germany]] and served as the "port of Berlin". During World War II the city was hit hard by Allied bombers - city centre, Old Town and industrial areas were totally ruined. After the Soviet forces invaded Nazi Germany in 1945, according to Potsdam Conference agreements Poland annexed all lands up to the Oder river, expelling the native German population and ultimately extending the border to include Stettin. Poland thus gained control of the city.\n\nIn more recent history, the city was (together with [[Tricity]]) one of the birthplaces of Solidarity movement.\n\nAn unusual feature of Szczecin is its urban planning - many roundabouts and wide avenues. Stettin was rebuilt in 1880\'s using designs by Georges-Eugene Haussmann, who also did the urban planning for [[Paris]]. His design style is still being used for newly-built (or modified) city areas.\n\nThe maritime industry is still strong with a busy port and repair shipyard, as well as being a center of service industries in Poland. Situated near the border between Germany and Poland, Szczecin is sometimes considered one of most liberal Polish cities.\n\n==Get in==\n\n===By plane===\n\nSzczecin-Goleni\xf3w airport (SZZ) [http://www.airport.com.pl/en/show/start-page] is located almost 50&nbsp;km from the city centre, near Goleni\xf3w ...
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2015-04-12T05:43:19Z'},
#  u'title': u'Szczecin'}

# %% [markdown]
# ### Now that we have a dictionary of travel guide articles, lets check out the article lenghts.

# %%
article_lengths_dict = {}
for key, value in articles_dict.iteritems():
    article_length = len(value['revision']['text']['#text'])
    article_lengths_dict[key] = article_length

article_lengths_dict
# Out:
# {'': 20,
#  'Szczecin': 33999,
#  'San Juan Islands': 21187,
#  'Rugia': 11293,
#  'New Australia': 875,
#  'Natchez, Mississippi': 21,
#  'Nampa': 7084,
#  'Jamaica (disambiguation)': 380,
#  'Hyanger': 791,
#  'Xigatse (prefecture)': 1794,
#  'York (Maine)': 19321,
#  'Calangute Beach': 23,
#  'Fulda': 9523,
#  'Novi Sad': 26800,
#  'Eure': 28,
#  'Moovattupuzha': 26,
#  'Gravesend': 1874,
#  'Turkmen phrasebook': 3126,
#  'Caen': 5997,
#  'Madeira Islands': 21,
#  'Miami Springs': 896,
#  'Houston/East Houston': 4176,
#  'Gwangalli': 26,
#  'Malabon': 1082,
#  'Wind surfing': 24,
#  'Hikone': 7609,
#  'Pea Ridge': 2272,
#  'Airline consolidators': 36,
#  'Kearney': 20,
#  'Mokhotlong': 1467,
#  'Loei': 7551,
#  'Loen': 19,
#  'Pergamon': 21,
#  'Paris/Champs Elysee': 38,
#  'Central Limburg (Belgium)': 31,
#  'Rio de janerio': 28,
#  'South Uist': 9641,
#  'Cahir': 1378,
#  'Volta Delta': 563,
#  'Jeffersonville': 703,
#  'Indian Harbour Beach (Florida)': 34,
#  'Orcas Village': 7316,
#  'Scituate (Rhode Island)': 12021,
#  'Western Nevada': 7920,
#  'Pampa': 12355,
#  "Church's Ferry": 27,
#  'Gangtok': 20410,
#  'Bali (Crete)': 8091,
#  'Lucknow': 32642,
#  'Montreal/Parc Jean-Drapeau': 6548,
#  'Kilimanjaro': 31,
#  'Shahrisabz': 25,
#  'Hamilton': 1086,
#  'Kaokoland': 6524,
#  'Fridley': 38,
#  'Florida (Uruguay)': 40,
#  'Santiago do Cacem': 975,
#  'Salem (Massachusetts)': 59333,
#  'Pleasure Island': 466,
#  'Northern Virginia': 12480,
#  'Caravanning': 25,
#  'Discovery Bay': 349,
#  'Limousin': 1127,
#  'Eco tour': 24,
#  'Narvik': 9754,
#  'Mont-Saint-Michel': 31,
#  'Mahajanga': 1051,
#  'Quartzsite': 10821,
#  'Mountainair': 4445,
#  'Stanhope': 2310,
#  'Palmyra': 13788,
#  'Nagano (city)': 20,
#  'Ungalik (Alaska)': 21,
#  'Northern Alberta': 32,
#  'Corydon (Indiana)': 21,
#  'Hallefors': 3538,
#  'Canton (Michigan)': 1280,
#  'Leonardo da Vinci-Fiumicino Airport': 8539,
#  'Harvey': 2396,
#  'Ambala': 4982,
#  'Montone': 2272,
#  'Rendsburg': 1272,
#  'Ulldecona': 23996,
#  'Halong': 9132,
#  'Alcoholic drinks': 33,
#  'Cooperstown ND': 40,
#  'Laguna Miramar': 7590,
#  'Wakefield (New Zealand)': 1125,
#  'Okeechobee': 3868,
#  'Nishitokyo': 8694,
#  'Sainybuli Province': 27,
#  'Taipei/Datong': 3052,
#  'Noukendai': 22,
#  'West Papua': 19,
#  'Banagher': 1059,
#  'Greater Santo Domingo': 3235,
#  'Fort Sumner': 1275,
#  'Wauchula': 5146,
#  'Woodland (California)': 5016,
#  'Dazaifu': 3548,
#  'Deutschland': 21,
#  'Montville (Connecticut)': 1646,
#  'Predjama': 22,
#  'Kallooppara': 6387,
#  "Zikhron Ya'akov": 595,
#  'Karonga': 3160,
#  'Dekalb County (Georgia)': 37,
#  'Singkep-Lingga': 4541,
#  'Rahacou': 1178,
#  'Malay Phrasebook': 30,
#  'Dac Lac': 41,
#  'Salamanca (city)': 23,
#  'Colombia': 63307,
#  'Boston (disambiguation)': 780,
#  'Zhejiang Province': 22,
#  'Travel news': 891,
#  'Mineral Bluff': 1539,
#  'Lolland-Falster': 1163,
#  'Aberdyfi': 18641,
#  'Haute-Garonne': 543,
#  'Mustang District': 23,
#  'Ylivieska': 4790,
#  'Sangkhla': 27,
#  'Oberon': 1075,
#  'Chicago/Chinatown': 42,
#  'Ly': 32,
#  'Inland Sea': 29,
#  'Sherman Oaks': 6431,
#  'Gracanica (Bosnia and Herzegovina)': 48,
#  'Godthaab': 18,
#  'Far Western Nepal': 19,
#  'Ponmudi': 2186,
#  'Bombay/Vikhroli': 36,
#  'Falcon': 20,
#  'Tanjore': 23,
#  'Lappajarvi': 5794,
#  'Barnesville': 464,
#  'Caledon': 449,
#  'Isabela (province)': 414,
#  'Fogo': 5925,
#  'Rail travel': 2417,
#  'Georgia (American state)': 29,
#  'El Jem': 4932,
#  'Rewalsar': 1578,
#  'Matunuck': 11609,
#  'Nizhniy Novgorod': 29,
#  'Manzanillo (Mexico)': 24,
#  'Ganzhou': 2029,
#  'Playas De Este': 20,
#  'Golden Triangle': 994,
#  'Gustrow': 951,
#  'Harlingen (Netherlands)': 11765,
#  'Urban backpacking': 8369,
#  'Ishpeming': 2187,
#  'Blackstone': 7914,
#  'Badajoz': 1252,
#  'Poipet': 24493,
#  'Diving the Cape Peninsula and False Bay/Balcony': 3683,
#  'Robertson': 3360,
#  'Ojcow National Park': 759,
#  'Boxford': 441,
#  'Viloyati Mukhtori Kuhistoni Badakhshon': 23,
#  'Weerribben-Wieden National Park': 9467,
#  'Central Wyoming': 3497,
#  'Alcantara': 1353,
#  'Stevenson Ranch': 27,
#  'Tianshui': 3391,
#  'Montague': 4200,
#  'Lung-tan': 21,
#  'Koidu': 1430,
#  'Unusual Places in Ashdown Forest': 28,
#  'Canton (disambiguation)': 1655,
#  'Gataia': 20,
#  'Newfoundland and Labradour': 39,
#  'Goshen': 7906,
#  'Aegina (city)': 1932,
#  'Hickory': 13937,
#  'Kashid': 7799,
#  'Pathum Thani': 6460,
#  'Medelpad': 35,
#  'Brighton (disambiguation)': 22,
#  'Freeport (Illinois)': 707,
#  'Thera': 18,
#  'Dumfries': 17326,
#  'Saxony Anhalt': 27,
#  'Pieterburen': 1852,
#  'Bowdon': 2535,
#  'Geraardsbergen': 707,
#  'Montpelier (Vermont)': 24,
#  'Magnesia': 3252,
#  'Frde': 2318,
#  'Marigha': 1630,
#  'Przemysl': 22,
#  'Satsuma': 36,
#  'Cavalcante': 15528,
#  'Kedzierzyn-Kozle': 787,
#  'Tiburon': 10441,
#  'Central and South Central (Parana)': 1003,
#  'Toamasina Province': 519,
#  'Jamestown': 658,
#  'Lutsk': 66728,
#  'Lao': 28,
#  'Pomerania': 23,
#  'Baoding': 1380,
#  'Cavado': 19,
#  'Bourgogne': 22,
#  'Great Eastern Highway': 3768,
#  'Indigenous Americans': 47,
#  'New Milford': 24448,
#  'Fort McMurray, Alberta': 27,
#  'Elazg': 20,
#  'Irwin (Pennsylvania)': 972,
#  'Rhinecliff': 23,
#  'Tarnaveni': 3284,
#  'Waterloo (Ontario)': 26812,
#  'Noboribetsu': 4415,
#  'Washington (State)': 32,
#  'Spiritwood': 707,
#  'Porquerolles': 7382,
#  'Tetun phrasebook': 30,
#  'Holland (Michigan)': 9139,
#  'Poulton-le-Fylde': 722,
#  'Cuzco': 89514,
#  'Outback (Australia)': 21,
#  'Yagodnoye': 1797,
#  'Arlington Heights': 8112,
#  'Niger': 26499,
#  'Kerikeri': 18147,
#  'Lampung': 2936,
#  'Dornogobi': 18,
#  'Montserrat (Spain)': 6369,
#  'Echo Park': 35,
#  'Sepupa': 1838,
#  'Sunshine Coast (British Columbia)': 5875,
#  'Ostia Antica': 19,
#  'Toronto/Scarborough': 10470,
#  'Driving in China': 35367,
#  'Rachel, Nevada': 20,
#  'Western Uganda': 3070,
#  'Ballina': 366,
#  'La Tomatina': 19,
#  'Lancaster (Lancashire)': 33,
#  'Introdacqua': 2140,
#  'Pillnitz': 21,
#  'San Juan (La Union)': 3903,
#  'Aran Islands': 10771,
#  'Scarboro': 42,
#  'Wupperthal': 4286,
#  'Chatham (Ontario)': 26,
#  'Niigata (city)': 21,
#  'Agadir': 16352,
#  'Diving the Cape Peninsula and False Bay/HNMS Bato': 4751,
#  'Ban Nalan trail': 29,
#  'Cheyenne Wells': 2051,
#  'Ballestas Islands': 664,
#  'Benton (disambiguation)': 20,
#  'Polish Phrasebook': 31,
#  'Zurich (region)': 1182,
#  'Bocas del Toro (town)': 28,
#  'Volta Region': 25,
#  'Ramkhamhaeng': 34,
#  'Arnhem Land': 20034,
#  'Rockland (Idaho)': 32,
#  "Diving the Cape Peninsula and False Bay/Finlay's Deep": 4725,
#  'Chicago': 154994,
#  'Fortuna (California)': 2277,
#  'Diving the Cape Peninsula and False Bay/SS Lusitania': 15575,
#  'Belarussian': 35,
#  'The Other 1': 4801,
#  'Nykbing F': 30,
#  'Kusinara': 24,
#  'Antrim (disambiguation)': 20,
#  'Narva-joesuu': 26,
#  'Waikoloa': 4776,
#  'Kismayo': 1825,
#  'Honaunau': 613,
#  'Roscommon': 7170,
#  'San Francisco/Western Addition': 21862,
#  'Krakow/Old Town': 56955,
#  'Arieseni': 22,
#  'Venice (disambiguation)': 682,
#  'Dothan': 15489,
#  'Playa Hermosa (Osa)': 2101,
#  'North Shore (New Zealand)/Torbay': 20,
#  'Azamgarh': 27,
#  'Oostende': 20,
#  'Seattle/West Seattle': 26,
#  'Kamphaeng Phet (province)': 28,
#  'Saint George': 1429,
#  'Pomerania lake district': 28,
#  'Indonesian Phrasebook': 35,
#  'Kentucky Bourbon Distilleries Tours': 13649,
#  'Far Northeast Philadelphia': 36,
#  'Shanhaiguan': 37,
#  'Sadecki Beskids': 25,
#  'Chico (WA)': 32,
#  'Caucasian Biosphere Reserve': 1986,
#  'Honolulu/Manoa': 22,
#  'Torno': 4413,
#  'Montefalco': 3690,
#  'Riberac': 2603,
#  'Rome (New York)': 2148,
#  'Bombay/Santa cruz': 36,
#  'Clarksville (Indiana)': 20941,
#  'Cunha': 3916,
#  'Gunnison': 306,
#  'Oberammergau': 6794,
#  'Haut-Rhin': 20,
#  'NEA ANCHIALOS': 27,
#  'Kyaukme': 2779,
#  'Dhulikhel': 5374,
#  'Itapecerica da Serra': 2438,
#  'Belmont (California)': 4964,
#  'Captian Obvious': 55,
#  'Ashburn (Virginia)': 7228,
#  'Kanazawa ward': 22,
#  'Worcester Hills': 10213,
#  'Winnemucca': 4737,
#  'Hillsboro (North Dakota)': 4733,
#  'French Gulch': 2710,
#  'Hoani': 1078,
#  'Dubrovnik-Neretva': 1735,
#  'Kilwa Kisiwani': 19,
#  'Newton (Massachusetts)': 19,
#  'Rawanduz': 1276,
#  'Garland (Arkansas)': 606,
#  'Washington (Pennsylvania)': 2803,
#  'Study Butte/Terlingua': 35,
#  'Congo, Republic of the': 35,
#  "'s-Hertogenbosch": 22309,
#  'Backpacking the Canadian Rockies': 43,
#  'Andover': 443,
#  'Kallil Temple': 20,
#  'Akhty': 527,
#  'Rio': 28,
#  'Khao Yai': 36,
#  'Landmannalaugar': 7208,
#  'Indianola': 497,
#  'Trebisacce': 913,
#  'Koege': 18,
#  'Sargodha Division': 22,
#  'Portsmouth (Dominica)': 899,
#  'Nagaon': 1190,
#  'Anderson': 342,
#  'Gaoxiong': 23,
#  'Jeffersonville (Indiana)': 17424,
#  'Narberth': 374,
#  'Bonito (Brazil)': 41,
#  'Rail Travel in North America': 42,
#  'Lower Caisse': 51,
#  'Tunbridge Wells': 22041,
#  'Flower Ridge Trail': 40,
#  'Guayana': 591,
#  'Eurail': 41,
#  'Chugoku': 15733,
#  'Northern Montserrat': 24,
#  'Bogota/Teusaquillo-Salitre': 40,
#  'Trekking in everest': 36,
#  'Ojen': 876,
#  'Burhaniye': 1565,
#  'Tokyo Station': 34,
#  'Dornod': 30,
#  'Perigueux': 23,
#  'Bronx': 43927,
#  'Norfolk (Massachusetts)': 622,
#  'Kargil District': 19,
#  'Mealhada': 1690,
#  'Sanjo': 1941,
#  'Lithia springs': 28,
#  'Isle (Minnesota)': 24,
#  'Casselberry (Florida)': 2037,
#  'Everglades and Lake Okeechobee': 31,
#  'Resolute': 2079,
#  'Cauvery Basin': 2977,
#  'Norvalspont': 1938,
#  'Hope (New Jersey)': 1087,
#  'Hightstown': 7472,
#  'Benalla': 1589,
#  'Logansport': 1377,
#  'Diving the Cape Peninsula and False Bay/Fishermans Beach': 3612,
#  'Xiaozhou': 23,
#  'New South Wales': 44282,
#  'Lincoln (Illinois)': 5492,
#  'Llanybydder': 837,
#  'Fuji-Hakone-Izu National Park': 4859,
#  'Hoge Veluwe': 39,
#  'First and business class travel': 15570,
#  'Balkh': 3211,
#  'Clarens': 572,
#  'Middle Volga': 26,
#  'Northern Italy': 19,
#  'Chicago skyline': 35,
#  'Iwakuni': 17339,
#  'Ko Phai': 29,
#  'Royal National Park (disambiguation)': 375,
#  'Guruvayoorappan': 23,
#  'Riviera adriatica': 31,
#  'Krasnoyarsk-26': 27,
#  'Bahasa Malaysia phrasebook': 30,
#  'Longtan': 4173,
#  'Pirin National Park': 5073,
#  'Santa Teresa (Costa Rica)': 4479,
#  'Machadodorp': 1789,
#  'Parsippany': 9809,
#  'Serbo Croatian': 28,
#  'Huntington (Virginia)': 624,
#  'Alencon': 21,
#  'Mountain Home (Idaho)': 2824,
#  'Consensus': 31,
#  'Barren Island': 32,
#  'Fjadundraland': 26,
#  'Acadia National Park': 15283,
#  'Elgin': 4024,
#  'Spello': 9098,
#  'Okehampton': 633,
#  'Courtray': 22,
#  'Manchester (Tennessee)': 995,
#  'TDF': 46,
#  'Yoshkar-Ola': 35073,
#  'Moritzburg': 713,
#  'Courtrai': 22,
#  'Bohemian-Moravian Highlands': 1323,
#  'European Turkey': 28,
#  'Chhukhung': 897,
#  'Puebla (state)': 706,
#  'Norwegian Cruise Line': 26,
#  'Clarksburg': 717,
#  'Puno (city)': 17,
#  'Marumbi': 1519,
#  'Neuquen': 30,
#  'Brookings': 288,
#  'Atlantic Seaboard': 653,
#  'South Coast Highway': 2292,
#  'Udaigiri': 20,
#  'Fort Myers': 16554,
#  'Central Aegean': 4788,
#  'Tahitian': 33,
#  'Moszna Castle (Zamek Moszna)': 28,
#  'Glengarriff': 6288,
#  "Les Sables d'Olonne": 1807,
#  'San Angelo': 30239,
#  'Bangka (Sumatra)': 29,
#  'Jacks Fork River': 22,
#  "Sant' Andrea Apostolo dello Jonio": 832,
#  'Chantilly (Virginia)': 11895,
#  'Rebun': 51,
#  'Woodridge (Illinois)': 935,
#  'Tahara': 3154,
#  'Kilwinning': 2746,
#  'Persia': 18,
#  'Karak (Khyber Pakhtunkhwa)': 32,
#  'Black Forest': 7392,
#  'Sherwood Forest (Massachusetts)': 20,
#  'Rapid Bay': 1336,
#  'Shinyokohama': 22,
#  'Washington (D.D.)/Southwest': 41,
#  'Florence (Province)': 33,
#  'Philadelphia/West Philly': 31,
#  'Chicago/West Town': 33,
#  'Kavieng': 5935,
#  'Hancock (Maryland)': 1552,
#  'Mountain Province': 877,
#  'Dexter': 1466,
#  'Mountain View (California)': 19143,
#  'Cerro Punta': 2032,
#  'Camalu': 3427,
#  'Winter Hill': 21,
#  'Johnson Creek': 2498,
#  'Ada (Michigan)': 785,
#  'Marina del Rey': 39413,
#  'Kashmir Valley': 15356,
#  'Suwa': 3262,
#  'Collier County': 31,
#  'Alphen aan den Rijn': 6990,
#  'Minneapolis/Stadium Village': 35,
#  'Cappadoccia': 24,
#  'Diving inland in South Africa/Wondergat': 7449,
#  'Connecticut': 21535,
#  'Albenga': 3117,
#  'Jokhang temple': 19,
#  'Rio de Janeiro/Santa Teresa': 34,
#  'Lampedusa': 28,
#  'North Stonington': 6788,
#  'Fucking, Austria': 21,
#  'Samut Prakan': 9054,
#  'Bath (Maine)': 4573,
#  'College Park (Maryland)': 18390,
#  'Tipping': 4464,
#  'Citta del Vaticano': 26,
#  'Silimbong': 1622,
#  'Schleswig-Holstein': 9406,
#  'Ko Jum': 7199,
#  'Sainte Genevieve': 28,
#  'Cullohill': 1481,
#  'Mount Meron': 1071,
#  'Leghorn': 21,
#  'Freetown (Massachusetts)': 5640,
#  'Janakpur (zone)': 19,
#  'Kununurra': 53639,
#  'Santa Rosa (Colombia)': 33,
#  'Hong Kong/Central Hong Kong Island': 31,
#  'Latera': 11243,
#  'Montignac, Dordogne': 34,
#  'Isla Ometepe': 29,
#  'Accomac (Virginia)': 21,
#  'Beskids': 1485,
#  'Ledu': 1084,
#  'Cuc Phuong': 38,
#  'Beskidy': 21,
#  'Mangamuka Bridge': 844,
#  'Pahokee': 513,
#  'South Corsica': 628,
#  'Passaic': 375,
#  'Perryton': 5078,
#  'Chubu Airport': 50,
#  'Ingleside': 409,
#  'Devanagari': 33,
#  'West Azerbaijan': 32,
#  'Celebration': 20246,
#  'Chihuahua (state)': 6100,
#  'Sosua': 28593,
#  'Cieszyn': 3079,
#  'Oxbow': 279,
#  'West Point': 34,
#  'Panhandle (Nebraska)': 5502,
#  'Papallacta': 3561,
#  'Statia': 28,
#  'Prinsenbeek': 19,
#  'Vintage railroad': 43,
#  'Hongrie': 21,
#  'Detroit (Oregon)': 48,
#  'Lavenham': 2515,
#  'Merida (Yucatan)': 29,
#  'Crystal Lake': 3003,
#  'China (Texas)': 948,
#  'Macclesfield': 7489,
#  'Central Slovenia': 2286,
#  'Sitka': 18675,
#  'Ladino phrasebook': 4138,
#  'Berlin (Connecticut)': 1192,
#  'Jotunheimen': 9422,
#  'Northwest (Rio Grande do Sul)': 763,
#  'Mary Province': 938,
#  'Vernon': 960,
#  'Bakel Fort': 19,
#  'Ende': 13195,
#  'Si Lom': 27,
#  'Grand Anse': 19,
#  'Bingzhongluo': 1906,
#  'Stockholm/Liljeholmen': 32,
#  'Rockland County': 9323,
#  'Franciacorta': 5084,
#  'Tokyo/Akihabara': 21311,
#  'Kinik': 19,
#  'Udon': 24,
#  'Film and TV series travel': 40,
#  'La Paz (Mexico)': 10310,
#  'Chubu Centrair International Airport': 12157,
#  'Hartford (Vermont)': 34,
#  'Gilli Islands': 26,
#  'Carlisle (Iowa)': 831,
#  'Thimpu': 21,
#  'Aakirkeby': 1326,
#  'Szamotuly': 23,
#  'Yaren': 19,
#  'Chainat': 22,
#  'Bocholt': 1866,
#  'Pleasanton': 9213,
#  'Sydney/Milsons Point': 38,
#  'Brest': 272,
#  'El Golea': 1795,
#  'Sao Paulo/Historic Center': 32,
#  'Jogindernagar': 21327,
#  'North Country': 4728,
#  'Xiazhou': 23,
#  'Sannicolau Mare': 1938,
#  'Arid Midlands': 27,
#  'Big Pine': 1826,
#  'Hovd (province)': 30,
#  'Bay Point': 286,
#  'Riverview': 590,
#  'Oberndorf bei Salzburg': 57,
#  'Rudolph, wisconsin': 21,
#  'McArthur': 2327,
#  'West (Hill Country)': 1127,
#  'Misquamicut': 11268,
#  'Bethany (Oklahoma)': 1020,
#  'Kaili': 4042,
#  'Targu-Mures': 25,
#  'Tokyo/Chiyoda': 23398,
#  'Cheorwon': 4991,
#  'Lake Habbaniyah': 26,
#  'Cuckoo trail': 26,
#  'Ialysos': 1936,
#  'Pelhrimov': 23,
#  'London (West)/Kensington': 45,
#  'Kullu Manali': 20,
#  'Catalan Phrasebook': 32,
#  'MacDonnell Ranges': 3739,
#  'Gardena': 3210,
#  'Melbourne': 92373,
#  'Chisago': 26,
#  'Wellington (Ontario)': 34,
#  'Inverigo': 1071,
#  'Suprasl': 23,
#  'Spennymoor': 21608,
#  'Ballycastle': 2985,
#  'Port Stephens (Australia)': 45,
#  'Pointe-Noire (Republic of the Congo)': 26,
#  'Wallowa County': 28,
#  'Clewiston': 1762,
#  'Nouakchott': 9202,
#  'Ithaca, New York': 31,
#  'Cacapava': 591,
#  'Bellevue (Nebraska)': 10931,
#  'Dallol depression': 32,
#  'Corentyne': 31,
#  'Holbk': 17236,
#  'Onslow County': 508,
#  'Kabale': 3599,
#  'Travel topics': 10618,
#  'Semmering': 11933,
#  'Ipswich': 452,
#  'Science-fiction tourism': 1415,
#  'Mundau': 1055,
#  'Lleida': 2465,
#  'Majuli': 3207,
#  'Kasauli': 10794,
#  'Fairmont City': 2766,
#  'Western Highlands': 243,
#  'Kherson': 2665,
#  'Lake District National Park': 18274,
#  'WikiVoyage': 27,
#  'Faliraki': 6641,
#  'Macedon Ranges': 1572,
#  'Bombay/Kurla': 36,
#  'Loudoun County (Virginia)': 11683,
#  'Ahmedabad': 100439,
#  'Northern Kazakhstan': 24,
#  'Trechtingshausen': 3415,
#  'Butaritari': 7216,
#  'Longwood (Florida)': 2300,
#  'Jungmun': 25,
#  'Cronulla': 29,
#  'Kelmend': 355,
#  'Enniskillen': 13674,
#  'Nicosia district (South)': 990,
#  'Skelleftea': 5642,
#  'Hjrundfjord': 6881,
#  'Northampton County': 27,
#  'Laguna Beach': 30074,
#  'Kuala Terengganu': 9343,
#  'Greenville (South Carolina)': 40150,
#  'Yukon Territory': 19,
#  'Kamyanets-Podilsky': 33,
#  'Marathon (Florida)': 19331,
#  'Santa Barbara': 61276,
#  'Spencer (West Virginia)': 6027,
#  'Tak': 6026,
#  'Mt Chokai': 24,
#  'Silvia': 855,
#  'Meru': 835,
#  'Kemmerer': 893,
#  'Plastira Lake': 2594,
#  'Pilion': 26,
#  'Hervey Bay': 19652,
#  '100 Mile House': 6897,
#  'Vila Real de Santo Antonio': 40,
#  'Kalinga': 784,
#  'Turkey (disambiguation)': 385,
#  'Berneray (disambiguation)': 552,
#  'Mandalgovi': 24,
#  "'s Hertogenbosch": 30,
#  'Peechi Vazhani Wildlife Sanctuary': 2099,
#  'Matabeleland South': 26,
#  'Pamplona': 19129,
#  'Mn': 3951,
#  'Staniel Cay,Exumas,Bahamas': 25,
#  'Somerset (Massachusetts)': 5178,
#  'Dorking': 3231,
#  'Richmond, ky': 33,
#  'Province of Chieti': 31,
#  'Krems an der Donau': 19,
#  'Suquamish (Washington)': 23,
#  'Interior (Iceland)': 4803,
#  'Isle of Lismore': 3580,
#  'Nevada (disambiguation)': 351,
#  'Montgomery Township': 3650,
#  'Chapada dos Guimaraes': 1403,
#  'Baiyu': 50,
#  'Bol': 9760,
#  'Jardin': 8889,
#  'Antep': 23,
#  'Bowling Green (Ohio)': 14983,
#  'Thornton': 3445,
#  'Khakassia': 2439,
#  'Ambalappuzha': 23,
#  'Clitheroe': 3352,
#  'Camp Chase Trail': 4508,
#  'Sedibeng': 759,
#  'Lake Louise': 14009,
#  "Praia D'El Rey": 20,
#  'Mardana': 1396,
#  'Davidson': 5450,
#  'August': 6037,
#  'Watsonville': 25659,
#  'Eco tourism': 24,
#  'Charlevoix michigan': 35,
#  'Nong Khai (province)': 23,
#  'Yulin (Guangxi)': 497,
#  'Bog': 602,
#  'Iris': 28,
#  'Hawera': 3309,
#  'Phillip Island': 10707,
#  'Mount Tai': 11637,
#  'Artyom': 2959,
#  'Prineville': 1772,
#  'Northern and western outskirts of Uppsala': 33,
#  'Caras Severin County': 19,
#  'Prague/West bank of Vltava': 15995,
#  'Chiufen': 20,
#  'Cape May': 25514,
#  'Hell (disambiguation)': 18,
#  'Devala': 1264,
#  'Helmstedt': 3596,
#  'Diving the Cape Peninsula and False Bay/Justins Caves': 10706,
#  'Sri petaling': 32,
#  'Dover (New Hampshire)': 9639,
#  'Salar de Uyuni': 18582,
#  'Katse': 20,
#  'Captain obvious': 55,
#  'Marquette (Iowa)': 815,
#  'Etawah': 3226,
#  'Laotian': 28,
#  'Lake Como': 16676,
#  'Golden Temple': 22,
#  'Diving the Cape Peninsula and False Bay/South Paw': 4851,
#  'Ls': 4315,
#  'Mexicali': 31261,
#  'Shelburne (Nova Scotia)': 1629,
#  'Punxsutawney': 3693,
#  'North (Canada)': 2960,
#  'Eastham': 22216,
#  'Karula National Park': 1986,
#  'Hecho': 1244,
#  'Robin Hood': 29,
#  'Issyk-Kul and the Tian Shan': 41,
#  'Shiga': 4700,
#  'Inner Hebrides': 4876,
#  'Agulhas National Park': 1532,
#  'Beichuan': 1732,
#  'Yukon (Oklahoma)': 959,
#  'Manning Park': 37,
#  'Joliet': 11755,
#  'Rodeo (event)': 478,
#  'Three Rivers': 6006,
#  'Tangomarkkinat': 22,
#  'Kura Araks Lowland': 32,
#  'Lamesa': 2507,
#  'STN': 36,
#  'Samsun': 14846,
#  'Far Eastern': 30,
#  'Italian lakes': 35,
#  'Dire-Dawa': 23,
#  'Sicilia': 20,
#  'Saintes Maries de la Mer': 1882,
#  'Opolskie Voivodship': 22,
#  'Travel videos': 32,
#  'Narragansett in the Winter': 26,
#  'Esmeraldas': 6934,
#  'Barcelona/Barceloneta': 36,
#  'Keminmaa': 18,
#  'Capena': 982,
#  'Arena football': 31,
#  'Fish Camp': 3551,
#  'Trebizond': 21,
#  'Vincentia': 1746,
#  'Kanye': 3787,
#  'Paris/10th arrondissement': 15209,
#  'Rancho Cucamonga': 6808,
#  'Northfield': 579,
#  'Nagoya (Batam)': 32,
#  'Pantellaeria': 25,
#  'Lhuentse': 696,
#  'Peterborough': 9761,
#  'Bowie': 11303,
#  'Southwest Florida': 15749,
#  'West Berlin': 20,
#  'Welwyn Garden City': 6678,
#  'Sturbridge': 27862,
#  'Manual of Style': 40,
#  'Cromwell': 731,
#  'Yarrawonga Mulwala': 32,
#  'Khewra Salt Mine': 2793,
#  'Cypress': 5270,
#  'Escanaba': 2623,
#  'GR 20': 3316,
#  'Nang Rong': 4876,
#  'Alvdalen': 1875,
#  'Assisi': 14095,
#  'Kien Giang': 30,
#  'Yarmouth (Maine)': 2167,
#  'Monza': 4654,
#  'Nantwich': 9028,
#  'Kruger National Park/Olifants': 34,
#  'Southern Streymoy': 617,
#  'Kemi': 8662,
#  'Surrey County': 2216,
#  'Superior (Montana)': 1486,
#  'Scarborough (Tobago)': 47,
#  'Webster': 860,
#  'Offenbach am Main': 23,
#  'Bali Township': 27,
#  'Fair Haven Disambiguation': 24,
#  'Ukhahlamba Drakensberg': 7845,
#  'Towada-Hachimantai National Park': 10161,
#  'Lesotho': 29359,
#  'Funafuti': 3332,
#  'Morenci': 256,
#  'Bechatow': 1630,
#  'San Francisco/Richmond': 39,
#  'Panzano': 19,
#  'Mactan Island': 24,
#  'Southeastern France': 2124,
#  'Rankin Inlet': 16762,
#  'Santa Fe De Bogota': 20,
#  'Hunedoara County': 23,
#  'Foochow': 20,
#  'Fanwood': 1134,
#  'New Castle (Delaware)': 13550,
#  'Devon (Alberta)': 592,
#  'Off-highway vehicle riding in Oregon': 5026,
#  'Killorglin': 1830,
#  'Bac Trung Bo': 37,
#  'Patagonia (Arizona)': 8080,
#  'Jiangsu': 5513,
#  'Seti (zone)': 19,
#  'Gering': 25,
#  'Michigan': 26496,
#  'Bungmati': 1907,
#  'Natham - Abiramam': 36,
#  'Mackenzie Country': 3881,
#  'Lefkara': 3309,
#  'Richmond (Tasmania)': 2957,
#  "Hawke's Bay": 6135,
#  'Mongar': 1693,
#  'Centre du Quebec': 30,
#  'Glacier National Park': 64014,
#  'Grasslands National Park': 1877,
#  'Banda Acheh': 24,
#  'Clearlake': 4553,
#  'Lower Peninsula': 1265,
#  'Indian Sub-continent': 24,
#  'Niassa': 33,
#  'St. Charles, Missouri': 36,
#  'Eftimie Murgu': 2769,
#  'Carcasonne': 25,
#  'Braintree (Massachusetts)': 5541,
#  'Coast and Mayombe': 567,
#  'Davidson County': 31,
#  'Arlington (Washington)': 1175,
#  'Fleurieu Peninsula': 586,
#  'South Africa': 112969,
#  'Prien am Chiemsee': 6825,
#  'Portarlington': 5278,
#  'Washington (D.C.)/Takoma-Petworth': 45,
#  'Murdeshwara': 2817,
#  'Ruvo di Puglia': 1354,
#  'Veitshochheim': 4064,
#  'Charleston (West Virginia)': 17076,
#  'Bombay/Malad': 30,
#  'Blenheim (New Zealand)': 28220,
#  'Kanipakam': 1513,
#  'Dane County': 34,
#  'Norwalk': 328,
#  'Bratsk': 1560,
#  'Port Augusta': 9357,
#  'Custer State Park': 1177,
#  'Kosovska Mitrovica': 23,
#  'Kirishima National Park': 42,
#  'Pixley': 2900,
#  'Majorda': 22,
#  'Marijampole': 563,
#  'South orange': 26,
#  'Istanbul/Golden Horn': 18190,
#  'Low cost flights': 36,
#  'Sipadan Island': 21,
#  'Swabi': 32,
#  'Kunene': 30,
#  'Kulpsville': 908,
#  'Suomenlinna': 34,
#  'Manovo Gounda St Floris National Park': 52,
#  'Hammerfest': 4253,
#  'Chittur': 3949,
#  'Culiacan Rosales': 22,
#  'Vulcano': 5278,
#  'Southeast Arizona': 31151,
#  'Time zones': 18827,
#  'Traveling with pets': 34,
#  'Manville (New Jersey)': 6170,
#  'Indian Pacific Railway': 58,
#  'Swanzey': 581,
#  'Waldo County': 3757,
#  'Zonguldak': 2000,
#  'Rio de Janeiro/Zona Oeste': 11575,
#  'Sangha and Likouala': 1095,
#  "O'Fallon (Illinois)": 2938,
#  'Houston/West Houston': 4367,
#  'Chamarajanagar (district)': 5426,
#  'Mindong phrasebook': 11956,
#  'Skaraborg': 31,
#  'Mu Ko Surin National Park': 1848,
#  'Penlee House': 22,
#  'West Chester (Pennsylvania)': 16748,
#  'New York City/Bronx': 19,
#  'Sutter County': 433,
#  'Ounasvaara': 23,
#  'Baoting': 1473,
#  'Port Angeles': 7039,
#  'Northumbria': 32,
#  'Qasr Amra': 1402,
#  'Newton-le-Willows': 1735,
#  'Ankola': 1047,
#  'Lester B Pearson International Airport': 51,
#  'Carlsbad Caverns': 44,
#  'Upper Takutu-Upper Essequibo': 32,
#  'Northern Tunisia': 1968,
#  'Tornedalen': 31,
#  'Trains in Sweden': 43,
#  'Hale': 24,
#  'Tegernsee': 8083,
#  'Southern Armenia': 13119,
#  'Limestone (disambiguation)': 23,
#  'Santa Cruz de la Sierra': 40,
#  'Gunung Mulu National Park': 11981,
#  'Sycamore': 3651,
#  'Pago Pago, American Samoa': 22,
#  'La Coruna': 21,
#  'Southwestern Indiana': 651,
#  'Frisian phrasebook': 37,
#  'Annur': 2491,
#  'Chicago/Near West side': 36,
#  'Muang Ngeun': 2164,
#  'Map showing Mexico Jalisco Chapala': 21,
#  'Skokloster': 22,
#  'Minca': 614,
#  'Colorado Bend State Park': 5630,
#  'Manchester (New Hampshire)': 27494,
#  'Munster (Ortze)': 36,
#  'Cheb': 3838,
#  'Northern Coast (Puerto Rico)': 737,
#  'Capurgana': 6881,
#  'Vire': 831,
#  'Charlestown (Saint Kitts and Nevis)': 19,
#  'Chem': 3934,
#  'Franeker': 2541,
#  'Chelmsford (England)': 30295,
#  'Geelong': 10708,
#  'Williams, California': 35,
#  'Pontiac (Michigan)': 1951,
#  'Vale dos Dinossauros': 861,
#  'Tohoku': 9983,
#  'Ethiopia': 55052,
#  'Yala (province)': 18,
#  'Mount Pleasant, MI': 39,
#  'Ski': 1782,
#  'Budoni': 1507,
#  'Pontal do Parana': 5992,
#  'Elmina': 5841,
#  'Llanrwst': 2059,
#  'Oakland (Maine)': 1122,
#  'Erechim': 4122,
#  'Tok Pisin phrasebook': 20875,
#  'Marshfield (Missouri)': 2349,
#  'Copper Canyon National Park': 27,
#  'Adilabad': 4471,
#  'Lewistown': 319,
#  'Rottweil': 4111,
#  'Berlin/Schoneberg': 30,
#  'North Africa': 5441,
#  'Montejaque': 3759,
#  'Swieradow-Zdroj': 889,
#  'Altamonte Springs': 3723,
#  'Buying a car in Australia': 34,
#  'Montgomery (Ohio)': 996,
#  'Saitama prefecture': 34,
#  'Natural Bridge State Park': 9650,
#  'Olean': 636,
#  'Mid-Atlantic': 25720,
#  'Upplands-Bro': 43,
#  'East Central Saskatchewan': 34,
#  'Rehoboth': 2467,
#  'Roccella Ionica': 2287,
#  'Connemara': 7920,
#  'Hakka Tulou': 29,
#  'Ostrava': 21177,
#  'Chainat town': 22,
#  'James River Plantations': 1879,
#  'Nederland (Colorado)': 1064,
#  'Gumusluk': 3748,
#  ...}

# %% [markdown]
# __Check out some articles with short lengths__

# %%
articles_dict['Berneray (disambiguation)']
# Out:
# {u'id': u'3554',
#  u'ns': u'0',
#  u'revision': {u'comment': u'/* United Kingdom */ Add Great Bernera',
#   u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#   u'format': u'text/x-wiki',
#   u'id': u'2592780',
#   u'model': u'wikitext',
#   u'parentid': u'2381967',
#   u'sha1': u'bz5yrk7qxjzi4c711uuyt1lmwgfk9u5',
#   u'text': {u'#text': u"{{pagebanner|Disambiguation banner.png|pgname=Berneray}}\nThere's more than one place called '''Berneray''':\n\n=== [[United Kingdom]] ===\n\n* [[Berneray]] (Bhe\xe0rnaraidh) - one of two inhabited islands in the Sound of Harris, to the north of [[North Uist]] in the [[Outer Hebrides]], [[Scotland]]\n\n* [[Berneray (Barra Head)]] - an uninhabited island, and the southernmost part of the [[Outer Hebrides]], [[Scotland]]\n\n* [[Great Bernera]] - is in an island off the northwest coast of [[Lewis]] in the [[Outer Hebrides]]. \n\n[[WikiPedia:Berneray]]\n\n{{disamb}}",
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2014-05-25T16:33:55Z'},
#  u'title': u'Berneray (disambiguation)'}

# %%
df_article_lengths = pd.DataFrame(article_lengths_dict.items(), columns = ['title', 'length'])

# %% [markdown]
# __Plot histogram to see the distribution of articles by length.__

# %%
condition1 = df_article_lengths['length'] < 10000
df_article_lengths[condition1].hist(bins=100);

# %%
### STUDY HOW MANY CHARS ARTICLES HAVE.
condition2 = df_article_lengths['length'] < 500
df_article_lengths[condition2].hist(bins=10)

## IT CAN BE SEEN THAT THERE ARE ABOUT 17,000 ARTICLES LESS THAN 200 CHARACTERS.
## ARTICLES WITH LESS THAN 200 WORDS WOULD MEAN THEY DON'T HAVE GOOD DESTINATION DESCRIPTONS OR ARE AMBIGUOUS DESTINATIONS, MEANING THEY AREN'T
## POPULAR DESTINATIONS.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x110bd20d0>]], dtype=object)

# %%
condition3 = df_article_lengths['length'] < 200
df_article_200_char_plus = df_article_lengths[-condition3]

# %%
final_titles = df_article_200_char_plus['title']

# %%
final_titles.head(10)
# Out:
# 1                     Szczecin
# 2             San Juan Islands
# 3                        Rugia
# 4                New Australia
# 6                        Nampa
# 7     Jamaica (disambiguation)
# 8                      Hyanger
# 9         Xigatse (prefecture)
# 10                York (Maine)
# 12                       Fulda
# Name: title, dtype: object

# %%
# Create dictionary of titles that have concatenated names as the values. For example: San Francisco: San_Francisco
def clean_final_titles(titles):
    final_titles_concat = {}
    for title in titles:
        if '(disambiguation)' not in title:
            key = title
            value = title.replace(' (', ',')
            value = value.replace(')', '')
            value = value.replace(' ','_')
            final_titles_concat[key] = value
    return final_titles_concat

# %%
final_titles_concat = clean_final_titles(final_titles)
final_titles_concat
# Out:
# {'Szczecin': 'Szczecin',
#  'Rugia': 'Rugia',
#  'New Australia': 'New_Australia',
#  'Nampa': 'Nampa',
#  'Hyanger': 'Hyanger',
#  'Xigatse (prefecture)': 'Xigatse,prefecture',
#  'York (Maine)': 'York,Maine',
#  'Fulda': 'Fulda',
#  'Novi Sad': 'Novi_Sad',
#  'Gravesend': 'Gravesend',
#  'Turkmen phrasebook': 'Turkmen_phrasebook',
#  'Caen': 'Caen',
#  'Miami Springs': 'Miami_Springs',
#  'Houston/East Houston': 'Houston/East_Houston',
#  'Malabon': 'Malabon',
#  'Hikone': 'Hikone',
#  'Pea Ridge': 'Pea_Ridge',
#  'Diest': 'Diest',
#  'Goshen': 'Goshen',
#  'Loei': 'Loei',
#  'Saco': 'Saco',
#  'South Uist': 'South_Uist',
#  'Cahir': 'Cahir',
#  'Volta Delta': 'Volta_Delta',
#  'Jeffersonville': 'Jeffersonville',
#  'Orcas Village': 'Orcas_Village',
#  'Scituate (Rhode Island)': 'Scituate,Rhode_Island',
#  'Western Nevada': 'Western_Nevada',
#  'Pampa': 'Pampa',
#  'Gangtok': 'Gangtok',
#  'Bali (Crete)': 'Bali,Crete',
#  'Oqaatsut': 'Oqaatsut',
#  'Montreal/Parc Jean-Drapeau': 'Montreal/Parc_Jean-Drapeau',
#  'Itapecerica da Serra': 'Itapecerica_da_Serra',
#  'Hamilton': 'Hamilton',
#  'Kaokoland': 'Kaokoland',
#  'Santiago do Cacem': 'Santiago_do_Cacem',
#  'Salem (Massachusetts)': 'Salem,Massachusetts',
#  'Pleasure Island': 'Pleasure_Island',
#  'Northern Virginia': 'Northern_Virginia',
#  'Discovery Bay': 'Discovery_Bay',
#  'Limousin': 'Limousin',
#  'Narvik': 'Narvik',
#  'Freedom (Wisconsin)': 'Freedom,Wisconsin',
#  'Quartzsite': 'Quartzsite',
#  'Mountainair': 'Mountainair',
#  'Stanhope': 'Stanhope',
#  'Palmyra': 'Palmyra',
#  'Herzliya': 'Herzliya',
#  'Dexter': 'Dexter',
#  'Hallefors': 'Hallefors',
#  'Canton (Michigan)': 'Canton,Michigan',
#  'Leonardo da Vinci-Fiumicino Airport': 'Leonardo_da_Vinci-Fiumicino_Airport',
#  'Harvey': 'Harvey',
#  'Ambala': 'Ambala',
#  'Montone': 'Montone',
#  'Rendsburg': 'Rendsburg',
#  'Ulldecona': 'Ulldecona',
#  'Halong': 'Halong',
#  'Wakefield (New Zealand)': 'Wakefield,New_Zealand',
#  'Okeechobee': 'Okeechobee',
#  'Nishitokyo': 'Nishitokyo',
#  'Vernon': 'Vernon',
#  'Taipei/Datong': 'Taipei/Datong',
#  'Franciacorta': 'Franciacorta',
#  'Banagher': 'Banagher',
#  'Greater Santo Domingo': 'Greater_Santo_Domingo',
#  'Fort Sumner': 'Fort_Sumner',
#  'Wauchula': 'Wauchula',
#  'Woodland (California)': 'Woodland,California',
#  'Dazaifu': 'Dazaifu',
#  'Montville (Connecticut)': 'Montville,Connecticut',
#  'Kallooppara': 'Kallooppara',
#  "Zikhron Ya'akov": "Zikhron_Ya'akov",
#  'Karonga': 'Karonga',
#  'Butaritari': 'Butaritari',
#  'Singkep-Lingga': 'Singkep-Lingga',
#  'Rahacou': 'Rahacou',
#  'Thuin': 'Thuin',
#  'Colombia': 'Colombia',
#  'Travel news': 'Travel_news',
#  'Mineral Bluff': 'Mineral_Bluff',
#  'Lolland-Falster': 'Lolland-Falster',
#  'Aberdyfi': 'Aberdyfi',
#  'Haute-Garonne': 'Haute-Garonne',
#  'Ls': 'Ls',
#  'Ylivieska': 'Ylivieska',
#  'Oberon': 'Oberon',
#  'Sherman Oaks': 'Sherman_Oaks',
#  'GR 20': 'GR_20',
#  'Ponmudi': 'Ponmudi',
#  'Lappajarvi': 'Lappajarvi',
#  'Barnesville': 'Barnesville',
#  'Caledon': 'Caledon',
#  'Isabela (province)': 'Isabela,province',
#  'Fogo': 'Fogo',
#  'Rail travel': 'Rail_travel',
#  'El Jem': 'El_Jem',
#  'Rewalsar': 'Rewalsar',
#  'Matunuck': 'Matunuck',
#  'Ganzhou': 'Ganzhou',
#  'Golden Triangle': 'Golden_Triangle',
#  'Gustrow': 'Gustrow',
#  'Harlingen (Netherlands)': 'Harlingen,Netherlands',
#  'Urban backpacking': 'Urban_backpacking',
#  'Ishpeming': 'Ishpeming',
#  'Blackstone': 'Blackstone',
#  'Badajoz': 'Badajoz',
#  'Poipet': 'Poipet',
#  'Diving the Cape Peninsula and False Bay/Balcony': 'Diving_the_Cape_Peninsula_and_False_Bay/Balcony',
#  'Robertson': 'Robertson',
#  'Ojcow National Park': 'Ojcow_National_Park',
#  'Boxford': 'Boxford',
#  'Mexico City/Zona Rosa': 'Mexico_City/Zona_Rosa',
#  'Weerribben-Wieden National Park': 'Weerribben-Wieden_National_Park',
#  'Whale Valley': 'Whale_Valley',
#  'Tianshui': 'Tianshui',
#  'Montague': 'Montague',
#  'Koidu': 'Koidu',
#  'Montignac (Dordogne)': 'Montignac,Dordogne',
#  'Mokhotlong': 'Mokhotlong',
#  'Aegina (city)': 'Aegina,city',
#  'Hickory': 'Hickory',
#  'Kashid': 'Kashid',
#  'Pathum Thani': 'Pathum_Thani',
#  'Freeport (Illinois)': 'Freeport,Illinois',
#  'Dumfries': 'Dumfries',
#  'Pieterburen': 'Pieterburen',
#  'Bowdon': 'Bowdon',
#  'Geraardsbergen': 'Geraardsbergen',
#  'Frde': 'Frde',
#  'Marigha': 'Marigha',
#  'Cavalcante': 'Cavalcante',
#  'Kedzierzyn-Kozle': 'Kedzierzyn-Kozle',
#  'Tiburon': 'Tiburon',
#  'Central and South Central (Parana)': 'Central_and_South_Central,Parana',
#  'Toamasina Province': 'Toamasina_Province',
#  'Jamestown': 'Jamestown',
#  'Lutsk': 'Lutsk',
#  'Baoding': 'Baoding',
#  'Great Eastern Highway': 'Great_Eastern_Highway',
#  'New Milford': 'New_Milford',
#  'Irwin (Pennsylvania)': 'Irwin,Pennsylvania',
#  'Tarnaveni': 'Tarnaveni',
#  'Waterloo (Ontario)': 'Waterloo,Ontario',
#  'Noboribetsu': 'Noboribetsu',
#  'Spiritwood': 'Spiritwood',
#  'Porquerolles': 'Porquerolles',
#  'Holland (Michigan)': 'Holland,Michigan',
#  'Poulton-le-Fylde': 'Poulton-le-Fylde',
#  'Cuzco': 'Cuzco',
#  'Yagodnoye': 'Yagodnoye',
#  'Palace on Wheels': 'Palace_on_Wheels',
#  'Niger': 'Niger',
#  'Kerikeri': 'Kerikeri',
#  'Lampung': 'Lampung',
#  'Sepupa': 'Sepupa',
#  'Sunshine Coast (British Columbia)': 'Sunshine_Coast,British_Columbia',
#  'Toronto/Scarborough': 'Toronto/Scarborough',
#  'Driving in China': 'Driving_in_China',
#  'Western Uganda': 'Western_Uganda',
#  'Ballina': 'Ballina',
#  'San Juan (La Union)': 'San_Juan,La_Union',
#  'Aran Islands': 'Aran_Islands',
#  'Wupperthal': 'Wupperthal',
#  'Agadir': 'Agadir',
#  'Diving the Cape Peninsula and False Bay/HNMS Bato': 'Diving_the_Cape_Peninsula_and_False_Bay/HNMS_Bato',
#  'Oracle': 'Oracle',
#  'Cheyenne Wells': 'Cheyenne_Wells',
#  'Ballestas Islands': 'Ballestas_Islands',
#  'Zurich (region)': 'Zurich,region',
#  'Porto Santo Stefano': 'Porto_Santo_Stefano',
#  'Arnhem Land': 'Arnhem_Land',
#  "Diving the Cape Peninsula and False Bay/Finlay's Deep": "Diving_the_Cape_Peninsula_and_False_Bay/Finlay's_Deep",
#  'Chicago': 'Chicago',
#  'Fortuna (California)': 'Fortuna,California',
#  'Diving the Cape Peninsula and False Bay/SS Lusitania': 'Diving_the_Cape_Peninsula_and_False_Bay/SS_Lusitania',
#  'The Other 1': 'The_Other_1',
#  'Tijuana/Playas': 'Tijuana/Playas',
#  'Kismayo': 'Kismayo',
#  'Honaunau': 'Honaunau',
#  'Roscommon': 'Roscommon',
#  'Dothan': 'Dothan',
#  'Playa Hermosa (Osa)': 'Playa_Hermosa,Osa',
#  'Zamora (Ecuador)': 'Zamora,Ecuador',
#  'Kentucky Bourbon Distilleries Tours': 'Kentucky_Bourbon_Distilleries_Tours',
#  'Zanzibar': 'Zanzibar',
#  'Caucasian Biosphere Reserve': 'Caucasian_Biosphere_Reserve',
#  'Torno': 'Torno',
#  'Montefalco': 'Montefalco',
#  'Riberac': 'Riberac',
#  'Rome (New York)': 'Rome,New_York',
#  'Muisne': 'Muisne',
#  'Clarksville (Indiana)': 'Clarksville,Indiana',
#  'Aurich': 'Aurich',
#  'Gunnison': 'Gunnison',
#  'Oberammergau': 'Oberammergau',
#  'Kyaukme': 'Kyaukme',
#  'Dhulikhel': 'Dhulikhel',
#  'Belmont (California)': 'Belmont,California',
#  'Ashburn (Virginia)': 'Ashburn,Virginia',
#  'Worcester Hills': 'Worcester_Hills',
#  'Winnemucca': 'Winnemucca',
#  'Hillsboro (North Dakota)': 'Hillsboro,North_Dakota',
#  'French Gulch': 'French_Gulch',
#  'Hoani': 'Hoani',
#  'Rawanduz': 'Rawanduz',
#  'Garland (Arkansas)': 'Garland,Arkansas',
#  'Washington (Pennsylvania)': 'Washington,Pennsylvania',
#  'Sakha phrasebook': 'Sakha_phrasebook',
#  'Laulasmaa': 'Laulasmaa',
#  'Andover': 'Andover',
#  'Akhty': 'Akhty',
#  'Poudre park': 'Poudre_park',
#  'Landmannalaugar': 'Landmannalaugar',
#  'Indianola': 'Indianola',
#  'Trebisacce': 'Trebisacce',
#  'Mammoth Lakes': 'Mammoth_Lakes',
#  'Portsmouth (Dominica)': 'Portsmouth,Dominica',
#  'Nagaon': 'Nagaon',
#  'Anderson': 'Anderson',
#  'Land Between the Lakes National Recreation Area': 'Land_Between_the_Lakes_National_Recreation_Area',
#  'Jeffersonville (Indiana)': 'Jeffersonville,Indiana',
#  'Narberth': 'Narberth',
#  'Tunbridge Wells': 'Tunbridge_Wells',
#  'Guayana': 'Guayana',
#  'Chugoku': 'Chugoku',
#  'Ojen': 'Ojen',
#  'Clayton (New Mexico)': 'Clayton,New_Mexico',
#  'Bronx': 'Bronx',
#  'Norfolk (Massachusetts)': 'Norfolk,Massachusetts',
#  'Mealhada': 'Mealhada',
#  'Sanjo': 'Sanjo',
#  'Casselberry (Florida)': 'Casselberry,Florida',
#  'Resolute': 'Resolute',
#  'Cauvery Basin': 'Cauvery_Basin',
#  'Norvalspont': 'Norvalspont',
#  'Hope (New Jersey)': 'Hope,New_Jersey',
#  'Hightstown': 'Hightstown',
#  'Logansport': 'Logansport',
#  'Diving the Cape Peninsula and False Bay/Fishermans Beach': 'Diving_the_Cape_Peninsula_and_False_Bay/Fishermans_Beach',
#  'New South Wales': 'New_South_Wales',
#  'Lincoln (Illinois)': 'Lincoln,Illinois',
#  'Llanybydder': 'Llanybydder',
#  'Fuji-Hakone-Izu National Park': 'Fuji-Hakone-Izu_National_Park',
#  'First and business class travel': 'First_and_business_class_travel',
#  'Balkh': 'Balkh',
#  'Clarens': 'Clarens',
#  'Vikings and the Old Norse': 'Vikings_and_the_Old_Norse',
#  'Iwakuni': 'Iwakuni',
#  'Ellmau': 'Ellmau',
#  'Longtan': 'Longtan',
#  'Pirin National Park': 'Pirin_National_Park',
#  'Santa Teresa (Costa Rica)': 'Santa_Teresa,Costa_Rica',
#  'Parsippany': 'Parsippany',
#  'Huntington (Virginia)': 'Huntington,Virginia',
#  'Mountain Home (Idaho)': 'Mountain_Home,Idaho',
#  'Acadia National Park': 'Acadia_National_Park',
#  'Elgin': 'Elgin',
#  'Spello': 'Spello',
#  'Okehampton': 'Okehampton',
#  'Manchester (Tennessee)': 'Manchester,Tennessee',
#  'Yoshkar-Ola': 'Yoshkar-Ola',
#  'Moritzburg': 'Moritzburg',
#  'Stroud (Oklahoma)': 'Stroud,Oklahoma',
#  'Bohemian-Moravian Highlands': 'Bohemian-Moravian_Highlands',
#  'Sigulda': 'Sigulda',
#  'Chhukhung': 'Chhukhung',
#  'Puebla (state)': 'Puebla,state',
#  'Skye': 'Skye',
#  'Clarksburg': 'Clarksburg',
#  'Marumbi': 'Marumbi',
#  'Brookings': 'Brookings',
#  'Atlantic Seaboard': 'Atlantic_Seaboard',
#  'South Coast Highway': 'South_Coast_Highway',
#  'Valley': 'Valley',
#  'Central Aegean': 'Central_Aegean',
#  'Apopka': 'Apopka',
#  'Glengarriff': 'Glengarriff',
#  "Les Sables d'Olonne": "Les_Sables_d'Olonne",
#  'San Angelo': 'San_Angelo',
#  'West Vancouver': 'West_Vancouver',
#  "Sant' Andrea Apostolo dello Jonio": "Sant'_Andrea_Apostolo_dello_Jonio",
#  'Chantilly (Virginia)': 'Chantilly,Virginia',
#  'Woodridge (Illinois)': 'Woodridge,Illinois',
#  'Big Timber': 'Big_Timber',
#  'Isles of Scilly': 'Isles_of_Scilly',
#  'Exton': 'Exton',
#  'Black Forest': 'Black_Forest',
#  'Rapid Bay': 'Rapid_Bay',
#  'Kavieng': 'Kavieng',
#  'Mountain Province': 'Mountain_Province',
#  'Mountain View (California)': 'Mountain_View,California',
#  'Cerro Punta': 'Cerro_Punta',
#  'Camalu': 'Camalu',
#  'Johnson Creek': 'Johnson_Creek',
#  'Ada (Michigan)': 'Ada,Michigan',
#  'Marina del Rey': 'Marina_del_Rey',
#  'Kashmir Valley': 'Kashmir_Valley',
#  'Suwa': 'Suwa',
#  'Alphen aan den Rijn': 'Alphen_aan_den_Rijn',
#  'Diving inland in South Africa/Wondergat': 'Diving_inland_in_South_Africa/Wondergat',
#  'Baghdad': 'Baghdad',
#  'Albenga': 'Albenga',
#  'North Stonington': 'North_Stonington',
#  'Samut Prakan': 'Samut_Prakan',
#  'Bath (Maine)': 'Bath,Maine',
#  'College Park (Maryland)': 'College_Park,Maryland',
#  'Tipping': 'Tipping',
#  'Central Bosnia': 'Central_Bosnia',
#  'Silimbong': 'Silimbong',
#  'Schleswig-Holstein': 'Schleswig-Holstein',
#  'Ko Jum': 'Ko_Jum',
#  'Cullohill': 'Cullohill',
#  'Mount Meron': 'Mount_Meron',
#  'Freetown (Massachusetts)': 'Freetown,Massachusetts',
#  'Kununurra': 'Kununurra',
#  'Manchester/Victoria-Shopping District': 'Manchester/Victoria-Shopping_District',
#  'Latera': 'Latera',
#  'Beskids': 'Beskids',
#  'National City': 'National_City',
#  'Cumberland Gap National Historical Park': 'Cumberland_Gap_National_Historical_Park',
#  'Mangamuka Bridge': 'Mangamuka_Bridge',
#  'Pahokee': 'Pahokee',
#  'South Corsica': 'South_Corsica',
#  'Passaic': 'Passaic',
#  'Perryton': 'Perryton',
#  'Ingleside': 'Ingleside',
#  'Celebration': 'Celebration',
#  'Chihuahua (state)': 'Chihuahua,state',
#  'Sosua': 'Sosua',
#  'Cieszyn': 'Cieszyn',
#  'Oxbow': 'Oxbow',
#  'Southern Africa': 'Southern_Africa',
#  'Lavenham': 'Lavenham',
#  'Crystal Lake': 'Crystal_Lake',
#  'China (Texas)': 'China,Texas',
#  'Central Slovenia': 'Central_Slovenia',
#  'Sitka': 'Sitka',
#  'Ladino phrasebook': 'Ladino_phrasebook',
#  'Berlin (Connecticut)': 'Berlin,Connecticut',
#  'Jotunheimen': 'Jotunheimen',
#  'Northwest (Rio Grande do Sul)': 'Northwest,Rio_Grande_do_Sul',
#  'Mary Province': 'Mary_Province',
#  'Ende': 'Ende',
#  'Bingzhongluo': 'Bingzhongluo',
#  'Rockland County': 'Rockland_County',
#  'Tokyo/Akihabara': 'Tokyo/Akihabara',
#  'La Paz (Mexico)': 'La_Paz,Mexico',
#  'Chubu Centrair International Airport': 'Chubu_Centrair_International_Airport',
#  'Carlisle (Iowa)': 'Carlisle,Iowa',
#  'Aakirkeby': 'Aakirkeby',
#  'Bocholt': 'Bocholt',
#  'Pleasanton': 'Pleasanton',
#  'Brest': 'Brest',
#  'El Golea': 'El_Golea',
#  'Leiria': 'Leiria',
#  'North Country': 'North_Country',
#  'Sannicolau Mare': 'Sannicolau_Mare',
#  'Big Pine': 'Big_Pine',
#  'Bay Point': 'Bay_Point',
#  'Riverview': 'Riverview',
#  'West (Hill Country)': 'West,Hill_Country',
#  'Misquamicut': 'Misquamicut',
#  'Bethany (Oklahoma)': 'Bethany,Oklahoma',
#  'Kaili': 'Kaili',
#  'Tokyo/Chiyoda': 'Tokyo/Chiyoda',
#  'Cheorwon': 'Cheorwon',
#  'Ialysos': 'Ialysos',
#  'MacDonnell Ranges': 'MacDonnell_Ranges',
#  'Gardena': 'Gardena',
#  'Melbourne': 'Melbourne',
#  'Inverigo': 'Inverigo',
#  'Spennymoor': 'Spennymoor',
#  'Nouakchott': 'Nouakchott',
#  'Cacapava': 'Cacapava',
#  'Bellevue (Nebraska)': 'Bellevue,Nebraska',
#  'Holbk': 'Holbk',
#  'Onslow County': 'Onslow_County',
#  'Kabale': 'Kabale',
#  'Freeland': 'Freeland',
#  'Semmering': 'Semmering',
#  'Ipswich': 'Ipswich',
#  'Science-fiction tourism': 'Science-fiction_tourism',
#  'Mundau': 'Mundau',
#  'Lleida': 'Lleida',
#  'Majuli': 'Majuli',
#  'Kasauli': 'Kasauli',
#  'Fairmont City': 'Fairmont_City',
#  'Western Highlands': 'Western_Highlands',
#  'Kherson': 'Kherson',
#  'Lake District National Park': 'Lake_District_National_Park',
#  'Faliraki': 'Faliraki',
#  'Macedon Ranges': 'Macedon_Ranges',
#  'Loudoun County (Virginia)': 'Loudoun_County,Virginia',
#  'Ahmedabad': 'Ahmedabad',
#  'Trechtingshausen': 'Trechtingshausen',
#  'Los Angeles/Northwest': 'Los_Angeles/Northwest',
#  'Longwood (Florida)': 'Longwood,Florida',
#  'Kelmend': 'Kelmend',
#  'Enniskillen': 'Enniskillen',
#  'Nicosia district (South)': 'Nicosia_district,South',
#  'Skelleftea': 'Skelleftea',
#  'Hjrundfjord': 'Hjrundfjord',
#  'Laguna Beach': 'Laguna_Beach',
#  'Kuala Terengganu': 'Kuala_Terengganu',
#  'Greenville (South Carolina)': 'Greenville,South_Carolina',
#  'Marathon (Florida)': 'Marathon,Florida',
#  'Santa Barbara': 'Santa_Barbara',
#  'Spencer (West Virginia)': 'Spencer,West_Virginia',
#  'Tak': 'Tak',
#  'Silvia': 'Silvia',
#  'North Platte': 'North_Platte',
#  'Kemmerer': 'Kemmerer',
#  'Hervey Bay': 'Hervey_Bay',
#  '100 Mile House': '100_Mile_House',
#  'Kalinga': 'Kalinga',
#  'Lake Elsinore': 'Lake_Elsinore',
#  'Peechi Vazhani Wildlife Sanctuary': 'Peechi_Vazhani_Wildlife_Sanctuary',
#  'Pamplona': 'Pamplona',
#  'Mn': 'Mn',
#  'Somerset (Massachusetts)': 'Somerset,Massachusetts',
#  'Dorking': 'Dorking',
#  'Interior (Iceland)': 'Interior,Iceland',
#  'Isle of Lismore': 'Isle_of_Lismore',
#  'Montgomery Township': 'Montgomery_Township',
#  'Chapada dos Guimaraes': 'Chapada_dos_Guimaraes',
#  'Bol': 'Bol',
#  'Jardin': 'Jardin',
#  'Bowling Green (Ohio)': 'Bowling_Green,Ohio',
#  'Thornton': 'Thornton',
#  'Khakassia': 'Khakassia',
#  'Clitheroe': 'Clitheroe',
#  'Hardin County': 'Hardin_County',
#  'Sedibeng': 'Sedibeng',
#  'Lake Louise': 'Lake_Louise',
#  'Mardana': 'Mardana',
#  'Davidson': 'Davidson',
#  'August': 'August',
#  'Watsonville': 'Watsonville',
#  'Yulin (Guangxi)': 'Yulin,Guangxi',
#  'Fujian': 'Fujian',
#  'Hawera': 'Hawera',
#  'Phillip Island': 'Phillip_Island',
#  'Mount Tai': 'Mount_Tai',
#  'Artyom': 'Artyom',
#  'Prineville': 'Prineville',
#  'Prague/West bank of Vltava': 'Prague/West_bank_of_Vltava',
#  'Cape May': 'Cape_May',
#  'Missouri Valley': 'Missouri_Valley',
#  'Devala': 'Devala',
#  'Helmstedt': 'Helmstedt',
#  'Diving the Cape Peninsula and False Bay/Justins Caves': 'Diving_the_Cape_Peninsula_and_False_Bay/Justins_Caves',
#  'Dover (New Hampshire)': 'Dover,New_Hampshire',
#  'Salar de Uyuni': 'Salar_de_Uyuni',
#  'Hershey': 'Hershey',
#  'Marquette (Iowa)': 'Marquette,Iowa',
#  'Etawah': 'Etawah',
#  'Lake Como': 'Lake_Como',
#  'Diving the Cape Peninsula and False Bay/South Paw': 'Diving_the_Cape_Peninsula_and_False_Bay/South_Paw',
#  'Mexicali': 'Mexicali',
#  'Shelburne (Nova Scotia)': 'Shelburne,Nova_Scotia',
#  'Punxsutawney': 'Punxsutawney',
#  'North (Canada)': 'North,Canada',
#  'Eastham': 'Eastham',
#  'Karula National Park': 'Karula_National_Park',
#  'Hecho': 'Hecho',
#  'Shiga': 'Shiga',
#  'Inner Hebrides': 'Inner_Hebrides',
#  'Agulhas National Park': 'Agulhas_National_Park',
#  'Beichuan': 'Beichuan',
#  'Yukon (Oklahoma)': 'Yukon,Oklahoma',
#  'Joliet': 'Joliet',
#  'Rodeo (event)': 'Rodeo,event',
#  'Three Rivers': 'Three_Rivers',
#  'Lamesa': 'Lamesa',
#  'Samsun': 'Samsun',
#  'Wilderness backpacking': 'Wilderness_backpacking',
#  'Saintes Maries de la Mer': 'Saintes_Maries_de_la_Mer',
#  'Esmeraldas': 'Esmeraldas',
#  'Chicago/Lincoln Park-Old Town': 'Chicago/Lincoln_Park-Old_Town',
#  'Capena': 'Capena',
#  'Fish Camp': 'Fish_Camp',
#  'Kanye': 'Kanye',
#  'Paris/10th arrondissement': 'Paris/10th_arrondissement',
#  'Novyi Svet': 'Novyi_Svet',
#  'Zhengzhou': 'Zhengzhou',
#  'Lhuentse': 'Lhuentse',
#  'Peterborough': 'Peterborough',
#  'Bowie': 'Bowie',
#  'Chuncheon': 'Chuncheon',
#  'Cromwell': 'Cromwell',
#  'Khewra Salt Mine': 'Khewra_Salt_Mine',
#  'Cypress': 'Cypress',
#  'Escanaba': 'Escanaba',
#  'Nang Rong': 'Nang_Rong',
#  'Alvdalen': 'Alvdalen',
#  'Assisi': 'Assisi',
#  'Yarmouth (Maine)': 'Yarmouth,Maine',
#  'Nantwich': 'Nantwich',
#  'Southern Streymoy': 'Southern_Streymoy',
#  'Kemi': 'Kemi',
#  'Surrey County': 'Surrey_County',
#  'Superior (Montana)': 'Superior,Montana',
#  'Webster': 'Webster',
#  'Ukhahlamba Drakensberg': 'Ukhahlamba_Drakensberg',
#  'Towada-Hachimantai National Park': 'Towada-Hachimantai_National_Park',
#  'Lesotho': 'Lesotho',
#  'Funafuti': 'Funafuti',
#  'Morenci': 'Morenci',
#  'Bechatow': 'Bechatow',
#  'Southeastern France': 'Southeastern_France',
#  'Rankin Inlet': 'Rankin_Inlet',
#  'Fanwood': 'Fanwood',
#  'New Castle (Delaware)': 'New_Castle,Delaware',
#  'Devon (Alberta)': 'Devon,Alberta',
#  'Off-highway vehicle riding in Oregon': 'Off-highway_vehicle_riding_in_Oregon',
#  'Killorglin': 'Killorglin',
#  'Taplejung': 'Taplejung',
#  'Patagonia (Arizona)': 'Patagonia,Arizona',
#  'Jiangsu': 'Jiangsu',
#  'Michigan': 'Michigan',
#  'Mackenzie Country': 'Mackenzie_Country',
#  'Lefkara': 'Lefkara',
#  'Richmond (Tasmania)': 'Richmond,Tasmania',
#  "Hawke's Bay": "Hawke's_Bay",
#  'Mongar': 'Mongar',
#  'Glacier National Park': 'Glacier_National_Park',
#  'Grasslands National Park': 'Grasslands_National_Park',
#  'Clearlake': 'Clearlake',
#  'Eftimie Murgu': 'Eftimie_Murgu',
#  'Braintree (Massachusetts)': 'Braintree,Massachusetts',
#  'Coast and Mayombe': 'Coast_and_Mayombe',
#  'Arlington (Washington)': 'Arlington,Washington',
#  'Fleurieu Peninsula': 'Fleurieu_Peninsula',
#  'South Africa': 'South_Africa',
#  'Prien am Chiemsee': 'Prien_am_Chiemsee',
#  'Portarlington': 'Portarlington',
#  'Murdeshwara': 'Murdeshwara',
#  'Ruvo di Puglia': 'Ruvo_di_Puglia',
#  'Veitshochheim': 'Veitshochheim',
#  'Blenheim (New Zealand)': 'Blenheim,New_Zealand',
#  'Kanipakam': 'Kanipakam',
#  'Norwalk': 'Norwalk',
#  'Bratsk': 'Bratsk',
#  'Port Augusta': 'Port_Augusta',
#  'Custer State Park': 'Custer_State_Park',
#  'Pixley': 'Pixley',
#  'Marijampole': 'Marijampole',
#  'Istanbul/Golden Horn': 'Istanbul/Golden_Horn',
#  'Kulpsville': 'Kulpsville',
#  'Hammerfest': 'Hammerfest',
#  'Chittur': 'Chittur',
#  'Nova Venecia': 'Nova_Venecia',
#  'Vulcano': 'Vulcano',
#  'Southeast Arizona': 'Southeast_Arizona',
#  'Time zones': 'Time_zones',
#  'Manville (New Jersey)': 'Manville,New_Jersey',
#  'Swanzey': 'Swanzey',
#  'Zonguldak': 'Zonguldak',
#  'Rio de Janeiro/Zona Oeste': 'Rio_de_Janeiro/Zona_Oeste',
#  'Sangha and Likouala': 'Sangha_and_Likouala',
#  "O'Fallon (Illinois)": "O'Fallon,Illinois",
#  'Houston/West Houston': 'Houston/West_Houston',
#  'Chamarajanagar (district)': 'Chamarajanagar,district',
#  'Mindong phrasebook': 'Mindong_phrasebook',
#  'Mu Ko Surin National Park': 'Mu_Ko_Surin_National_Park',
#  'West Chester (Pennsylvania)': 'West_Chester,Pennsylvania',
#  'Sutter County': 'Sutter_County',
#  'Saharan Mauritania': 'Saharan_Mauritania',
#  'Field': 'Field',
#  'Port Angeles': 'Port_Angeles',
#  'Qasr Amra': 'Qasr_Amra',
#  'Newton-le-Willows': 'Newton-le-Willows',
#  'Ankola': 'Ankola',
#  'Northern Tunisia': 'Northern_Tunisia',
#  'Tegernsee': 'Tegernsee',
#  'Southern Armenia': 'Southern_Armenia',
#  'Gunung Mulu National Park': 'Gunung_Mulu_National_Park',
#  'Sycamore': 'Sycamore',
#  'Southwestern Indiana': 'Southwestern_Indiana',
#  'Annur': 'Annur',
#  'Muang Ngeun': 'Muang_Ngeun',
#  'Minca': 'Minca',
#  'Zaandam': 'Zaandam',
#  'Phuket Town': 'Phuket_Town',
#  'Cheb': 'Cheb',
#  'Northern Coast (Puerto Rico)': 'Northern_Coast,Puerto_Rico',
#  'Capurgana': 'Capurgana',
#  'Vire': 'Vire',
#  'Chem': 'Chem',
#  'Travelling during Ramadan': 'Travelling_during_Ramadan',
#  'Chelmsford (England)': 'Chelmsford,England',
#  'Geelong': 'Geelong',
#  'Pontiac (Michigan)': 'Pontiac,Michigan',
#  'Vale dos Dinossauros': 'Vale_dos_Dinossauros',
#  'Chamba': 'Chamba',
#  'Ethiopia': 'Ethiopia',
#  'Ski': 'Ski',
#  'Budoni': 'Budoni',
#  'Pontal do Parana': 'Pontal_do_Parana',
#  'Elmina': 'Elmina',
#  'Llanrwst': 'Llanrwst',
#  'Erechim': 'Erechim',
#  'Marshfield (Missouri)': 'Marshfield,Missouri',
#  'Adilabad': 'Adilabad',
#  'Lewistown': 'Lewistown',
#  'Rottweil': 'Rottweil',
#  'North Africa': 'North_Africa',
#  'Montejaque': 'Montejaque',
#  'Swieradow-Zdroj': 'Swieradow-Zdroj',
#  'Altamonte Springs': 'Altamonte_Springs',
#  'Hall in Tirol': 'Hall_in_Tirol',
#  'Montgomery (Ohio)': 'Montgomery,Ohio',
#  'Tupana': 'Tupana',
#  'Natural Bridge State Park': 'Natural_Bridge_State_Park',
#  'Olean': 'Olean',
#  'Mid-Atlantic': 'Mid-Atlantic',
#  'Rehoboth': 'Rehoboth',
#  'Roccella Ionica': 'Roccella_Ionica',
#  'Connemara': 'Connemara',
#  'Ostrava': 'Ostrava',
#  'Grand Turk': 'Grand_Turk',
#  'James River Plantations': 'James_River_Plantations',
#  'Nederland (Colorado)': 'Nederland,Colorado',
#  'Gumusluk': 'Gumusluk',
#  'Pawtucket': 'Pawtucket',
#  'Santana': 'Santana',
#  'Samedan': 'Samedan',
#  'Ischigualasto Provincial Park': 'Ischigualasto_Provincial_Park',
#  'Puerto Madryn': 'Puerto_Madryn',
#  'LGBT Stockholm': 'LGBT_Stockholm',
#  'Hyder': 'Hyder',
#  'Princeton (North Carolina)': 'Princeton,North_Carolina',
#  'Kingston-on-Murray': 'Kingston-on-Murray',
#  'Labhpur': 'Labhpur',
#  'Pucallpa': 'Pucallpa',
#  'Hyden': 'Hyden',
#  'South Sound': 'South_Sound',
#  'Awa': 'Awa',
#  'Niagara-on-the-Lake': 'Niagara-on-the-Lake',
#  'Sa Kaeo': 'Sa_Kaeo',
#  'Karkonosze National Park': 'Karkonosze_National_Park',
#  'Calf of Man': 'Calf_of_Man',
#  'Czech phrasebook': 'Czech_phrasebook',
#  'Tiberias': 'Tiberias',
#  'Bishop Auckland': 'Bishop_Auckland',
#  'Konya': 'Konya',
#  'Mazeri': 'Mazeri',
#  'Skien': 'Skien',
#  'U.S. Virgin Islands': 'U.S._Virgin_Islands',
#  'Alcantara': 'Alcantara',
#  'Fairbanks': 'Fairbanks',
#  'Wangdue Phodrang': 'Wangdue_Phodrang',
#  'Freeland (Washington)': 'Freeland,Washington',
#  'Westfjords': 'Westfjords',
#  'Settler Country': 'Settler_Country',
#  'Gansu': 'Gansu',
#  'Birr': 'Birr',
#  'Kuala Lumpur/Tuanku Abdul Rahman': 'Kuala_Lumpur/Tuanku_Abdul_Rahman',
#  'Maquine': 'Maquine',
#  'Nundle': 'Nundle',
#  'Asheville': 'Asheville',
#  'Reconcavo': 'Reconcavo',
#  'Wisbech': 'Wisbech',
#  'Twin Falls': 'Twin_Falls',
#  'Englishtown': 'Englishtown',
#  'Cleethorpes': 'Cleethorpes',
#  'Angola (Indiana)': 'Angola,Indiana',
#  'Aptos': 'Aptos',
#  'Gwinnett County (Georgia)': 'Gwinnett_County,Georgia',
#  'Olinda': 'Olinda',
#  'Hampshire County': 'Hampshire_County',
#  'Amherst (Massachusetts)': 'Amherst,Massachusetts',
#  'Whangarei': 'Whangarei',
#  'Brewster (Washington)': 'Brewster,Washington',
#  'Cesenatico': 'Cesenatico',
#  'Annandale': 'Annandale',
#  'Coquitlam': 'Coquitlam',
#  'Uppsala countryside': 'Uppsala_countryside',
#  'Mazar-e Sharif': 'Mazar-e_Sharif',
#  'Dallas/Northwest Dallas': 'Dallas/Northwest_Dallas',
#  'Nagoya': 'Nagoya',
#  'Rio Vista (California)': 'Rio_Vista,California',
#  'Snowy Mountains': 'Snowy_Mountains',
#  'Triglav National Park': 'Triglav_National_Park',
#  'Bosaso': 'Bosaso',
#  'Lebanon (Missouri)': 'Lebanon,Missouri',
#  'Midnapore': 'Midnapore',
#  'Tumwater': 'Tumwater',
#  'Diving the Cape Peninsula and False Bay/Coral Gardens (Rooi-els)': 'Diving_the_Cape_Peninsula_and_False_Bay/Coral_Gardens,Rooi-els',
#  'Redang': 'Redang',
#  'Panch Kedar': 'Panch_Kedar',
#  'Uppland Plains': 'Uppland_Plains',
#  'Hummingbird Highway': 'Hummingbird_Highway',
#  'Florenceville-Bristol': 'Florenceville-Bristol',
#  'Pori': 'Pori',
#  'North Pole (New York)': 'North_Pole,New_York',
#  'Fairport': 'Fairport',
#  'Kenting National Park': 'Kenting_National_Park',
#  'South Hadley': 'South_Hadley',
#  'Yingge': 'Yingge',
#  'Lewisporte': 'Lewisporte',
#  'Diving the Cape Peninsula and False Bay/SAS Gelderland': 'Diving_the_Cape_Peninsula_and_False_Bay/SAS_Gelderland',
#  'Bangkok/Dusit': 'Bangkok/Dusit',
#  'Gorongosa': 'Gorongosa',
#  'Wachau': 'Wachau',
#  'Plain of Jars': 'Plain_of_Jars',
#  'Tenorio Volcano National Park': 'Tenorio_Volcano_National_Park',
#  'Bunratty': 'Bunratty',
#  'Washington, D.C./Waterfront': 'Washington,_D.C./Waterfront',
#  'Grand Isle (Louisiana)': 'Grand_Isle,Louisiana',
#  'Concerns': 'Concerns',
#  'Puttaparthi': 'Puttaparthi',
#  'Georgetown (Guyana)': 'Georgetown,Guyana',
#  'Yuma': 'Yuma',
#  'Barnaul': 'Barnaul',
#  'Dunkeld': 'Dunkeld',
#  'Far North Queensland': 'Far_North_Queensland',
#  'Orange (New South Wales)': 'Orange,New_South_Wales',
#  'Marshall (Michigan)': 'Marshall,Michigan',
#  'Takasaki': 'Takasaki',
#  'Mumbai/Harbour suburbs': 'Mumbai/Harbour_suburbs',
#  'Sao Joao da Barra': 'Sao_Joao_da_Barra',
#  'Cupramontana': 'Cupramontana',
#  'Sturgeon Bay': 'Sturgeon_Bay',
#  'Nakbe': 'Nakbe',
#  'Green River (Wyoming)': 'Green_River,Wyoming',
#  'Huntly': 'Huntly',
#  'Rail travel in the United Kingdom': 'Rail_travel_in_the_United_Kingdom',
#  'Rio Branco': 'Rio_Branco',
#  'Central Florida': 'Central_Florida',
#  'Castellammare del Golfo': 'Castellammare_del_Golfo',
#  'Murter': 'Murter',
#  'Coimbatore': 'Coimbatore',
#  'Hainan': 'Hainan',
#  'Dalsland': 'Dalsland',
#  'Caherciveen': 'Caherciveen',
#  'Bacolod': 'Bacolod',
#  'Colonial Williamsburg': 'Colonial_Williamsburg',
#  'Sumba (Faroe Islands)': 'Sumba,Faroe_Islands',
#  'Kingsville (Ontario)': 'Kingsville,Ontario',
#  'Apex Mountain Ski Resort': 'Apex_Mountain_Ski_Resort',
#  'Grafenwohr': 'Grafenwohr',
#  'Honolulu/Waikiki': 'Honolulu/Waikiki',
#  'East High Country': 'East_High_Country',
#  'Cenotes of the Yucatan': 'Cenotes_of_the_Yucatan',
#  'Gaud': 'Gaud',
#  'Vienna (Virginia)': 'Vienna,Virginia',
#  'Estremoz': 'Estremoz',
#  'Holywell': 'Holywell',
#  'Goorambat': 'Goorambat',
#  'Central Queensland': 'Central_Queensland',
#  'Dallas/Lower Greenville': 'Dallas/Lower_Greenville',
#  'Guyanese Coastal Plain': 'Guyanese_Coastal_Plain',
#  'Antofagasta': 'Antofagasta',
#  'Aberfeldy': 'Aberfeldy',
#  'Shunan Zhuhai National Park': 'Shunan_Zhuhai_National_Park',
#  'Durban': 'Durban',
#  'Peninsula': 'Peninsula',
#  'Kunming': 'Kunming',
#  'Konjic': 'Konjic',
#  'Diving in South Australia/Shark cage diving at the Neptune Islands': 'Diving_in_South_Australia/Shark_cage_diving_at_the_Neptune_Islands',
#  'Winner': 'Winner',
#  "D'Iberville": "D'Iberville",
#  'Porta del Sol': 'Porta_del_Sol',
#  'Out Stack': 'Out_Stack',
#  'Barreal': 'Barreal',
#  'Southgate': 'Southgate',
#  'Pennsburg': 'Pennsburg',
#  'Amphawa': 'Amphawa',
#  'Guanaja': 'Guanaja',
#  'Kanata': 'Kanata',
#  'Frenchman Coulee': 'Frenchman_Coulee',
#  'Shizuishan': 'Shizuishan',
#  'Sarawak': 'Sarawak',
#  "Diving the Cape Peninsula and False Bay/Noah's Ark": "Diving_the_Cape_Peninsula_and_False_Bay/Noah's_Ark",
#  'RMS Titanic': 'RMS_Titanic',
#  'Burnley': 'Burnley',
#  'Pedro Gonzalez': 'Pedro_Gonzalez',
#  'Hundested': 'Hundested',
#  'Guanajuato (state)': 'Guanajuato,state',
#  'Diving Aliwal Shoal/North Sands': 'Diving_Aliwal_Shoal/North_Sands',
#  'Jingyuetan National Forest Park': 'Jingyuetan_National_Forest_Park',
#  'Lower Austria': 'Lower_Austria',
#  'Balbriggan': 'Balbriggan',
#  'Elista': 'Elista',
#  'Geeveston': 'Geeveston',
#  'Urfa': 'Urfa',
#  'Biak': 'Biak',
#  'Central Zambia': 'Central_Zambia',
#  'Thalmassing': 'Thalmassing',
#  'Franklin (Kentucky)': 'Franklin,Kentucky',
#  'Franklin Township': 'Franklin_Township',
#  'Moorhead': 'Moorhead',
#  'Seattle/West': 'Seattle/West',
#  'Alampur': 'Alampur',
#  'Alausi': 'Alausi',
#  'Diving the Cape Peninsula and False Bay/RMS Athens': 'Diving_the_Cape_Peninsula_and_False_Bay/RMS_Athens',
#  'Achziv': 'Achziv',
#  'Chitimba': 'Chitimba',
#  'Waterbury': 'Waterbury',
#  'Plymouth (Wisconsin)': 'Plymouth,Wisconsin',
#  'Ribeirao Preto': 'Ribeirao_Preto',
#  'Brevard County': 'Brevard_County',
#  'Kerak': 'Kerak',
#  'Jaipur Division': 'Jaipur_Division',
#  'Neil Island': 'Neil_Island',
#  'Robbinsville (North Carolina)': 'Robbinsville,North_Carolina',
#  'Hacketstown': 'Hacketstown',
#  'Lexington Park': 'Lexington_Park',
#  'Blumenau': 'Blumenau',
#  'Shanghai/Huangpu': 'Shanghai/Huangpu',
#  'Bamako': 'Bamako',
#  'Grindelwald': 'Grindelwald',
#  'Congaree National Park': 'Congaree_National_Park',
#  'Broken Arrow': 'Broken_Arrow',
#  'Salzburg (state)': 'Salzburg,state',
#  'Torrington (Wyoming)': 'Torrington,Wyoming',
#  'Ranikhet': 'Ranikhet',
#  'Sparta (Wisconsin)': 'Sparta,Wisconsin',
#  'Carlsbad Caverns National Park': 'Carlsbad_Caverns_National_Park',
#  'Fayetteville (West Virginia)': 'Fayetteville,West_Virginia',
#  'Arnprior': 'Arnprior',
#  'Struga': 'Struga',
#  'Rogiet': 'Rogiet',
#  'Khmelnytskyi': 'Khmelnytskyi',
#  'Nanjangud': 'Nanjangud',
#  'Morvan Regional Natural Park': 'Morvan_Regional_Natural_Park',
#  'Oak Harbor': 'Oak_Harbor',
#  'Huntley': 'Huntley',
#  'Perissa': 'Perissa',
#  'Digby': 'Digby',
#  'Dullatur': 'Dullatur',
#  'Spencer': 'Spencer',
#  'Visby': 'Visby',
#  'Gondik': 'Gondik',
#  'Megaplatanos': 'Megaplatanos',
#  'Perak': 'Perak',
#  'Aruja': 'Aruja',
#  'Buffalo/Elmwood Village': 'Buffalo/Elmwood_Village',
#  'Saint Petersburg/Petrograd Side': 'Saint_Petersburg/Petrograd_Side',
#  'Nioumachoua': 'Nioumachoua',
#  'Diving the Mokohinau Islands': 'Diving_the_Mokohinau_Islands',
#  'Kuwait': 'Kuwait',
#  'Weatherford (Oklahoma)': 'Weatherford,Oklahoma',
#  'Richmond': 'Richmond',
#  'Bad Sobernheim': 'Bad_Sobernheim',
#  'Fort William': 'Fort_William',
#  'North Pittsburgh Region': 'North_Pittsburgh_Region',
#  'Diving in Thailand/Richelieu Rock': 'Diving_in_Thailand/Richelieu_Rock',
#  'Daventry': 'Daventry',
#  'Cotati': 'Cotati',
#  'Wrexham (county)': 'Wrexham,county',
#  'Bonda': 'Bonda',
#  'Amesbury (Massachusetts)': 'Amesbury,Massachusetts',
#  'Rot an der Rot': 'Rot_an_der_Rot',
#  'Tracy City': 'Tracy_City',
#  'Espanola (Galapagos)': 'Espanola,Galapagos',
#  'Subic': 'Subic',
#  'Willows': 'Willows',
#  'Kahurangi National Park': 'Kahurangi_National_Park',
#  'Raja': 'Raja',
#  'Southern Wisconsin River Valley': 'Southern_Wisconsin_River_Valley',
#  'Andohahela National Park': 'Andohahela_National_Park',
#  'St Francis': 'St_Francis',
#  'Segou': 'Segou',
#  'Bradenton': 'Bradenton',
#  'Glasgow': 'Glasgow',
#  'Kansai International Airport': 'Kansai_International_Airport',
#  'Ettelbruck': 'Ettelbruck',
#  'North Sea': 'North_Sea',
#  'Kirzhach': 'Kirzhach',
#  'Inveraray': 'Inveraray',
#  'Sudbury (Suffolk)': 'Sudbury,Suffolk',
#  'Staraya Ladoga': 'Staraya_Ladoga',
#  'Marple (England)': 'Marple,England',
#  'Champlain Valley': 'Champlain_Valley',
#  'Medfield': 'Medfield',
#  'Machranga Dweep': 'Machranga_Dweep',
#  'Kei Mouth': 'Kei_Mouth',
#  'Arlington Heights': 'Arlington_Heights',
#  'Milford (Texas)': 'Milford,Texas',
#  'Clare Valley': 'Clare_Valley',
#  'Woonsocket': 'Woonsocket',
#  'Heflin (Alabama)': 'Heflin,Alabama',
#  'Frigiliana': 'Frigiliana',
#  'Bridgetown': 'Bridgetown',
#  'Hammaslahti': 'Hammaslahti',
#  'Amelinghausen': 'Amelinghausen',
#  'Cuyo': 'Cuyo',
#  'Ridgewood': 'Ridgewood',
#  'Afton': 'Afton',
#  'Middle East': 'Middle_East',
#  'SeaWorld': 'SeaWorld',
#  'Oppdal': 'Oppdal',
#  'Machu Picchu': 'Machu_Picchu',
#  'Mystic (Connecticut)': 'Mystic,Connecticut',
#  'Along the Yangtze River': 'Along_the_Yangtze_River',
#  'Reading (Massachusetts)': 'Reading,Massachusetts',
#  'Brussels': 'Brussels',
#  'Bethlehem (New Hampshire)': 'Bethlehem,New_Hampshire',
#  'Momence': 'Momence',
#  'Pangkalanbun': 'Pangkalanbun',
#  'Narrandera': 'Narrandera',
#  'Carlisle (Pennsylvania)': 'Carlisle,Pennsylvania',
#  'Sikeston': 'Sikeston',
#  'Caucaia': 'Caucaia',
#  'Enchanted Rock State Natural Area': 'Enchanted_Rock_State_Natural_Area',
#  'Wilsons Promontory': 'Wilsons_Promontory',
#  'Diyarbakir': 'Diyarbakir',
#  'Rasht': 'Rasht',
#  'Mithur': 'Mithur',
#  'Pasay': 'Pasay',
#  'Soltau': 'Soltau',
#  'Kailua-Kona': 'Kailua-Kona',
#  'Tamana': 'Tamana',
#  'Groton (Connecticut)': 'Groton,Connecticut',
#  'Ruta Puuc': 'Ruta_Puuc',
#  'Tokaj-Hegyalja': 'Tokaj-Hegyalja',
#  'Contiguous United States': 'Contiguous_United_States',
#  'Kimberley (British Columbia)': 'Kimberley,British_Columbia',
#  'Solva': 'Solva',
#  'Central Falls (Rhode Island)': 'Central_Falls,Rhode_Island',
#  'Lexington (South Carolina)': 'Lexington,South_Carolina',
#  'South Sichuan': 'South_Sichuan',
#  'Bunya Mountains National Park': 'Bunya_Mountains_National_Park',
#  'Vikasnagar': 'Vikasnagar',
#  'Cocuy National Park': 'Cocuy_National_Park',
#  'Englewood (New Jersey)': 'Englewood,New_Jersey',
#  'Madidi National Park': 'Madidi_National_Park',
#  'Luquillo': 'Luquillo',
#  'Red River Valley (North Dakota)': 'Red_River_Valley,North_Dakota',
#  'Nardo': 'Nardo',
#  'Lubuskie': 'Lubuskie',
#  'Haukeli': 'Haukeli',
#  'Military museums and sites in Australia': 'Military_museums_and_sites_in_Australia',
#  'Hay-on-Wye': 'Hay-on-Wye',
#  'Dalat': 'Dalat',
#  'Puerto Rio Tranquilo': 'Puerto_Rio_Tranquilo',
#  'Gualala': 'Gualala',
#  'Clinton County (Ohio)': 'Clinton_County,Ohio',
#  'Gelderland': 'Gelderland',
#  'Lawrence (Massachusetts)': 'Lawrence,Massachusetts',
#  'Knysna': 'Knysna',
#  'Dudinka': 'Dudinka',
#  'St. Just in Penwith': 'St._Just_in_Penwith',
#  'Rolette': 'Rolette',
#  'Newberry (Michigan)': 'Newberry,Michigan',
#  'Carrick-on-Shannon': 'Carrick-on-Shannon',
#  'Baie St-Paul': 'Baie_St-Paul',
#  'Bominaco': 'Bominaco',
#  'Buga': 'Buga',
#  'Kumasi': 'Kumasi',
#  'Vancouver (Washington)': 'Vancouver,Washington',
#  'Hyvinkaa': 'Hyvinkaa',
#  'Redcliffe': 'Redcliffe',
#  'Kubah National Park': 'Kubah_National_Park',
#  'Milan/Outer Milan': 'Milan/Outer_Milan',
#  'Peach Springs': 'Peach_Springs',
#  'Serbia and Montenegro': 'Serbia_and_Montenegro',
#  'Marathi phrasebook': 'Marathi_phrasebook',
#  'Langley (Washington)': 'Langley,Washington',
#  'E9 European Coast Path': 'E9_European_Coast_Path',
#  'Muotkatunturit Wilderness Area': 'Muotkatunturit_Wilderness_Area',
#  'Study Butte-Terlingua': 'Study_Butte-Terlingua',
#  'Aruana': 'Aruana',
#  'Triangle': 'Triangle',
#  'Rijeka': 'Rijeka',
#  'Rossland': 'Rossland',
#  'Norway': 'Norway',
#  'Niedzica': 'Niedzica',
#  'Mount Vernon (Washington)': 'Mount_Vernon,Washington',
#  'Othello': 'Othello',
#  'Thompson Falls': 'Thompson_Falls',
#  'Bathurst (Eastern Cape)': 'Bathurst,Eastern_Cape',
#  'Grand Falls-Windsor': 'Grand_Falls-Windsor',
#  'Glacial Lakes': 'Glacial_Lakes',
#  'Tashkent Region': 'Tashkent_Region',
#  'Sweetwater': 'Sweetwater',
#  'Zelienople': 'Zelienople',
#  'Sherpa phrasebook': 'Sherpa_phrasebook',
#  'Williamsburg (Kentucky)': 'Williamsburg,Kentucky',
#  'Yarkand': 'Yarkand',
#  'Central Iran': 'Central_Iran',
#  'Pokolbin': 'Pokolbin',
#  'Sanibel Island': 'Sanibel_Island',
#  'Bass Lake': 'Bass_Lake',
#  'Hay': 'Hay',
#  'Easton (Pennsylvania)': 'Easton,Pennsylvania',
#  'Columbus (Minnesota)': 'Columbus,Minnesota',
#  'Longquan': 'Longquan',
#  'Sepidan': 'Sepidan',
#  'Labuan': 'Labuan',
#  'Aroostook': 'Aroostook',
#  'Mole National Park': 'Mole_National_Park',
#  'North Lebanon': 'North_Lebanon',
#  'Kluang': 'Kluang',
#  'Bagnara di Romagna': 'Bagnara_di_Romagna',
#  'Bridgeport (West Virginia)': 'Bridgeport,West_Virginia',
#  ...}

# %% [markdown]
# __There are still disambiguation articles which don't add much information so lets get rid of them.__

# %%
final_articles = {}
for title in final_titles_concat.iterkeys():
    concat_title = final_titles_concat[title]
    final_articles[concat_title] = unicodedata.normalize('NFKD', articles_dict[title]['revision']['text']['#text']).encode('ascii','ignore')
final_articles
print len(final_articles)
# Out:
# 25495

# %%
#final_articles['Paris']

# %%
def clean_paragraph(string):
    # get rid of https:
    m = re.sub(r'(https?://\S+\ +\S+)', '', string)
    # get rid of [File:stuff]
    m = re.sub(r'\[File:[^)]*\]','', m)
    # get rid of ==stuff==
    m = re.sub(r'(\=+[^)]+\=+)','', m)
    #get rid of ], [, '. E.g. [[Paris]] --> Paris
    m = re.sub(r'[\[\]\']','',unicodedata.normalize('NFKD', m).encode('ascii','ignore')).strip()

    return m

# %%
def clean_sentence(string):
    # punctuation and numbers to be removed
    punctuation1 = re.compile(r'[*.?!,"0-9]')
    punctuation2 = re.compile(r'[-:;()|]')
    sent = re.sub(punctuation1,'', string)
    sent = re.sub(punctuation2, ' ', sent)
    return sent

# %%
clean_sentence('seoul-incheon internatio*nal)')
# Out:
# 'seoul incheon international '

# %%
def convert_article_into_list_of_words(article):
    md = mistune.markdown(article)
    parsed_md = BeautifulSoup(md, 'html.parser')
    
    parsed_test_wo_dict = []
    
    #Grab all the paragraphs and lists
    for line in parsed_md.find_all(['p','li']):
        text = line.text
        
        #remove dictionaries by filtering on {{
        if '{{' not in text:
            #clean the paragraph by removing things like https:stuff, File:stuff
            text = clean_paragraph(text)
            
            #tokenize paragraph to sentences
            sentences = sent_tokenize(text)
            
            for sentence in sentences:
                #clean sentence by removing numbers and punctuations
                sent = clean_sentence(sentence)
                #convert sentence to list of words
                word_list = sent.split()
                #keep the sentence if there are more than 3 words.
                if len(word_list) > 3:
                    parsed_test_wo_dict.append(word_list)
    return parsed_test_wo_dict

# %%
final_articles.keys()
# Out:
# ['Albion,California',
#  'Szczecin',
#  'Bowling_Green,Kentucky',
#  'Rugia',
#  'Nampa',
#  'Hyanger',
#  'Fazenda_Nova',
#  'Fulda',
#  'Gravesend',
#  'Thuin',
#  'Malabon',
#  'Hikone',
#  'Independence,Kansas',
#  'Upper_Cape',
#  'Brady,Texas',
#  'Diest',
#  'Mokhotlong',
#  'Loei',
#  'Burlington,Colorado',
#  'Saco',
#  'Lake_Manyara_National_Park',
#  'Lexington,Kentucky',
#  'Finland_in_ten_days_by_car',
#  'Cahir',
#  'Garamba_National_Park',
#  'Jeffersonville',
#  'Latgale',
#  'Wells,Maine',
#  'Massa-Carrara,province',
#  'Pampa',
#  'Gangtok',
#  'Lucknow',
#  'Hamilton',
#  'Pateros,Philippines',
#  'Kaokoland',
#  'Durham,New_Hampshire',
#  'Mount_Washington,Massachusetts',
#  'Rugby,England',
#  'Limousin',
#  'Narvik',
#  'Quartzsite',
#  'Mountainair',
#  'Cheyenne_Wells',
#  'Stanhope',
#  'Palmyra',
#  'Dexter',
#  'Hallefors',
#  'Valley_City,North_Dakota',
#  'Harvey',
#  'Le_Diamant',
#  'Fairfield,Iowa',
#  'Pom_Pom_Island',
#  'Ambala',
#  'Montone',
#  'Blue_Earth',
#  'Rendsburg',
#  'Ulldecona',
#  'Halong',
#  'Daytona_Beach_Shores',
#  'Okeechobee',
#  'Nishitokyo',
#  'Vernon',
#  'Taipei/Datong',
#  'Franciacorta',
#  'Banagher',
#  'Wauchula',
#  'Dazaifu',
#  'New_London,New_Hampshire',
#  'Kallooppara',
#  'Mexico_City/Condesa_and_Roma',
#  'Karonga',
#  'Butaritari',
#  'Singkep-Lingga',
#  'Rahacou',
#  'Lao_phrasebook',
#  'Caen',
#  'Colombia',
#  'Mount_Assiniboine_Provincial_Park',
#  'Trinidad,Colorado',
#  'Lolland-Falster',
#  'Aberdyfi',
#  'Haute-Garonne',
#  'Ls',
#  'Ylivieska',
#  'Oberon',
#  'Eastern_Angola',
#  'Sherborne',
#  'Rome/Old_Rome',
#  'Ponmudi',
#  'Wichita_Falls',
#  'Lappajarvi',
#  'Cape_Agulhas',
#  'Barnesville',
#  'Caledon',
#  'Fogo',
#  'Rewalsar',
#  'Matunuck',
#  'Ganzhou',
#  'Mapungubwe_National_Park',
#  'Gustrow',
#  'Ishpeming',
#  'Blackstone',
#  'Addo_Elephant_National_Park',
#  'Badajoz',
#  'Poipet',
#  'Ixil_Triangle',
#  'Robertson',
#  'Fondo_Grande',
#  'Boxford',
#  'Ozark_National_Scenic_Riverways',
#  'Atwater,Ohio',
#  'Dundee,Michigan',
#  'Alcantara',
#  'Van_Wert_County',
#  'Tianshui',
#  'Montague',
#  'Bay_Area,California',
#  'Koidu',
#  'Shah_Alam',
#  'Weimar,Texas',
#  'Goshen',
#  'Baxter_Springs',
#  'Hickory',
#  'Kashid',
#  'Tortuga,Haiti',
#  'Scottsville,Kentucky',
#  'Northern_Spain',
#  'Dumfries',
#  'Southwest_Washington',
#  'Pieterburen',
#  'Bowdon',
#  'Geraardsbergen',
#  'Turkmen_phrasebook',
#  'Marigha',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Blue_Rock_Quarry',
#  'Williamson,West_Virginia',
#  'Cavalcante',
#  'Kedzierzyn-Kozle',
#  'Bay_County',
#  'Tiburon',
#  'Jamestown',
#  'Lutsk',
#  'Misty_Fiords_National_Monument',
#  'Baoding',
#  'Baixo_Alentejo',
#  'Pskov_Oblast',
#  'Mayflower,Arkansas',
#  'Tatranska_Magistrala',
#  'Bed_and_breakfasts',
#  'Tarnaveni',
#  'Zaanse_Schans',
#  'Noboribetsu',
#  'Spiritwood',
#  'Porquerolles',
#  'North_Western_Province,Sri_Lanka',
#  'Poulton-le-Fylde',
#  'Central_Slovenia',
#  'Cuzco',
#  'Yagodnoye',
#  'Niger',
#  'Kerikeri',
#  'Lampung',
#  'Salinas_de_Guaranda',
#  'Hlane_Royal_National_Park',
#  'Chora,Greece',
#  'Sepupa',
#  'Mississippi_Delta',
#  "Sant'Angelo_Dei_Lombardi",
#  'Toronto/Scarborough',
#  'Kishwaukee_Valley',
#  'Ballina',
#  'Sandoval',
#  'Jamestown,Rhode_Island',
#  'Mount_Putuo',
#  'Wupperthal',
#  'Agadir',
#  'Oracle',
#  'Le_Roy,New_York',
#  'Pacific_Coast,Mexico',
#  'Ozarks,Arkansas',
#  'Marshall_Islands',
#  'Havelock_North',
#  'Nea_Kallikratia',
#  'San_Francisco/Union_Square-Financial_District',
#  'Chicago',
#  'Jemez_Mountains',
#  'Southern_Reef_Islands',
#  'Vila_Nova_de_Gaia',
#  'Tijuana/Playas',
#  'Fredonia,New_York',
#  'Kismayo',
#  'Honaunau',
#  'Roscommon',
#  'Praia_de_Pipa',
#  'Dothan',
#  'Indian_National_Parks_and_Wildlife_Sanctuaries',
#  'Heppenheim',
#  'Pelorus_Bridge_Scenic_Reserve',
#  'Eastern_Myanmar',
#  'Wahiba_Sands',
#  'Badlands_National_Park',
#  'Holly_Springs',
#  'Zanzibar',
#  'Torno',
#  'Montefalco',
#  'Torna',
#  'North_Central',
#  'Muisne',
#  'Cunha',
#  'Gunnison',
#  'Oberammergau',
#  'Kyaukme',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Atlantis_Reef',
#  'Dinas_Dinlle',
#  'Dhulikhel',
#  'West_Pomerania',
#  'Bella_Bella',
#  'Winnemucca',
#  'Hoani',
#  'Rencontre_East',
#  'Seto_Inland_Sea',
#  'Rawanduz',
#  'Mount_Pearl',
#  'Sun_Valley',
#  'Northern_Coast,Peru',
#  "'s-Hertogenbosch",
#  'Andover',
#  'Akhty',
#  'Xijiang',
#  'Sydney/Palm_Beach',
#  'Landmannalaugar',
#  'Indianola',
#  'Trebisacce',
#  'Nagaon',
#  'Anderson',
#  'South_Seas',
#  'Narberth',
#  'East_Brunswick',
#  'Guayana',
#  'Chugoku',
#  'Boca_Chica',
#  'Ojen',
#  'North_Coast,KwaZulu-Natal',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Vogelsteen',
#  'Bronx',
#  'Mealhada',
#  'Apollo_Bay',
#  'Sanjo',
#  'West_Stockbridge',
#  'Raiguer',
#  'Resolute',
#  'Norvalspont',
#  'Hightstown',
#  'Logansport',
#  'Toodyay',
#  'Llanybydder',
#  'Natural_Bridge_State_Park',
#  'Kondotty',
#  'Balkh',
#  'Clarens',
#  'Iwakuni',
#  'Ellmau',
#  'Serpentine_National_Park',
#  'Longtan',
#  'Frequent_flyer_programmes',
#  'Parsippany',
#  'Ar_Rutba',
#  'Elgin',
#  'Spello',
#  'Cobb_County,Georgia',
#  'Okehampton',
#  'Ponca_City',
#  'Playa_Santa_Lucia',
#  'Longview,Texas',
#  'Yoshkar-Ola',
#  'Moritzburg',
#  'New_Orleans',
#  'Chiang_Mai_to_Chiang_Rai_in_3_days',
#  'Chhukhung',
#  'Gainesville,Florida',
#  'Skye',
#  'Clarksburg',
#  'Potomac',
#  'Simi_Valley',
#  'Cumberland_Gap_National_Historical_Park',
#  'Brookings',
#  'Duluth,Georgia',
#  'Skopelos,town',
#  'Scioto_County,Ohio',
#  'Apopka',
#  'Glengarriff',
#  'Damascus,Virginia',
#  'Brownsville,Kentucky',
#  'Tahara',
#  'Kilwinning',
#  'Corning,California',
#  'North_Africa',
#  'Kavieng',
#  "Quarto_d'Altino",
#  'Camalu',
#  'Norte_de_Santander',
#  'Suwa',
#  'Park_Ridge,Illinois',
#  'Davenport,Washington',
#  'Baghdad',
#  'Albenga',
#  'Ravenna,province',
#  'Rail_travel_in_the_United_States',
#  'County_Longford',
#  'Hiking_and_backpacking_in_Israel',
#  'Antsiranana_Province',
#  'Tipping',
#  'Atlanta/Atlantic_Station',
#  'Mid_Cape',
#  'Silimbong',
#  'Schleswig-Holstein',
#  'Cullohill',
#  "Arthur's_Pass_National_Park",
#  'Kununurra',
#  'Bhopal-Narmadapuram_Division',
#  'Latera',
#  'Greater_Phoenix',
#  'Beskids',
#  'Goodyear',
#  'Pahokee',
#  'Passaic',
#  'Perryton',
#  'Danakil_Depression',
#  'Danville,Indiana',
#  'Lakewood,Ohio',
#  'Celebration',
#  'East_Palo_Alto',
#  'Sosua',
#  'Oxbow',
#  'Portland,Oregon',
#  'Isle_of_Jura',
#  'East_Khasi_Hills',
#  'Dadra_and_Nagar_Haveli',
#  'West_Greenwich',
#  'Winthrop,Washington',
#  'Bowling_Green,Missouri',
#  'Lavenham',
#  'Midlands,KwaZulu-Natal',
#  'Fort_Mill',
#  'Valdez',
#  'Sitka',
#  'Jotunheimen',
#  'Rockland,Massachusetts',
#  'Ende',
#  'Chieti,province',
#  'Bingzhongluo',
#  'Snow_safety',
#  'Kisa_to_Boxholm_following_the_Malexandermorden_trail_by_car',
#  'Tokyo/Akihabara',
#  'Rocky_Mountains',
#  'Manchu_phrasebook',
#  'Aakirkeby',
#  'Valle_de_Cocora',
#  'Bocholt',
#  'Pleasanton',
#  'Philadelphia/Old_City',
#  'Manhattan/Financial_District',
#  'Brest',
#  'Ketron_Island',
#  'Balneario_Camboriu',
#  'Trinidad,Paraguay',
#  'Tuolumne_County',
#  'Sand_Hills',
#  'La_Grange',
#  'Diving_the_Mokohinau_Islands',
#  'Dakar',
#  'Rail_travel_in_Europe',
#  'Rialto,California',
#  'Samoeng_Loop',
#  'Jodhpur_Division',
#  'Misquamicut',
#  'Kaili',
#  'Tokyo/Chiyoda',
#  'Cheorwon',
#  'Ialysos',
#  'Bruny_Island',
#  'Hanseatic_League',
#  'Mourne_Mountains',
#  'Spittal_an_der_Drau',
#  'Gardena',
#  'Melbourne',
#  'Eastern_Panama',
#  'Inverigo',
#  'Lakes_and_Gardens',
#  'Spennymoor',
#  'Central_Mozambique',
#  'Pittsburg,California',
#  'Triglav_National_Park',
#  'Nouakchott',
#  'Ko_Samet',
#  'Cacapava',
#  'Memphis,Texas',
#  'Holbk',
#  'Kabale',
#  'Kent_Island',
#  'Semmering',
#  'Ipswich',
#  'Douglas_County',
#  'Mundau',
#  'Lleida',
#  'Majuli',
#  'Kasauli',
#  'Kherson',
#  'Faliraki',
#  'Ahmedabad',
#  'Trechtingshausen',
#  'Golan_Trail',
#  'Dudley,England',
#  'Jiuzhaigou_Nature_Reserve',
#  'Inner_Hebrides',
#  'Kelmend',
#  'Enniskillen',
#  'Skelleftea',
#  'Hjrundfjord',
#  'Ulyanovsk_Oblast',
#  'Serra_dos_Orgaos_National_Park',
#  'Bluegrass_Region',
#  'St._Louis_Park',
#  'North_West_Coastal_Highway',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Bantry_Bay',
#  'Tak',
#  'Red_Carpet_Country',
#  'Silvia',
#  'Valladolid,Spain',
#  'Jining,Inner_Mongolia',
#  'Kemmerer',
#  'Plymouth,Indiana',
#  'Hartford,Illinois',
#  'Oboke_and_Koboke',
#  'Grand_Teton_National_Park',
#  'Jamestown,New_York',
#  'Kalinga',
#  'Barra_do_Turvo',
#  'Duval_County',
#  'Kuala_Gandah',
#  'Mn',
#  'Marina_di_Ragusa',
#  'Dorking',
#  'Boston,England',
#  'Elmira,Ontario',
#  'Saint-Paul_de_Vence',
#  'Eastern_Newfoundland',
#  'Zambales',
#  'Cobourg',
#  'Bol',
#  'Port_Orford',
#  'Jardin',
#  'Copenhagen/Indre_By',
#  'Thornton',
#  'Khakassia',
#  'Clitheroe',
#  'Sedibeng',
#  'Sultan_Bathery',
#  'Southwestern_Indiana',
#  'Mardana',
#  'Davidson',
#  'Bang_Saen',
#  'August',
#  'Watsonville',
#  'San_Martin_de_los_Llanos',
#  'Esino_Lario',
#  'Pinsk',
#  'Bog',
#  'Bull_Shoals',
#  'Los_Patos',
#  'Hawera',
#  'Ko_Maphrao',
#  'Artyom',
#  'Prineville',
#  'Devala',
#  'Helmstedt',
#  'Hershey',
#  'Etawah',
#  'Muang_Ngeun',
#  'Mexicali',
#  'Punxsutawney',
#  'Chuquisaca,department',
#  'Eastham',
#  'Aran_Islands',
#  'Hecho',
#  'Shiga',
#  'Belum_Caves',
#  'Bukit_Barisan_Selatan_National_Park',
#  'Beichuan',
#  'Milford_Track',
#  'Juanjui',
#  'Joliet',
#  'St_Helens,Tasmania',
#  'Lamesa',
#  'Skellig_Michael',
#  'Samsun',
#  'Vienna,Virginia',
#  'Lawrence,Massachusetts',
#  'Esmeraldas',
#  'Capena',
#  'Richmond,Tasmania',
#  'Silverton,Oregon',
#  'Kanye',
#  'Tavarnelle_Val_di_Pesa',
#  'Seychellois_Creole_phrasebook',
#  'Zhengzhou',
#  'Lhuentse',
#  'Manitoulin_Island',
#  'Peterborough',
#  'Bowie',
#  'Chuncheon',
#  'Northwestern_Karnataka',
#  'Cromwell',
#  'Cypress',
#  'Escanaba',
#  'Alvdalen',
#  'Assisi',
#  'Nantwich',
#  'Kemi',
#  'Saint_Martin',
#  'Webster',
#  'Miami_Gardens',
#  'Istanbul/Sultanahmet-Old_City',
#  'Lesotho',
#  'Funafuti',
#  'Morenci',
#  'Bechatow',
#  'Limestone,Maine',
#  'Fanwood',
#  'Northern_Cameroon',
#  'San_Bernardino,Paraguay',
#  'Killorglin',
#  'Taplejung',
#  'Jiangsu',
#  'Michigan',
#  'Tonk',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Castle_Rocks',
#  'Lefkara',
#  'Colca_Canyon',
#  'Mongar',
#  'Citta_di_Castello',
#  'Clearlake',
#  'Van_Nuys',
#  'San_Luis_de_Pambil',
#  'Deep_South',
#  'Sylheti_phrasebook',
#  'Portarlington',
#  'Hermitage',
#  'Murdeshwara',
#  'Veitshochheim',
#  'Kanipakam',
#  'Norwalk',
#  'Bratsk',
#  'Pixley',
#  'Marijampole',
#  'Des_Moines',
#  'Paris_Charles_de_Gaulle_Airport',
#  'Toronto/West_End',
#  'White_Mountain_National_Forest',
#  'Kulpsville',
#  'Hammerfest',
#  'Chittur',
#  'Kolkata/Dum_Dum',
#  'The_Rosses',
#  'Kota_Division',
#  'Vulcano',
#  'Sucre,Venezuela',
#  'San_Diego/Mission_Beach-Pacific_Beach',
#  'Swanzey',
#  'Santa_Teresa,New_Mexico',
#  'Zonguldak',
#  'Port_of_Spain',
#  'Bonners_Ferry',
#  'Field',
#  'Berlin,New_Hampshire',
#  'Tam_Dao',
#  'Newton-le-Willows',
#  'Grand_Lake',
#  'Ankola',
#  'North_Attleborough',
#  'Marlborough,New_Zealand',
#  'Tegernsee',
#  'Grenada,island',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Coral_Gardens,Oudekraal',
#  'Sycamore',
#  'Alleghenies_and_Susquehanna_Valley',
#  'Odense',
#  'Manchester_Airport',
#  'Annur',
#  'Minca',
#  'Cheb',
#  'La_Ceiba',
#  'Capurgana',
#  'Vire',
#  'Chem',
#  'Franeker',
#  'Geelong',
#  'Chamba',
#  'Ethiopia',
#  'Ski',
#  'Budoni',
#  'Waynesburg,Ohio',
#  'Elmina',
#  'Llanrwst',
#  'Erechim',
#  'Eastern_Inner_Mongolia',
#  'Adilabad',
#  'Rockaway,New_Jersey',
#  'Lewistown',
#  'Rottweil',
#  'Montejaque',
#  'Swieradow-Zdroj',
#  'Belmont,California',
#  'Wakhan_Corridor',
#  'Otago',
#  'Boxford,Massachusetts',
#  'Tupana',
#  'Olean',
#  'Gurzuf',
#  'Rehoboth',
#  'Connemara',
#  'Ostrava',
#  'Persian_phrasebook',
#  'Nordland',
#  'Gumusluk',
#  'Pawtucket',
#  "Incisa_Val_d'Arno",
#  'Santana',
#  'Samedan',
#  'Para,Brazil',
#  'Richmond/East_End',
#  'Castel_Goffredo',
#  'Ek_Balam',
#  'Willamette_Valley',
#  'Hyder',
#  'Batu_Karas',
#  'Western_Netherlands',
#  'Mexico_City/Santa_Fe',
#  'Kingston-on-Murray',
#  'Sumqayit',
#  'Pucallpa',
#  'Chambers_Pillar_Historical_Reserve',
#  'Marlow,Oklahoma',
#  'Mae_Sariang',
#  'Awa',
#  'Niagara-on-the-Lake',
#  'Thompson_Springs',
#  'Nueva_Viscaya',
#  'Lithia_Springs',
#  'Esperanto_phrasebook',
#  'Sasak_phrasebook',
#  'Tiberias',
#  'Guernsey_Island',
#  'Konya',
#  'Mazeri',
#  'Skien',
#  'Middelburg,Zeeland',
#  'Fairbanks',
#  'Northeast,Bahia',
#  'Westfjords',
#  'Sunny_Beach',
#  'Monticello,Utah',
#  'Gansu',
#  'Maquine',
#  'Toms_River',
#  'Ciudad_del_Este',
#  'Asheville',
#  'Reconcavo',
#  'Wisbech',
#  'Arezzo,province',
#  'Englishtown',
#  'Cleethorpes',
#  'Aptos',
#  'Olinda',
#  'Whangarei',
#  'Cesenatico',
#  'Chicago/Far_Northwest_Side',
#  'Northern_Rift_Valley',
#  'Annandale',
#  'Coquitlam',
#  'Riau_Islands',
#  'Fairfield,Ohio',
#  'Nagoya',
#  'Langley,Washington',
#  'Nevada,Ohio',
#  'Kingston,Massachusetts',
#  'Baldwin_Park',
#  'Bosaso',
#  'Central_Myanmar',
#  'Midnapore',
#  'Tumwater',
#  'Pantalica',
#  'Forest_Lake',
#  'Taichung',
#  'Redang',
#  'Kushal_Nagar',
#  'Hitchhiking_phrasebook',
#  'Florenceville-Bristol',
#  'Pori',
#  'Fish_Creek',
#  'Fairport',
#  'Keystone,South_Dakota',
#  'Luosto',
#  'Yingge',
#  'Lewisporte',
#  'Deer_Lake',
#  'Bangkok/Dusit',
#  'Gorongosa',
#  'Wachau',
#  'Glass_House_Mountains_National_Park',
#  'Bunratty',
#  'Port_aux_Basques',
#  'Concerns',
#  'Peneda-Geres_National_Park',
#  'Puttaparthi',
#  'Yuma',
#  'Choum',
#  'Barnaul',
#  'Dunkeld',
#  'Old_96_District',
#  'Literary_travel',
#  'Ambergris_Caye',
#  'West_Wyalong',
#  'Takasaki',
#  'Santa_Cruz_Trek',
#  'Montreal/South_West',
#  'Gotska_Sandon',
#  'Indiana_Dunes_National_Lakeshore',
#  'Diving_the_Cape_Peninsula_and_False_Bay/SS_Cape_Matapan',
#  'Corcovado_National_Park',
#  'Cupramontana',
#  'Ocean_Shores',
#  'Dover,New_Jersey',
#  'San_Diego/Downtown',
#  'Nakbe',
#  'Huntly',
#  'White_Bear_Lake',
#  'Amana_Colonies',
#  'Frde',
#  'Murter',
#  'Virgin_Islands',
#  'Buldhana',
#  'Coimbatore',
#  'Ben_Lomond_National_Park',
#  'Dalsland',
#  'Caherciveen',
#  'Bacolod',
#  'Rashaya',
#  'Tokyo_Disney_Resort',
#  'Colfax,Washington',
#  'Grafenwohr',
#  'Honolulu/Waikiki',
#  'Neos_Marmaras',
#  'New_Glasgow',
#  'San_Pedro_Sula',
#  'Gaud',
#  'Estremoz',
#  'Holywell',
#  'Goorambat',
#  'Jungle_Interior,Gabon',
#  'Antofagasta',
#  'Yangmingshan_National_Park',
#  'Aberfeldy',
#  'Bass_Coast',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Rocky_Bay',
#  'Durban',
#  'Mountain_View,California',
#  'Isla_de_la_Luna',
#  'Peninsula',
#  'Kunming',
#  'Suffolk_County,New_York',
#  'Alba_Iulia',
#  'Serra_da_Mantiqueira',
#  "D'Iberville",
#  'Eftimie_Murgu',
#  'La_Laguna',
#  'Barreal',
#  'Southgate',
#  'Mount_Lemmon',
#  'Pennsburg',
#  'Amphawa',
#  'Guanaja',
#  'Kanata',
#  'Guinee_Maritime',
#  'Kham_uc',
#  'Norfolk,England',
#  'Hann._Munden',
#  'Shizuishan',
#  'Sarawak',
#  'Southwestern_Georgia',
#  'Plettenberg_Bay',
#  'Damnoen_Saduak',
#  'Burnley',
#  'Diving_in_Thailand/Richelieu_Rock',
#  'Hundested',
#  'Mumbai/Harbour_suburbs',
#  'Balbriggan',
#  'Byron,Minnesota',
#  'Sun_City',
#  'Elista',
#  'Geeveston',
#  'Urfa',
#  'Eastern_India',
#  'Biak',
#  'Thalmassing',
#  'Foulness_Island',
#  'Moorhead',
#  'Seattle/West',
#  'Alampur',
#  'Wayne_County,Michigan',
#  'Alausi',
#  'Achziv',
#  'Purnululu_National_Park',
#  'Chitimba',
#  'Olympic_National_Park',
#  'Waterbury',
#  'Anaheim_Hills',
#  'Mount_Ishizuchi',
#  'Kerak',
#  'Gardnerville',
#  'Porto_Seguro',
#  'Hacketstown',
#  'Samut_Songkhram',
#  'Blumenau',
#  'Shanghai/Huangpu',
#  'Bamako',
#  'Northern_Quebec',
#  'Grindelwald',
#  'Ranikhet',
#  'Ellsworth,Maine',
#  'Arnprior',
#  'Struga',
#  'Rogiet',
#  'Khmelnytskyi',
#  'Frisco,Colorado',
#  'Nanjangud',
#  'Wallachian_Plain',
#  'San_Jose,Occidental_Mindoro',
#  'Elgin_County',
#  'Huntley',
#  'Perissa',
#  'Digby',
#  'Dullatur',
#  'Spencer',
#  'Visby',
#  'Gondik',
#  'Megaplatanos',
#  'Mercer',
#  'Aruja',
#  'Eaton_Rapids',
#  'Dubai/Jebel_Ali',
#  'Nioumachoua',
#  'Kuwait',
#  'Loveland,Ohio',
#  'Richmond',
#  'Somerset,England',
#  'Twin_Cities',
#  'Ocean_City,New_Jersey',
#  'Sydney_Airport',
#  'Cotati',
#  'Uhldingen-Muhlhofen',
#  'East_Palestine',
#  'Agia_Anna,Evvia',
#  'Kokoda_Track',
#  'Bijelo_Polje',
#  'Vinh',
#  'Mountain_City,Tennessee',
#  'Subic',
#  'Willows',
#  'Freeport,Bahamas',
#  'Mount_Gilead',
#  'Raja',
#  'Niari_Valley',
#  'Segou',
#  'Northern_Punjab',
#  'Miyazaki,prefecture',
#  'Glasgow',
#  'Kirzhach',
#  'Inveraray',
#  'Western_Highlands',
#  'Staniel_Cay',
#  'Miami_Springs',
#  'Smithfield-Selma',
#  'Medfield',
#  'Woonsocket',
#  'Garden_Grove',
#  'River_Edge',
#  'Thirthahalli',
#  'Bridgetown',
#  'Costa_Smeralda',
#  'Albany,Oregon',
#  'Chhapra',
#  'Amelinghausen',
#  'Cuyo',
#  'Ridgewood',
#  'Afton',
#  'SeaWorld',
#  "O'Hare_International_Airport",
#  'Oppdal',
#  'Deokjeok_Island',
#  'Bandarban_Town',
#  'Brussels',
#  'Momence',
#  'Luxor/East_Bank',
#  'Pangkalanbun',
#  'Narrandera',
#  'Tamar_Valley',
#  'Gili_Air',
#  'Sparta,Kentucky',
#  'Webster,Massachusetts',
#  'Sikeston',
#  'Caucaia',
#  'Sathing_Phra',
#  'Central_Java',
#  'Punjab,India',
#  'West_Java',
#  'Hillsboro,North_Dakota',
#  'Princeton,Massachusetts',
#  'Diyarbakir',
#  'Diving_the_Poor_Knights_Islands',
#  'Somerdale',
#  'Mithur',
#  'Pasay',
#  'Diving_in_Mozambique/Island_Rock',
#  'Soltau',
#  'Kailua-Kona',
#  'Amazonas,Venezuela',
#  'Tamana',
#  'Tokaj-Hegyalja',
#  'Fire_Island_National_Seashore',
#  'Estes_Park',
#  'Solva',
#  'Grand_Beach_Provincial_Park',
#  'Vikasnagar',
#  'Loup_Valley',
#  'Munich/South-West',
#  'Luquillo',
#  'Burley,Washington',
#  'Litchfield_Hills',
#  'Nardo',
#  'Lubuskie',
#  'Haukeli',
#  'Juan_de_Nova_Island',
#  'Union_Pier',
#  'Hay-on-Wye',
#  'Dalat',
#  'Gualala',
#  'El_Mina',
#  'Gelderland',
#  'Saharan_Mauritania',
#  'Dudinka',
#  'San_Marino',
#  'Rolette',
#  'Carrick-on-Shannon',
#  'Bominaco',
#  "Martha's_Vineyard",
#  'Ballestas_Islands',
#  'Buga',
#  'Kumasi',
#  'Talampaya_National_Park',
#  'Hyvinkaa',
#  'Redcliffe',
#  'Warth_and_Schrocken',
#  'Sabang,Mindoro',
#  'Willow_Creek',
#  'Aruana',
#  'Triangle',
#  'Rijeka',
#  'Rossland',
#  'Saint_Petersburg',
#  'Niedzica',
#  'Othello',
#  'Pacific,Missouri',
#  'Expo_2005',
#  'Rau_de_Mori',
#  'Wheeler_Ridge',
#  'Sweetwater',
#  'Zelienople',
#  'Windsor,California',
#  'Yarkand',
#  'Pokolbin',
#  'Hoquiam',
#  'Hay',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Kruis',
#  'Mazara_del_Vallo',
#  'Stillwater,Oklahoma',
#  'Nord-Pas_de_Calais',
#  'South,Brazil',
#  'Longquan',
#  'Lipetsk_Oblast',
#  'Sepidan',
#  'Hillsborough,Grenada',
#  'Aroostook',
#  'Kluang',
#  'Gdynia',
#  'Hilversum',
#  'Trentino-Alto_Adige',
#  'Maplewood,New_Jersey',
#  'Sevan',
#  'Los_Cristianos',
#  ...]

# %%
convert_article_into_list_of_words(final_articles['The_Other_1'])[0]
# Out:
# ['Here',
#  'the',
#  'itinerary',
#  'is',
#  'described',
#  'north',
#  'to',
#  'south',
#  'for',
#  'the',
#  'other',
#  'direction',
#  'see',
#  'The',
#  'Other',
#  'northbound']

# %%
final_articles_words = {}

for article in final_articles.iterkeys():
# for key, value in final_articles.iteritems():
#     final_articles_words[key] = convert_article_into_list_of_words(value)
    #print article
    final_articles_words[article] = convert_article_into_list_of_words(final_articles[article])

# %%
final_articles_list_of_words = []
final_articles_doc2vec_labels = []
for key, value in final_articles_words.iteritems():
    for sentence in value:
        final_articles_doc2vec_labels.append(key.lower())
        final_articles_list_of_words.append([word.lower() for word in sentence])

# %%
final_articles_list_of_words[0]
# Out:
# [['imagecloverdale',
#   'california',
#   'cloverdale',
#   'minorr=boonville',
#   'california',
#   'boonville',
#   '}}'],
#  ['dmoz',
#   'regional/north',
#   'america/united',
#   'states/california/localities/a/albion/',
#   'wikipedia',
#   'albion',
#   'california',
#   'commons',
#   'category',
#   'albion'],
#  ['pronounced',
#   'shchetsin',
#   'german',
#   'stettin',
#   'latin',
#   'stetinum',
#   'is',
#   'maritime',
#   'port',
#   'city',
#   'and',
#   'the',
#   'capital',
#   'of',
#   'zachodniopomorskie',
#   'in',
#   'poland'],
#  ['the',
#   'city',
#   'has',
#   'a',
#   'population',
#   'of',
#   'over',
#   'thousand',
#   'with',
#   'almost',
#   'living',
#   'its',
#   'metro',
#   'area',
#   'and',
#   'is',
#   'one',
#   'of',
#   'the',
#   'seven',
#   'largest',
#   'metropoles',
#   'in',
#   'the',
#   'country'],
#  ['it',
#   'lies',
#   'in',
#   'the',
#   'northwestern',
#   'corner',
#   'of',
#   'poland',
#   'very',
#   'close',
#   'to',
#   'the',
#   'german',
#   'border',
#   'and',
#   'it',
#   'is',
#   'in',
#   'fact',
#   'easier',
#   'to',
#   'get',
#   'to',
#   'szczecin',
#   'from',
#   'some',
#   'parts',
#   'of',
#   'germany',
#   'notable',
#   'from',
#   'berlin',
#   'than',
#   'it',
#   'is',
#   'from',
#   'much',
#   'of',
#   'the',
#   'polish',
#   'territory'],
#  ['for',
#   'a',
#   'significant',
#   'part',
#   'of',
#   'its',
#   'history',
#   'actually',
#   'szczecin',
#   'was',
#   'a',
#   'part',
#   'of',
#   'germany',
#   'as',
#   'well',
#   'as',
#   'in',
#   'other',
#   'periods',
#   'of',
#   'denmark',
#   'and',
#   'sweden'],
#  ['szczecin',
#   'is',
#   'polands',
#   'third',
#   'largest',
#   'port',
#   'and',
#   'much',
#   'of',
#   'its',
#   'industrial',
#   'base',
#   'used',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of',
#   'an',
#   'important',
#   'shipyard',
#   'so',
#   'it',
#   'may',
#   'come',
#   'as',
#   'a',
#   'surprise',
#   'to',
#   'the',
#   'casual',
#   'tourist',
#   'that',
#   'the',
#   'city',
#   'does',
#   'not',
#   'lay',
#   'on',
#   'a',
#   'seaside',
#   'but',
#   'rather',
#   'over',
#   'the',
#   'river',
#   'odra',
#   'german',
#   'oder',
#   'some',
#   'kilometres',
#   'south',
#   'of',
#   'the',
#   'baltic',
#   'sea',
#   'as',
#   'the',
#   'crow',
#   'flies',
#   'and',
#   'many',
#   'more',
#   'by',
#   'road'],
#  ['many',
#   'visitors',
#   'to',
#   'poland',
#   'are',
#   'also',
#   'unaware',
#   'of',
#   'szczecins',
#   'architectural',
#   'attractiveness',
#   'as',
#   'the',
#   'large',
#   'parts',
#   'of',
#   'the',
#   'city',
#   'were',
#   'designed',
#   'by',
#   'baron',
#   'haussmann',
#   'the',
#   'same',
#   'gentleman',
#   'who',
#   'designed',
#   'the',
#   'boulevards',
#   'of',
#   'paris'],
#  ['the',
#   'place',
#   'now',
#   'known',
#   'as',
#   'szczecin',
#   'was',
#   'first',
#   'mentioned',
#   'in',
#   'written',
#   'history',
#   'in',
#   'st',
#   'century',
#   'when',
#   'west',
#   'roman',
#   'historian',
#   'tacitus',
#   'located',
#   'east',
#   'germanic',
#   'tribe',
#   'of',
#   'rugians',
#   'somewhere',
#   'in',
#   'the',
#   'area',
#   'the',
#   'rugians',
#   'left',
#   'in',
#   'th',
#   'century',
#   'during',
#   'the',
#   'great',
#   'migration'],
#  ['sometime',
#   'in',
#   'the',
#   'th',
#   'century',
#   'western',
#   'slavic',
#   'tribe',
#   'of',
#   'pomeranians',
#   'built',
#   'their',
#   'stronghold',
#   'here'],
#  ['in',
#   'th',
#   'century',
#   'the',
#   'town',
#   'was',
#   'mentioned',
#   'as',
#   'one',
#   'of',
#   'major',
#   'in',
#   'pomerania',
#   'in',
#   'abraham',
#   'ben',
#   'jacobs',
#   'chronicle'],
#  ['in',
#   'approximately',
#   'its',
#   'area',
#   'was',
#   'incorporated',
#   'into',
#   'poland',
#   'but',
#   'within',
#   'eight',
#   'years',
#   'the',
#   'town',
#   'was',
#   'controlled',
#   'by',
#   'the',
#   'dukedom',
#   'of',
#   'pomerania',
#   'and',
#   'five',
#   'years',
#   'later',
#   'denmark'],
#  ['in',
#   'th',
#   'century',
#   'when',
#   'its',
#   'competitor',
#   'wolin',
#   'also',
#   'known',
#   'as',
#   'veneta',
#   'in',
#   'medieval',
#   'chronicles',
#   'declined',
#   'szczecin',
#   'began',
#   'to',
#   'prosper',
#   'from',
#   'trade',
#   'and',
#   'became',
#   'one',
#   'of',
#   'the',
#   'major',
#   'baltic',
#   'sea',
#   'harbours'],
#  ['its', 'name', 'was', 'first', 'recorded', 'in', 'as', 'stetin'],
#  ['in', 'pomeranian', 'dukes', 'joined', 'holy', 'roman', 'empire'],
#  ['in',
#   'szczecin',
#   'got',
#   'city',
#   'rights',
#   'before',
#   'it',
#   'became',
#   'member',
#   'of',
#   'the',
#   'hanseatic',
#   'league',
#   'in'],
#  ['until',
#   'early',
#   'th',
#   'century',
#   'the',
#   'city',
#   'was',
#   'the',
#   'capital',
#   'of',
#   'pomeranian',
#   'dukedom',
#   'then',
#   'in',
#   'when',
#   'local',
#   'dukes',
#   'died',
#   'out',
#   'it',
#   'became',
#   'part',
#   'of',
#   'sweden',
#   'then',
#   'kingdom',
#   'of',
#   'prussia',
#   'then',
#   'for',
#   'a',
#   'brief',
#   'period',
#   'due',
#   'to',
#   'napoleons',
#   'conquests',
#   'the',
#   'empire',
#   'of',
#   'france'],
#  ['beginning',
#   'in',
#   'the',
#   'th',
#   'century',
#   'the',
#   'city',
#   'constituted',
#   'as',
#   'a',
#   'part',
#   'of',
#   'germany',
#   'and',
#   'served',
#   'as',
#   'the',
#   'port',
#   'of',
#   'berlin'],
#  ['during',
#   'world',
#   'war',
#   'ii',
#   'the',
#   'city',
#   'was',
#   'hit',
#   'hard',
#   'by',
#   'allied',
#   'bombers',
#   'city',
#   'centre',
#   'old',
#   'town',
#   'and',
#   'industrial',
#   'areas',
#   'were',
#   'totally',
#   'ruined'],
#  ['after',
#   'the',
#   'soviet',
#   'forces',
#   'invaded',
#   'nazi',
#   'germany',
#   'in',
#   'according',
#   'to',
#   'potsdam',
#   'conference',
#   'agreements',
#   'poland',
#   'annexed',
#   'all',
#   'lands',
#   'up',
#   'to',
#   'the',
#   'oder',
#   'river',
#   'expelling',
#   'the',
#   'native',
#   'german',
#   'population',
#   'and',
#   'ultimately',
#   'extending',
#   'the',
#   'border',
#   'to',
#   'include',
#   'stettin'],
#  ['poland', 'thus', 'gained', 'control', 'of', 'the', 'city'],
#  ['in',
#   'more',
#   'recent',
#   'history',
#   'the',
#   'city',
#   'was',
#   'together',
#   'with',
#   'tricity',
#   'one',
#   'of',
#   'the',
#   'birthplaces',
#   'of',
#   'solidarity',
#   'movement'],
#  ['an',
#   'unusual',
#   'feature',
#   'of',
#   'szczecin',
#   'is',
#   'its',
#   'urban',
#   'planning',
#   'many',
#   'roundabouts',
#   'and',
#   'wide',
#   'avenues'],
#  ['stettin',
#   'was',
#   'rebuilt',
#   'in',
#   's',
#   'using',
#   'designs',
#   'by',
#   'georges',
#   'eugene',
#   'haussmann',
#   'who',
#   'also',
#   'did',
#   'the',
#   'urban',
#   'planning',
#   'for',
#   'paris'],
#  ['his',
#   'design',
#   'style',
#   'is',
#   'still',
#   'being',
#   'used',
#   'for',
#   'newly',
#   'built',
#   'or',
#   'modified',
#   'city',
#   'areas'],
#  ['the',
#   'maritime',
#   'industry',
#   'is',
#   'still',
#   'strong',
#   'with',
#   'a',
#   'busy',
#   'port',
#   'and',
#   'repair',
#   'shipyard',
#   'as',
#   'well',
#   'as',
#   'being',
#   'a',
#   'center',
#   'of',
#   'service',
#   'industries',
#   'in',
#   'poland'],
#  ['situated',
#   'near',
#   'the',
#   'border',
#   'between',
#   'germany',
#   'and',
#   'poland',
#   'szczecin',
#   'is',
#   'sometimes',
#   'considered',
#   'one',
#   'of',
#   'most',
#   'liberal',
#   'polish',
#   'cities'],
#  ['szczecin',
#   'goleniow',
#   'airport',
#   'szz',
#   'located',
#   'almost',
#   'km',
#   'from',
#   'the',
#   'city',
#   'centre',
#   'near',
#   'goleniow'],
#  ['ryanair',
#   'operates',
#   'daily',
#   'flights',
#   'between',
#   'szczecin',
#   'and',
#   'london',
#   'stansted',
#   'and',
#   'flights',
#   'per',
#   'week',
#   'to',
#   'and',
#   'from',
#   'dublin',
#   'and',
#   'liverpool'],
#  ['lot',
#   'has',
#   'several',
#   'flights',
#   'daily',
#   'between',
#   'szczecin',
#   'and',
#   'warsaw'],
#  ['note',
#   'that',
#   'cancellations',
#   'do',
#   'happen',
#   'so',
#   'take',
#   'that',
#   'into',
#   'account',
#   'when',
#   'planning',
#   'onward',
#   'travel'],
#  ['eurolot',
#   'flights',
#   'from',
#   'szczecin',
#   'to',
#   'krakow',
#   'both',
#   'direct',
#   'and',
#   'via',
#   'poznan',
#   'times',
#   'a',
#   'week',
#   'and',
#   'to',
#   'rzeszow',
#   'twice',
#   'a',
#   'week'],
#  ['norwegian',
#   'operates',
#   'two',
#   'flights',
#   'per',
#   'week',
#   'between',
#   'szczecin',
#   'and',
#   'both',
#   'trondheim',
#   'and',
#   'oslo'],
#  ['you',
#   'can',
#   'reach',
#   'the',
#   'airport',
#   'by',
#   'car',
#   'the',
#   'journey',
#   'may',
#   'take',
#   'up',
#   'to',
#   'hour',
#   'depending',
#   'on',
#   'traffic',
#   'by',
#   'taxi',
#   'about',
#   'pln',
#   'or',
#   'by',
#   'minibus',
#   'lot',
#   'operates',
#   'a',
#   'minibus',
#   'to',
#   'and',
#   'from',
#   'the',
#   'airport',
#   'for',
#   'all',
#   'lots',
#   'flights',
#   'free',
#   'of',
#   'charge',
#   'for',
#   'passengers',
#   'leaving',
#   'from',
#   'lots',
#   'office',
#   'al'],
#  ['wyzwolenia',
#   'about',
#   'minutes',
#   'before',
#   'departure',
#   'and',
#   'interglobus',
#   'has',
#   'minibuses',
#   'for',
#   'all',
#   'international',
#   'flights'],
#  ['in',
#   'july',
#   'a',
#   'railway',
#   'service',
#   'linking',
#   'the',
#   'airports',
#   'terminal',
#   'directly',
#   'with',
#   'szczecins',
#   'main',
#   'railway',
#   'station',
#   'and',
#   'with',
#   'koobrzeg',
#   'was',
#   'inaugurated'],
#  ['due',
#   'to',
#   'szczecins',
#   'proximity',
#   'to',
#   'berlin',
#   'you',
#   'may',
#   'use',
#   'the',
#   'latters',
#   'airports',
#   'to',
#   'get',
#   'to',
#   'szczecin',
#   'as',
#   'well'],
#  ['from',
#   'there',
#   'you',
#   'can',
#   'reach',
#   'szczecin',
#   'by',
#   'minibus',
#   'numerous',
#   'szczecin',
#   'based',
#   'companies',
#   'including',
#   'atlastransfer',
#   'berliniaeu',
#   'interglobus',
#   'regular',
#   'services',
#   'to',
#   'tegel',
#   'and',
#   'schoenefeld',
#   'airports',
#   'at',
#   'attractive',
#   'prices',
#   'by',
#   'car',
#   'or',
#   'by',
#   'train',
#   'in',
#   'hours'],
#  ['polish',
#   'state',
#   'railways',
#   'pkp',
#   'connections',
#   'to',
#   'and',
#   'from',
#   'all',
#   'major',
#   'polish',
#   'cities'],
#  ['there',
#   'are',
#   'several',
#   'trains',
#   'daily',
#   'to',
#   'and',
#   'from',
#   'warsaw',
#   'travel',
#   'time',
#   'on',
#   'express',
#   'or',
#   'intercity',
#   'trains',
#   'is',
#   'less',
#   'than',
#   'hours',
#   'but',
#   'minor',
#   'delays',
#   'are',
#   'not',
#   'uncommon'],
#  ['to',
#   'poznan',
#   'travel',
#   'time',
#   'is',
#   'about',
#   'hours',
#   'from',
#   'pln',
#   'with',
#   'frequent',
#   'trains',
#   'running',
#   'throughout',
#   'the',
#   'day'],
#  ['there', 'are', 'also', 'frequent', 'trains', 'to', 'swinoujscie', 'hours'],
#  ['german',
#   'railways',
#   'train',
#   'connections',
#   'from',
#   'berlin',
#   'amsterdam',
#   'prague',
#   'and',
#   'many',
#   'cities',
#   'in',
#   'neighboring',
#   'mecklenburg',
#   'western',
#   'pomerania'],
#  ['the',
#   'cheapest',
#   'way',
#   'to',
#   'get',
#   'to',
#   'berlin',
#   'is',
#   'by',
#   'joining',
#   'a',
#   'group',
#   'of',
#   'up',
#   'to',
#   'people',
#   'riding',
#   'on',
#   'one',
#   'berlin',
#   'brandenburg',
#   'ticket',
#   'which',
#   'is',
#   'valid',
#   'from',
#   'am',
#   'to',
#   'am',
#   'the',
#   'following',
#   'day',
#   'for',
#   'travel',
#   'on',
#   'all',
#   'local',
#   'and',
#   'regional',
#   'german',
#   'trains',
#   'and',
#   'on',
#   'local',
#   'public',
#   'transport',
#   'systems',
#   'in',
#   'all',
#   'cities',
#   'and',
#   'towns',
#   'including',
#   'berlin',
#   'and',
#   'szczecin'],
#  ['the',
#   'ticket',
#   'costs',
#   'euros',
#   'so',
#   'one',
#   'person',
#   'can',
#   'travel',
#   'for',
#   'ca'],
#  ['the',
#   'groups',
#   'often',
#   'form',
#   'spontaneously',
#   'before',
#   'departure',
#   'or',
#   'on',
#   'the',
#   'train',
#   'itself'],
#  ['there',
#   'is',
#   'also',
#   'the',
#   'new',
#   'berlin',
#   'stettin',
#   'ticket',
#   'for',
#   'euros',
#   'per',
#   'person',
#   'one',
#   'way'],
#  ['berlin',
#   'stettin',
#   'ticket',
#   'brandenburg',
#   'berlin',
#   'ticket',
#   'brandenburg',
#   'berlin',
#   'ticket',
#   'nacht',
#   'mecklenburg',
#   'vorpommern',
#   'ticket',
#   'and',
#   'schones',
#   'wochenende',
#   'ticket',
#   'are',
#   'valid',
#   'for',
#   'routes',
#   'to',
#   'and',
#   'from',
#   'the',
#   'city',
#   'of',
#   'szczecin',
#   'and',
#   'for',
#   'the',
#   'entire',
#   'public',
#   'transport',
#   'system',
#   'in',
#   'szczecin'],
#  ['you',
#   'even',
#   'can',
#   'get',
#   'from',
#   'or',
#   'to',
#   'the',
#   'danish',
#   'border',
#   'via',
#   'schleswig',
#   'holstein',
#   'ticket',
#   'valid',
#   'in',
#   'the',
#   'regional',
#   'trains',
#   'of',
#   'mecklenburg',
#   'vorpommern',
#   'hamburg',
#   'schleswig',
#   'holstein',
#   'until',
#   'padborg',
#   'or',
#   'tonder',
#   'dk',
#   'with',
#   'a',
#   'surcharge',
#   'of',
#   'for',
#   'the',
#   'ride',
#   'from',
#   'the',
#   'polish',
#   'border',
#   'to',
#   'szczecin'],
#  ['you',
#   'can',
#   'reach',
#   'szczecin',
#   'by',
#   'car',
#   'from',
#   'major',
#   'polish',
#   'cities',
#   'including',
#   'warsaw',
#   'poznan',
#   'gdansk',
#   'wrocaw',
#   'and',
#   'also',
#   'from',
#   'berlin'],
#  ['thanks',
#   'to',
#   'its',
#   'location',
#   'close',
#   'to',
#   'the',
#   'border',
#   'and',
#   'direct',
#   'link',
#   'with',
#   'the',
#   'german',
#   'motorway',
#   'system',
#   'szczecin',
#   'has',
#   'the',
#   'best',
#   'road',
#   'connection',
#   'with',
#   'western',
#   'europe',
#   'of',
#   'all',
#   'polish',
#   'cities'],
#  ['the',
#   'main',
#   'route',
#   'to',
#   'szczecin',
#   'from',
#   'berlin',
#   'is',
#   'the',
#   'e',
#   'german',
#   'a',
#   'polish',
#   'a'],
#  ['the', 'journey', 'takes', 'about', 'hours', 'depending', 'on', 'traffic'],
#  ['note',
#   'that',
#   'the',
#   'german',
#   'a',
#   'motorway',
#   'is',
#   'undergoing',
#   'continuous',
#   'improvements',
#   'resulting',
#   'in',
#   'some',
#   'disturbances',
#   'in',
#   'certain',
#   'sections'],
#  ['travelling',
#   'by',
#   'car',
#   'to',
#   'and',
#   'from',
#   'other',
#   'parts',
#   'of',
#   'poland',
#   'can',
#   'be',
#   'troublesome',
#   'the',
#   'traffic',
#   'is',
#   'pretty',
#   'heavy',
#   'the',
#   'distances',
#   'are',
#   'large',
#   'and',
#   'there',
#   'is',
#   'a',
#   'general',
#   'shortage',
#   'of',
#   'motorways'],
#  ['it',
#   'also',
#   'takes',
#   'quite',
#   'some',
#   'time',
#   'for',
#   'example',
#   'the',
#   'trip',
#   'to',
#   'gdansk',
#   'km',
#   'usually',
#   'takes',
#   'hours',
#   'and',
#   'to',
#   'warsaw',
#   'km',
#   'along',
#   'national',
#   'road',
#   'no'],
#  ['you',
#   'need',
#   'at',
#   'least',
#   'hours',
#   'even',
#   'if',
#   'you',
#   'dont',
#   'follow',
#   'the',
#   'speed',
#   'limits',
#   'too',
#   'strictly'],
#  ['you',
#   'can',
#   'also',
#   'reach',
#   'szczecin',
#   'from',
#   'sweden',
#   'ystad',
#   'and',
#   'denmark',
#   'copenhagen',
#   'using',
#   'the',
#   'ferry',
#   'connections',
#   'to',
#   'and',
#   'from',
#   'swinoujscie'],
#  ['from',
#   'there',
#   'the',
#   'journey',
#   'takes',
#   'about',
#   'hours',
#   'although',
#   'this',
#   'road',
#   'gets',
#   'completely',
#   'jammed',
#   'on',
#   'summer',
#   'weekends'],
#  ['to',
#   'avoid',
#   'traffic',
#   'jams',
#   'in',
#   'high',
#   'season',
#   'follow',
#   'the',
#   'yellow',
#   'tourist',
#   'route',
#   'trasa',
#   'turystyczna',
#   'signs'],
#  ['these',
#   'will',
#   'take',
#   'you',
#   'along',
#   'b',
#   'roads',
#   'bypassing',
#   'the',
#   'most',
#   'crowded',
#   'section',
#   'of',
#   'national',
#   'road',
#   'no'],
#  ['many',
#   'international',
#   'and',
#   'domestic',
#   'connections',
#   'see',
#   'poland#by',
#   'bus',
#   'poland',
#   'by',
#   'bus'],
#  ['szczecin',
#   'operates',
#   'daily',
#   'connection',
#   'with',
#   'schwedt',
#   'in',
#   'germany'],
#  ['dozens',
#   'of',
#   'minibus',
#   'operators',
#   'driving',
#   'to',
#   'and',
#   'from',
#   'berlin'],
#  ['szczecin',
#   'is',
#   'situated',
#   'on',
#   'the',
#   'banks',
#   'of',
#   'the',
#   'oder',
#   'polish',
#   'odra',
#   'and',
#   'regalica',
#   'branch',
#   'of',
#   'the',
#   'oder',
#   'rivers',
#   'and',
#   'lake',
#   'dabie',
#   'near',
#   'the',
#   'szczecin',
#   'lagoon'],
#  ['there',
#   'is',
#   'a',
#   'number',
#   'of',
#   'marinas',
#   'most',
#   'of',
#   'them',
#   'situated',
#   'in',
#   'the',
#   'northern',
#   'districts',
#   'and',
#   'on',
#   'the',
#   'shores',
#   'of',
#   'lake',
#   'dabie'],
#  ['in',
#   'april',
#   'hydrofoil',
#   'service',
#   'was',
#   're',
#   'established',
#   'between',
#   'szczecin',
#   'and',
#   'swinoujscie'],
#  ['bosman',
#   'express',
#   'runs',
#   'twice',
#   'a',
#   'day',
#   'from',
#   'the',
#   'way',
#   'chrobrego',
#   'embankment',
#   'reaching',
#   'swinoujscie',
#   'in',
#   'about',
#   'minutes'],
#  ['tickets',
#   'are',
#   'a',
#   'bit',
#   'overpriced',
#   'at',
#   'pln',
#   '/',
#   'economy/vip',
#   'class',
#   'but',
#   'dont',
#   'expect',
#   'any',
#   'luxury',
#   'and',
#   'there',
#   'are',
#   'discounts',
#   'for',
#   'children',
#   'and',
#   'groups'],
#  ['there', 'is', 'a', 'snack', 'bar', 'on', 'board', 'beer', 'is', 'served'],
#  ['there', 'is', 'also', 'a', 'small', 'viewing', 'deck'],
#  ['along',
#   'the',
#   'way',
#   'you',
#   'can',
#   'see',
#   'some',
#   'quite',
#   'interesting',
#   'industrial',
#   'sights',
#   'in',
#   'the',
#   'northern',
#   'part',
#   'of',
#   'szczecin'],
#  ['despite',
#   'being',
#   'a',
#   'restored',
#   'soviet',
#   'made',
#   'meteor',
#   'now',
#   'equipped',
#   'with',
#   'new',
#   'engines',
#   'the',
#   'hydrofoil',
#   'is',
#   'the',
#   'quickest',
#   'way',
#   'to',
#   'get',
#   'to',
#   'swinoujscie',
#   'it',
#   'moors',
#   'at',
#   'the',
#   'left',
#   'western',
#   'bank',
#   'of',
#   'the',
#   'swina',
#   'so',
#   'the',
#   'passengers',
#   'avoid',
#   'the',
#   'need',
#   'to',
#   'use',
#   'the',
#   'ferry'],
#  ['szczecin',
#   'is',
#   'split',
#   'in',
#   'two',
#   'parts',
#   'lewobrzeze',
#   'and',
#   'prawobrzeze',
#   'named',
#   'after',
#   'their',
#   'location',
#   'on',
#   'banks',
#   'of',
#   'oder',
#   'lewobrzeze',
#   '=',
#   'left',
#   'bank',
#   'and',
#   'regalica',
#   'prawobrzeze',
#   '=',
#   'right',
#   'bank',
#   'rivers'],
#  ['the', 'port', 'is', 'situated', 'in', 'between'],
#  ['city',
#   'centre',
#   'and',
#   'most',
#   'of',
#   'attractions',
#   'are',
#   'situated',
#   'in',
#   'lewobrzeze'],
#  ['image',
#   'szczecinfacadesjpg',
#   'thumb',
#   'facades',
#   'in',
#   'new',
#   'old',
#   'town'],
#  ['trams',
#   'and',
#   'schedules',
#   'can',
#   'also',
#   'install',
#   'the',
#   'timetables',
#   'on',
#   'your',
#   'mobile',
#   'phone',
#   'for',
#   'jme',
#   'compatible',
#   'phones',
#   'and',
#   'symbian',
#   'mpk',
#   'mobile',
#   'android',
#   'and',
#   'windows',
#   'phone',
#   'transportoid',
#   'http',
#   '//transportoidcom/'],
#  ['tickets',
#   'are',
#   'randomly',
#   'checked',
#   'by',
#   'plain',
#   'clothed',
#   'inspectors',
#   'fines',
#   'are',
#   'severe',
#   'and',
#   'can',
#   'be',
#   'a',
#   'major',
#   'hassle',
#   'so',
#   'its',
#   'better',
#   'for',
#   'you',
#   'to',
#   'buy',
#   'them'],
#  ['they',
#   'are',
#   'available',
#   'at',
#   'all',
#   'newspaper',
#   'stands',
#   'and',
#   'you',
#   'can',
#   'buy',
#   'them',
#   'from',
#   'the',
#   'driver',
#   'after'],
#  ['if',
#   'you',
#   'happen',
#   'to',
#   'have',
#   'an',
#   'account',
#   'in',
#   'polish',
#   'bank',
#   'you',
#   'can',
#   'also',
#   'use',
#   'your',
#   'mobile',
#   'phone',
#   'hours',
#   'are',
#   'and',
#   'night',
#   'hours',
#   'are',
#   'between',
#   'and'],
#  ['tickets', 'for', 'express', 'buses', 'are', 'twice', 'expensive'],
#  ['you',
#   'can',
#   'change',
#   'between',
#   'lines',
#   'freely',
#   'as',
#   'long',
#   'you',
#   'stay',
#   'within',
#   'time',
#   'limit',
#   'the',
#   'exception',
#   'is',
#   'changing',
#   'from',
#   'normal',
#   'bus',
#   'or',
#   'tram',
#   'to',
#   'express',
#   'bus'],
#  ['family',
#   'weekend',
#   'ticket',
#   'z',
#   'valid',
#   'on',
#   'weekends',
#   'for',
#   'one',
#   'or',
#   'two',
#   'adults',
#   'with',
#   'at',
#   'least',
#   'one',
#   'child',
#   'up',
#   'to',
#   'years',
#   'old'],
#  ['there',
#   'are',
#   'also',
#   'tickets',
#   'valid',
#   'for',
#   'days',
#   'a',
#   'month',
#   'and',
#   'a',
#   'quarter'],
#  ['remember',
#   'to',
#   'stamp',
#   'your',
#   'ticket',
#   'immediately',
#   'after',
#   'you',
#   'board',
#   'the',
#   'tram/bus'],
#  ['brandenburg',
#   'berlin',
#   'mecklenburg',
#   'vorpommern',
#   'schleswig',
#   'holstein',
#   'schones',
#   'wochenende',
#   'and',
#   'brandenburg',
#   'berlin',
#   'nacht',
#   'tickets',
#   'issued',
#   'by',
#   'deutsche',
#   'bahn',
#   'are',
#   'valid',
#   'for',
#   'public',
#   'transport',
#   'operated',
#   'by',
#   'zditm',
#   'trams',
#   'and',
#   'buses',
#   'in',
#   'szczecin'],
#  ['monthly/quarterly',
#   'tickets',
#   'issued',
#   'by',
#   'zditm',
#   'are',
#   'valid',
#   'for',
#   'db',
#   'trains',
#   'within',
#   'the',
#   'city',
#   'szczecin',
#   'gowny',
#   'szczecin',
#   'gumience',
#   'http',
#   '//bipumszczecinpl/files/deefaeefbafdcc/',
#   'pdf'],
#  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'express', 'buses'],
#  ['xx', 'free', 'buses', 'to', 'and', 'from', 'shopping', 'malls'],
#  ['tourist',
#   'lines',
#   'vintage',
#   'trams',
#   'and',
#   'buses',
#   'operate',
#   'in',
#   'july',
#   'and',
#   'august',
#   'on',
#   'saturdays',
#   'and',
#   'sundays'],
#  ['the', 'fare', 'costs', 'z', 'paid', 'to', 'the', 'driver'],
#  ['line', 'numbers', 'tram', 'and', 'buses'],
#  ['if',
#   'for',
#   'any',
#   'reason',
#   'you',
#   'want',
#   'to',
#   'go',
#   'to',
#   'or',
#   'from',
#   'the',
#   'city',
#   'centre',
#   'station',
#   'name',
#   'szczecin',
#   'gowny',
#   'to',
#   'districts',
#   'of',
#   'dabie',
#   'gumience',
#   'podjuchy',
#   'zdroje',
#   'zdunowo',
#   'or',
#   'zaom',
#   'or',
#   'nearby',
#   'suburban',
#   'towns',
#   'of',
#   'goleniow',
#   'gryfino',
#   'or',
#   'stargard',
#   'the',
#   'fastest',
#   'way',
#   'might',
#   'be',
#   'the',
#   'train'],
#  ['check',
#   'times',
#   'with',
#   'pkp',
#   'have',
#   'to',
#   'buy',
#   'separate',
#   'ticket',
#   'z',
#   'one',
#   'way',
#   'no',
#   'matter',
#   'how',
#   'many',
#   'stops',
#   'the',
#   'exception',
#   'are',
#   'trains',
#   'operated',
#   'by',
#   'db',
#   'see',
#   'above'],
#  ['city',
#   'center',
#   'can',
#   'be',
#   'covered',
#   'by',
#   'foot',
#   'depending',
#   'on',
#   'your',
#   'fitness',
#   'etc'],
#  ['look',
#   'for',
#   'the',
#   'red',
#   'line',
#   'on',
#   'the',
#   'pavements',
#   'so',
#   'called',
#   'red',
#   'walk',
#   'which',
#   'connects',
#   'nearly',
#   'all',
#   'the',
#   'attractions',
#   'within',
#   'the',
#   'centre'],
#  ['this',
#   'is',
#   'by',
#   'far',
#   'the',
#   'best',
#   'way',
#   'to',
#   'discover',
#   'the',
#   'centre',
#   'on',
#   'foot',
#   'as',
#   'all',
#   'attractions',
#   'are',
#   'marked',
#   'by',
#   'a',
#   'number',
#   'there',
#   'are',
#   'about',
#   'on',
#   'the',
#   'pavement',
#   'so',
#   'you',
#   'wont',
#   'miss',
#   'one'],
#  ['at',
#   'each',
#   'of',
#   'them',
#   'there',
#   'is',
#   'a',
#   'sign',
#   'explaining',
#   'some',
#   'details',
#   'about',
#   'the',
#   'sight'],
#  ['the',
#   'red',
#   'line',
#   'starts',
#   'and',
#   'ends',
#   'at',
#   'the',
#   'train',
#   'station'],
#  ['when',
#   'you',
#   'exit',
#   'through',
#   'the',
#   'main',
#   'entrance',
#   'turn',
#   'left',
#   'on',
#   'the',
#   'sidewalk',
#   'and',
#   'look',
#   'for',
#   'it',
#   'some',
#   'of',
#   'the',
#   'paint',
#   'may',
#   'have',
#   'already',
#   'vanished'],
#  ['close',
#   'to',
#   'the',
#   'start',
#   'is',
#   'also',
#   'a',
#   'map',
#   'showing',
#   'the',
#   'route',
#   'and',
#   'the',
#   'attractions'],
#  ['you',
#   'can',
#   'get',
#   'a',
#   'similar',
#   'map',
#   'that',
#   'also',
#   'includes',
#   'the',
#   'red',
#   'line',
#   'at',
#   'the',
#   'tourist',
#   'information',
#   'center'],
#  ['image',
#   'squareinnewoldszczecinjpg',
#   'thumb',
#   'museum',
#   'at',
#   'new',
#   'old',
#   'town'],
#  ['streets',
#   'in',
#   'szczecin',
#   'are',
#   'compared',
#   'to',
#   'other',
#   'polish',
#   'cities',
#   'easy',
#   'to',
#   'navigate',
#   'and',
#   'not',
#   'congested'],
#  ['however',
#   'parking',
#   'within',
#   'the',
#   'centre',
#   'during',
#   'business',
#   'hours',
#   'from',
#   'monday',
#   'to',
#   'friday',
#   'after',
#   'and',
#   'on',
#   'weekends',
#   'it',
#   'is',
#   'free',
#   'is',
#   'paid',
#   'the',
#   'pay',
#   'depends',
#   'on',
#   'the',
#   'zone',
#   'and',
#   'parking',
#   'time'],
#  ['you', 'can', 'buy', 'tickets', 'from', 'vending', 'machines'],
#  ['most',
#   'of',
#   'malls',
#   'have',
#   'free',
#   'parking',
#   'and',
#   'no',
#   'one',
#   'will',
#   'check',
#   'if',
#   'you',
#   'visited',
#   'the',
#   'mall',
#   'or',
#   'just',
#   'used',
#   'free',
#   'parking',
#   'opportunity'],
#  ['dui',
#   'is',
#   'serious',
#   'criminal',
#   'offense',
#   'up',
#   'to',
#   'years',
#   'in',
#   'prison',
#   'and',
#   'the',
#   'police',
#   'have',
#   'no',
#   'mercy',
#   'for',
#   'drunk',
#   'drivers',
#   'many',
#   'of',
#   'zero',
#   'tolerance',
#   'for',
#   'drunk',
#   'drivers',
#   'programs',
#   'ongoing',
#   'in',
#   'poland',
#   'have',
#   'started',
#   'in',
#   'szczecin'],
#  ['because',
#   'of',
#   'major',
#   'renovation',
#   'works',
#   'in',
#   'the',
#   'city',
#   'centre',
#   'and',
#   'niebuszewo',
#   'district',
#   'held',
#   'this',
#   'year',
#   'expect',
#   'detours',
#   'and/or',
#   'traffic',
#   'jams',
#   'especially',
#   'during',
#   'rush',
#   'hours'],
#  ['if',
#   'you',
#   'stay',
#   'in',
#   'the',
#   'city',
#   'consider',
#   'leaving',
#   'your',
#   'car',
#   'on',
#   'parking',
#   'and',
#   'using',
#   'public',
#   'transport'],
#  ['there',
#   'is',
#   'network',
#   'of',
#   'cycling',
#   'bicycle',
#   'paths',
#   'connecting',
#   'the',
#   'city',
#   'center',
#   'with',
#   'the',
#   'suburbs'],
#  ['you',
#   'can',
#   'take',
#   'your',
#   'bike',
#   'on',
#   'public',
#   'transport',
#   'for',
#   'free',
#   'outside',
#   'rush',
#   'hours'],
#  ['if',
#   'you',
#   'want',
#   'to',
#   'see',
#   'szczecin',
#   'from',
#   'the',
#   'bicycle',
#   'but',
#   'dont',
#   'have',
#   'one',
#   'you',
#   'can',
#   'rent',
#   'it'],
#  ['biker', 'swietego', 'ducha', 'a', 'tel'],
#  ['centrum', 'wynajmu', 'i', 'turystyki', 'kolumba', '/m', 'tel'],
#  ['+',
#   'near',
#   'szczecin',
#   'gowny',
#   'railway',
#   'station',
#   'if',
#   'you',
#   'happen',
#   'to',
#   'be',
#   'present',
#   'in',
#   'szczecin',
#   'on',
#   'any',
#   'last',
#   'friday',
#   'of',
#   'the',
#   'month',
#   'feel',
#   'free',
#   'to',
#   'join',
#   'the',
#   'critical',
#   'mass',
#   'the',
#   'start',
#   'point',
#   'is',
#   'plac',
#   'lotnikow',
#   'square',
#   'pm'],
#  ['hail',
#   'taxi',
#   'cab',
#   'from',
#   'the',
#   'street',
#   'or',
#   'stand',
#   'only',
#   'in',
#   'emergency',
#   'or',
#   'if',
#   'very',
#   'tired/drunk'],
#  ['it',
#   'is',
#   'much',
#   'cheaper',
#   'to',
#   'call',
#   'for',
#   'one',
#   'ask',
#   'locals',
#   'for',
#   'numbers',
#   'or',
#   'see',
#   'taxi',
#   'advertisements',
#   'they',
#   'are',
#   'nearly',
#   'everywhere'],
#  ['when',
#   'you',
#   'call',
#   'ask',
#   'the',
#   'operator',
#   'when',
#   'the',
#   'taxi',
#   'will',
#   'arrive',
#   'and',
#   'then',
#   'look',
#   'for',
#   'car',
#   'plastered',
#   'with',
#   'number',
#   'of',
#   'company',
#   'you',
#   'called'],
#  ['there',
#   'is',
#   'taxi',
#   'mafia',
#   'operating',
#   'from',
#   'stands',
#   'near',
#   'railway',
#   'station',
#   'popular',
#   'clubs',
#   'hotels',
#   'etc'],
#  ['avoid', 'these', 'rip', 'offs', 'they', 'are', 'very', 'expensive'],
#  ['taxi',
#   'fare',
#   'within',
#   'the',
#   'centre',
#   'shouldnt',
#   'cost',
#   'you',
#   'more',
#   'than',
#   'about',
#   'z'],
#  ['fare',
#   'from',
#   'left',
#   'side',
#   'of',
#   'the',
#   'river',
#   'lewobrzeze',
#   'to',
#   'the',
#   'right',
#   'side',
#   'prawobrzeze',
#   'or',
#   'the',
#   'other',
#   'way',
#   'is',
#   'about',
#   'z'],
#  ['fares', 'during', 'the', 'night', 'are', 'slightly', 'more', 'expensive'],
#  ['all',
#   'officially',
#   'registered',
#   'taxis',
#   'have',
#   'meters',
#   'the',
#   'driver',
#   'should',
#   'turn',
#   'them',
#   'on',
#   'just',
#   'after',
#   'you',
#   'enter'],
#  ['payment',
#   'have',
#   'cash',
#   'ready',
#   'only',
#   'the',
#   'minority',
#   'of',
#   'taxi',
#   'drivers',
#   'have',
#   'necessary',
#   'equipment',
#   'for',
#   'payments',
#   'with',
#   'debit',
#   'or',
#   'credit',
#   'cards'],
#  ['ask', 'if', 'in', 'doubt'],
#  ['some', 'of', 'taxi', 'companies', 'operating', 'in', 'the', 'city'],
#  ['image',
#   'szczecincastlejpg',
#   'thumb',
#   'castle',
#   'file',
#   'polandszczecinportgatejpg',
#   'thumb',
#   'harbour',
#   'gate',
#   'brama',
#   'portowa'],
#  ['pomeranian',
#   'dukes',
#   'castle',
#   'ksiazat',
#   'pomorskich',
#   'which',
#   'houses',
#   'museum',
#   'restaurants',
#   'and',
#   'cafes'],
#  ['it',
#   'also',
#   'houses',
#   'tourist',
#   'information',
#   'office',
#   'you',
#   'can',
#   'get',
#   'some',
#   'free',
#   'maps',
#   'pamphlets',
#   'etc'],
#  ['old',
#   'town',
#   'stary',
#   'rynek',
#   'despite',
#   'being',
#   'jokingly',
#   'referred',
#   'to',
#   'by',
#   'locals',
#   'as',
#   'brand',
#   'new',
#   'old',
#   'town',
#   'it',
#   'was',
#   'started',
#   'to',
#   'be',
#   'rebuilt',
#   'in',
#   'late',
#   's',
#   'the',
#   'reconstruction',
#   'is',
#   'still',
#   'ongoing',
#   'there',
#   'are',
#   'some',
#   'nice',
#   'houses',
#   'rebuilt',
#   'to',
#   'original',
#   'plans'],
#  ['many', 'shops', 'restaurants', 'and', 'cafes'],
#  ['there', 'is', 'museum', 'situated', 'in', 'old', 'town', 'hall'],
#  ['kamienica',
#   'loitzow',
#   'loitzs',
#   'tenement',
#   'interesting',
#   'tenement',
#   'just',
#   'next',
#   'to',
#   'old',
#   'town'],
#  ['go',
#   'from',
#   'old',
#   'town',
#   'in',
#   'direction',
#   'of',
#   'castle',
#   'and',
#   'youll',
#   'see',
#   'it',
#   'after',
#   'about',
#   'meters',
#   'on',
#   'the',
#   'left',
#   'side'],
#  ['it', 'is', 'painted', 'flashy', 'orange', 'you', 'cant', 'miss', 'it'],
#  ['way',
#   'chrobrego',
#   'german',
#   'name',
#   'hakenterrasse',
#   'promenade',
#   'with',
#   'great',
#   'views',
#   'on',
#   'oder',
#   'river',
#   'and',
#   'port'],
#  ['many', 'cafes', 'are', 'situated', 'here'],
#  ['see',
#   'the',
#   'museum',
#   'muzeum',
#   'morskie',
#   'situated',
#   'just',
#   'in',
#   'the',
#   'center',
#   'of',
#   'waly',
#   'which',
#   'houses',
#   'some',
#   'artifacts',
#   'from',
#   'history',
#   'of',
#   'the',
#   'city',
#   'and',
#   'also',
#   'has',
#   'big',
#   'collections',
#   'of',
#   'african',
#   'and',
#   'maritime',
#   'artifacts'],
#  ['katedra',
#   'sw',
#   'jakuba',
#   'st',
#   'jacobs',
#   'cathedral',
#   'big',
#   'gothic',
#   'cathedral'],
#  ['park',
#   'kasprowicza',
#   'city',
#   'park',
#   'place',
#   'for',
#   'all',
#   'kinds',
#   'of',
#   'physical',
#   'activities',
#   'by',
#   'locals',
#   'spreading',
#   'through',
#   'nearly',
#   'all',
#   'of',
#   'the',
#   'city'],
#  ['just', 'behind', 'the', 'city', 'council'],
#  ['park',
#   'zeromskiego',
#   'another',
#   'city',
#   'park',
#   'situated',
#   'in',
#   'the',
#   'very',
#   'center',
#   'of',
#   'the',
#   'city',
#   'between',
#   'waly',
#   'chrobrego',
#   'and',
#   'pazim/galaxy'],
#  ['cmentarz', 'centralny', 'third', 'biggest', 'cemetery', 'in', 'europe'],
#  ['s',
#   'blast',
#   '&',
#   'fallout',
#   'shelter',
#   'biggest',
#   'in',
#   'poland',
#   'entry',
#   'z'],
#  ['two', 'tours', 'to', 'choose', 'wwii', 'or', 'cold', 'war'],
#  ['pionier',
#   'cinema',
#   'oldest',
#   'cinema',
#   'in',
#   'the',
#   'world',
#   'still',
#   'in',
#   'operation',
#   'est'],
#  ['railway',
#   'suspension',
#   'bridge',
#   'on',
#   'regalica',
#   'something',
#   'for',
#   'railway',
#   'fans',
#   'the',
#   'only',
#   'one',
#   'of',
#   'a',
#   'kind',
#   'in',
#   'operation',
#   'in',
#   'poland'],
#  ['emerald',
#   'lake',
#   'jezioro',
#   'szmaragdowe',
#   'and',
#   'puszcza',
#   'bukowa',
#   'lake',
#   'artificial',
#   'cave',
#   'and',
#   'forest',
#   'area',
#   'situated',
#   'in',
#   'zdroje',
#   'district'],
#  ['many',
#   'great',
#   'views',
#   'on',
#   'the',
#   'city',
#   'and',
#   'nice',
#   'area',
#   'for',
#   'one',
#   'day',
#   'hiking/bike',
#   'riding'],
#  ['paac',
#   'pod',
#   'globusem',
#   'palace',
#   'under',
#   'the',
#   'globe',
#   '/',
#   'palace',
#   'of',
#   'grumbkov',
#   'the',
#   'building',
#   'where',
#   'two',
#   'rulers',
#   'of',
#   'russia',
#   'catherine',
#   'ii',
#   'and',
#   'maria',
#   'fiodorovna',
#   'were',
#   'born'],
#  ['parisienne',
#   'sub',
#   'urb',
#   'many',
#   'historistic',
#   'and',
#   'art',
#   'nouveau',
#   'boulevards',
#   'in',
#   'prussian',
#   'pseudo',
#   'parissienne',
#   'style',
#   'around',
#   'plac',
#   'grunwaldzki',
#   'jagiellonska',
#   'and',
#   'wielkopolska',
#   'streets'],
#  ['museum',
#   'of',
#   'technology',
#   'muzeum',
#   'techniki',
#   'has',
#   'nice',
#   'collection',
#   'of',
#   'vintage',
#   'cars',
#   'motorcycles',
#   'buses',
#   'and',
#   'trams'],
#  ['see',
#   'the',
#   'panorama',
#   'of',
#   'szczecin',
#   'from',
#   'the',
#   'cafe',
#   'on',
#   'top',
#   'of',
#   'pazim',
#   'building',
#   'just',
#   'by',
#   'galaxy',
#   'shopping',
#   'center',
#   'admission',
#   'free',
#   'from',
#   'stjacobs',
#   'cathedral',
#   'tower',
#   'paid',
#   'admission',
#   'or',
#   'from',
#   'one',
#   'of',
#   'the',
#   'towers',
#   'of',
#   'pomeranian',
#   'dukes',
#   'castle'],
#  ['take',
#   'a',
#   'trip',
#   'through',
#   'szczecins',
#   'waterways',
#   'and',
#   'port',
#   'many',
#   'boats',
#   'go',
#   'from',
#   'the',
#   'river',
#   'bank',
#   'near',
#   'way',
#   'chrobrego'],
#  ['kayak',
#   'through',
#   'the',
#   'city',
#   'and',
#   'lower',
#   'oder',
#   'valley',
#   'if',
#   'you',
#   'dont',
#   'have',
#   'your',
#   'kayak',
#   'you',
#   'can',
#   'borrow',
#   'one',
#   'at',
#   'kapielisko',
#   'dziewoklicz',
#   'ul'],
#  ['autostrada', 'poznanska', 'public', 'transport', 'bus', 'no'],
#  ['stop',
#   'dziewoklicz',
#   'or',
#   'any',
#   'of',
#   'the',
#   'neighbouring',
#   'towns',
#   'situated',
#   'by',
#   'the',
#   'oder',
#   'river',
#   'look',
#   'for',
#   'wypozyczalnia',
#   'kajakow',
#   'kayak',
#   'rentals',
#   'or',
#   'kajaki',
#   'kayaks'],
#  ['see', 'dancing', 'fountain', 'near', 'teatr', 'pleciuga', 'ul'],
#  ['it',
#   'might',
#   'not',
#   'be',
#   'the',
#   'most',
#   'impressive',
#   'fountain',
#   'show',
#   'in',
#   'the',
#   'world',
#   'but',
#   'still',
#   'its',
#   'nice',
#   'eyecandy',
#   'and',
#   'its',
#   'free'],
#  ['the',
#   'show',
#   'lasts',
#   'minutes',
#   'and',
#   'starts',
#   'every',
#   'summer',
#   'day',
#   'at'],
#  ['baltic', 'rock', 'meeting', 'may', 'june'],
#  ['dni', 'morza', '/', 'days', 'of', 'the', 'sea'],
#  ['maritime', 'university', 'of', 'szczecin', 'http', '//amszczecinpl'],
#  ['university', 'of', 'szczecin', 'http', '//wwwusszcpl/'],
#  ['west',
#   'pomeranian',
#   'university',
#   'of',
#   'technology',
#   'http',
#   '//wwwzutedupl/'],
#  ['pomeranian', 'medical', 'university', 'http', '//wwwpamszczecinpl/'],
#  ['academy', 'of', 'arts', 'http', '//wwwakademiasztukieu/'],
#  ['west', 'pomeranian', 'business', 'school', 'http', '//wwwzpsbszczecinpl/'],
#  ['english',
#   'teachers',
#   'and',
#   'it',
#   'developers/engineers',
#   'are',
#   'in',
#   'high',
#   'demand'],
#  ['szczecin', 'has', 'many', 'shopping', 'malls'],
#  ['auchan', 'situated', 'in', 'ustowo'],
#  ['dont',
#   'go',
#   'there',
#   'if',
#   'you',
#   'dont',
#   'have',
#   'a',
#   'car',
#   'the',
#   'place',
#   'is',
#   'totally',
#   'pedestrian',
#   'unfriendly'],
#  ['carrefour',
#   'situated',
#   'near',
#   'media',
#   'markt',
#   'mall',
#   'with',
#   'electronics',
#   'in',
#   'pomorzany',
#   'district'],
#  ['ch',
#   'ster',
#   'situated',
#   'near',
#   'castorama',
#   'big',
#   'shop',
#   'for',
#   'diy',
#   'builders',
#   'in',
#   'gumience',
#   'district',
#   'nearest',
#   'mall',
#   'from',
#   'the',
#   'german',
#   'border'],
#  ['ch', 'turzyn', 'another', 'mall', 'in', 'the', 'center'],
#  ['kaskada',
#   'the',
#   'newest',
#   'and',
#   'the',
#   'biggest',
#   'shopping',
#   'mall',
#   'in',
#   'szczecin',
#   'best',
#   'brands',
#   'and',
#   'spacious',
#   'foodcourt'],
#  ['galaxy', 'shopping', 'mall', 'many', 'outlets', 'of', 'major', 'brands'],
#  ['situated', 'in', 'the', 'centernear', 'kaskada'],
#  ['tesco',
#   'another',
#   'one',
#   'just',
#   'across',
#   'the',
#   'street',
#   'of',
#   'the',
#   'carrefour',
#   'mentioned',
#   'above'],
#  ['you',
#   'will',
#   'easily',
#   'find',
#   'global',
#   'favorites',
#   'like',
#   'hamburgers',
#   'hot',
#   'dogs',
#   'kebabs',
#   'pizza',
#   'etc',
#   'but',
#   'for',
#   'unique',
#   'szczecin',
#   'twist',
#   'on',
#   'fast',
#   'food',
#   'try',
#   'paszteciki',
#   'plural',
#   'singular',
#   'is',
#   'pasztecik',
#   'which',
#   'are',
#   'kind',
#   'of',
#   'deep',
#   'fried',
#   'cake',
#   'with',
#   'meat',
#   'or',
#   'cheese',
#   'and',
#   'mushrooms',
#   'filling'],
#  ['they',
#   'taste',
#   'best',
#   'hot',
#   'and',
#   'combined',
#   'with',
#   'a',
#   'cup',
#   'of',
#   'barszcz',
#   'czerwony',
#   'red',
#   'beetroot',
#   'soup'],
#  ['turysta', 'milk', 'bar', 'obroncow', 'stalingradu', 'a', 'open'],
#  ['zacisze', 'bar', 'asnyka', 'niebuszewo', 'district'],
#  ['akademia', 'kulinarna', 'mickiewicza', 'open'],
#  ['bar',
#   'zen',
#   'bohaterow',
#   'warszawy',
#   'near',
#   'ch',
#   'turzyn',
#   'vietnamese',
#   'buddhist',
#   'cuisine',
#   'vegan',
#   'open'],
#  ['amar',
#   'slaska',
#   'open',
#   'monday',
#   'friday',
#   'saturday',
#   '&',
#   'sunday',
#   'vegan',
#   '&',
#   'vegetarian'],
#  ['if',
#   'you',
#   'are',
#   'on',
#   'limited',
#   'budget',
#   'order',
#   'their',
#   'danie',
#   'dnia',
#   'dish',
#   'of',
#   'a',
#   'day',
#   'and/or',
#   'zupa',
#   'dnia',
#   'soup',
#   'of',
#   'a',
#   'day',
#   'which',
#   'are',
#   'always',
#   'very',
#   'affordable'],
#  ['brama',
#   'jazz',
#   'cafe',
#   'plac',
#   'hodu',
#   'pruskiego',
#   'mexican',
#   '&',
#   'fusion'],
#  ['green',
#   'way',
#   'krzywoustego',
#   'open',
#   'monday',
#   'friday',
#   'weekends',
#   'vegetarian'],
#  ['golden', 'dragon', 'jana', 'kazimierza', 'chinese'],
#  ['chief', 'rayskiego', 'all', 'kinds', 'of', 'sea', 'food'],
#  ['adoga', 'jana', 'z', 'kolna', 'russian'],
#  ['sushi',
#   'mado',
#   'pocztowa',
#   'entry',
#   'from',
#   'bohaterow',
#   'warszawy',
#   'japanese'],
#  ['columbus', 'on', 'waly', 'chrobrego', 'by', 'marine', 'academy'],
#  ['colorado', 'on', 'waly', 'chrobrego', 'by', 'polski', 'theatre'],
#  ['colorado', 'on', 'waly', 'chrobrego', 'by', 'polski', 'theatre'],
#  ['karczma', 'polska', 'lotnikow', 'square'],
#  ['szpilka', 'ulmaopolska', 'delicious', 'fusion'],
#  ['the',
#   'majority',
#   'of',
#   'pubs',
#   'and',
#   'bars',
#   'can',
#   'be',
#   'found',
#   'in',
#   'the',
#   'old',
#   'town',
#   'stary',
#   'rynek',
#   'or',
#   'around',
#   'ul'],
#  ['bogusawa', 'in', 'the', 'middle', 'town', 'area'],
#  ['expect',
#   'to',
#   'pay',
#   'between',
#   'zl',
#   'and',
#   'zl',
#   'for',
#   'a',
#   'large',
#   'beer',
#   'and',
#   'around',
#   'zl',
#   'for',
#   'a',
#   'ml',
#   'shot',
#   'of',
#   'vodka'],
#  ['bosman', 'beer', 'is', 'made', 'by', 'local', 'brewery'],
#  ['there',
#   'are',
#   'variants',
#   'with',
#   'red',
#   'czerwony',
#   'and',
#   'green',
#   'zielony',
#   'label',
#   'both',
#   'of',
#   'them',
#   'are',
#   'lager'],
#  ['you',
#   'can',
#   'buy',
#   'it',
#   'at',
#   'most',
#   'of',
#   'general',
#   'stores',
#   'and',
#   'some',
#   'pubs'],
#  ['taverna',
#   'pub',
#   'has',
#   'its',
#   'own',
#   'microbrewery',
#   'making',
#   'lager',
#   'and',
#   'porter',
#   'type',
#   'beers'],
#  ['starka',
#   'is',
#   'a',
#   'special',
#   'kind',
#   'of',
#   'seasoned',
#   'vodka',
#   'made',
#   'by',
#   'polmos',
#   'szczecin',
#   'distillery'],
#  ['there', 'are', 'variants', 'which', 'are', 'and', 'years', 'old'],
#  ['you',
#   'can',
#   'buy',
#   'them',
#   'at',
#   'polmos',
#   'store',
#   'situated',
#   'corner',
#   'of',
#   'jagiellonska',
#   'and',
#   'bohaterow',
#   'warszawy',
#   'streets',
#   'as',
#   'you',
#   'can',
#   'guess',
#   'starka',
#   'is',
#   'rather',
#   'expensive',
#   'especially',
#   'the',
#   'year',
#   'old',
#   'one',
#   'and',
#   'available',
#   'only',
#   'in',
#   'limited',
#   'amounts'],
#  ['you',
#   'can',
#   'also',
#   'tour',
#   'the',
#   'factory',
#   'is',
#   'quite',
#   'interesting',
#   'tasting',
#   'starka',
#   'is',
#   'included',
#   'with',
#   'the',
#   'tour',
#   'email',
#   'them',
#   'for',
#   'booking',
#   'and',
#   'information'],
#  ['brama', 'jazz', 'cafe', 'ul'],
#  ['city', 'council', 'building', 'pl'],
#  ['ksiaznica', 'pomorska', 'public', 'library', 'ul'],
#  ['park',
#   'kasprowicza',
#   'city',
#   'park',
#   'jasne',
#   'bonia',
#   'whole',
#   'area',
#   'between',
#   'city',
#   'council',
#   'building',
#   'and',
#   'three',
#   'eagles',
#   'monument'],
#  ['piwnica', 'przy', 'kanie', 'pl'],
#  ['sw', 'piotra', 'i', 'pawa', '/'],
#  ['politechnika',
#   'szczecinska',
#   'wydzia',
#   'mechaniczny',
#   'technical',
#   'university',
#   'of',
#   'szczecin',
#   'al'],
#  ['pub', 'colorado', 'way', 'chrobrego', 'a'],
#  ['uniwersytet',
#   'szczecinski',
#   'wydzia',
#   'nauk',
#   'ekonomicznych',
#   'i',
#   'zarzadzania',
#   'university',
#   'of',
#   'szczecin',
#   'ul'],
#  ['wyzsza',
#   'szkoa',
#   'administracji',
#   'publicznej',
#   'higher',
#   'school',
#   'of',
#   'public',
#   'administration',
#   'ul'],
#  ['zachodniopomorska',
#   'szkoa',
#   'biznesu',
#   'budynek',
#   'a',
#   'west',
#   'pomeranian',
#   'business',
#   'school',
#   'ul'],
#  ['szczecin',
#   'used',
#   'to',
#   'be',
#   'infamous',
#   'in',
#   'poland',
#   'for',
#   'its',
#   'organized',
#   'crime',
#   'but',
#   'these',
#   'days',
#   'are',
#   'long',
#   'gone',
#   'nearly',
#   'all',
#   'the',
#   'gangsters',
#   'are',
#   'dead',
#   'or',
#   'in',
#   'prison'],
#  ['nowadays', 'it', 'is', 'a', 'very', 'safe', 'city'],
#  ['however',
#   'you',
#   'should',
#   'stay',
#   'away',
#   'from',
#   'some',
#   'of',
#   'its',
#   'bad',
#   'suburbs',
#   'like',
#   'gocaw',
#   'especially',
#   'after',
#   'dark'],
#  ['as', 'always', 'use', 'your', 'common', 'sense'],
#  ['be',
#   'careful',
#   'when',
#   'crossing',
#   'streets',
#   'jaywalking',
#   'is',
#   'a',
#   'crime',
#   'in',
#   'poland',
#   'and',
#   'the',
#   'police',
#   'often',
#   'lie',
#   'in',
#   'wait',
#   'for',
#   'tourists',
#   'crossing',
#   'streets',
#   'when',
#   'the',
#   'pedestrian',
#   'crossing',
#   'is',
#   'on',
#   'red'],
#  ['if',
#   'stopped',
#   'claim',
#   'that',
#   'your',
#   'money',
#   'and',
#   'passport',
#   'are',
#   'in',
#   'your',
#   'hotel',
#   'and',
#   'you',
#   'may',
#   'get',
#   'away',
#   'with',
#   'it'],
#  ['kurza', 'stopka', '/cd', '/'],
#  ['the',
#   'town',
#   'of',
#   'police',
#   'and',
#   'its',
#   'jasienica',
#   'district',
#   'monuments',
#   'from',
#   'the',
#   'middle',
#   'ages',
#   'small',
#   'marina',
#   'in',
#   'the',
#   'old',
#   'town',
#   'on',
#   'the',
#   'arpia',
#   'oder',
#   'river',
#   'and',
#   'wwii',
#   'ruins',
#   'of',
#   'hydrierwerke',
#   'synthetic',
#   'gasoline',
#   'factory'],
#  ['szczecin',
#   'shares',
#   'its',
#   'public',
#   'transport',
#   'with',
#   'police',
#   'and',
#   'borders',
#   'the',
#   'town',
#   'you',
#   'can',
#   'go',
#   'to',
#   'police',
#   'by',
#   'taking',
#   'public',
#   'bus'],
#  ['sea', 'resort', 'and', 'medieval', 'town', 'of', 'kamien', 'pomorski'],
#  ['sea', 'resort', 'and', 'medieval', 'town', 'of', 'koobrzeg'],
#  ['gothic', 'church', 'ruins', 'in', 'trzesacz'],
#  ['medieval',
#   'town',
#   'of',
#   'stargard',
#   'szczecinski',
#   'with',
#   'a',
#   'cathedral',
#   'over',
#   'a',
#   'hundred',
#   'metres',
#   'high'],
#  ['birds', 'reservation', 'in', 'swidwie'],
#  ['miedzyodrze',
#   'lower',
#   'oder',
#   'valley',
#   'picturesque',
#   'marsh',
#   'area',
#   'full',
#   'of',
#   'wildlife'],
#  ['quiet', 'medieval', 'town', 'of', 'nowe', 'warpno'],
#  ['resort', 'of', 'trzebiez', 'with', 'big', 'marina'],
#  ['on', 'the', 'wolin', 'island'],
#  ['game', 'reserve', 'of', 'wisents'],
#  ['metres', 'high', 'gosan', 'cliff'],
#  ['sea', 'resort', 'and', 'port', 'swinoujscie'],
#  ['ancient', 'town', 'of', 'wolin', 'town'],
#  ['medieval', 'town', 'of', 'lubin'],
#  ['commons',
#   'szczecin',
#   'wikipedia',
#   'szczecin',
#   'dmoz',
#   'regional/europe/poland/voivodships/western',
#   'pomerania/szczecin'],
#  ['bowling',
#   'green',
#   'is',
#   'accessible',
#   'by',
#   'car',
#   'primarily',
#   'from',
#   'i',
#   'which',
#   'connects',
#   'it',
#   'with',
#   'nashville',
#   'to',
#   'the',
#   'south',
#   'and',
#   'louisville',
#   'to',
#   'the',
#   'north'],
#  ['two',
#   'roads',
#   'in',
#   'the',
#   'states',
#   'parkway',
#   'system',
#   'of',
#   'former',
#   'toll',
#   'roads',
#   'serve',
#   'the',
#   'bowling',
#   'green',
#   'area'],
#  ['the',
#   'william',
#   'natcher',
#   'parkway',
#   'formerly',
#   'green',
#   'river',
#   'parkway',
#   'connects',
#   'i',
#   'in',
#   'bowling',
#   'green',
#   'with',
#   'owensboro',
#   'miles',
#   'to',
#   'the',
#   'northwest'],
#  ['the',
#   'natcher',
#   'intersects',
#   'with',
#   'the',
#   'western',
#   'kentucky',
#   'parkway',
#   'near',
#   'beaver',
#   'dam',
#   'giving',
#   'bowling',
#   'green',
#   'easy',
#   'access',
#   'to',
#   'paducah',
#   'and',
#   'the',
#   'land',
#   'between',
#   'the',
#   'lakes',
#   'national',
#   'recreation',
#   'area',
#   'land',
#   'between',
#   'the',
#   'lakes'],
#  ['the',
#   'cumberland',
#   'parkway',
#   'connects',
#   'i',
#   'northeast',
#   'of',
#   'bowling',
#   'green',
#   'to',
#   'somerset',
#   'kentucky',
#   'somerset',
#   'miles',
#   'to',
#   'the',
#   'east'],
#  ['from',
#   'there',
#   'ky',
#   'provides',
#   'access',
#   'to',
#   'i',
#   'at',
#   'london',
#   'kentucky',
#   'london'],
#  ['another', 'major', 'road', 'in', 'the', 'area', 'is', 'us'],
#  ['to',
#   'the',
#   'east',
#   'of',
#   'the',
#   'city',
#   'it',
#   'is',
#   'a',
#   'two',
#   'lane',
#   'road',
#   'that',
#   'largely',
#   'parallels',
#   'i',
#   'and',
#   'the',
#   'cumberland',
#   'parkway',
#   'before',
#   'taking',
#   'a',
#   'sharp',
#   'turn',
#   'toward',
#   'central',
#   'kentucky'],
#  ['however',
#   'to',
#   'the',
#   'west',
#   'it',
#   'is',
#   'a',
#   'four',
#   'lane',
#   'divided',
#   'highway',
#   'though',
#   'with',
#   'at',
#   'grade',
#   'intersections',
#   'until',
#   'the',
#   'town',
#   'of',
#   'cadiz',
#   'near',
#   'land',
#   'between',
#   'the',
#   'lakes'],
#  ['bowling',
#   'green',
#   'warren',
#   'county',
#   'regional',
#   'airport',
#   'woodhurst',
#   'st',
#   '+',
#   'flight',
#   'service',
#   'all',
#   'weather',
#   'capability',
#   'fbo',
#   'hours',
#   'days',
#   'a',
#   'week',
#   'rental',
#   'cars',
#   'aircraft',
#   'maintenance',
#   'free',
#   'parking',
#   'courtesy',
#   'car',
#   'two',
#   'flight',
#   'schools',
#   'and',
#   'charter',
#   'service'],
#  ['louisville',
#   'international',
#   'airport',
#   'two',
#   'hours',
#   'north',
#   'of',
#   'bowling',
#   'green'],
#  ['nashville',
#   'international',
#   'airport',
#   'one',
#   'hour',
#   'south',
#   'of',
#   'bowling',
#   'green'],
#  ['bowling',
#   'green',
#   'public',
#   'transit',
#   'by',
#   'community',
#   'action',
#   'of',
#   'southern',
#   'ky',
#   '+'],
#  ['greyhound', 'bus', 'lines', 'parker', 'ave', '+'],
#  ['avis', 'us', 'w', 'bypass', 'bp', 'service', 'station', '+', 'or', '+'],
#  ['enterprise',
#   'rent',
#   'a',
#   'car',
#   'us',
#   'w',
#   'bypass',
#   '+',
#   'and',
#   'scottsville',
#   'rd'],
#  ['hertz', 'rent', 'a', 'car', 'us', 'w', 'bypass', '+', 'or', '+'],
#  ['u', 'save', 'auto', 'rental', 'us', 'w', 'bypass', '+', 'or', '+'],
#  ['lost',
#   'river',
#   'cave',
#   'and',
#   'valley',
#   'i',
#   'exit',
#   'left',
#   'at',
#   'stoplight',
#   '#',
#   'right',
#   'on',
#   'nashville',
#   'road',
#   '+',
#   'or',
#   '+',
#   'boat',
#   'tours',
#   'subject',
#   'to',
#   'weather',
#   'so',
#   'call',
#   'ahead'],
#  ['kentuckys',
#   'only',
#   'underground',
#   'boat',
#   'tour',
#   'and',
#   'the',
#   'enchanting',
#   'butterfly',
#   'habitat'],
#  ['ripleys',
#   'believe',
#   'it',
#   'or',
#   'not',
#   'claims',
#   'is',
#   'the',
#   'shortest',
#   'deepest',
#   'in',
#   'the',
#   'world'],
#  ['the',
#   'walking',
#   'tour',
#   'along',
#   'the',
#   'rivers',
#   'edge',
#   'will',
#   'bring',
#   'alive',
#   'stories',
#   'of',
#   'native',
#   'americans',
#   'early',
#   'european',
#   'settlers',
#   'civil',
#   'war',
#   'troops',
#   'and',
#   'the',
#   'notorious',
#   'jesse',
#   'james'],
#  ['enjoy',
#   'treetop',
#   'bridge',
#   'nature',
#   'trails',
#   'bird',
#   'watching',
#   'stations',
#   'picnic',
#   'area',
#   'gemstone',
#   'sluice',
#   'old',
#   'mill',
#   'gifts',
#   'and',
#   'the',
#   'rock',
#   'climbing',
#   'wall'],
#  ['leonard',
#   'd',
#   'brown',
#   'agricultural',
#   'exposition',
#   'center',
#   'wku',
#   'farm',
#   'miles',
#   'south',
#   'of',
#   'bowling',
#   'green',
#   'off',
#   'nashville',
#   'road',
#   'us',
#   'w',
#   '+',
#   'held',
#   'year',
#   'round',
#   'include',
#   'livestock',
#   'shows',
#   'sales',
#   'clinics',
#   'machinery',
#   'shows',
#   'rodeos',
#   'and',
#   'other',
#   'public',
#   'events'],
#  ['the',
#   'centers',
#   'main',
#   'arena',
#   'seats',
#   'with',
#   'a',
#   'sales',
#   'arena',
#   'seating'],
#  ['there', 'are', 'also', 'meeting', 'and', 'banquet', 'rooms'],
#  ['civil', 'war', 'discovery', 'trail', '+'],
#  ['thirteen',
#   'sites',
#   'are',
#   'available',
#   'to',
#   'the',
#   'public',
#   'and',
#   'include',
#   'earthworks',
#   'a',
#   'cave',
#   'a',
#   'house',
#   'museum',
#   'monuments',
#   'and',
#   'markers'],
#  ['with',
#   'kentuckians',
#   'divided',
#   'between',
#   'north',
#   'and',
#   'south',
#   'the',
#   'state',
#   'adopted',
#   'a',
#   'policy',
#   'of',
#   'neutrality',
#   'at',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'civil',
#   'war'],
#  ['bowling',
#   'greens',
#   'reliable',
#   'and',
#   'defensible',
#   'transportation',
#   'network',
#   'and',
#   'the',
#   'collection',
#   'of',
#   'hills',
#   'that',
#   'surrounded',
#   'the',
#   'city',
#   'made',
#   'it',
#   'one',
#   'of',
#   'the',
#   'most',
#   'strategic',
#   'cities',
#   'in',
#   'the',
#   'state'],
#  ['in',
#   'november',
#   'bowling',
#   'green',
#   'was',
#   'declared',
#   'the',
#   'capital',
#   'of',
#   'the',
#   'confederate',
#   'state',
#   'of',
#   'kentucky',
#   'but',
#   'by',
#   'mid',
#   'february',
#   'fell',
#   'into',
#   'union',
#   'hands'],
#  ['bowling',
#   'green',
#   'was',
#   'also',
#   'the',
#   'site',
#   'of',
#   'a',
#   'federal',
#   'government',
#   'campaign',
#   'to',
#   'enlist',
#   'slaves',
#   'as',
#   'union',
#   'soldiers'],
#  ['duncan',
#   'hines',
#   'scenic',
#   'byway',
#   'this',
#   'mile',
#   'route',
#   'which',
#   'runs',
#   'through',
#   'warren',
#   'and',
#   'edmonson',
#   'counties',
#   'passes',
#   'many',
#   'historic',
#   'homes',
#   'and',
#   'churches'],
#  ['beginning',
#   'in',
#   'bowling',
#   'green',
#   'at',
#   'the',
#   'former',
#   'home',
#   'and',
#   'office',
#   'of',
#   'author',
#   'duncan',
#   'hines',
#   'it',
#   'then',
#   'runs',
#   'through',
#   'several',
#   'small',
#   'towns',
#   'and',
#   'mammoth',
#   'cave',
#   'national',
#   'park',
#   'where',
#   'it',
#   'crosses',
#   'the',
#   'green',
#   'river',
#   'by',
#   'ferry'],
#  ['along',
#   'the',
#   'route',
#   'are',
#   'stately',
#   'mansions',
#   'quaint',
#   'homes',
#   'antique',
#   'shops',
#   'one',
#   'room',
#   'school',
#   'houses',
#   'an',
#   'old',
#   'train',
#   'depot',
#   'historic',
#   'cemeteries',
#   'civil',
#   'war',
#   'battlefields',
#   'an',
#   'old',
#   'grainery',
#   'and',
#   'a',
#   'stagecoach',
#   'stop',
#   'which',
#   'was',
#   'once',
#   'the',
#   'home',
# ...
#   'the',
#   'time',
#   'of',
#   'day'],
#  ['downtown',
#   'nampa',
#   'has',
#   'three',
#   'notable',
#   'used',
#   'book',
#   'dealers',
#   'all',
#   'within',
#   'walking',
#   'distance',
#   'of',
#   'each',
#   'other'],
#  ['downtown',
#   'nampa',
#   'also',
#   'has',
#   'a',
#   'variety',
#   'of',
#   'other',
#   'small',
#   'shops',
#   'and',
#   'businesses'],
#  ['the', 'local', 'paper', 'in', 'nampa', 'is', 'the', 'press', 'tribune'],
#  ['lowell',
#   'and',
#   'the',
#   'deer',
#   'flat',
#   'national',
#   'wildlife',
#   'refuge',
#   'an',
#   'acre',
#   'wildlife',
#   'refuge',
#   'excellent',
#   'for',
#   'birding'],
#  ['dmoz',
#   'regional/north',
#   'america/united',
#   'states/idaho/localities/n/nampa/'],
#  ['massa', 'capital', 'of', 'the', 'province', 'carrara'],
#  ['lunigiana', 'a', 'region', 'within', 'massa', 'carrara'],
#  ['us',
#   'connects',
#   'to',
#   'pampa',
#   'from',
#   'amarillo',
#   'about',
#   'an',
#   'hour',
#   'to',
#   'the',
#   'west/southwest',
#   'and',
#   'from',
#   'canadian',
#   'to',
#   'the',
#   'east'],
#  ['tx',
#   'connects',
#   'with',
#   'perryton',
#   'to',
#   'the',
#   'north',
#   'and',
#   'has',
#   'important',
#   'connections',
#   'to',
#   'the',
#   'south',
#   'with',
#   'i',
#   'near',
#   'groom',
#   'minutes',
#   'and',
#   'with',
#   'us',
#   'at',
#   'clarendon',
#   'for',
#   'those',
#   'coming',
#   'from',
#   'the',
#   'wichita',
#   'falls',
#   'or',
#   'dfw',
#   'metroplex',
#   'dallas',
#   'fort',
#   'worth',
#   'areas'],
#  ['tx',
#   'leads',
#   'into',
#   'town',
#   'from',
#   'the',
#   'northwest',
#   'from',
#   'borger',
#   'minutes',
#   'dumas',
#   'minutes',
#   'or',
#   'dalhart'],
#  ['there',
#   'is',
#   'really',
#   'no',
#   'public',
#   'transportation',
#   'here',
#   'so',
#   'you',
#   'will',
#   'need',
#   'a',
#   'car'],
#  ['should',
#   'you',
#   'somehow',
#   'find',
#   'yourself',
#   'here',
#   'without',
#   'one',
#   'there',
#   'is',
#   'one',
#   'call',
#   'taxi',
#   'service'],
#  ['pampa', 'has', 'a', 'number', 'of', 'crafts', 'and', 'antiques', 'shops'],
#  ['image', 'lake', 'mcclellanjpg', 'thumb', 'lake', 'mcclellan'],
#  ['black',
#   'kettle',
#   'national',
#   'grassland',
#   'northeast',
#   'about',
#   'miles',
#   'on',
#   'texas',
#   'highway',
#   'look',
#   'for',
#   'the',
#   'turnoff',
#   'about',
#   'miles',
#   'beyond',
#   'canadian'],
#  ['part', 'of', 'cibola', 'national', 'forest'],
#  ['while',
#   'most',
#   'of',
#   'this',
#   'park',
#   'is',
#   'in',
#   'oklahoma',
#   'this',
#   'separate',
#   'acre',
#   'park',
#   'includes',
#   'lake',
#   'marvin',
#   'providing',
#   'a',
#   'beautiful',
#   'relaxation',
#   'spot',
#   'for',
#   'any',
#   'panhandle',
#   'traveller',
#   'who',
#   'misses',
#   'seeing',
#   'lots',
#   'of',
#   'trees'],
#  ['mcclellan',
#   'creek',
#   'national',
#   'grassland',
#   'miles',
#   'to',
#   'the',
#   'south',
#   'on',
#   'highway'],
#  ['part',
#   'of',
#   'cibola',
#   'national',
#   'forest',
#   'this',
#   'park',
#   'has',
#   'passable',
#   'campground',
#   'facilities',
#   'and',
#   'rv',
#   'hook',
#   'ups',
#   'and',
#   'offers',
#   'fishing',
#   'hiking',
#   'and',
#   'wildlife',
#   'viewing',
#   'opportunities'],
#  ['be', 'cautious', 'of', 'rattlesnakes'],
#  ['lake',
#   'meredith',
#   'at',
#   'fritch',
#   'has',
#   'good',
#   'boating',
#   'facilities',
#   'and',
#   'is',
#   'a',
#   'popular',
#   'fishing',
#   'spot'],
#  ['perryton',
#   'north',
#   'of',
#   'highway',
#   'has',
#   'a',
#   'museum',
#   'with',
#   'exhibits',
#   'on',
#   'the',
#   'panhandle',
#   'plains',
#   'villagers',
#   'of',
#   'pre',
#   'colonization',
#   'times'],
#  ['square',
#   'house',
#   'museum',
#   'in',
#   'panhandle',
#   'texas',
#   'city',
#   'panhandle',
#   'minutes',
#   'west',
#   'on',
#   'highway'],
#  ['imagepanhandle', 'texas', 'city', 'panhandle', 'directionrcanadian'],
#  ['imagesayre', 'oklahoma', 'sayre', 'minorr=wheeler'],
#  ['gangtok',
#   'is',
#   'popular',
#   'place',
#   'with',
#   'tourists',
#   'heading',
#   'on',
#   'treks',
#   'though',
#   'the',
#   'facilities',
#   'do',
#   'not',
#   'reflect',
#   'the',
#   'number',
#   'of',
#   'international',
#   'visitors'],
#  ['however',
#   'efforts',
#   'are',
#   'being',
#   'made',
#   'by',
#   'the',
#   'government',
#   'to',
#   'improve',
#   'the',
#   'conditions'],
#  ['gangtok',
#   'would',
#   'be',
#   'easily',
#   'one',
#   'of',
#   'the',
#   'most',
#   'cleanest',
#   'cities',
#   'you',
#   'would',
#   'ever',
#   'come',
#   'across',
#   'highly',
#   'organized',
#   'and',
#   'beautifully',
#   'maintained',
#   'it',
#   'the',
#   'switzerland',
#   'of',
#   'the',
#   'east'],
#  ['tourists',
#   'are',
#   'of',
#   'paramount',
#   'importance',
#   'hence',
#   'rules',
#   'have',
#   'been',
#   'laid',
#   'in',
#   'order',
#   'to',
#   'prevent',
#   'tourists',
#   'from',
#   'being',
#   'cheated'],
#  ['fares', 'of', 'cabs', 'are', 'mostly', 'fixed', 'for', 'such', 'reason'],
#  ['a', 'really', 'nice', 'place', 'to', 'unwind'],
#  ['quite',
#   'a',
#   'few',
#   'places',
#   'for',
#   'vegetarians',
#   'to',
#   'eat',
#   'since',
#   'it',
#   'is',
#   'mostly',
#   'dominated',
#   'by',
#   'buddhist',
#   'culture'],
#  ['the', 'city', 'resembles', 'the', 'bhutanese', 'capital'],
#  ['devoid',
#   'of',
#   'large',
#   'stores',
#   'book',
#   'shops',
#   'this',
#   'place',
#   'is',
#   'an',
#   'nice',
#   'break',
#   'away',
#   'from',
#   'typical',
#   'city',
#   'lives'],
#  ['still',
#   'the',
#   'city',
#   'is',
#   'a',
#   'fascinating',
#   'place',
#   'to',
#   'spend',
#   'a',
#   'few',
#   'nights',
#   'the',
#   'winding',
#   'side',
#   'alleys',
#   'hide',
#   'some',
#   'unexpected',
#   'gems',
#   'and',
#   'the',
#   'main',
#   'street',
#   'mg',
#   'marg',
#   'is',
#   'pedestrianized',
#   'and',
#   'a',
#   'pleasant',
#   'place',
#   'to',
#   'take',
#   'a',
#   'stroll'],
#  ['the',
#   'city',
#   'sleeps',
#   'by',
#   'pm',
#   'mostly',
#   'except',
#   'for',
#   'a',
#   'few',
#   'pubs',
#   'which',
#   'are',
#   'open',
#   'till',
#   'pm'],
#  ['the', 'best', 'season', 'to', 'visit', 'gangtok', 'is', 'jan', 'march'],
#  ['the',
#   'nearest',
#   'airport',
#   'is',
#   'at',
#   'bagdogra',
#   'ixb',
#   'at',
#   'a',
#   'distance',
#   'of',
#   'roughly',
#   'kilometers'],
#  ['the',
#   'bagdogra',
#   'airport',
#   'kms',
#   'from',
#   'siliguri',
#   'is',
#   'served',
#   'by',
#   'direct',
#   'flights',
#   'from',
#   'kolkata',
#   'and',
#   'new',
#   'delhi'],
#  ['from',
#   'airport',
#   'you',
#   'can',
#   'hire',
#   'a',
#   'taxi',
#   'or',
#   'cab',
#   'to',
#   'reach',
#   'at',
#   'gangtok'],
#  ['frequent',
#   'direct',
#   'flights',
#   'are',
#   'also',
#   'available',
#   'for',
#   'bagdogra',
#   'and',
#   'a',
#   'lovely',
#   'highway',
#   'passing',
#   'through',
#   'beautiful',
#   'scenery',
#   'waterfall',
#   'and',
#   'mountains',
#   'will',
#   'take',
#   'you',
#   'to',
#   'the',
#   'gangtok'],
#  ['a',
#   'helicopter',
#   'flies',
#   'between',
#   'the',
#   'bagdogra',
#   'and',
#   'gangtok',
#   'once',
#   'a',
#   'day',
#   'around',
#   'pm',
#   'and',
#   'requires',
#   'pre',
#   'booking',
#   'as',
#   'it',
#   'carries',
#   'only',
#   'passengers'],
#  ['the',
#   'nearest',
#   'train',
#   'station',
#   'to',
#   'gangtok',
#   'is',
#   'new',
#   'jalpaiguri',
#   'in',
#   'siliguri',
#   'which',
#   'has',
#   'direct',
#   'connections',
#   'to',
#   'new',
#   'delhi',
#   'kolkata',
#   'and',
#   'other',
#   'major',
#   'cities',
#   'in',
#   'india'],
#  ['it', 'is', 'a', 'hour', 'journey', 'from', 'kolkata'],
#  ['once',
#   'you',
#   'arrive',
#   'in',
#   'new',
#   'jalpaiguri',
#   'you',
#   'can',
#   'either',
#   'hire',
#   'a',
#   'taxi',
#   'from',
#   'the',
#   'station',
#   'itself',
#   'or',
#   'take',
#   'an',
#   'auto',
#   'rickshaw',
#   'to',
#   'the',
#   'siliguri',
#   'bus',
#   'stand'],
#  ['from',
#   'there',
#   'you',
#   'have',
#   'the',
#   'option',
#   'of',
#   'travelling',
#   'to',
#   'gangtok',
#   'by',
#   'state',
#   'bus',
#   'roughly',
#   'a',
#   'hour',
#   'journey'],
#  ['the',
#   'roads',
#   'in',
#   'the',
#   'area',
#   'are',
#   'all',
#   'winding',
#   'mountain',
#   'roads',
#   'in',
#   'poor',
#   'condition'],
#  ['the',
#   'average',
#   'travel',
#   'speed',
#   'between',
#   'gangtok',
#   'and',
#   'other',
#   'cities',
#   'is',
#   'around',
#   'km/h'],
#  ['shared',
#   'jeeps',
#   'connect',
#   'gangtok',
#   'to',
#   'siliguri',
#   'darjeeling',
#   'kalimpong',
#   'and',
#   'other',
#   'mountain',
#   'locales'],
#  ['jeeps',
#   'leave',
#   'when',
#   'full',
#   'and',
#   'are',
#   'filled',
#   'up',
#   'by',
#   'priority',
#   'order',
#   'so',
#   'the',
#   'price',
#   'is',
#   'generally',
#   'fixed'],
#  ['jeeps',
#   'to',
#   'namchi',
#   'a',
#   'nearby',
#   'tourist',
#   'destination',
#   'with',
#   'many',
#   'holy',
#   'sites',
#   'costs',
#   'around',
#   'rupees',
#   'and',
#   'takes',
#   'about',
#   'hours'],
#  ['jeeps',
#   'to',
#   'kalimpong',
#   'cost',
#   'rupees',
#   'and',
#   'are',
#   'available',
#   'from',
#   'deorali',
#   'or',
#   'mainline',
#   'bus',
#   'stand',
#   'distance',
#   'of',
#   'around',
#   'km',
#   'and',
#   'time',
#   'around',
#   'hours'],
#  ['fare',
#   'of',
#   'the',
#   'shared',
#   'cabs',
#   'is',
#   'generally',
#   'fixed',
#   'around',
#   'rs',
#   'to',
#   'gangtok',
#   'from',
#   'njp',
#   'station'],
#  ['drivers',
#   'might',
#   'try',
#   'to',
#   'charge',
#   'high',
#   'so',
#   'check',
#   'for',
#   'the',
#   'fare',
#   'with',
#   'other',
#   'cabs',
#   'before',
#   'taking',
#   'one'],
#  ['taxis',
#   'are',
#   'the',
#   'dominant',
#   'form',
#   'of',
#   'transportation',
#   'due',
#   'to',
#   'gangtoks',
#   'hilly',
#   'and',
#   'steep',
#   'roads'],
#  ['there',
#   'are',
#   'standard',
#   'charges',
#   'within',
#   'the',
#   'main',
#   'areas',
#   'rs',
#   'for',
#   'private',
#   'service',
#   'and',
#   'rs',
#   'for',
#   'shared'],
#  ['taxis', 'are', 'available', 'from', 'designated', 'taxi', 'stands'],
#  ['one',
#   'popular',
#   'day',
#   'trip',
#   'is',
#   'to',
#   'visit',
#   'lake',
#   'tsomgo',
#   'a',
#   'scenic',
#   'lake',
#   'around',
#   'km',
#   'from',
#   'gangtok',
#   'at',
#   'an',
#   'elevation',
#   'of',
#   'm',
#   'stops',
#   'along',
#   'this',
#   'day',
#   'trip',
#   'include',
#   'hanuman',
#   'tok',
#   'and',
#   'ganesh',
#   'tok',
#   'monasteries',
#   'with',
#   'views',
#   'of',
#   'kanchenjunga'],
#  ['enchey',
#   'monastery',
#   'is',
#   'a',
#   'two',
#   'hundred',
#   'year',
#   'old',
#   'monastery',
#   'in',
#   'the',
#   'nyingma',
#   'tradition',
#   'of',
#   'tibetan',
#   'buddhism',
#   'located',
#   'above',
#   'gangtok',
#   'just',
#   'off',
#   'the',
#   'road',
#   'to',
#   'lake',
#   'tsomgo'],
#  ['another',
#   'popular',
#   'day',
#   'trip',
#   'winds',
#   'around',
#   'the',
#   'valley',
#   'which',
#   'gangtok',
#   'overlooks',
#   'to',
#   'monastery',
#   'and',
#   'ranka',
#   'monastery'],
#  ['rumtek',
#   'monastery',
#   'km',
#   'from',
#   'gangtok',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'famous',
#   'things',
#   'to',
#   'see',
#   'near',
#   'gangtok'],
#  ['ranka',
#   'monastery',
#   'km',
#   'from',
#   'gangtok',
#   'is',
#   'newer',
#   'and',
#   'quieter',
#   'but',
#   'also',
#   'very',
#   'beautiful'],
#  ['nearby',
#   'ranka',
#   'monastery',
#   'is',
#   'the',
#   'kanchenjunga',
#   'tourist',
#   'complex',
#   'a',
#   'combination',
#   'hotel',
#   'and',
#   'family',
#   'amusement',
#   'park'],
#  ['these',
#   'day',
#   'trips',
#   'can',
#   'be',
#   'booked',
#   'from',
#   'travel',
#   'agencies',
#   'and',
#   'hotels'],
#  ['without',
#   'booking',
#   'jeeps',
#   'may',
#   'be',
#   'available',
#   'from',
#   'the',
#   'private',
#   'taxi',
#   'stand',
#   'a',
#   'few',
#   'minutes',
#   'downhill',
#   'from',
#   'mg',
#   'marg'],
#  ['however',
#   'most',
#   'of',
#   'these',
#   'will',
#   'be',
#   'shared',
#   'jeeps',
#   'that',
#   'are',
#   'one',
#   'way',
#   'so',
#   'it',
#   'would',
#   'be',
#   'prudent',
#   'to',
#   'inquire',
#   'ahead',
#   'of',
#   'time'],
#  ['mahatma',
#   'gandhi',
#   'marg',
#   'mg',
#   'marg',
#   'is',
#   'a',
#   'pedestrian',
#   'only',
#   'avenue',
#   'which',
#   'forms',
#   'the',
#   'main',
#   'shopping',
#   'district'],
#  ['near',
#   'the',
#   'main',
#   'entrance',
#   'of',
#   'mg',
#   'marg',
#   'is',
#   'the',
#   'tourist',
#   'information',
#   'office',
#   'and',
#   'a',
#   'taxi',
#   'stand',
#   'the',
#   'final',
#   'destination',
#   'of',
#   'many',
#   'taxis',
#   'from',
#   'other',
#   'parts',
#   'of',
#   'the',
#   'city'],
#  ['in',
#   'the',
#   'deorali',
#   'district',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'gangtok',
#   'there',
#   'is',
#   'do',
#   'drul',
#   'chorten',
#   'a',
#   'buddhist',
#   'stupa',
#   'complex',
#   'constructed',
#   'in'],
#  ['a',
#   'few',
#   'minutes',
#   'walk',
#   'down',
#   'the',
#   'hill',
#   'from',
#   'do',
#   'drul',
#   'chorten',
#   'is',
#   'the',
#   'namgyal',
#   'institute',
#   'of',
#   'tibetology',
#   'a',
#   'small',
#   'but',
#   'informative',
#   'museum',
#   'providing',
#   'a',
#   'general',
#   'introduction',
#   'of',
#   'tibetan',
#   'buddhism',
#   'using',
#   'authentic',
#   'artifacts',
#   'such',
#   'as',
#   'thankas',
#   'and',
#   'statues'],
#  ['entrance', 'fee', 'is', 'rupees'],
#  ['about',
#   'minutes',
#   'from',
#   'the',
#   'museum',
#   'is',
#   'the',
#   'gangtok',
#   'ropeway',
#   'or',
#   'damodar',
#   'ropeway',
#   'a',
#   'cable',
#   'car',
#   'which',
#   'connects',
#   'deorali',
#   'to',
#   'a',
#   'hill',
#   'above',
#   'gangtok'],
#  ['one',
#   'way',
#   'or',
#   'round',
#   'trip',
#   'cost',
#   'is',
#   'rupees',
#   'with',
#   'a',
#   'childrens',
#   'discount'],
#  ['sikkim',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'fruit',
#   'processing',
#   'and',
#   'tea',
#   'aside',
#   'from',
#   'the',
#   'local',
#   'handicraftpassion',
#   'fruit',
#   'squash',
#   'alpine',
#   'cheese',
#   'temi',
#   'tea',
#   '&',
#   'maha',
#   'gurudev',
#   'tea',
#   'are',
#   'some',
#   'of',
#   'the',
#   'local',
#   'products'],
#  ['there',
#   'are',
#   'many',
#   'great',
#   'and',
#   'cheap',
#   'places',
#   'to',
#   'eat',
#   'in',
#   'gangtok'],
#  ['parivars',
#   'on',
#   'mg',
#   'marg',
#   'down',
#   'a',
#   'short',
#   'flight',
#   'of',
#   'stairs',
#   'serves',
#   'some',
#   'of',
#   'the',
#   'best',
#   'food',
#   'in',
#   'town',
#   'and',
#   'is',
#   'very',
#   'popular',
#   'with',
#   'locals'],
#  ['parivars',
#   'on',
#   'mg',
#   'marg',
#   'down',
#   'a',
#   'short',
#   'flight',
#   'of',
#   'stairs',
#   'serves',
#   'some',
#   'of',
#   'the',
#   'best',
#   'food',
#   'in',
#   'town',
#   'and',
#   'is',
#   'very',
#   'popular',
#   'with',
#   'locals'],
#  ['quick',
#   'bite',
#   'and',
#   'numerous',
#   'other',
#   'sweet',
#   'shops',
#   'up',
#   'and',
#   'down',
#   'mg',
#   'marg',
#   'serve',
#   'up',
#   'everything',
#   'from',
#   'samosas',
#   'to',
#   'momos'],
#  ['the',
#   'roll',
#   'house',
#   'tucked',
#   'on',
#   'the',
#   'side',
#   'of',
#   'a',
#   'stairway',
#   'between',
#   'mg',
#   'marg',
#   'and',
#   'the',
#   'main',
#   'market',
#   'serves',
#   'up',
#   'veg',
#   'momos',
#   '&',
#   'hot',
#   'chapatis',
#   'roll',
#   'with',
#   'various',
#   'fillings',
#   'paneer',
#   'egg',
#   'veggies'],
#  ['this',
#   'place',
#   'is',
#   'always',
#   'packed',
#   'with',
#   'both',
#   'tourists',
#   'and',
#   'locals',
#   'and',
#   'deservedly',
#   'so'],
#  ['the',
#   'roll',
#   'house',
#   'tucked',
#   'on',
#   'the',
#   'side',
#   'of',
#   'a',
#   'stairway',
#   'between',
#   'mg',
#   'marg',
#   'and',
#   'the',
#   'main',
#   'market',
#   'serves',
#   'up',
#   'veg',
#   'momos',
#   '&',
#   'hot',
#   'chapatis',
#   'roll',
#   'with',
#   'various',
#   'fillings',
#   'paneer',
#   'egg',
#   'veggies'],
#  ['this',
#   'place',
#   'is',
#   'always',
#   'packed',
#   'with',
#   'both',
#   'tourists',
#   'and',
#   'locals',
#   'and',
#   'deservedly',
#   'so'],
#  ['thalung',
#   'mahatma',
#   'gandhi',
#   'marg',
#   'about',
#   '/',
#   'of',
#   'the',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'tourist',
#   'information',
#   'center',
#   'to',
#   'the',
#   'far',
#   'end',
#   'of',
#   'the',
#   'central',
#   'pedestrian',
#   'promenade',
#   'on',
#   'the',
#   'right',
#   'side'],
#  ['a',
#   'cultural',
#   'relic',
#   'not',
#   'to',
#   'be',
#   'missed',
#   'this',
#   'fast',
#   'food',
#   'outlet',
#   'located',
#   'in',
#   'a',
#   'wooden',
#   'hut',
#   'perhaps',
#   'the',
#   'last',
#   'traditional',
#   'building',
#   'surviving',
#   'in',
#   'the',
#   'remodelled',
#   'central',
#   'area',
#   'serves',
#   'a',
#   'rigorous',
#   'menu',
#   'consisting',
#   'of',
#   'items',
#   'beef',
#   'momos',
#   'tibetan',
#   'dumplings',
#   'and',
#   'beef',
#   'noodle',
#   'soup'],
#  ['the', 'food', 'is', 'completely', 'devoid', 'of', 'spices', 'and', 'salt'],
#  ['chili',
#   'paste',
#   'soy',
#   'sauce',
#   'and',
#   'salt',
#   'are',
#   'provided',
#   'as',
#   'side',
#   'condiments'],
#  ['the',
#   'building',
#   'is',
#   'somewhat',
#   'skewed',
#   'and',
#   'may',
#   'present',
#   'safety',
#   'hazards',
#   'but',
#   'it',
#   'appears',
#   'to',
#   'have',
#   'survived',
#   'generations',
#   'of',
#   'customers',
#   'and',
#   'the',
#   'upper',
#   'floor',
#   'offers',
#   'an',
#   'agreeable',
#   'view'],
#  ['an',
#   'antique',
#   'portrait',
#   'of',
#   'dalai',
#   'lama',
#   'xiv',
#   'around',
#   'the',
#   'age',
#   'of',
#   'graces',
#   'the',
#   'front',
#   'counter'],
#  ...]

# %%
#bigram = gensim.models.Phrases(final_articles_list_of_words)
#model_bigrams = gensim.models.Word2Vec(bigram[final_articles_list_of_words], min_count=5, size = 200)

# %%
#model_bigrams.most_similar(positive=['hong_kong'], topn=20)

# %%
bigram_mc_th = gensim.models.Phrases(final_articles_list_of_words, min_count = 15, threshold = 30)

# %%
model_bigrams_mc_th1 = gensim.models.Word2Vec(bigram_mc_th[final_articles_list_of_words], negative = 5, min_count = 15, size = 200)

# %%
model_bigrams_mc_th.most_similar(positive=['france','ecuador'], topn=20)
# Out:
# [(u'benelux', 0.7367185950279236),
#  (u'finland_france', 0.731681227684021),
#  (u'france_germany', 0.7237454056739807),
#  (u'germany_greece', 0.7166575193405151),
#  (u'estonia_finland', 0.7161133885383606),
#  (u'portugal', 0.7031844854354858),
#  (u'denmark_finland', 0.7017202377319336),
#  (u'french_guiana', 0.6969060897827148),
#  (u'andorra', 0.6953140497207642),
#  (u'canada_chile', 0.6939041018486023),
#  (u'latvia_lithuania', 0.6938678026199341),
#  (u'dominica', 0.6924014091491699),
#  (u'monaco', 0.691116213798523),
#  (u'bulgaria', 0.6907615661621094),
#  (u'spain_sweden', 0.6902792453765869),
#  (u'colombia', 0.6884804964065552),
#  (u'andean_highlands', 0.6878082752227783),
#  (u'andorra_argentina', 0.6869897246360779),
#  (u'swaziland', 0.6869431734085083),
#  (u'train__rail', 0.6835832595825195)]
