# %% [markdown]
# # WIKIVOYAGE EDA

# %%
import pandas as pd
import json
from collections import defaultdict
import unicodedata
import mistune
from bs4 import BeautifulSoup
import string
import re
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
import cPickle
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Load & Extract Articles

# %%
with open('../data/wikivoyage.json','rb') as f:
    data = json.loads(f.read())

# %% [markdown]
# ###Extract Article texts

# %%
articles = data['mediawiki']['page']

# %%
data['mediawiki'].keys()
# Out:
# [u'@xmlns',
#  u'siteinfo',
#  u'@xsi:schemaLocation',
#  u'@xml:lang',
#  u'@xmlns:xsi',
#  u'@version',
#  u'page']

# %%
data['mediawiki']['page'][200]
# Out:
# {u'id': u'266',
#  u'ns': u'0',
#  u'revision': {u'comment': u'use airport templates',
#   u'contributor': {u'id': u'113846', u'username': u'WOSlinker'},
#   u'format': u'text/x-wiki',
#   u'id': u'2508545',
#   u'model': u'wikitext',
#   u'parentid': u'2398904',
#   u'sha1': u'11lmcytyyj1mriurwb9n6l8qn8fw5ab',
#   u'text': {u'#text': u'{{pagebanner|Pagebanner default.jpg}}\n[[Image:Afandou Beach.jpg|thumb|Afandou Beach]]\n\n\'\'\'Afandou\'\'\' is on the [[Greece|Greek]] island of [[Rhodes]].  Founded in the days when pirates were ravaging the Mediterranean, it is said that the village owes its name to the place where it was built. A place that was afanto, or afando " \u0386\u03c6\u03b1\u03bd\u03c4\u03bf" which in Greek means invisible from the sea. Afandou is an attractive traditional Greek village surrounded by beautiful countryside. For a complete change of pace and scenery, the hectic resort of Faliraki is only a short distance away.\n\nAfandou mainly attracts families and couples who like to relax during the day & have a central location in Rhodes Island. It\'s one of the biggest traditional villages in Rhodes. Here you\'ll find numerous bars, cafes, taverns restaurants and clubs. The local cuisine has always been one of the strong points of hospitality and culture in Afandou.\n\n==Get in==\n\nThe main air gateway (Diagoras International Airport ({{IATA|RHO}}) is located to the southwest of Rhodes in Paradisi, Approximately 20 km distance from Afandou.\n\n==Get around==\n\n==See==\n\nPAPA OUZO - an elderly gentleman who likes to dance and drink ouzo... See him at Greek Night in Afandou...\n\n==Do==\n*\'\'\'Golf\'\'\'\n*\'\'\'Swimming and sunbathing\'\'\'\n\n==Buy==\n\nOlive Oil, seasonal fruits, souvenir.\n\n==Eat==\n\nThere are many traditional restaurants, cafeterias with snack, Gyros and Souvlaki shops. In Kolymbia you can visit a restaurant with authentic German and Austrian cuisine.\n\n==Drink==\n\nMinas\' Bar, Afandou centre. Friendly and well priced bar with plenty of entertainment.\n\n==Sleep==\n\nThere are many self-catering lodgings and hotels. Afandou is only a short distance away from Kolimbia (Kolymbia ) area. Kolimbia started to develop only a few years ago, and has managed to maintain its natural beauty also the traditional Greek Island look. Here, you will find some of the finest hotels and apartments on the island. There are plenty of traditional Greek taverns and restaurants, clubs, cafes and they are most favorite amongst the local people.\n\nKolympus View Villas [http://www.kolympusviewvillas.co.uk/]. Located on the outskirts of Afandou, nestled within a peaceful countryside setting, six modern and luxurious villas enjoy scenic mountain and sea views, whilst only being a 15 minute walk from the Afandou centre.\n\nA quite place to stay is Olive Garden Houses [http://www.olivegardenhouses.com/] a central accommodation between the golf course, the beach and Afandou City.\n\n==Go next==\n\n\'\'\'Tsampika beach\'\'\', a 10 minute drive south from Afandou. Enjoy a nice winding drive down from the main road to the long sandy beach surrounded by the rocky scenic hills. Turquoise waters and golden sands create a beautiful scene, ideal to relax and enjoy the sun. Water sports are available as well as a mini-market and several small snack and drinks bars.\n\n*[[Faliraki]] area and its water park.\n\n{{outlinecity}}\n\n{{geo|36.3000|28.1667}}\n\n{{IsPartOf|Rhodes}}\n\n[[wikipedia:Afantou]]',
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2014-01-18T13:40:43Z'},
#  u'title': u'Afandou'}

# %% [markdown]
# ### Save Articles by Titles

# %%
def rmdiacritics(char):
    '''
    Return the base character of char, by "removing" any
    diacritics like accents or curls and strokes and the like.
    '''
    try:
        desc = unicodedata.name(unicode(char))
        cutoff = desc.find(' WITH ')
        if cutoff != -1:
            desc = desc[:cutoff]
        result = unicodedata.lookup(desc)
    except ValueError:
        result = char
    except KeyError:
        result = char
    return result

def remove_accents(input_str):
    nkfd_form = unicodedata.normalize('NFKD', input_str)
    value = u"".join([rmdiacritics(c) for c in nkfd_form])
    value = unicodedata.normalize('NFKD', value).encode('ascii','ignore')
    return value

# Create dictionary of titles that have concatenated names as the values. For example: San Francisco: San_Francisco
def clean_word(title):
    
    value = remove_accents(title)

    value = value.replace(' ','_')

    return value

# %%
articles_dict = {}
for article in articles:
    # Lets strip the accents
    title = article['title']
    title = clean_word(title)
    articles_dict[title] = article

# %%
articles_dict.keys()[:10]
# Out:
# ['',
#  'Sparta_Wisconsin',
#  'Ward_County_(North_Dakota)',
#  'Chama_(district)',
#  'Szczecin',
#  'Carlsbad_(New_Mexico)',
#  'Havelock_island',
#  'Rugia',
#  'North_Shore_(New_Zealand)/Torbay',
#  'Nampa']

# %% [markdown]
# __You can see that some articles are files, categories ,etc with : in their names.
# Lets see how many of these there are.__

# %%
junk_articles_dict = defaultdict(int)
for article in articles:
    title = article['title']
    if ':' in title:
        junk_articles_dict[title.split(':')[0]] += 1

print len(junk_articles_dict)
junk_articles_dict
# Out:
# 11
# defaultdict(<type 'int'>, {u'Category': 4561, u'Itinerary': 1, u'General/Wikivoyage': 1, u'MediaWiki': 142, u'File': 816, u'Poland': 1, u'La Manzanilla': 1, u'Module': 23, u'Wikivoyage': 1561, u'Template': 1043, u'Help': 8})

# %% [markdown]
# __There are a lot of special type articles. Let's actually take a look at the content to see if they are useful.__

# %%
special_articles_dict = defaultdict(list)
for article in articles:
    title = article['title']
    if ':' in title:
        if len(special_articles_dict[title.split(':')[0]]) < 5:
            special_articles_dict[title.split(':')[0]].append(article) 

print len(special_articles_dict)
special_articles_dict.keys()
# Out:
# 11
# [u'Category',
#  u'Itinerary',
#  u'General/Wikivoyage',
#  u'MediaWiki',
#  u'File',
#  u'Poland',
#  u'La Manzanilla',
#  u'Module',
#  u'Wikivoyage',
#  u'Template',
#  u'Help']

# %% [markdown]
# __Let's take a look at two most common special type articles__

# %%
special_articles_dict['MediaWiki']
# Out:
# [{u'id': u'69005',
#   u'ns': u'8',
#   u'revision': {u'comment': u'+arytrekking\\.com',
#    u'contributor': {u'id': u'36420', u'username': u'Ikan Kekek'},
#    u'format': u'text/x-wiki',
#    u'id': u'2796508',
#    u'model': u'wikitext',
#    u'parentid': u'2781066',
#    u'sha1': u'l0bq8j7kgs7ttk8ngewi2h36byn4q61',
#    u'text': {u'#text': u'#{{shortcut|[[Spam]]<br>[[Blacklist]]}} \n #{{notice|\'\'\'DO NOT\'\'\' remove any URL or pattern from this list without first gaining consensus on [[{{TALKSPACE}}:{{PAGENAME}}]]. In addition to being used to block automated spam attacks this list is also occasionally used to stop persistent abuse of the [[Project:External links]] and [[Project:Don\'t tout]] policies.  Please add violators of the external links policy to this page \'\'\'ONLY\'\'\' after first trying to educate the user about why the link is inappropriate.  When adding external link violators to this page please explain the reason for the addition on [[{{TALKSPACE}}:{{PAGENAME}}]].}}\n\n # This is the local blacklist for Wiki spam URLs for Wikivoyage. It\'s used\n # by the \'\'\'[[Project:spam filter|spam filter]]\'\'\' to block contributions that use these URLs.\n #\n # To add a URL to the spam filter list just add the spam URL including\n # everything \'\'\'after\'\'\' the "http://" and \'\'\'before\'\'\' the first "/" to the list. \n #\n # In addition, the spam filter uses what are called regular expressions, so\n # special characters such as periods need to be escaped by putting a "\\" in\n # front of them.\n #\n # For example, <nowiki>"http://spam.spammer.net/foo.html"</nowiki> would be added as\n # "spam\\.spammer\\.net".  Notice that we don\'t include the "http://" nor\n # anything after the first "/" following the "http://" so "/foo.html" should\n # not be added.\n #\n # One caveat is that if the entire domain seems to be used only for spam we\n # don\'t bother to worry about sub-domains and in the example above would just\n # list "spammer\\.net".  \n #\n # For the spam filter to work properly you must indent one (1) space. It\n # helps everyone stay sane and find things better if the list is in\n # alphabetical order.\n #\n # External URLs matching this list will be blocked when added to a page.\n # This list affects only this wiki; refer also to the global blacklist.\n # For documentation see http://www.mediawiki.org/wiki/Extension:SpamBlacklist\n #\n # Syntax is as follows:\n #   * Everything from a "#" character to the end of the line is a comment\n #   * Every non-blank line is a regex fragment which will only match hosts inside URLs\n\n (Yangshuo).*(Julie)\n ((t|T)op.?level.?tour)\n 1cheaphotels\\.com\n 1carrental\\.org\n a-prague\\.com\n a2zrooms\\.com\n aaalimos\n abetterstay\\.com\n activetravelvietnam\\.com\n adollarhost\\.com\n adriatic-express\\.com\n africabusiness\\.com\n www\\.africanbluetours\\.com\n aiguarentacar\\.it\n air520\\.com\n airline-tickets\\.kwik\\.to\n airporttaxicabservices\\.com\n al-sufarahotel\\.com\n alemi2424\\.blogspot\\.com\n alemi24@gmail\\.com\n alfamahouse\\.com\n alleurohotels\\.com\n all-hotels-motels\\.com\n allmovieshere\\.servik\\.com\n amorpensionhouse\\.webs\\.com \n anycarhire\\.com\n apartmentsabroad\\.com\n apartmentsholiday\\.com\n apnabus\\.in\n archsanblas\\.tripod\\.com \n arguscarhire\\.com\n argusrentals\\.com\n aroundworld\\.in\\.ua\n arytrekking\\.com\n artofafricasafari\\.com\n auto-europe\\.co\n ayachtcharterathens\\.com\n ayachtcharterbodrum\\.com\n ayachtchartergreece\\.com\n ayachtcharteribiza\\.com\n ayachtcharteritaly\\.com\n ayachtchartermarmaris\\.com\n ayachtcharterspain\\.com\n ayachtcharterturkey\\.com\n azul-barcelona\\.com\n baligotours\\.com\n balipropertyconsultancy\\.com\n bandarbantours\\.com\n www\\.barcelonacheckin\\.com\n barcelonapoint\\.com\n bargains-hunter\\.blogspot\\.com\n baylodging\\.com\n bbvaticanstpeter\\.com\n bedandbreakfastmare\\.it\n begin_of_the_skype_highlighting\n benusang\n bh-hotels\\.com\n bienngoccruise\\.com\n bluesardiniaholidays\\.com\n www\\.booking\\.com\n boracay\\.cc\n boracay\\.org\\.ph\n boracay-packages\\.com\n boracay4less\\.com\n boracaypackages\\.spaces\\.live\\.com \n boracaypackages\\.net\n boracayregency\\.com\n boracayvacationpackages\\.com\n borneotourgigant\\.com\n budget\\.co\\.uk\n budpocketguide\\.com\n but ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-05-26T10:04:51Z'},
#   u'title': u'MediaWiki:Spam-blacklist'},
#  {u'id': u'69006',
#   u'ns': u'8',
#   u'revision': {u'comment': u'this is a legitimate listing that should be allowed',
#    u'contributor': {u'id': u'109373', u'username': u'Texugo'},
#    u'format': u'text/x-wiki',
#    u'id': u'2560091',
#    u'model': u'wikitext',
#    u'parentid': u'2389682',
#    u'sha1': u'scyypemwlpv7aq9jnukfart07dr1y5o',
#    u'text': {u'#text': u"#This is the local whitelist for URLs that are being incorrectly blocked by the [[Project:Spam filter]]. \n #Note that this list will have no effect on patterns being blocked by the [[Project:Local spam blacklist]], but it will unblock patterns that are being blocked by the http://wikivoyage.org/bannedcontent.txt list. \n #Note that the whitelist pattern must ''exactly'' match the pattern from the banned content list in order to be unblocked.\n\n #To add URLs or URL fragments to this list, add them in in alphabetical order between the pre tags, and indent one (1) space. \n #You should also leave a note on the [[Project:Local spam whitelist|talk page]] indicating why the URL is valid.\n\n#<pre>\n \\w+\\.sh\\.cn\n 00100roma\\.it\n aladdincasino\\.com\n albury-wodonga\\.com\n almaty-bus\\.narod\\.ru\n almaty-tramway\\.narod\\.ru\n almaty-trolleybus\\.narod\\.ru\n biscuit-palace\\.com\n casinovenezia\\.it\n chinabeijinghotel\\.com\\.cn\n china\\.com\n cuc\\.edu\\.cn\n cyu\\.edu\\.cn\n donga\\.com\n expo2010china\\.com\n freewebs\\.com\n fremontcasino\\.com\n gb\\.com\n geocities\\.com\n goldcoastcasino\\.com\n joes\\.com\n luggagestoregallery\\.org\n mainstreetcasino\\.com\n milfordplaza\\.com\n milford\\.com\n Milford\n nouveaucasino\\.net\n nynyhotelcasino\\.com\n pharmacymuseum\\.org\n pralniawodnik\\.republika\\.pl\n premiumflats\\.com\n reefcasino\\.com\\.au\n stbishoy\\.8k\\.com\n u-tokyo\\.ac\\.jp\n wikivoyage\\.org\n ya\\.ru\n#</pre>\n\n#{{WikivoyageDoc|administration}}\n\n#[[ru:Project:Spam whitelist]]\n#[[sv:Project:L\xe4nkar som inte skall blockeras]]",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2014-03-31T11:28:59Z'},
#   u'title': u'MediaWiki:Spam-whitelist'},
#  {u'id': u'78090',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Restore upgrade deletion problem (Import from wikitravel.org/en)',
#    u'contributor': {u'id': u'81383', u'username': u'EvanProdromou'},
#    u'format': u'text/x-wiki',
#    u'id': u'1850421',
#    u'model': u'wikitext',
#    u'sha1': u'rvpy29ko1t8vosvmt168nkph5xpneuf',
#    u'text': {u'#text': u'About Docents', u'@xml:space': u'preserve'},
#    u'timestamp': u'2007-07-02T13:02:37Z'},
#   u'title': u'MediaWiki:Aboutdocent'},
#  {u'id': u'78091',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879147',
#    u'model': u'wikitext',
#    u'parentid': u'1850423',
#    u'sha1': u'd5kvojs0geevrb5gt4nyso31trh02v7',
#    u'text': {u'#text': u'Wikivoyage:What is a docent?',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Aboutdocentpage'},
#  {u'id': u'78092',
#   u'ns': u'8',
#   u'revision': {u'comment': u'Some post import adaptions.',
#    u'contributor': {u'id': u'21', u'username': u'(WV-en) ImportBot'},
#    u'format': u'text/x-wiki',
#    u'id': u'1879148',
#    u'model': u'wikitext',
#    u'parentid': u'1850424',
#    u'sha1': u'ofn3tpgcinir20ysedeykrruclghdm8',
#    u'text': {u'#text': u'Combined display of all available logs of {{SITENAME}}.\nYou can narrow down the view by selecting a log type, the user name, or the affected page.\n\n\n[[de:Special:Log]]\n\n[[es:Special:Log]]\n[[fi:Special:Log]]\n[[fr:Special:Log]]\n\n\n[[hu:Special:Log]]\n[[it:Special:Log]]\n[[ja:Special:Log]]\n[[nl:Special:Log]]\n[[pl:Special:Log]]\n[[pt:Special:Log]]\n[[ro:Special:Log]]\n[[ru:Special:Log]]\n[[sv:Special:Log]]',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-08-30T11:16:52Z'},
#   u'title': u'MediaWiki:Alllogstext'}]

# %%
special_articles_dict['Wikivoyage']
# Out:
# [{u'id': u'1539',
#   u'ns': u'4',
#   u'revision': {u'comment': u'isPartOf',
#    u'contributor': {u'id': u'1844', u'username': u'Globe-trotter'},
#    u'format': u'text/x-wiki',
#    u'id': u'2043579',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'1923444',
#    u'sha1': u'q2bedim1zidlfvjh6qy4zo6xf076gon',
#    u'text': {u'#text': u'{{joke}}\n\n\'\'\'Arial\'\'\' (Goudy: \'\'Helvetica\'\'), on [[Wikivoyage:Joke articles/Lower Caisse|Lower Caisse]], is a smaller and quieter town than hurly-burly [[Wikivoyage:Joke articles/Bodoni|Bodoni]], but travellers will get a chance to experience the \'\'real\'\' [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]] on a visit to this town.\n\nFounded in the 19th century by a colony of Swiss Utopians fleeing persecution in their own country, Arial has a Nordic look with somewhat more steeply sloped tin roofs to the buildings. The city is worth visiting for its period architecture and its white spaces. \n\n==Get in==\n===By parachute===\nUS navy aircraft regularly overfly the city. If you hitch a ride with them, you can drop in. This is by far the most convenient way of entering the city. \n\n===By helicopter===\nHelicopters can be hired from Poor Richard in [[Wikivoyage:Joke articles/Port Clarendon|Port Clarendon]]. As there is no helipad, you will have to \'\'\'rappel down\'\'\' once you reach your destination.\n\n==Get around==\n\n==See==\n\n[[Image:MissionSanJoseCA.LYH.jpg|right|thumb|The Spanish Mission is old.]]\n* \'\'\'Mission San Serriffe\'\'\'.  The oldest building in the country, the mission was built during the brief and ill-fated Spanish colonization period of the country.  The Mission\'s "leaning" attitude is one of the few remaining examples in the world of the "Italic Style" popular in Spain during the early 1500s. Islanders often come here for shelter during thunderstorms to pray for a blue skies to return.  Sometimes their prayers are answered, particularly during years when the El Ni\xf1o weather pattern is operating.\n\n==Do==\n\n* \'\'\'Pray for blue skies\'\'\' with the indigenous population wherever you may find yourself during a downpour.  It\'s a great way to immerse yourself in the local culture as this is one of the most popular pastimes on the island.\n* \'\'\'Jump\'\'\' Once a year on 31st June, you can participate in the Mission Jump. This bungee jump takes places off the Mission San Serriffe. Though you should beware of Rod Transparent objects, as they have caused problems in the past.\n\n==Buy==\n\n==Eat==\n*Aharoni is the pasta delicacy of the area, while bolder travellers may like to try the famous Magneto ice cream.\n\n==Drink==\n*Should you ever find yourself out and about Arial, completely thirsty and in need of a drink, visit the newly built pub, the Parchment.\n\n==Sleep==\n\n==Go next==\n\n{{joke}}\n{{isPartOf|Wikivoyage:Joke articles/Lower_Caisse}}',
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2012-12-14T17:35:40Z'},
#   u'title': u'Wikivoyage:Joke articles/Arial'},
#  {u'id': u'1888',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Conversion of 5 legacy XML listings to [[Template:Listing]] per [[Wikivoyage talk:Listings#Tags to templates]]',
#    u'contributor': {u'id': u'210638', u'username': u'Wrh2Bot'},
#    u'format': u'text/x-wiki',
#    u'id': u'2316040',
#    u'minor': None,
#    u'model': u'wikitext',
#    u'parentid': u'2192469',
#    u'sha1': u'm3sb7wodgdaxbns7rkpnw1tnq5vweal',
#    u'text': {u'#text': u'{{joke}}\n\n[[Image:Kelp forest on high profile reef P9041231.JPG|thumb|300px|Another day in Atlantis]]\n\n\'\'\'Atlantis\'\'\' is in the [[Islands of the Atlantic Ocean|Atlantic Ocean]]. Literally.\n\n==Regions==\n\n==Cities==\n* \'\'\'[[Bensalem]]\'\'\' - the largest city, founded by [[:WikiPedia:New Atlantis|Sir Francis Bacon]]. The sign says the city is where "generosity and enlightenment, dignity and splendour, piety and public spirit" are the norms of the local residents. It\'s a load of crock. \'\'\'Salomon\'s House\'\'\' is worth a visit, though.\n\n==Other destinations==\n\n==Understand==\n[[Image:Athanasius Kircher\'s Atlantis.gif|thumb|250px|Map of Atlantis, however, it might not be up to date]]\nAtlantis is a unique destination on the bottom of the Atlantic Ocean. It is governed by President Poseidon.\n\n===History===\nAtlantis allegedly sunk to the bottom of the ocean when the classified [[:WikiPedia:Eureka_(word)#Archimedes|Eureka!]]-project led by Archimedes went horribly wrong. \nIt is also <strike>suspected</strike> rumored that the [[:Wikipedia:New World Order (conspiracy theory)|New World Order]] had something to do with that event. Among the first visitors was the Greek philosopher Plato.\n\n==Talk==\nThe official language is [[Greek phrasebook|Ancient Greek]], but major world languages are spoken in establishments aimed at tourists.\n\n==Get in==\n{{VisaRestriction|[[Wikivoyage:Joke articles/Hell (Hades)|Hell]] blocks passports containing stamps or visas from Atlantis. Relations between Hades (Dictator of Hell) and President Poseidon have been strained after the [[:Wikipedia:The Lightning Thief|lightning bolt theft incident]]. If you plan to travel to [[Wikivoyage:Joke articles/Hell (Hades)|Hell]] after visiting Atlantis, you must get a second passport.}}\n[[Image:Yonaguni Ruins Scuba.jpg|thumb|300px|Diving offers a more intimate entrance into Atlantis]]\nTo get in to Atlantis you will need a valid visa and [[diving]] equipment. The most difficult part is knowing where to go, as Atlantis is not marked on regular maps.\n\n===By submarine===\nSome submarines are known to transport visitors to and from Atlantis. Prices are, however in the same class with tickets to [[space]].\n\n===By plane===\n\'\'\'Atlantis International Airport\'\'\' is connected by regular flights from [[Bermuda]] operated by Triangle Airlines and Oceanic Airlines. The return ticket will, however be virtually impossible to get. There are also non-stop flights from [[Mount Olympus]].\n\n===By train===\n\'\'\'Atlantis Train Station\'\'\' is served by 5000mph maglev trains coming from [[New York City|New York]] and [[London]] via the  [[:Wikipedia:Transatlantic tunnel|Transatlantic Tunnel]]. From [[London#By_train|London\'s Kings Cross Station]], take the train from [[:Wikipedia:Platform 9 \xbe|Platform 9 \xbe]]. From [[New_York_City#By_train|New York Grand Central Station]], trains leave from the [[:Wikipedia:Grand_Central_Station#Layout|"secret" sub-basement known as M42]].\n\n===By diving===\nThe backpacker\'s alternative - cheap and reliable. If you take your own sail boat it\'ll be very cheap.\n\n===By teleport===\nCheap as free! Just close your eyes and wish really hard. Next thing you know you are there!\n\n===By ruby slippers===\nClose your eyes, click your heels. Then just keep saying "There is no place like home, there\'s no place like home..."\n\n==Get around==\n===By subway===\n[[File:NYC Subway Atlantic Ave Station.jpg|thumb|200px|Atlantic Avenue Station: The Atlantis Subway System suffers from neglect and mismanagement.]]\nThousands of years ago, Atlantis was renowned for its cutting-edge mass transit system, but centuries of neglect, mismanagement, and extensive use have taken their toll. Vehicles are noisy and break down on a regular basis, the interiors are crowded, and the drivers can be very rude. On top of that, with recent budget cuts the fares keep rising. But the system is extensive and will ev ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-06-24T23:51:18Z'},
#   u'title': u'Wikivoyage:Joke articles/Atlantis'},
#  {u'id': u'4134',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* See */ Replace broken image',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420760',
#    u'model': u'wikitext',
#    u'parentid': u'2174923',
#    u'sha1': u'c4aq6msdqrmy50tkg11f7i7r4dyalbe',
#    u'text': {u'#text': u"{{joke}}\n\n'''Bodoni''' is [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]]'s tropical capital. With its heritage of Brutalist concrete architecture intermixed with the spices and mayhem of the South Seas, Bodoni presents a bold face to \nthe world and to the curious traveler.\n\n[[Image:Unarizaki PineappleHouse.JPG|thumb|400px|The Pineapple House, a local landmark]]\n\n==Understand==\n\n\n\n==Get in==\n\n===By plane===\n\n'''National Hero Antonio Bourgeois International Airport''' (IATA code: '''NHB''') is located just outside the city limits.  It's a bit too far to walk, so consider hiring a donqtuque to take you there.\n\n===By car===\n\nIf you want to get here by car, your car's wheels must be strong enough because there are many sharp stones on the city streets.\n\n===By bus===\n\nThere is only one bus service every day connecting the city hall and the mayor's official residence.\n\n===By boat===\n\nYour boat must be strong enough and not attract the sharks.\n\n==Get around==\nBecause of the small number of taxis (the only 4 licences are held by the President's sons), it is very difficult to catch one. Fights are very common and are encouraged by government as a way to solve disputes. The last man standing has the right to use the taxi. Unfortunately two of President's sons have a passion for gambling so don't be surprised if they lose the taxi at it while you're fighting.\n\n==See==\n\n* '''Pilcrow Palace''', 61 Avenida do Plenk.  An architectural landmark shaped like the letter P, painted in imposing shades of gray and constructed on the order of General Pica.  Now open to the public, sights inside include the mirror-lined '''Combat Duty Bedroom of the General''' and the grim '''Disco Inferno''', where political dissidents were subjected to reruns of ''Saturday Night Fever'' until they broke down and confessed.  Open alternate Tuesdays from 9:45 to 10:30 AM, admission 200 dR.\n* '''Hai Phen''', avenida do Bahia Tilde (''go the end of the trolley line, then join up with the beginning''). Bodoni's Little Chinatown, the Hai Phen district features many different kinds of spicey and ginger-scented swarfega prepared in Chinese style. Legal and gray-market CDs and DVDs are available, but be careful: many are region 8 encoded and dubbed over in Goudy.\n\n==Do==\n*'''Bodoni Theatre of the Incomprehensible''', 15 Avenida du Enigma. Actors perform on a giant scrabble board while the audience plays scrabble. Words from any of San Serriffe's many languages are allowed. As each word forms, the actors weave it into the story and continue the performance. The performance is known as a '''Play on Words'''. Tickets 125 dRn. (''Includes a complementary bottle of Plenque'')\n\n==Learn==\n\n==Work==\n\n==Buy==\n[[Image:Chipata_Market_Beans.JPG|thumb|Shopping at the Bean Market]]\n\n* '''Bean Market''' (''Mercado do Feij\xe3o'').  Popular among souvenir-shoppers, this market offers a wide selection of white beans, violet beans, purple beans and, on festive occasions, small dried fish.  Haggling is necessary.  It's advisable to visit the market in the morning, as in the afternoon the merchants' lunches start to digest and air quality tends to deteriorate.\n\n* '''Pineapple House''', 42 Calle do Anan\xe1s.  This distinctively-shaped building is a famed Bodonian landmark and nearly all tourists are dragged here by touts and/or the police at least twice per day.  Once inside, you have the choice of purchasing pineapple products like mashed pineapple, pineapple jam, pineapple wine (also available as an enema), etc.  Free entry, but getting out tends to be expensive.\n\n==Eat==\nBodoni provides an excellent opportunity to take a break from a monotonous diet of mashed swarfega and try everybody's favorite root vegetable in stewed or deep-fried form instead.  There are persistent rumors of turnips and even the occasional potato being available on the black market and served in private rooms at high-end restaurants, bu ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:49Z'},
#   u'title': u'Wikivoyage:Joke articles/Bodoni'},
#  {u'id': u'7878',
#   u'ns': u'4',
#   u'revision': {u'comment': u'Replace broken images',
#    u'contributor': {u'id': u'1812', u'username': u'AlasdairW'},
#    u'format': u'text/x-wiki',
#    u'id': u'2420759',
#    u'model': u'wikitext',
#    u'parentid': u'2043584',
#    u'sha1': u'fomf53acdni87my07vrc51p34nmkh0g',
#    u'text': {u'#text': u"{{joke}}\n\n[[File:Walking through the rocks to Lannacombe Beach - geograph.org.uk - 563727.jpg|thumb|400px|Looking for sand at Cocobanana Beach]]\n\n'''COCOBANANA BEACH''' is in [[Wikivoyage:Joke articles/Upper Caisse|Upper Caisse]], [[Wikivoyage:Joke articles/San Serriffe|San Serriffe]].\n\n==Get in==\nThe only safest way to get here is by jeep. You can try another way by sea but beware of the sharks because many sharks want to be your friends.\n\n==Get around==\nYou can see shark palace in the bottom of the sea, but you have to have permission from immigration office.\n\n==See==\nCocobanana Beach is, of course, famed for '''its vast expanse of white sand''' and its bevy of Serriffean lovelies wearing only '''Flong thongs''', a garment prepared from coconut husk that can also be used to remove pieces of swarfega from between your teeth.  It should, however, be noted that the Flong thongs are traditionally worn only by men who have passed the demanding initiation rites of the '''Very Brotherly Fraternity of the Homoglyph''', and women usually opt for burlap sacks, or go naked, instead.\n\nCocobanana has suffered somewhat from development recently, with some residents objecting that the '''giant boulders of rock''' dumped from the nearby quarry onto the beach detract from the scenic beauty.  However, protests have quieted down after mine management, yielding to public pressure in a sign of the times, gave residents the democratic option of having the boulders quarried to either the beach or on top of their huts.\n\n==Do==\nYou can be sharks's friend by visiting them in their palace.\n\n==Buy==\nThere is only one mall around here selling cattles.\n\n==Eat==\nThere is no restaurant here, so you have to fish by yourself.\n\n==Drink==\nYou can drink water from the wells.\n\n==Sleep==\n[[File:Sijungho Rest House. W\u014fnsan Beach, North Korea.jpg|thumb|240px|Honeymoon Hideaway Suite at the Cocobanana Beach Resort]]\nThere is only one hotel around here, but beware of the mosquitos.\n\n===Splurge===\n* '''Cocobanana Beach Resort''', on National Highway 1, [http://cocobanana.com/].  Visitors to Cocobanana Beach Resort never cease to be amazed by its stunning appearance and the level of services available, and often leave with indelible memories of their experience.  For easy access, National Highway 1 runs right through the resort, and complimentary donkey carts to the beach (17 km away) are provided weekly.\n\n==Stay safe==\nBeware of locals with large sacks over their shoulder contacting you about purchase of foreign tubers. Remember: '''possession of foreign vegetables is a crime'''. Also, some of the local law enforcement officials pose as tuber salesmen to trap foreign visitors. If you are a victim of one of these traps, a payment offer 2,000dNr will normally allow you to go on your way (and you can keep the tubers).\n\n==Go next==\nIf you want to get out fast from this place just call 911.\n{{isPartOf|Wikivoyage:Joke articles/Upper_Caisse}}\n{{joke}}",
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2013-09-19T20:21:04Z'},
#   u'title': u'Wikivoyage:Joke articles/Cocobanana Beach'},
#  {u'id': u'8213',
#   u'ns': u'4',
#   u'revision': {u'comment': u'/* Things for users to know */',
#    u'contributor': {u'id': u'188833', u'username': u'GZWDer'},
#    u'format': u'text/x-wiki',
#    u'id': u'2711166',
#    u'model': u'wikitext',
#    u'parentid': u'2691276',
#    u'sha1': u'tcjjs7wkqhav49aabwumx9rlcsr5lgm',
#    u'text': {u'#text': u'{{nutshell|All written contributions to this project are automatically licenced under CC BY-SA 3.0. All files uploaded to the project must be licenced under CC BY-SA or a compatible licence.}}\n{{shortcut|[[WV:Copyvio]]}}\n[[Image:The Universal Declaration of Wikivoyage Copyleft.png|thumb|370px|The Universal License of Our Wiki]]\n\nWikivoyage uses a \'\'\'copyleft\'\'\' license for all content on the website. \'\'\'Anyone can use\'\'\' Wikivoyage content according to the terms of the \'\'\'Creative Commons Attribution-ShareAlike\'\'\' license. And \'\'\'anyone can contribute\'\'\' their own or other people\'s content, as long as the work is their own or available under a compatible license.\n\nIt is very important that you \'\'\'understand how copyleft works before you contribute to Wikivoyage\'\'\'.  If you find your work reused by someone else in a manner that you didn\'t consider, or if you stop using Wikivoyage for any reason, it is not possible to change the license for the work you have done. Although you always own the copyright in your work, that does not give you the right to change its license retrospectively.\n\n==Licensing==\n\n\'\'If this seems confusing, <big>\'\'\'skip down to [[#Frequently asked questions|the FAQ]].\'\'\'</big>\'\'\n\nAll \'\'\'written contributions\'\'\' to Wikivoyage are and must be licensed under Creative Commons Attribution-ShareAlike 3.0 ([http://creativecommons.org/licenses/by-sa/3.0/legalcode CC-by-SA 3.0]) or a compatible license (e.g., Public Domain, CC-by-SA any, dual CC-by-SA/GFDL any, etc.). Consequently, all redistributed and derivative works of Wikivoyage text must also be licensed as CC-by-SA 3.0.\n\n\'\'\'Images\'\'\' almost always must be uploaded to [[:Commons:Main page|Wikimedia Commons]], and images\' individual licensing is described on individual image pages. Any images hosted locally on Wikivoyage comply with our [[Wikivoyage:Non-free content]], meaning that they do have a license compatible with our copyleft, but are derivative works of something \'\'not\'\' free, like a work of art. As with text contributions, all files uploaded here must have a license that allows derivative works and commercial re-use (usually CC-by or CC-by-SA, never CC-No Derivatives or CC-Non-Commercial)\u2014see [[Wikivoyage:Non-free content#Exemption Doctrine Policy]] for more information.\n\nAll redistributed and derivative works including Wikivoyage images and other files must provide file-specific attribution and licensing information, available on the individual file page.\n\n==Things for users to know==\n\n\'\'\'Copyleft\'\'\' means that every single author, editor, illustrator, mapmaker, factchecker and photographer who puts their work into Wikivoyage gives you the right to read, copy, print, save, download, read aloud, project, modify, email, distribute, sell, photocopy and correct their work however you want to.\n\nThe only restrictions are that:\n* \'\'if you distribute it, or derive new work from it\'\'\n** you must give \'\'\'attribution\'\'\' to the creators\n** you must retain the work and any derivative works \'\'\'under the same licensing\'\'\'.\n\n[[Image:Cc-by new.svg|thumb|150px|Attribution]]\n\nIn other words, we give you practically every freedom within the boundaries of the law to use the information in Wikivoyage, except the freedom to take that freedom away from others.\n\nThe license we use is the \'\'\'Attribution-ShareAlike\'\'\' license. It\'s a piece of legal documentation created by the great people at [http://www.creativecommons.org/ Creative Commons] that basically says the same thing as above: give Wikivoyagers credit for their work, and share with other people.\n\nIf you want you can read the [http://creativecommons.org/licenses/by-sa/3.0/legalcode full text of the Attribution-ShareAlike 3.0 license]. For the purposes of the License, a \'\'Work\'\' is the formatted text that makes up a single Wikivoyage article. Each image individually is ...
#     u'@xml:space': u'preserve'},
#    u'timestamp': u'2015-01-09T05:07:38Z'},
#   u'title': u'Wikivoyage:Copyleft'}]

# %% [markdown]
# __These special articles are not actual travel guide articles so I will create a new dictionary without them.__

# %%
# articles without :'s in their titles
articles_dict = {}
for article in articles:
    # Lets strip the accents using unicodedata
        # Lets strip the accents
    title = article['title']
    title = clean_word(title)
    
    if ':' not in title:
        articles_dict[title] = article

print len(articles_dict)
articles_dict[articles_dict.keys()[1]]
# Out:
# 42674
# {u'id': u'33833',
#  u'ns': u'0',
#  u'redirect': {u'@title': u'Sparta (Wisconsin)'},
#  u'revision': {u'comment': u'[[Sparta Wisconsin]] moved to [[Sparta (Wisconsin)]]: +[[Project:Article naming conventions]] (Import from wikitravel.org/en)',
#   u'contributor': {u'id': u'229', u'username': u'Wrh2'},
#   u'format': u'text/x-wiki',
#   u'id': u'1369491',
#   u'model': u'wikitext',
#   u'sha1': u'ckl4ahtdgcj9jjrkw2w0kwglvlv0kb5',
#   u'text': {u'#text': u'#REDIRECT [[Sparta (Wisconsin)]]',
#    u'@xml:space': u'preserve'},
#   u'timestamp': u'2006-11-20T21:02:49Z'},
#  u'title': u'Sparta Wisconsin'}

# %% [markdown]
# ### Now that we have a dictionary of travel guide articles, lets check out the article lenghts.

# %%
article_lengths_dict = {}
for key, value in articles_dict.iteritems():
    article_length = len(value['revision']['text']['#text'])
    article_lengths_dict[key] = article_length

article_lengths_dict
# Out:
# {'': 20,
#  'Sparta_Wisconsin': 32,
#  'St_Clair_Shores': 30,
#  'Chama_(district)': 28,
#  'Szczecin': 33999,
#  'Carlsbad_(New_Mexico)': 6381,
#  'Havelock_island': 29,
#  'Rugia': 11293,
#  'North_Shore_(New_Zealand)/Torbay': 20,
#  'Nampa': 7084,
#  'Mehedinti_County': 21,
#  'Sao_Paulo/Brooklin_and_Campo_Belo': 33,
#  'Fazenda_Nova': 451,
#  'Bass_Strait_Islands': 599,
#  'Fulda': 9523,
#  'Tokyo/Meguro': 13788,
#  'Eure': 28,
#  'Moovattupuzha': 26,
#  'Gravesend': 1874,
#  'Caen': 5997,
#  'Nauvoo_(Illinois)': 20,
#  'Catalan_Phrasebook': 32,
#  'Gwangalli': 26,
#  'Malabon': 1082,
#  'Southeastern_Massachusetts': 37,
#  'Hikone': 7609,
#  'Upper_Cape': 1161,
#  'Canoeing_The_San_Marcos': 43,
#  'Kearney': 20,
#  'Phetchabun_(province)': 24,
#  'Mokhotlong': 1467,
#  'Loei': 7551,
#  'South_Hollandic_Islands': 37,
#  'Loen': 19,
#  'Bago_(Myanmar)': 9294,
#  'Pergamon': 21,
#  'Baitadi_(district)': 21,
#  'Lake_Manyara_National_Park': 852,
#  'Olalla_(Washington)': 14489,
#  'Finland_in_ten_days_by_car': 17182,
#  'Cahir': 1378,
#  'Tremont_(Maine)': 2986,
#  'Garamba_National_Park': 3614,
#  'George_Town_(Malaysia)': 74080,
#  'Ballina': 366,
#  'Latgale': 1458,
#  'United_Nations_headquarters': 28,
#  'Gardner_(North_Dakota)': 19,
#  'Pampa': 12355,
#  'Miami_travel_tips': 19,
#  'Ban_Sok_Noi': 27,
#  'Gangtok': 20410,
#  'Lucknow': 32642,
#  'Rio_de_Janeiro_(city)/Zona_Norte': 39,
#  'Migjorn_de_Mallorca': 2258,
#  'Kiyosato_plateau': 30,
#  'Kilimanjaro': 31,
#  'Shahrisabz': 25,
#  'Hamilton': 1086,
#  'Kaokoland': 6524,
#  'East_Windsor_(Connecticut)': 1230,
#  'Caoling_Historic_Trail': 38,
#  'Fridley': 38,
#  'Hostile_environment': 29,
#  'Cuxhaven': 11617,
#  'Tomakomai': 2770,
#  'Cerbere': 665,
#  'Caravanning': 25,
#  'Upper_Manhattan': 49,
#  'Limousin': 1127,
#  'Maggie_valley': 27,
#  'Narvik': 9754,
#  'Mont-Saint-Michel': 31,
#  'Mahajanga': 1051,
#  'Pacific_County': 34,
#  'Quartzsite': 10821,
#  'Kittitas_County': 36,
#  'Mountainair': 4445,
#  'Cheyenne_Wells': 2051,
#  'Cumberland_Gap_National_Historical_Park': 3506,
#  'Palmyra': 13788,
#  'High_Veluwe': 39,
#  'Oklahoma_City/Uptown_and_Midtown': 33,
#  'Dexter': 1466,
#  'Hallefors': 3538,
#  'Gilbert_Islands': 1839,
#  'Le_Diamant': 915,
#  'Mount_Wudang': 20,
#  'Pom_Pom_Island': 1996,
#  'Ambala': 4982,
#  'South_Karachi': 21,
#  'Montone': 2272,
#  'Blue_Earth': 959,
#  'Rwenzori_Mountains_National_Park': 5543,
#  'Ulldecona': 23996,
#  'Halong': 9132,
#  'Daytona_Beach_Shores': 33783,
#  'Okeechobee': 3868,
#  'Fort_Mill': 730,
#  'Breton_Point_State_Park': 38,
#  'Vernon': 960,
#  'Snow_safety': 995,
#  'Noukendai': 22,
#  'Banagher': 1059,
#  'Pas_de_Calais': 32,
#  'Wauchula': 5146,
#  'Dazaifu': 3548,
#  'Deutschland': 21,
#  'Rapid_City_(South_Dakota)': 24,
#  'Predjama': 22,
#  'Gwangju,_Gyeonggi': 32,
#  'Kallooppara': 6387,
#  'Mexico_City/Condesa_and_Roma': 21484,
#  'Karonga': 3160,
#  'Golan_Trail': 46716,
#  'Singkep-Lingga': 4541,
#  'Rahacou': 1178,
#  'Oxford_Street_(disambiguation)': 27,
#  'Lao_phrasebook': 21767,
#  'James_Island': 33,
#  'Thuin': 4839,
#  'Uttaradit_(province)': 23,
#  'Upper_East_Side': 38,
#  'Mount_Assiniboine_Provincial_Park': 749,
#  'Glendale_(California)': 6860,
#  'Yunotsu_Onsen': 21,
#  'Lolland-Falster': 1163,
#  'Aberdyfi': 18641,
#  'Mount_Semeru': 48,
#  'Darling': 1682,
#  'Haute-Garonne': 543,
#  'Madison_wi': 21,
#  'Sangkhla': 27,
#  'Oberon': 1075,
#  'Chicago/Chinatown': 42,
#  'Eastern_Angola': 351,
#  'Tegus': 25,
#  'Rome/Old_Rome': 40039,
#  'Ponmudi': 2186,
#  'Bombay/Vikhroli': 36,
#  'Middleburg_(Virginia)': 24,
#  'Falcon': 20,
#  'Tanjore': 23,
#  'Wichita_Falls': 11834,
#  'Lappajarvi': 5794,
#  'Cape_Agulhas': 3293,
#  'Kuala_Gandah_Elephant_Sanctuary': 20,
#  'Barnesville': 464,
#  'Caledon': 449,
#  'Dutch_Country_Roads': 40,
#  'Travel_safety': 23,
#  'Pop_music_festival': 36,
#  'Burj_al-Arab_Hotel': 19,
#  'Fogo': 5925,
#  'Brewster_(Washington)': 2819,
#  'Rewalsar': 1578,
#  'Matunuck': 11609,
#  'Ganzhou': 2029,
#  'Nokia,_Finland': 19,
#  'Mapungubwe_National_Park': 1596,
#  'Gustrow': 951,
#  'Isola_Comacina': 1812,
#  'Ishpeming': 2187,
#  'Blackstone': 7914,
#  'Addo_Elephant_National_Park': 5669,
#  'Badajoz': 1252,
#  'Persian_phrasebook': 52400,
#  'Sydney/Five_Dock': 31,
#  'Republic_of_Cameroon': 22,
#  'Robertson': 3360,
#  'Fondo_Grande': 360,
#  'Boxford': 441,
#  'Ozark_National_Scenic_Riverways': 8821,
#  'Iseo,_Lombardy': 18,
#  'Rabat_(Malta)': 4364,
#  'Alcantara': 1353,
#  'Van_Wert_County': 1186,
#  'Tianshui': 3391,
#  'Ang_Thong_town': 23,
#  'Four_Days_in_the_New_Hampshire_White_Mountains': 45,
#  'Mill_Creek_(California)': 1257,
#  'Lung-tan': 21,
#  'Koidu': 1430,
#  'Shah_Alam': 22616,
#  'Goshen': 7906,
#  'Baxter_Springs': 9231,
#  'Hickory': 13937,
#  'Texarkana_(Arkansas)': 23,
#  'Kashid': 7799,
#  'Wrangell_St_Elias_National_Park_and_Preserve': 59,
#  'Medelpad': 35,
#  'Northern_Spain': 653,
#  'Thera': 18,
#  'Dumfries': 17326,
#  'Southwest_Washington': 9455,
#  'Pieterburen': 1852,
#  'Bowdon': 2535,
#  'Geraardsbergen': 707,
#  'Magnesia': 3252,
#  'Turkmen_phrasebook': 3126,
#  'Marigha': 1630,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Blue_Rock_Quarry': 11817,
#  'Xosa_phrasebook': 30,
#  'Saint_Petersburg_(district)': 1603,
#  'Przemysl': 22,
#  'Bristol_County_(Massachusetts)': 28,
#  'Satsuma': 36,
#  'Cavalcante': 15528,
#  'Kedzierzyn-Kozle': 787,
#  'Baharia_Oasis': 23,
#  'Bay_County': 220,
#  'Volcanic_Plateau': 34,
#  'La_Rioja': 446,
#  'Tiburon': 10441,
#  'Bhaktapur_(district)': 23,
#  'Rheinzabern': 28,
#  'Toronto/Deer_Park': 28,
#  'Jamestown': 658,
#  'Lutsk': 66728,
#  'Misty_Fiords_National_Monument': 1419,
#  'Pomerania': 23,
#  'Baoding': 1380,
#  'Sao_Paulo_(city)': 23,
#  'Cavado': 19,
#  'Salisbury_(Connecticut)': 2006,
#  'Baixo_Alentejo': 668,
#  'Bourgogne': 22,
#  'Inner_Harbor': 36,
#  'Pskov_Oblast': 3418,
#  'Kjerag': 21,
#  'Badlands_(North_Dakota)': 2133,
#  'Kings_Cross_(disambiguation)': 383,
#  'Buffalo_(disambiguation)': 1691,
#  'Elazg': 20,
#  'Tatranska_Magistrala': 3075,
#  'St._Lucia_(South_Africa)': 38,
#  'Ardrossan_(South_Australia)': 5435,
#  'Rhinecliff': 23,
#  'Bull_Run_(Virginia)': 200,
#  'Tarnaveni': 3284,
#  'Bed_and_Breakfasts': 32,
#  'Hastings_(Sussex)': 32,
#  'Zaanse_Schans': 9334,
#  'Noboribetsu': 4415,
#  'Sporades_Islands': 1777,
#  'Spiritwood': 707,
#  'Porquerolles': 7382,
#  'Poulton-le-Fylde': 722,
#  'Central_Slovenia': 2286,
#  'Cuzco': 89514,
#  'Yagodnoye': 1797,
#  'South_Bay_(San_Diego_County)': 4221,
#  'Niger': 26499,
#  'Central_Plains': 27,
#  'Kerikeri': 18147,
#  'Lampung': 2936,
#  'Dornogobi': 18,
#  'Salinas_de_Guaranda': 5108,
#  'Hlane_Royal_National_Park': 2647,
#  'Sepupa': 1838,
#  'Erie_(Pennsylvania)': 18,
#  'Bad_Bergzabern': 1040,
#  'Mississippi_Delta': 5359,
#  'Fire_Island_National_Seashore': 17012,
#  'Toronto/Scarborough': 10470,
#  'Hollywood_(Florida)': 14274,
#  'Kishwaukee_Valley': 2493,
#  'Jeffersonville': 703,
#  'The_Low_Countries': 21,
#  'San_Bernardino_(Paraguay)': 829,
#  'St_Johann': 24,
#  'Pillnitz': 21,
#  'Mount_Putuo': 10690,
#  'Chatham_(Ontario)': 26,
#  'Central_(Russia)': 28,
#  'Scarboro': 42,
#  'Ningde_Prefecture': 20,
#  'Wupperthal': 4286,
#  'Agadir': 16352,
#  'Table_Rock_Lake': 20,
#  'Oracle': 7913,
#  'Northern_Islands': 445,
#  'Ngari_(prefecture)': 2402,
#  'Marshall_Islands': 11399,
#  "Cote_d'Ivoire": 27,
#  'Central_(Iowa)': 26,
#  'Catalunya': 23,
#  'Burra': 2509,
#  'Riederalp-Bettmeralp': 3909,
#  'Ramkhamhaeng': 34,
#  'Central_West_(Minas_Gerais)': 942,
#  'Havelock_North': 7119,
#  'Nea_Kallikratia': 1918,
#  'Sangli_(district)': 33,
#  'San_Francisco/Union_Square-Financial_District': 51019,
#  'Paxton_(Illinois)': 1309,
#  'Chicago': 154994,
#  'Ireland_(disambiguation)': 402,
#  'Jemez_Mountains': 12107,
#  'Belarussian': 35,
#  'Southern_Reef_Islands': 673,
#  'Segovia_(city)': 21,
#  'Vila_Nova_de_Gaia': 2158,
#  'Tijuana/Playas': 4478,
#  'Kusinara': 24,
#  'Narva-joesuu': 26,
#  'Kismayo': 1825,
#  'Honaunau': 613,
#  'Roscommon': 7170,
#  'Arieseni': 22,
#  'Praia_de_Pipa': 3253,
#  'Dothan': 15489,
#  'Central_Province_(Sri_Lanka)': 2625,
#  'Laguna_hills': 26,
#  'Havana_(province)': 493,
#  'Azamgarh': 27,
#  'Oostende': 20,
#  'Indian_National_Parks_and_Wildlife_Sanctuaries': 34351,
#  'Heppenheim': 7468,
#  'Sydney_harbour_islands': 36,
#  'Sebastopol': 11052,
#  'St._Johns': 41,
#  'Pelorus_Bridge_Scenic_Reserve': 773,
#  '1url': 65,
#  'Eastern_Myanmar': 3008,
#  'Wahiba_Sands': 3450,
#  'Badlands_National_Park': 22374,
#  'Shanhaiguan': 37,
#  'Holly_Springs': 8626,
#  'Pittsburg/Downtown': 33,
#  'Embrun,_Ontario': 31,
#  'Honolulu/Manoa': 22,
#  'Torno': 4413,
#  'Montefalco': 3690,
#  'Riberac': 2603,
#  'North_Central': 435,
#  'Muisne': 1650,
#  'Nelson_County_(North_Dakota)': 45,
#  'Cunha': 3916,
#  'Gunnison': 306,
#  'Oberammergau': 6794,
#  'Perth_(Australia)': 19,
#  'Haut-Rhin': 20,
#  'Mae_Sarieng': 25,
#  'Perrysburg_(Ohio': 31,
#  'Jebel_Barkal': 20,
#  'Kyaukme': 2779,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Atlantis_Reef': 13960,
#  'Dinas_Dinlle': 1894,
#  'Dhulikhel': 5374,
#  'West_Pomerania': 369,
#  'Bella_Bella': 3606,
#  'Owings_Mills/Garrison': 26,
#  'Nanson': 30,
#  'Winnemucca': 4737,
#  'Nakhon_Sawan_(city)': 26,
#  "Manchester/Peter's_Fields": 48,
#  'Hoani': 1078,
#  'Rencontre_East': 1522,
#  'Seto_Inland_Sea': 2419,
#  'Rawanduz': 1276,
#  'Mount_Pearl': 1844,
#  'Sun_Valley': 237,
#  "'s-Hertogenbosch": 22309,
#  'Berkeley_(Gloucestershire)': 32,
#  'Andover': 443,
#  'Akhty': 527,
#  'Rio': 28,
#  'Sydney/Palm_Beach': 3104,
#  'Bur_Said': 23,
#  'Indianola': 497,
#  'Trebisacce': 913,
#  'Koege': 18,
#  'El_Meta': 18,
#  'Nagaon': 1190,
#  'Anderson': 342,
#  'Gaoxiong': 23,
#  'Narberth': 374,
#  'Agjabadi_Rayonu': 33,
#  'East_Brunswick': 10666,
#  'Trekking_in_everest': 36,
#  'Cuba_(Missouri)': 5011,
#  'Guayana': 591,
#  'Religious_destinations_of_Kerala': 20,
#  'Chugoku': 15733,
#  'Ingleside_(Texas)': 5013,
#  'Bogota/Teusaquillo-Salitre': 40,
#  'Boca_Chica': 3058,
#  'Ojen': 876,
#  'Irvine,_California': 20,
#  'Western_Karadenz': 31,
#  'St_Michaels': 26,
#  'Dornod': 30,
#  'Perigueux': 23,
#  'Bronx': 43927,
#  'Islands_(Chile)': 27,
#  'Mealhada': 1690,
#  'Apollo_Bay': 7779,
#  'Kilimanjaro_National_Park': 31,
#  'Sanjo': 1941,
#  'West_Stockbridge': 1004,
#  'Paris/13th': 39,
#  'Resolute': 2079,
#  'Norvalspont': 1938,
#  'Hightstown': 7472,
#  'Felecite_Island': 22,
#  'Logansport': 1377,
#  'Xiaozhou': 23,
#  'Colletto_Fava': 22,
#  'Coastal_Smaland': 21,
#  'Toodyay': 7878,
#  'Llanybydder': 837,
#  'Natural_Bridge_State_Park': 9650,
#  'Balkh': 3211,
#  'Clarens': 572,
#  'Broadway': 550,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Blouklip': 5515,
#  'Copperbelt_Province': 24,
#  'Chubu_Centrair_International_Airport': 12157,
#  'Iwakuni': 17339,
#  'Guruvayoorappan': 23,
#  'Krasnoyarsk-26': 27,
#  'New_York_(city)/Lower_Manhattan': 42,
#  'Fijian': 31,
#  'Longtan': 4173,
#  'Frequent_flyer_programmes': 31289,
#  'Machadodorp': 1789,
#  'Jamestown_(California)': 9242,
#  'Parsippany': 9809,
#  'Upper_Hutt': 10652,
#  'Trail_of_Israel': 35,
#  'Alencon': 21,
#  'Consensus': 31,
#  'Ashland_(Wisconsin)': 9410,
#  'Fjadundraland': 26,
#  'Open_fire': 22,
#  'Grande_Floripa': 34,
#  'Four_Day_Summer_Family_Trip_in_Lower_Cape_Cod': 24,
#  'Santiago_de_Chile/Bellavista': 7840,
#  'Spello': 9098,
#  'Okehampton': 633,
#  'Centreville_(Virginia)': 42,
#  'Courtray': 22,
#  'Playa_Santa_Lucia': 962,
#  'TDF': 46,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Friskies_Pinnacle': 5658,
#  'Ziarat': 20,
#  'Moritzburg': 713,
#  'New_Orleans': 71005,
#  'Courtrai': 22,
#  'Ludlow_(Vermont)': 8129,
#  'Vegetarian_and_vegan_food': 39,
#  'Chiang_Mai_to_Chiang_Rai_in_3_days': 7631,
#  'Llandudno_junction': 32,
#  'Chhukhung': 897,
#  'Skye': 37126,
#  'Clarksburg': 717,
#  'Potomac': 8205,
#  'Simi_Valley': 16948,
#  'Neuquen': 30,
#  'Stanhope': 2310,
#  'Emu_Park': 21,
#  'Brookings': 288,
#  'Koh_Tao': 20,
#  'Huron_County_(Ontario)': 1952,
#  'Udaigiri': 20,
#  'St_John': 41,
#  'Hartford_(Vermont)': 34,
#  'Glengarriff': 6288,
#  'Santiago_de_Compostella': 35,
#  'Louang_Prabang': 27,
#  'Rebun': 51,
#  'Tel_Megiddo_National_Park': 21,
#  'Puebla_de_Zaragoza': 20,
#  'Tahara': 3154,
#  'Kilwinning': 2746,
#  'Persia': 18,
#  'La_Condamine': 19,
#  'Calgary_(Scotland)': 1234,
#  'North_Africa': 5441,
#  'Carbondale_(Illinois)': 22220,
#  'Quang_Ngai': 24,
#  'San_Juan_(Puerto_Rico)/Old_San_Juan': 35,
#  'Balinese_Islands': 34,
#  'Malabon_City': 21,
#  'Shinyokohama': 22,
#  'Gjirokastra': 25,
#  'Ischigualasto_Provincial_Park': 2731,
#  'Nakhchivan_(region)': 5130,
#  'Sun_Peaks_Resort': 23,
#  'Kavieng': 5935,
#  "Quarto_d'Altino": 799,
#  'Camalu': 3427,
#  'Norte_de_Santander': 403,
#  'Nong_Khai_(province)': 23,
#  'Mount_Lassen': 43,
#  'Saga_prefecture': 31,
#  'Suwa': 3262,
#  'Jerome_(Arizona)': 11307,
#  'Jackson_(Mississippi)': 16702,
#  'West_Coast_(Finland)': 6337,
#  'Cappadoccia': 24,
#  'Philadelphia,_Pennsylvania': 26,
#  'Connecticut': 21535,
#  'Harvey': 2396,
#  'Stevenson_Ranch': 27,
#  'Tokyo_Olympic_and_Paralympic_Games_2020': 24,
#  'Rail_travel_in_the_United_States': 43760,
#  'Lampedusa': 28,
#  'County_Longford': 3558,
#  'Ubon_Ratchathani_(province)': 30,
#  'Hiking_and_backpacking_in_Israel': 45632,
#  'Antsiranana_Province': 775,
#  'Tipping': 4464,
#  'Atlanta/Atlantic_Station': 4044,
#  'Mid_Cape': 951,
#  'Silimbong': 1622,
#  'Schleswig-Holstein': 9406,
#  'One_day_in_Fenway_Park': 34,
#  'Cullohill': 1481,
#  'Leghorn': 21,
#  'Czech_Silesia': 39,
#  "Arthur's_Pass_National_Park": 13383,
#  'Phitsanulok_(province)': 25,
#  'Swedish': 32,
#  'Mt_isa': 23,
#  'Kununurra': 53639,
#  'Hanzeatic_league': 30,
#  'Bhopal-Narmadapuram_Division': 1070,
#  'Latera': 11243,
#  'Greater_Phoenix': 1682,
#  'Beskids': 1485,
#  'Goodyear': 2516,
#  'Pahokee': 513,
#  'Choolannur_peafowl_Sanctuary': 40,
#  'Metro_Atlanta': 11946,
#  'Passaic': 375,
#  'Perryton': 5078,
#  'Devanagari': 33,
#  'Danakil_Depression': 8787,
#  'Celebration': 20246,
#  'Merlins_Bridge': 26,
#  'East_Palo_Alto': 2052,
#  'Sosua': 28593,
#  'Oxbow': 279,
#  'Four_days_in_Bangkok': 32,
#  'Hillsborough_(Northern_Ireland)': 1271,
#  'Yarrawonga_Mulwala': 32,
#  'Isle_of_Jura': 10132,
#  'Malheur_County,_Oregon': 28,
#  'Chantilly_(Virginia)': 11895,
#  'East_Khasi_Hills': 713,
#  'Statia': 28,
#  'Prinsenbeek': 19,
#  'Hongrie': 21,
#  'Dadra_and_Nagar_Haveli': 8210,
#  'Mount_Tai': 11637,
#  'West_Greenwich': 13970,
#  'Lavenham': 2515,
#  'Hermann_(Missouri)': 21,
#  'South_(Louisiana)': 22,
#  'Aojiang': 5985,
#  'Nishitokyo': 8694,
#  'Valdez': 4493,
#  'Sitka': 18675,
#  'Dobrudja': 21,
#  'Ras_al-Khaymah': 29,
#  'Golden_Triangle_(India)': 41,
#  'Allinge_Sandvig': 29,
#  'Jotunheimen': 9422,
#  'Plzen_Region': 26,
#  'Island_Peak': 30,
#  'Quincy_(Illinois)': 12969,
#  'Devonport_(New_Zealand)': 8188,
#  'Patuxent_River': 28,
#  'Bingzhongluo': 1906,
#  'Stockholm/Liljeholmen': 32,
#  'Islamabad_town': 22,
#  'London_Underground': 51,
#  'Bogota/Zona_Rosa': 30,
#  'Kisa_to_Boxholm_following_the_Malexandermorden_trail_by_car': 5648,
#  'Franciacorta': 5084,
#  'Tokyo/Akihabara': 21311,
#  'Richmond_(Virginia)/the_Museum_District': 38,
#  'Kinik': 19,
#  'Udon': 24,
#  'North_Carolina_Mountains': 7962,
#  'Rocky_Mountains': 364,
#  'Manchu_phrasebook': 12432,
#  'Collegeville_pennsylvania': 26,
#  'Welcome,_business_owners': 46,
#  'Thimpu': 21,
#  'Aakirkeby': 1326,
#  'Hudson_(New_York_(state))': 31,
#  'Travel_topic': 27,
#  'Atlantico_Sur': 24,
#  'Yaren': 19,
#  'Valle_de_Cocora': 11084,
#  'Chainat': 22,
#  'Bocholt': 1866,
#  'Pleasanton': 9213,
#  'Philadelphia/Old_City': 39122,
#  'New_Okhla_Industrial_Development_Authority': 19,
#  'Spitsbergen': 22,
#  'Brest': 272,
#  'Ketron_Island': 1863,
#  'Balneario_Camboriu': 5964,
#  'Central_Coast_(NSW)': 45,
#  'Tuolumne_County': 6964,
#  'Xiazhou': 23,
#  'Sand_Hills': 588,
#  'La_Grange': 392,
#  'Diving_the_Mokohinau_Islands': 5218,
#  'Riverview': 590,
#  'Hopkins_(Minnesota)': 13075,
#  'Nrbo': 4414,
#  'Wilton_Manors': 29,
#  'Central_Poland': 25,
#  'Samoeng_Loop': 14354,
#  'Canton_(Michigan)': 1280,
#  'Jodhpur_Division': 1458,
#  'Misquamicut': 11268,
#  'Slovak_Karst': 40,
#  'Pays_de_Montfort': 29,
#  'Targu-Mures': 25,
#  'Tokyo/Chiyoda': 23398,
#  'Cheorwon': 4991,
#  'Medford_(Oregon)': 17233,
#  'Ialysos': 1936,
#  'Pelhrimov': 23,
#  'Bruny_Island': 19331,
#  'Hanseatic_League': 3349,
#  'Samut_Songkhram_(province)': 29,
#  'Sorsogon': 446,
#  'Spittal_an_der_Drau': 861,
#  'Gardena': 3210,
#  'Great_Basin_National_Park': 8445,
#  'Chisago': 26,
#  'Singapore_Airlines': 39,
#  'Inverigo': 1071,
#  'Lakes_and_Gardens': 807,
#  'Suprasl': 23,
#  'Spennymoor': 21608,
#  'Maroussi': 21,
#  'Ballycastle': 2985,
#  'North_Gujarat': 1962,
#  'Central_Mozambique': 2092,
#  'Dymond': 32,
#  'Triglav_National_Park': 14286,
#  'Clewiston': 1762,
#  'Northern_Ohio_River_Region': 5129,
#  'Ko_Samet': 36404,
#  'Cacapava': 591,
#  'Iles_des_Pins': 26,
#  'Corentyne': 31,
#  'Holbk': 17236,
#  'Kabale': 3599,
#  'Freeland': 970,
#  'Semmering': 11933,
#  'Northeast': 465,
#  'Huntington_(town,_New_York)': 35,
#  'Ipswich': 452,
#  'Douglas_County': 1069,
#  'Mundau': 1055,
#  'Lleida': 2465,
#  'Majuli': 3207,
#  'Kasauli': 10794,
#  'West_Volga_Region': 26,
#  'WikiVoyage': 27,
#  'Faliraki': 6641,
#  'Amravati': 5549,
#  'Bombay/Kurla': 36,
#  'Lynchburg_(Tennessee)': 1619,
#  'Eagle_River': 1378,
#  'Ahmedabad': 100439,
#  'Trechtingshausen': 3415,
#  'Butaritari': 7216,
#  'Jungmun': 25,
#  'Camino_de_Santiago': 30,
#  'Jiuzhaigou_Nature_Reserve': 28927,
#  'Cronulla': 29,
#  'Inner_Hebrides': 4876,
#  'Kelmend': 355,
#  'Enniskillen': 13674,
#  'Northeast_(Brazil)': 6443,
#  'Skelleftea': 5642,
#  'Ulyanovsk_Oblast': 1303,
#  'Kochi_(Kerala)/Aluva': 19,
#  'Serra_dos_Orgaos_National_Park': 1089,
#  'Bluegrass_Region': 14417,
#  'St._Louis_Park': 3930,
#  'Kamyanets-Podilsky': 33,
#  'Travnik': 1705,
#  'North_West_Coastal_Highway': 6993,
#  'Morris,_Illinois': 31,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Bantry_Bay': 4683,
#  'Tak': 6026,
#  'Behasy': 295,
#  'Disentis_(Region)': 31,
#  'Silvia': 855,
#  'Kemmerer': 893,
#  'Virginia_City,_NV': 36,
#  'Merv': 10170,
#  'Pilion': 26,
#  'Oboke_and_Koboke': 9109,
#  'Grand_Teton_National_Park': 21556,
#  'Langkawi_Island': 22,
#  'Newport_News,_VA': 26,
#  'Lembongan_Island': 28,
#  'New_York_(city)/Manhattan/Upper_West_Side': 39,
#  'Kalinga': 784,
#  'Barra_do_Turvo': 2724,
#  'Mandalgovi': 24,
#  'San_Francisco/Potrero_Hill': 37,
#  'Peabody_(Massachusetts)': 21,
#  'Duval_County': 293,
#  'Colombia': 63307,
#  'Kuala_Gandah': 2551,
#  'Kuala_Kubu_Bahru': 30,
#  'Marina_di_Ragusa': 4955,
#  'Nahuel_Huapi_National_Park': 14533,
#  'Mt._Everest_Base_Camp_Trek': 36,
#  'Pembroke_(Wales)': 5437,
#  'Cu_Chi': 5787,
#  'Saint-Paul_de_Vence': 2642,
#  'Eastern_Newfoundland': 798,
#  'Wallingford_(England)': 3541,
#  'Zambales': 4223,
#  'Baiyu': 50,
#  'Bol': 9760,
#  'Port_Orford': 551,
#  'Peterborough_(New_Hampshire)': 4444,
#  'Jardin': 8889,
#  'Copenhagen/Indre_By': 82081,
#  'Antep': 23,
#  'Santarem_(Brazil)': 3181,
#  'Le_Flore_County': 30,
#  'Thornton': 3445,
#  'Khakassia': 2439,
#  'Ambalappuzha': 23,
#  'Clitheroe': 3352,
#  'Sedibeng': 759,
#  'Sultan_Bathery': 13893,
#  'Vienne_(city)': 3143,
#  'Southwestern_Indiana': 651,
#  'Mardana': 1396,
#  'Davidson': 5450,
#  'Bang_Saen': 4606,
#  'August': 6037,
#  'Austin/Northwest_Austin': 30,
#  'San_Martin_de_los_Llanos': 1294,
#  'East_(China)': 24,
#  'Esino_Lario': 68299,
#  'Inland_Honduras': 32,
#  'Bull_Shoals': 2970,
#  'Iris': 28,
#  'Los_Patos': 1064,
#  'Hawera': 3309,
#  'Factoryville,_Pennsylvania': 26,
#  'Ko_Maphrao': 602,
#  'Artyom': 2959,
#  'Cassadaga_(Florida)': 4035,
#  'Prineville': 1772,
#  'El_Aioun': 22,
#  'Chiufen': 20,
#  'Devala': 1264,
#  'Helmstedt': 3596,
#  'Cameron_(Louisiana)': 614,
#  'Tokushima_Prefecture': 36,
#  'Hershey': 16436,
#  'Etawah': 3226,
#  'Laotian': 28,
#  'Muang_Ngeun': 2164,
#  'Silk_Route': 23,
#  'Mexicali': 31261,
#  'Lake_County_(South_Dakota)': 36,
#  'Port_Richey': 3627,
#  'Oshima_Subprefecture': 30,
#  'Eastham': 22216,
#  'Aran_Islands': 10771,
#  'Hecho': 1244,
#  'Washington_(D.C.)/Capitol_Hill': 43,
#  'San_Diego/Northeastern': 29,
#  'Shiga': 4700,
#  'Outback_(South_Australia)': 651,
#  'Waterberg_Meander': 616,
#  'Bukit_Barisan_Selatan_National_Park': 1385,
#  'Beichuan': 1732,
#  'Milford_Track': 15143,
#  'Juanjui': 772,
#  'Joliet': 11755,
#  'Hengsha_Island': 32,
#  'Tangomarkkinat': 22,
#  'Hainan_(prefecture)': 21,
#  'Lamesa': 2507,
#  'Skellig_Michael': 13611,
#  'Samsun': 14846,
#  'Dire-Dawa': 23,
#  'Sicilia': 20,
#  'Scamander': 1187,
#  'Johnson_City,_TN': 38,
#  'Barcelona/Barceloneta': 36,
#  'Carlsbad_Caverns': 44,
#  'Keminmaa': 18,
#  'Capena': 982,
#  'Southeast_Wisconsin': 2182,
#  'Samaria_Gorge': 26,
#  'Chippewa_(disambiguation)': 22,
#  'Kanye': 3787,
#  'Tavarnelle_Val_di_Pesa': 1796,
#  'Seychellois_Creole_phrasebook': 5755,
#  'Leeward_Coast_(Oahu)': 2296,
#  'Zhengzhou': 22361,
#  'Pantellaeria': 25,
#  'Lhuentse': 696,
#  'Manitoulin_Island': 13065,
#  'Peterborough': 9761,
#  'Bowie': 11303,
#  'Chennai/Besant_nagar': 21,
#  'Hythe_(disambiguation)': 19,
#  'Chuncheon': 23313,
#  'Northwestern_Karnataka': 787,
#  'Cromwell': 731,
#  'Rocky_Mountains_(Canada)': 5721,
#  'Berlin_(El_Salvador)': 6186,
#  'New_York_City/Gramercy_Flatiron': 41,
#  'Cypress': 5270,
#  'Escanaba': 2623,
#  'Alvdalen': 1875,
#  'Assisi': 14095,
#  'Iwate_(prefecture)': 19,
#  'Nantwich': 9028,
#  'Nord_(France)': 32,
#  'Madurai_district': 37,
#  'Bulgarian_seaside': 39,
#  'Fort_Saint_John': 26,
#  'Gobustan': 22,
#  'Saint_Martin': 38788,
#  'Hibbing_(Minnesota)': 21,
#  'Webster': 860,
#  'Harrison_(Ohio)': 1070,
#  'Miami_Gardens': 550,
#  'Manhattan/Harlem': 50,
#  'Istanbul/Sultanahmet-Old_City': 83272,
#  'Marysville_(Ohio)': 2838,
#  'Perth/Southern_Suburbs': 31,
#  'Lesotho': 29359,
#  'Funafuti': 3332,
#  'River_Valley_(disambiguation)': 726,
#  'Morenci': 256,
#  'The_Abbey_of_San_Galgano': 19,
#  'Singapore/CBD': 23,
#  'Panzano': 19,
#  'Sterling_(Utah)': 2664,
#  'Bangor_(Kitsap)': 30,
#  'Zelena_Hora': 30,
#  'Foochow': 20,
#  'Nananu-i-Ra_Island': 25,
#  'Fanwood': 1134,
#  'Northern_Cameroon': 775,
#  'Mat-Su_Valley': 39,
#  'Killorglin': 1830,
#  'Taplejung': 347,
#  'Jiangsu': 5513,
#  'Newburgh_(New_York)': 2722,
#  'Gering': 25,
#  'Southwestern_Zealand': 21,
#  'Michigan': 26496,
#  'Bungmati': 1907,
#  'Diving_the_Cape_Peninsula_and_False_Bay/Castle_Rocks': 13353,
#  'Lefkara': 3309,
#  'Metropolitan_Alabama': 1193,
#  'Colca_Canyon': 14444,
#  'Mongar': 1693,
#  'Hardee_County': 31,
#  'Bedford_(Indiana)': 23421,
#  'Manovo_Gounda_St_Floris_National_Park': 52,
#  'Clearlake': 4553,
#  'Niassa': 33,
#  'Van_Nuys': 8789,
#  'Carcasonne': 25,
#  'Campo_Grande': 34778,
#  'New_York_City/Soho': 28,
#  'Agrigento_Province': 34,
#  'San_Luis_de_Pambil': 4663,
#  'Valley_of_the_Kings': 39,
#  'Deep_South': 427,
#  'Stone_town': 24,
#  'Sylheti_phrasebook': 77566,
#  'Portarlington': 5278,
#  'Altai_Tavan_Bogd_National_Park': 44318,
#  'Murdeshwara': 2817,
#  'Veitshochheim': 4064,
#  'Bombay/Malad': 30,
#  'Dennisport': 20,
#  'Kanipakam': 1513,
#  'Siroki_Brijeg': 27,
#  'Bratsk': 1560,
#  'Egadi_Islands': 30,
#  'Silverdale_(Washington)': 17571,
#  'Pixley': 2900,
#  'Wedding_and_honeymoon_travel': 146,
#  'Majorda': 22,
#  'Marijampole': 563,
#  'Des_Moines': 79221,
#  'St._Helier': 26,
#  'Paris_Charles_de_Gaulle_Airport': 10604,
#  'Toronto/West_End': 16417,
#  'Swabi': 32,
#  'Kunene': 30,
#  'Irving_(Texas)': 20,
#  'St_Anton_am_Arlberg': 23,
#  'Kulpsville': 908,
#  'Suomenlinna': 34,
#  'Hammerfest': 4253,
#  'Chittur': 3949,
#  'Carlsberg_Sky_Tower': 31,
#  'Isle_of_barra': 19,
#  'Kolkata/Dum_Dum': 553,
#  'Bellingham_(Massachusetts)': 864,
#  'The_Rosses': 5714,
#  'Kota_Division': 854,
#  'Dallas/West_Dallas': 966,
#  'Byron_(Maine)': 948,
#  'Meppadi': 8855,
#  'San_Diego/Mission_Beach-Pacific_Beach': 28567,
#  'Prishtine,_Kosovo': 22,
#  'Swanzey': 581,
#  'Borjomi': 8272,
#  'Zonguldak': 2000,
#  'Khao_Lampi_-_Hat_Thai_Mueang_National_Park': 54,
#  'Port_of_Spain': 15410,
#  'Vancouver_southern_suburbs': 1476,
#  'Manovo-Gounda_Saint_Floris_National_Park': 52,
#  'Bonners_Ferry': 2585,
#  'Surinamese_East_Coast': 22,
#  'Skaraborg': 31,
#  'Islas_de_San_Bernardo': 31,
#  'Ounasvaara': 23,
#  'Baoting': 1473,
#  'Upper_Falls_(West_Virginia)': 3489,
#  'Northumbria': 32,
#  'Kargil_District': 19,
#  'Newton-le-Willows': 1735,
#  'Grand_Lake': 735,
#  'Ankola': 1047,
#  'North_Attleborough': 12683,
#  'Fairfield_County_(Ohio)': 3229,
#  'Tornedalen': 31,
#  'Hillsboro_(New_Hampshire)': 42,
#  'Hale': 24,
#  'Dead_Sea_(Jordan)': 17049,
#  'Mesquite_(Texas)': 1286,
#  'Hall': 27,
#  'Sycamore': 3651,
#  'Pemberton_(Western_Australia)': 2714,
#  'Alleghenies_and_Susquehanna_Valley': 3639,
#  'Bistrita_Nasaud_County': 36,
#  'Point_Reyes_National_Seashore': 20377,
#  'Manchester_Airport': 24544,
#  'Annur': 2491,
#  'Isla_Santa_Cruz': 24,
#  'Satellite_phone': 48,
#  'Minca': 614,
#  'Zaandam': 7315,
#  'Probolingo': 25,
#  'Cheb': 3838,
#  'La_Ceiba': 12236,
#  'Capurgana': 6881,
#  'Olympic_Peninsula': 16074,
#  'Sudbury_suffolk': 31,
#  'CGK': 49,
#  'Franeker': 2541,
#  'Kodak': 1079,
#  'Geelong': 10708,
#  'Isle_of_Pines': 26,
#  'Circum-Baikal_Railway': 5098,
#  'Tohoku': 9983,
#  'Monte_Carlo': 20,
#  'Ethiopia': 55052,
#  'Eagleville_pa': 24,
#  'Ski': 1782,
#  'Budoni': 1507,
#  'Elmina': 5841,
#  'Llanrwst': 2059,
#  'Al_Uyun': 22,
#  'Cooperstown_(North_Dakota)': 5072,
#  'Erechim': 4122,
#  'Eastern_Inner_Mongolia': 1373,
#  'Captiva_Island': 4677,
#  'Adilabad': 4471,
#  'Janakpur_(zone)': 19,
#  'Lewistown': 319,
#  'Maison_St._Charles': 32,
#  'Emlicin': 20,
#  'Cartwright_(North_Dakota)': 2321,
#  'Montejaque': 3759,
#  'North_Vacherie': 22,
#  'Swieradow-Zdroj': 889,
#  'Wakhan_Corridor': 6773,
#  ...}

# %% [markdown]
# __Check out some articles with short lengths__

# %%
articles_dict['Uttaradit_(province)']
# Out:
# {u'id': u'37451',
#  u'ns': u'0',
#  u'redirect': {u'@title': u'Uttaradit'},
#  u'revision': {u'comment': u'moved to uttaradit (Import from wikitravel.org/en)',
#   u'contributor': {u'id': u'1844', u'username': u'Globe-trotter'},
#   u'format': u'text/x-wiki',
#   u'id': u'1517490',
#   u'model': u'wikitext',
#   u'parentid': u'1517489',
#   u'sha1': u'bf1olkjbo5ahz3kgjtxu5dq5hlj90j3',
#   u'text': {u'#text': u'#REDIRECT [[Uttaradit]]', u'@xml:space': u'preserve'},
#   u'timestamp': u'2010-02-05T19:36:28Z'},
#  u'title': u'Uttaradit (province)'}

# %%
df_article_lengths = pd.DataFrame(article_lengths_dict.items(), columns = ['title', 'length'])

# %% [markdown]
# __Plot histogram to see the distribution of articles by length.__

# %%
condition1 = df_article_lengths['length'] < 10000
df_article_lengths[condition1].hist(bins=100);

# %%
### STUDY HOW MANY CHARS ARTICLES HAVE.
condition2 = df_article_lengths['length'] < 500
df_article_lengths[condition2].hist(bins=10)

## IT CAN BE SEEN THAT THERE ARE ABOUT 17,000 ARTICLES LESS THAN 200 CHARACTERS.
## ARTICLES WITH LESS THAN 200 WORDS WOULD MEAN THEY DON'T HAVE GOOD DESTINATION DESCRIPTONS OR ARE AMBIGUOUS DESTINATIONS, MEANING THEY AREN'T
## POPULAR DESTINATIONS.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x110df9b50>]], dtype=object)

# %%
condition3 = df_article_lengths['length'] < 200
df_article_200_char_plus = df_article_lengths[-condition3]

# %%
final_titles = df_article_200_char_plus['title']

# %%
len(final_titles)
# Out:
# 25861

# %% [markdown]
# __There are still disambiguation articles which don't add much information so lets get rid of them.__

# %%
final_articles = {}
for title in final_titles:
    if '(disambiguation)' not in title:
        final_articles[title] = articles_dict[title]['revision']['text']['#text']
print len(final_articles)
# Out:
# 25440

# %%
def clean_paragraph(string):
    # get rid of https:
    m = re.sub(r'(https?://\S+\ +\S+)', '', string)
    # get rid of [File:stuff]
    m = re.sub(r'\[File:[^)]*\]','', m)
    # get rid of \n
    m = re.sub(r'(\n)','', m)
    
    # get rid of ==stuff==
    m = re.sub(r'(\=+[^)]+\=+)','', m)
    #remove accents
    m = remove_accents(m)
    #get rid of ], [, '. E.g. [[Paris]] --> Paris
    m = re.sub(r'[\[\]\']','',m).strip()

    return m

# %%
def clean_sentence(string):
    # punctuation and numbers to be removed
    punctuation1 = re.compile(r'[*.?!,"0-9]')
    punctuation2 = re.compile(r'[-:;()|]')
    sent = re.sub(punctuation1,'', string)
    sent = re.sub(punctuation2, ' ', sent)
    return sent

# %%
clean_sentence('seoul-incheon internatio*nal)')
# Out:
# 'seoul incheon international '

# %%
def convert_article_into_list_of_words(article):
    md = mistune.markdown(article)
    parsed_md = BeautifulSoup(md, 'html.parser')
    
    parsed_test_wo_dict = []
    
    #Grab all the paragraphs and lists
    for line in parsed_md.find_all(['p','li']):
        text = line.text
        
        #remove dictionaries by filtering on {{
        if '{{' not in text:
            #clean the paragraph by removing things like https:stuff, File:stuff
            text = clean_paragraph(text)
            #tokenize paragraph to sentences
            sentences = sent_tokenize(text)
            
            for sentence in sentences:
                #clean sentence by removing numbers and punctuations
                sent = clean_sentence(sentence).lower()
                #convert sentence to list of words
                word_list = sent.split()
                #keep the sentence if there are more than 3 words.
                if len(word_list) > 3:
                    parsed_test_wo_dict.append(word_list)
    return parsed_test_wo_dict

# %%
final_articles.keys()
# Out:
# ['Szczecin',
#  'Carlsbad_(New_Mexico)',
#  'Rugia',
#  'Nampa',
#  'Wulai',
#  'Fazenda_Nova',
#  'Oviedo_(Spain)',
#  'Fulda',
#  'Gravesend',
#  'Thuin',
#  'Malabon',
#  'Hikone',
#  'Upper_Cape',
#  'Goshen',
#  'Loei',
#  'Bago_(Myanmar)',
#  'Saco',
#  'Lake_Manyara_National_Park',
#  'Finland_in_ten_days_by_car',
#  'Cahir',
#  'Tremont_(Maine)',
#  'Garamba_National_Park',
#  'George_Town_(Malaysia)',
#  'Ballina',
#  'Maasin',
#  'Pampa',
#  'Gangtok',
#  'Lucknow',
#  'Hamilton',
#  'Kaokoland',
#  'East_Windsor_(Connecticut)',
#  'Cuxhaven',
#  'Limousin',
#  'Narvik',
#  'Quartzsite',
#  'Mountainair',
#  'Cheyenne_Wells',
#  'Cumberland_Gap_National_Historical_Park',
#  'Palmyra',
#  'Schwabenheim',
#  'Dexter',
#  'Hallefors',
#  'Harvey',
#  'Le_Diamant',
#  'Pom_Pom_Island',
#  'Ambala',
#  'Montone',
#  'Blue_Earth',
#  'Danakil_Depression',
#  'Ulldecona',
#  'Halong',
#  'Daytona_Beach_Shores',
#  'Okeechobee',
#  'Fort_Mill',
#  'Vernon',
#  'Snow_safety',
#  'Franciacorta',
#  'Banagher',
#  'Wauchula',
#  'Dazaifu',
#  'Kallooppara',
#  'Mexico_City/Condesa_and_Roma',
#  'Karonga',
#  'Butaritari',
#  'Singkep-Lingga',
#  'Rahacou',
#  'Lao_phrasebook',
#  'Caen',
#  'Colombia',
#  'Mount_Assiniboine_Provincial_Park',
#  'Glendale_(California)',
#  'Lolland-Falster',
#  'Aberdyfi',
#  'Haute-Garonne',
#  'Ylivieska',
#  'Oberon',
#  'Eastern_Angola',
#  'Rome/Old_Rome',
#  'Ponmudi',
#  'Wichita_Falls',
#  'Lappajarvi',
#  'Cape_Agulhas',
#  'Barnesville',
#  'Caledon',
#  'Fogo',
#  'Brewster_(Washington)',
#  'Rewalsar',
#  'Matunuck',
#  'Ganzhou',
#  'Mapungubwe_National_Park',
#  'Gustrow',
#  'Greensburg_(Indiana)',
#  'Ishpeming',
#  'Blackstone',
#  'Addo_Elephant_National_Park',
#  'Badajoz',
#  'Persian_phrasebook',
#  'Robertson',
#  'Fondo_Grande',
#  'Boxford',
#  'Ozark_National_Scenic_Riverways',
#  'Rabat_(Malta)',
#  'Alcantara',
#  'Van_Wert_County',
#  'Tianshui',
#  'Montague',
#  'Mill_Creek_(California)',
#  'Koidu',
#  'Shah_Alam',
#  'Mokhotlong',
#  'Baxter_Springs',
#  'Hickory',
#  'Kashid',
#  'Northern_Spain',
#  'Dumfries',
#  'Southwest_Washington',
#  'Pieterburen',
#  'Bowdon',
#  'Geraardsbergen',
#  'Turkmen_phrasebook',
#  'Marigha',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Blue_Rock_Quarry',
#  'Saint_Petersburg_(district)',
#  'Cavalcante',
#  'Kedzierzyn-Kozle',
#  'Bay_County',
#  'Tiburon',
#  'Jamestown',
#  'Lutsk',
#  'Misty_Fiords_National_Monument',
#  'Baoding',
#  'Baixo_Alentejo',
#  'Pskov_Oblast',
#  'Badlands_(North_Dakota)',
#  'Tatranska_Magistrala',
#  'Bed_and_breakfasts',
#  'Bull_Run_(Virginia)',
#  'Tarnaveni',
#  'Zaanse_Schans',
#  'Noboribetsu',
#  'Spiritwood',
#  'Porquerolles',
#  'Poulton-le-Fylde',
#  'Central_Slovenia',
#  'Cuzco',
#  'Smithfield-Selma',
#  'South_Bay_(San_Diego_County)',
#  'Niger',
#  'Kerikeri',
#  'Lampung',
#  'Salinas_de_Guaranda',
#  'Hlane_Royal_National_Park',
#  'Sepupa',
#  'Mississippi_Delta',
#  "Sant'Angelo_Dei_Lombardi",
#  'Toronto/Scarborough',
#  'Hollywood_(Florida)',
#  'Kishwaukee_Valley',
#  'Jeffersonville',
#  'San_Bernardino_(Paraguay)',
#  'Mount_Putuo',
#  'Wupperthal',
#  'Agadir',
#  'Oracle',
#  'Marshall_Islands',
#  'Fredericksburg_(Texas)',
#  'Burra',
#  'Riederalp-Bettmeralp',
#  'Central_West_(Minas_Gerais)',
#  'Havelock_North',
#  'Nea_Kallikratia',
#  'San_Francisco/Union_Square-Financial_District',
#  'Paxton_(Illinois)',
#  'Chicago',
#  'Jemez_Mountains',
#  'Southern_Reef_Islands',
#  'Vila_Nova_de_Gaia',
#  'Tijuana/Playas',
#  'Kismayo',
#  'Honaunau',
#  'Roscommon',
#  'Praia_de_Pipa',
#  'Dothan',
#  'Central_Province_(Sri_Lanka)',
#  'Lexington_(Missouri)',
#  'Havana_(province)',
#  'Indian_National_Parks_and_Wildlife_Sanctuaries',
#  'Heppenheim',
#  'Thame_(Nepal)',
#  'Pelorus_Bridge_Scenic_Reserve',
#  'Eastern_Myanmar',
#  'Wahiba_Sands',
#  'Badlands_National_Park',
#  'Holly_Springs',
#  'Zanzibar',
#  'Torno',
#  'Montefalco',
#  'Riberac',
#  'North_Central',
#  'Muisne',
#  'Cunha',
#  'Gunnison',
#  'Oberammergau',
#  'Kyaukme',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Atlantis_Reef',
#  'Dinas_Dinlle',
#  'Dhulikhel',
#  'West_Pomerania',
#  'Bella_Bella',
#  'Winnemucca',
#  'Hoani',
#  'Rencontre_East',
#  'Seto_Inland_Sea',
#  'Rawanduz',
#  'Mount_Pearl',
#  'Sun_Valley',
#  'Laulasmaa',
#  'Andover',
#  'Akhty',
#  'Sydney/Palm_Beach',
#  'North_Bay',
#  'Indianola',
#  'Trebisacce',
#  'Nagaon',
#  'Anderson',
#  'South_Seas',
#  'Narberth',
#  'East_Brunswick',
#  'Cuba_(Missouri)',
#  'Guayana',
#  'Chugoku',
#  'Ingleside_(Texas)',
#  'Boca_Chica',
#  'Ojen',
#  'Brahmanbaria_District',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Vogelsteen',
#  'Bronx',
#  'Mealhada',
#  'Apollo_Bay',
#  'Sanjo',
#  'West_Stockbridge',
#  'Raiguer',
#  'Resolute',
#  'Norvalspont',
#  'Hightstown',
#  'Logansport',
#  'Toodyay',
#  'Llanybydder',
#  'Natural_Bridge_State_Park',
#  'Balkh',
#  'Clarens',
#  'Iwakuni',
#  'Ellmau',
#  'Longtan',
#  'Chaung_Tha',
#  'Jamestown_(California)',
#  'Parsippany',
#  'Ashland_(Wisconsin)',
#  'Saint-Jean-Pied-de-Port',
#  'Elgin',
#  'Spello',
#  'Okehampton',
#  'Ponca_City',
#  'Playa_Santa_Lucia',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Friskies_Pinnacle',
#  'Moritzburg',
#  'New_Orleans',
#  'Ludlow_(Vermont)',
#  'Chiang_Mai_to_Chiang_Rai_in_3_days',
#  'Chhukhung',
#  'Skye',
#  'Clarksburg',
#  'Potomac',
#  'Simi_Valley',
#  'Stanhope',
#  'Brookings',
#  'Huron_County_(Ontario)',
#  'Apopka',
#  'Glengarriff',
#  'Aberporth',
#  'Tahara',
#  'Kilwinning',
#  'North_Africa',
#  'Tallberg',
#  'Nakhchivan_(region)',
#  'Kavieng',
#  "Quarto_d'Altino",
#  'Camalu',
#  'Norte_de_Santander',
#  'Suwa',
#  'Jerome_(Arizona)',
#  'Jackson_(Mississippi)',
#  'West_Coast_(Finland)',
#  'Baghdad',
#  'Gilbert_Islands',
#  'Rail_travel_in_the_United_States',
#  'County_Longford',
#  'Hiking_and_backpacking_in_Israel',
#  'Antsiranana_Province',
#  'Tipping',
#  'Atlanta/Atlantic_Station',
#  'Mid_Cape',
#  'Silimbong',
#  'Schleswig-Holstein',
#  'Bunaken',
#  'Cullohill',
#  "Arthur's_Pass_National_Park",
#  'Kununurra',
#  'Bhopal-Narmadapuram_Division',
#  'Latera',
#  'Greater_Phoenix',
#  'Beskids',
#  'Goodyear',
#  'Pahokee',
#  'Dixon_(California)',
#  'Passaic',
#  'Perryton',
#  'Rwenzori_Mountains_National_Park',
#  'Celebration',
#  'East_Palo_Alto',
#  'Sosua',
#  'Ssese_Islands',
#  'Oxbow',
#  'Papallacta',
#  'Isle_of_Jura',
#  'Chantilly_(Virginia)',
#  'East_Khasi_Hills',
#  'Dadra_and_Nagar_Haveli',
#  'West_Greenwich',
#  'Lavenham',
#  'Nishitokyo',
#  'Valdez',
#  'Sitka',
#  'Jotunheimen',
#  'Quincy_(Illinois)',
#  'Devonport_(New_Zealand)',
#  'Bingzhongluo',
#  'Taipei/Datong',
#  'Kisa_to_Boxholm_following_the_Malexandermorden_trail_by_car',
#  'Tokyo/Akihabara',
#  'Rocky_Mountains',
#  'Manchu_phrasebook',
#  'Aakirkeby',
#  'Valle_de_Cocora',
#  'Bocholt',
#  'Pleasanton',
#  'Philadelphia/Old_City',
#  'Empuriabrava',
#  'Brest',
#  'Ketron_Island',
#  'Balneario_Camboriu',
#  'Tuolumne_County',
#  'Sand_Hills',
#  'La_Grange',
#  'Diving_the_Mokohinau_Islands',
#  'Riverview',
#  'Hopkins_(Minnesota)',
#  'Nrbo',
#  'Samoeng_Loop',
#  'Canton_(Michigan)',
#  'Jodhpur_Division',
#  'Misquamicut',
#  'Kaili',
#  'Tokyo/Chiyoda',
#  'Cheorwon',
#  'Medford_(Oregon)',
#  'Ialysos',
#  'Bruny_Island',
#  'Hanseatic_League',
#  'Mourne_Mountains',
#  'Waterford_(Michigan)',
#  'Spittal_an_der_Drau',
#  'Gardena',
#  'Great_Basin_National_Park',
#  'Beirut/Ain_El_Mraiseh',
#  'Inverigo',
#  'Lakes_and_Gardens',
#  'Spennymoor',
#  'Central_Mozambique',
#  'Triglav_National_Park',
#  'Northern_Ohio_River_Region',
#  'Ko_Samet',
#  'Cacapava',
#  'Holbk',
#  'Kabale',
#  'Kent_Island',
#  'Semmering',
#  'Ipswich',
#  'Douglas_County',
#  'Mundau',
#  'Lleida',
#  'Majuli',
#  'Kasauli',
#  'Kherson',
#  'Faliraki',
#  'Lynchburg_(Tennessee)',
#  'Eagle_River',
#  'Ahmedabad',
#  'Trechtingshausen',
#  'Golan_Trail',
#  'Jiuzhaigou_Nature_Reserve',
#  'Inner_Hebrides',
#  'Kelmend',
#  'Enniskillen',
#  'Northeast_(Brazil)',
#  'Skelleftea',
#  'Ulyanovsk_Oblast',
#  'Serra_dos_Orgaos_National_Park',
#  'Bluegrass_Region',
#  'St._Louis_Park',
#  'Travnik',
#  'North_West_Coastal_Highway',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Bantry_Bay',
#  'Tak',
#  'Red_Carpet_Country',
#  'Silvia',
#  'Kemmerer',
#  'Oboke_and_Koboke',
#  'Grand_Teton_National_Park',
#  'Kalinga',
#  'Barra_do_Turvo',
#  'Alpena_(Arkansas)',
#  'Duval_County',
#  'Kuala_Gandah',
#  'Marina_di_Ragusa',
#  'Dorking',
#  'Pembroke_(Wales)',
#  'Saint-Paul_de_Vence',
#  'Eastern_Newfoundland',
#  'Wallingford_(England)',
#  'Zambales',
#  'Bol',
#  'Port_Orford',
#  'Peterborough_(New_Hampshire)',
#  'Jardin',
#  'Copenhagen/Indre_By',
#  'Thornton',
#  'Khakassia',
#  'Parque_Nacional_La_Guira',
#  'Clitheroe',
#  'Sedibeng',
#  'Sultan_Bathery',
#  'Vienne_(city)',
#  'Southwestern_Indiana',
#  'Mardana',
#  'Davidson',
#  'Bang_Saen',
#  'Kanangra_Boyd_National_Park',
#  'Watsonville',
#  'San_Martin_de_los_Llanos',
#  'Monroe_(North_Carolina)',
#  'Esino_Lario',
#  'Pinsk',
#  'Bull_Shoals',
#  'Los_Patos',
#  'Hawera',
#  'Ko_Maphrao',
#  'Artyom',
#  'Cassadaga_(Florida)',
#  'Prineville',
#  'Devala',
#  'Helmstedt',
#  'Cameron_(Louisiana)',
#  'Hershey',
#  'Etawah',
#  'Muang_Ngeun',
#  'Mexicali',
#  'Port_Richey',
#  'Hechi',
#  'Aran_Islands',
#  'Hecho',
#  'Shiga',
#  'Tatra_Mountains_(Poland)',
#  'Waterberg_Meander',
#  'Bukit_Barisan_Selatan_National_Park',
#  'Beichuan',
#  'Milford_Track',
#  'Juanjui',
#  'Joliet',
#  'Lamesa',
#  'Skellig_Michael',
#  'Samsun',
#  'Esmeraldas',
#  'Capena',
#  'Southeast_Wisconsin',
#  'Kanye',
#  'Tavarnelle_Val_di_Pesa',
#  'Seychellois_Creole_phrasebook',
#  'Leeward_Coast_(Oahu)',
#  'Zhengzhou',
#  'Lhuentse',
#  'Manitoulin_Island',
#  'Peterborough',
#  'Bowie',
#  'Chuncheon',
#  'Northwestern_Karnataka',
#  'Cromwell',
#  'Rocky_Mountains_(Canada)',
#  'Berlin_(El_Salvador)',
#  'Cypress',
#  'Escanaba',
#  'Alvdalen',
#  'Assisi',
#  'Nantwich',
#  'Kemi',
#  'Saint_Martin',
#  'Webster',
#  'Harrison_(Ohio)',
#  'Miami_Gardens',
#  'Istanbul/Sultanahmet-Old_City',
#  'Marysville_(Ohio)',
#  'Lesotho',
#  'Funafuti',
#  'Morenci',
#  'Sterling_(Utah)',
#  'Fanwood',
#  'Northern_Cameroon',
#  'Killorglin',
#  'Taplejung',
#  'Jiangsu',
#  'Newburgh_(New_York)',
#  'Michigan',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Castle_Rocks',
#  'Lefkara',
#  'Colca_Canyon',
#  'Southwest_(Rio_Grande_do_Sul)',
#  'Bedford_(Indiana)',
#  'Clearlake',
#  'Van_Nuys',
#  'San_Luis_de_Pambil',
#  'Deep_South',
#  'Sylheti_phrasebook',
#  'Portarlington',
#  'Hermitage',
#  'Murdeshwara',
#  'Veitshochheim',
#  'Kanipakam',
#  'Norwalk',
#  'Bratsk',
#  'Silverdale_(Washington)',
#  'Pixley',
#  'Marijampole',
#  'Des_Moines',
#  'Paris_Charles_de_Gaulle_Airport',
#  'Toronto/West_End',
#  'White_Mountain_National_Forest',
#  'Kulpsville',
#  'Hammerfest',
#  'Chittur',
#  'Kolkata/Dum_Dum',
#  'Bellingham_(Massachusetts)',
#  'The_Rosses',
#  'Kota_Division',
#  'Vulcano',
#  'Byron_(Maine)',
#  'San_Diego/Mission_Beach-Pacific_Beach',
#  'Swanzey',
#  'Zonguldak',
#  'Port_of_Spain',
#  'Bonners_Ferry',
#  'Field',
#  'Cangzhou',
#  'Tam_Dao',
#  'Newton-le-Willows',
#  'Grand_Lake',
#  'Ankola',
#  'North_Attleborough',
#  'Fairfield_County_(Ohio)',
#  'Tegernsee',
#  'Mesquite_(Texas)',
#  'Sycamore',
#  'Pemberton_(Western_Australia)',
#  'Alleghenies_and_Susquehanna_Valley',
#  'Point_Reyes_National_Seashore',
#  'Manchester_Airport',
#  'Annur',
#  'Minca',
#  'Cheb',
#  'Kota_Kinabalu',
#  'Capurgana',
#  'Vire',
#  'Franeker',
#  'Geelong',
#  'Tohoku',
#  'Ethiopia',
#  'Ski',
#  'Budoni',
#  'Elmina',
#  'Llanrwst',
#  'Cooperstown_(North_Dakota)',
#  'Erechim',
#  'Eastern_Inner_Mongolia',
#  'Adilabad',
#  'Lewistown',
#  'Rottweil',
#  'Cartwright_(North_Dakota)',
#  'Montejaque',
#  'Swieradow-Zdroj',
#  'Wakhan_Corridor',
#  'Otago',
#  'Tupana',
#  'Olean',
#  'Mid-Atlantic',
#  'Munster_(Indiana)',
#  'Rehoboth',
#  'Connemara',
#  'Ostrava',
#  'Galena_(Kansas)',
#  'Poipet',
#  'Nordland',
#  'Gumusluk',
#  'Pawtucket',
#  "Incisa_Val_d'Arno",
#  'Santana',
#  'Samedan',
#  'Hobart_(Indiana)',
#  'Richmond/East_End',
#  'Surin_(Southern_Thailand)',
#  'Castel_Goffredo',
#  'Ek_Balam',
#  'Willamette_Valley',
#  'Hyder',
#  'Batu_Karas',
#  'Western_Netherlands',
#  'Fairlee_(Vermont)',
#  'Colonia_Suiza_(Argentina)',
#  'Mexico_City/Santa_Fe',
#  'Kingston-on-Murray',
#  'Labhpur',
#  'Pucallpa',
#  'Chambers_Pillar_Historical_Reserve',
#  'Coastal_Plain_(Gabon)',
#  'Hyden',
#  'Mae_Sariang',
#  'Awa',
#  'Niagara-on-the-Lake',
#  'Sabang_(Indonesia)',
#  'Thompson_Springs',
#  'Nueva_Viscaya',
#  'Lithia_Springs',
#  'Esperanto_phrasebook',
#  'Sasak_phrasebook',
#  'Tiberias',
#  'Guernsey_Island',
#  'New_Canaan_(Connecticut)',
#  'Konya',
#  'Mato_Grosso',
#  'Skien',
#  'Miami/Coconut_Grove',
#  'Fairbanks',
#  'Westfjords',
#  'Northern_Haiti',
#  'Gansu',
#  'Birr',
#  'Murray_(Kentucky)',
#  'Maquine',
#  'Toms_River',
#  'Longview_(Alberta)',
#  'Ciudad_del_Este',
#  'Asheville',
#  'Cabo_San_Lucas',
#  'Wisbech',
#  'Caspian_Iran',
#  'Englishtown',
#  'Cleethorpes',
#  'Aptos',
#  'Olinda',
#  'East_Bali',
#  'Davenport_(Oklahoma)',
#  'Cesenatico',
#  'Chicago/Far_Northwest_Side',
#  'Northern_Rift_Valley',
#  'High-speed_rail_in_China',
#  'Coquitlam',
#  'Riau_Islands',
#  'Sydney/Darling_Harbour',
#  'Fairfield_(Connecticut)',
#  'Nagoya',
#  'Jammu_and_Kashmir',
#  'Baldwin_Park',
#  'Bosaso',
#  'Central_Myanmar',
#  'Midnapore',
#  'Tumwater',
#  'Sidney_(Ohio)',
#  'Taichung',
#  'Redang',
#  'Kushal_Nagar',
#  'Hitchhiking_phrasebook',
#  'Para_(Brazil)',
#  'Florenceville-Bristol',
#  'Pori',
#  'Fish_Creek',
#  'Fairport',
#  'Bonito_(Mato_Grosso_do_Sul)',
#  'Yingge',
#  'Lewisporte',
#  'Deer_Lake',
#  'Bangkok/Dusit',
#  'Gorongosa',
#  'Wachau',
#  'Glass_House_Mountains_National_Park',
#  'Bunratty',
#  'Concerns',
#  'La_Rioja_(city,_Argentina)',
#  'Peneda-Geres_National_Park',
#  'Puttaparthi',
#  'Yuma',
#  'Choum',
#  'Boylston',
#  'Biliran',
#  'Middletown_(Ohio)',
#  'Old_96_District',
#  'Literary_travel',
#  'Ambergris_Caye',
#  'Ada_(Ghana)',
#  'West_Wyalong',
#  'Takasaki',
#  'Santa_Cruz_Trek',
#  'Norfolk_(Nebraska)',
#  'Gotska_Sandon',
#  'Indiana_Dunes_National_Lakeshore',
#  'Diving_the_Cape_Peninsula_and_False_Bay/SS_Cape_Matapan',
#  'Corcovado_National_Park',
#  'Cupramontana',
#  'Ocean_Shores',
#  'San_Diego/Downtown',
#  'Hachimantai',
#  'Huntly',
#  'White_Bear_Lake',
#  'Amana_Colonies',
#  'Andean_Highlands_(Ecuador)',
#  'Murter',
#  'Virgin_Islands',
#  'Buldhana',
#  'Coimbatore',
#  'Ben_Lomond_National_Park',
#  'Dalsland',
#  'Caherciveen',
#  'Bacolod',
#  'Rashaya',
#  'Tokyo_Disney_Resort',
#  'Doylestown_(Ohio)',
#  'Grafenwohr',
#  'Honolulu/Waikiki',
#  'Neos_Marmaras',
#  'Barker_(New_York)',
#  'Warren_County_(New_Jersey)',
#  'New_Glasgow',
#  'Awash_National_Park',
#  'Gaud',
#  'Estremoz',
#  'Holywell',
#  'Goorambat',
#  'San_Luis_(Arizona)',
#  'Antofagasta',
#  'Church_Bay_(Anglesey)',
#  'Yangmingshan_National_Park',
#  'Aberfeldy',
#  'Bass_Coast',
#  'Grafton_(Wisconsin)',
#  'Red_Lodge_(Montana)',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Rocky_Bay',
#  'Durban',
#  'Isla_de_la_Luna',
#  'Peninsula',
#  'Kunming',
#  'Alba_Iulia',
#  'Snyder_(Texas)',
#  'Serra_da_Mantiqueira',
#  "D'Iberville",
#  'Ilha_do_Marajo',
#  'Taft',
#  'Barreal',
#  'Southgate',
#  'Mount_Lemmon',
#  'Saxon_Elbland',
#  'Pennsburg',
#  'Amphawa',
#  'Guanaja',
#  'Algarrobo_(Chile)',
#  'Hackberry',
#  'Guinee_Maritime',
#  'Hann._Munden',
#  'Shizuishan',
#  'Santiago_de_Chile/Barrio_Brasil',
#  'Southwestern_Georgia',
#  'Plettenberg_Bay',
#  'Damnoen_Saduak',
#  'Burnley',
#  'Diving_in_Thailand/Richelieu_Rock',
#  'Hundested',
#  'Mumbai/Harbour_suburbs',
#  'Nazareth_(Pennsylvania)',
#  'Balbriggan',
#  'Sun_City',
#  'Elista',
#  'Geeveston',
#  'Urfa',
#  'Biak',
#  'Thalmassing',
#  'Foulness_Island',
#  'Moorhead',
#  'Seattle/West',
#  'Oviedo_(Florida)',
#  'Alampur',
#  'Alausi',
#  'Achziv',
#  'Purnululu_National_Park',
#  'Chitimba',
#  'Olympic_National_Park',
#  'Waterbury',
#  'Anaheim_Hills',
#  'Mount_Ishizuchi',
#  'Shelby_(Ohio)',
#  'Southern_Namibia',
#  'Hacketstown',
#  'Samut_Songkhram',
#  'Blumenau',
#  'Shanghai/Huangpu',
#  'Fall_River_(Massachusetts)',
#  'Bamako',
#  'Northern_Quebec',
#  'Grindelwald',
#  'Ranikhet',
#  'Arnprior',
#  'Struga',
#  'Bhojpur',
#  'Rogiet',
#  'Khmelnytskyi',
#  'Nanjangud',
#  'Wallachian_Plain',
#  'Quezon_(Palawan)',
#  'Punta_Gorda_(Florida)',
#  'Elgin_County',
#  'Huntley',
#  'Perissa',
#  'Digby',
#  'Dullatur',
#  'Spencer',
#  'Visby',
#  'Gondik',
#  'Megaplatanos',
#  'Perak',
#  'Aruja',
#  'Eaton_Rapids',
#  'Dubai/Jebel_Ali',
#  'Nioumachoua',
#  'Margoon_Waterfall',
#  'Kuwait',
#  'Richmond',
#  'North_Adams',
#  'Sydney_Airport',
#  'Cotati',
#  'Uhldingen-Muhlhofen',
#  'East_Palestine',
#  'Kokoda_Track',
#  'Bijelo_Polje',
#  'Vinh',
#  'Hamilton_(Ontario)',
#  'Fairview_(Utah)',
#  'Subic',
#  'Willows',
#  'Raja',
#  'Niari_Valley',
#  'Segou',
#  'Northern_Punjab',
#  'Glasgow',
#  'Namangan',
#  'Kirzhach',
#  'Inveraray',
#  'Ibajay',
#  'Staniel_Cay',
#  'Yagodnoye',
#  'Medfield',
#  'National_Park_of_American_Samoa',
#  'Londrina',
#  'Woonsocket',
#  'Garden_Grove',
#  'River_Edge',
#  'Frigiliana',
#  'Bridgetown',
#  'Costa_Smeralda',
#  'Hammaslahti',
#  'Amelinghausen',
#  'Cuyo',
#  'Ridgewood',
#  'Afton',
#  'SeaWorld',
#  'Belize_District',
#  'Oppdal',
#  'Aba_(prefecture)',
#  'Deokjeok_Island',
#  'Bandarban_Town',
#  'Brussels',
#  'Big_Bend_(California)',
#  'Nome_(Alaska)',
#  'Ipswich_(Massachusetts)',
#  'Momence',
#  'Luxor/East_Bank',
#  'Lyndon_B._Johnson_National_Historical_Park',
#  'Narrandera',
#  'Tamar_Valley',
#  'Gili_Air',
#  'Sikeston',
#  'Caucaia',
#  'Central_Ostrobothnia',
#  'St._Clair_County_(Michigan)',
#  'Sathing_Phra',
#  'Central_Java',
#  'West_Java',
#  'Harrisburg_(North_Carolina)',
#  'Benton_(Pennsylvania)',
#  'Diyarbakir',
#  'Diving_the_Poor_Knights_Islands',
#  'Rasht',
#  'Mithur',
#  'Krugersdorp',
#  'Diving_in_Mozambique/Island_Rock',
#  'Soltau',
#  'Kailua-Kona',
#  'Norfolk_(England)',
#  'Tamana',
#  'Tokaj-Hegyalja',
#  'Fire_Island_National_Seashore',
#  'Estes_Park',
#  'Buena_Vista_(Colorado)',
#  'Grand_Beach_Provincial_Park',
#  'Vikasnagar',
#  'Loup_Valley',
#  'Taunton_(England)',
#  'Luquillo',
#  'Litchfield_Hills',
#  'Nardo',
#  'Lubuskie',
#  'Haukeli',
#  'Juan_de_Nova_Island',
#  'Union_Pier',
#  'Hay-on-Wye',
#  'Dalat',
#  'Wakefield_(Quebec)',
#  'Gualala',
#  'El_Mina',
#  'Gelderland',
#  'St_Lucia_(KwaZulu-Natal)',
#  'Knysna',
#  'Dudinka',
#  'San_Marino',
#  'Rolette',
#  'Carrick-on-Shannon',
#  'Bominaco',
#  "Martha's_Vineyard",
#  'Boone_(Iowa)',
#  'Buga',
#  'Kumasi',
#  'Talampaya_National_Park',
#  'Hyvinkaa',
#  'Redcliffe',
#  'Warth_and_Schrocken',
#  'Willow_Creek',
#  'Portage_(Wisconsin)',
#  'Aruana',
#  'Triangle',
#  'Rijeka',
#  'Rossland',
#  'Saint_Petersburg',
#  'Niedzica',
#  'Goldsboro_(North_Carolina)',
#  'Othello',
#  'Shamali_Plain',
#  'Rau_de_Mori',
#  'Wheeler_Ridge',
#  'Sweetwater',
#  'Zelienople',
#  'Yarkand',
#  'Pokolbin',
#  'Hoquiam',
#  'Hay',
#  'Diving_the_Cape_Peninsula_and_False_Bay/Kruis',
#  'Mazara_del_Vallo',
#  'Scarborough_(Maine)',
#  'Nord-Pas_de_Calais',
#  'Hailuoto',
#  'Lewes_(Delaware)',
#  'Kimberley_(Northern_Cape)',
#  'Lipetsk_Oblast',
#  'Sepidan',
#  'Labuan',
#  'Aroostook',
#  'Kluang',
#  'Gdynia',
#  'Hilversum',
#  'Trentino-Alto_Adige',
#  'Sevan',
#  'Los_Cristianos',
#  'Lebanon_(Illinois)',
#  'Malvern_(England)',
#  'Arvada',
#  'Pamukkale',
#  'Southern_Highlands_(Tanzania)',
#  ...]

# %%
final_articles['Cacapava']
# Out:
# u"{{pagebanner|S-amer africa default banner.jpg}}\n'''Ca\xe7apava''' is in a city in the [[North Coast (S\xe3o Paulo)|North Coast]] region of [[S\xe3o Paulo (state)|S\xe3o Paulo]].\n\n==Understand==\n\n==Get in==\n\n==Get around==\n\n==See==\n\n==Do==\n\n==Buy==\n\n==Eat==\n\n==Drink==\n\n==Sleep==\n\n==Connect==\n\n==Go next==\n\n{{routebox-1\n| image1=BR-116.png\n| imagesize1=22\n| directionl1=S\n| majorl1=[[S\xe3o Paulo]]\n| minorl1='''[[S\xe3o Jos\xe9 dos Campos]]'''\n| directionr1=N\n| majorr1=[[Resende]]\n| minorr1=[[Taubat\xe9]]\n}}\n{{IsPartOf|North Coast (S\xe3o Paulo)}}\n{{outlinecity}}\n{{geo|-23.100833|-45.706944}}\n[[wikipedia:Ca\xe7apava]]"

# %%
final_articles_words = {}

for key, value in final_articles.iteritems():
# for key, value in final_articles.iteritems():
#     final_articles_words[key] = convert_article_into_list_of_words(value)
    #print article
    final_articles_words[key] = convert_article_into_list_of_words(value)

# %%
final_articles_words['DeKalb']
# Out:
# [['dekalb', 'county', 'forest', 'preserves'],
#  ['river', 'heights', 'golf', 'course'],
#  ['buena', 'vista', 'golf', 'course'],
#  ['prairie', 'pines', 'golf', 'club'],
#  ['annual',
#   'dekalb',
#   'kite',
#   'fest',
#   'mid',
#   'september',
#   'at',
#   'northern',
#   'illinois',
#   'university',
#   'september',
#   'th',
#   'from',
#   'pm'],
#  ['this',
#   'festival',
#   'features',
#   'many',
#   'kites',
#   'that',
#   'are',
#   'over',
#   'ft'],
#  ['in',
#   'length',
#   'and',
#   'boasts',
#   'kites',
#   'that',
#   'are',
#   'actually',
#   'five',
#   'stories',
#   'high'],
#  ['enjoy',
#   'dancing',
#   'kites',
#   'stunt',
#   'kites',
#   'fighting',
#   'kites',
#   'and',
#   'other',
#   'specialty',
#   'kites',
#   'that',
#   'change',
#   'on',
#   'an',
#   'annual',
#   'basis'],
#  ['there',
#   'are',
#   'games',
#   'family',
#   'entertainment',
#   'food',
#   'and',
#   'wide',
#   'open',
#   'spaces'],
#  ['festival',
#   'features',
#   'a',
#   'candy',
#   'drop',
#   'and',
#   'kite',
#   'making',
#   'for',
#   'kids'],
#  ['imagedixon', 'illinois', 'dixon', 'minorlglen', 'ellyn}}'],
#  ['wikipedia',
#   'dekalb',
#   'illinoisdmoz',
#   'regional/north_america/united_states/illinois/localities/d/dekalb/commons',
#   'kishwaukee',
#   'river',
#   'flood']]

# %%
final_articles_list_of_words = []
final_articles_doc2vec_labels = []
final_articles_doc2vec_labels_upper = []
for key, value in final_articles_words.iteritems():
    for sentence in value:
        final_articles_doc2vec_labels.append(key.lower())
        final_articles_doc2vec_labels_upper.append(key.upper())
        final_articles_list_of_words.append([word.lower() for word in sentence])

# %%
final_articles_list_of_words[2]
# Out:
# ['it',
#  'lies',
#  'in',
#  'the',
#  'northwestern',
#  'corner',
#  'of',
#  'poland',
#  'very',
#  'close',
#  'to',
#  'the',
#  'german',
#  'border',
#  'and',
#  'it',
#  'is',
#  'in',
#  'fact',
#  'easier',
#  'to',
#  'get',
#  'to',
#  'szczecin',
#  'from',
#  'some',
#  'parts',
#  'of',
#  'germany',
#  'notable',
#  'from',
#  'berlin',
#  'than',
#  'it',
#  'is',
#  'from',
#  'much',
#  'of',
#  'the',
#  'polish',
#  'territory']

# %%
with open ('../data/wikivoyage_list_of_words.pkl','wb') as f:
    cPickle.dump(final_articles_list_of_words, f)
